# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from unidecode import unidecode
import re
import unicodedata

# %%
def fill_district(truocsapnhap):
    parts = truocsapnhap.split(', ')
    current_district = None
    filled = []

    # Loop từ phải qua trái
    for part in reversed(parts):
        # Tìm district trong ngoặc
        m = re.search(r'\((.*?)\)', part)
        if m:
            current_district = m.group(1)
        # Nếu chưa có district thì bỏ qua
        if current_district:
            # Bỏ ngoặc cũ nếu có
            part = re.sub(r'\(.*?\)', '', part).strip()
            part = f"{part} ({current_district})"
        filled.append(part)

    # Đảo lại đúng thứ tự ban đầu
    filled = list(reversed(filled))
    return ', '.join(filled)

def extract_district(truocsapnhap):
    unit = truocsapnhap.split(' (')
    district = np.nan
    if len(unit) > 1:
        district = unit[1][:-1]
        if ' - Tỉnh ' in district:
            district = district.split(' - Tỉnh ')[0]
    return district

def extract_province(truocsapnhap):
    unit = truocsapnhap.split(' (')
    province = np.nan
    if len(unit) > 1:
        district = unit[1][:-1]
        if ' - Tỉnh ' in district:
            province = district.split(' - ')[1]
    return province

def extract_ward(truocsapnhap):
    unit = truocsapnhap.split(' (')
    ward = unit[0]
    return ward

def cap_first(text):
    if isinstance(text, str):
        split_text = text.split()
        split_text = [i[0].capitalize() + i[1:] if split_text.index(i)==0 else i for i in split_text]
        return ' '.join(split_text)
    return np.nan

def title_safely(text):
    if isinstance(text, str):
        split_text = text.split()
        split_text = [i[0].capitalize() + i[1:] for i in split_text]
        text = ' '.join(split_text)
        split_text = text.split("'")
        split_text = [i[0].capitalize() + i[1:] for i in split_text]
        return "'".join(split_text)
    return np.nan

def lower_safely(text):
    if isinstance(text, str):
        return text.lower()
    return np.nan

def normalize_quotes(text):
    if isinstance(text, str):
        return text.replace("’", "'").replace("‘", "'").replace("“", '"').replace("”", '"')
    return np.nan

def unidecode_pro(text):
    if isinstance(text, str):
        text = unidecode(text)
        text = re.sub(r'[^a-zA-Z0-9]+', ' ', text)  # chỉ giữ a-z, A-Z, 0-9, thay phần còn lại bằng khoảng trắng
        text = re.sub(r'\s+', ' ', text)
        return text.strip().lower()
    return np.nan

def unicode_normalize(text):
    '''
    Chuyển Unicode tổ hợp sang Unicode dựng sẵn
    :param text:
    :return:
    '''
    if isinstance(text, str):
        text = unicodedata.normalize('NFC', text)
        text = normalize_quotes(text).strip()
        return text
    return np.nan

# %%
title_safely('ha nOi')
# Out:
# 'Ha NOi'

# %%
title_safely("Thị Trấn Ea T'ling")
# Out:
# "Thị Trấn Ea T'Ling"

# %%
unicode_normalize("Cư K’nia")
# Out:
# "Cư K'nia"

# %% [markdown]
# # Chuẩn bị danh mục

# %%
df_danhmuc_district = pd.read_csv('data/danhmuchanhchinh.gso.gov.vn_district_2025-07-18.csv')

# %%
df_danhmuc_ward = pd.read_csv('data/danhmuchanhchinh.gso.gov.vn_2025-07-18.csv')

# %%
rename_cols = {
    'Mã': 'wardCode',
    'Mã QH': 'districtCode',
    'Mã TP': 'provinceCode',
    'Cấp': 'wardType',
    'Tên': 'ward',
    'Quận Huyện': 'district',
    'Tỉnh / Thành Phố': 'province'
}
df_danhmuc_ward = df_danhmuc_ward.rename(columns=rename_cols)[rename_cols.values()]

# %%
rename_cols = {
    'Mã': 'districtCode',
    'Mã TP': 'provinceCode',
    'Cấp': 'districtType',
    'Tên': 'district',
    'Tỉnh / Thành Phố': 'province'
}

df_danhmuc_district = df_danhmuc_district.rename(columns=rename_cols)[rename_cols.values()]

# %%
df_danhmuc_ward.shape
# Out:
# (10035, 7)

# %%
df_danhmuc_district.shape
# Out:
# (696, 5)

# %%
common = list(set(df_danhmuc_ward.columns.tolist()) & set(df_danhmuc_district.columns.tolist()))
df_danhmuc = pd.merge(df_danhmuc_district, df_danhmuc_ward, on=common, how='left')

# %%
df_danhmuc
# Out:
#        districtCode  provinceCode districtType         district  \
# 0                 1             1         Quận     Quận Ba Đình
# 1                 1             1         Quận     Quận Ba Đình
# 2                 1             1         Quận     Quận Ba Đình
# 3                 1             1         Quận     Quận Ba Đình
# 4                 1             1         Quận     Quận Ba Đình
# ...             ...           ...          ...              ...
# 10035           973            96        Huyện  Huyện Ngọc Hiển
# 10036           973            96        Huyện  Huyện Ngọc Hiển
# 10037           973            96        Huyện  Huyện Ngọc Hiển
# 10038           973            96        Huyện  Huyện Ngọc Hiển
# 10039           973            96        Huyện  Huyện Ngọc Hiển
#
#                province  wardCode  wardType               ward
# 0      Thành phố Hà Nội       1.0    Phường     Phường Phúc Xá
# 1      Thành phố Hà Nội       4.0    Phường   Phường Trúc Bạch
# 2      Thành phố Hà Nội       6.0    Phường   Phường Vĩnh Phúc
# 3      Thành phố Hà Nội       7.0    Phường     Phường Cống Vị
# 4      Thành phố Hà Nội       8.0    Phường   Phường Liễu Giai
# ...                 ...       ...       ...                ...
# 10035       Tỉnh Cà Mau   32239.0        Xã    Xã Viên An Đông
# 10036       Tỉnh Cà Mau   32242.0        Xã         Xã Viên An
# 10037       Tỉnh Cà Mau   32244.0  Thị trấn  Thị trấn Rạch Gốc
# 10038       Tỉnh Cà Mau   32245.0        Xã          Xã Tân Ân
# 10039       Tỉnh Cà Mau   32248.0        Xã         Xã Đất Mũi
#
# [10040 rows x 8 columns]

# %%
df_danhmuc[df_danhmuc['ward'].isna()]
# Out:
#       districtCode  provinceCode districtType            district  \
# 3582           318            31        Huyện  Huyện Bạch Long Vĩ
# 5794           471            45        Huyện        Huyện Cồn Cỏ
# 5975           498            48        Huyện      Huyện Hoàng Sa
# 6379           536            51        Huyện        Huyện Lý Sơn
# 8196           755            77        Huyện       Huyện Côn Đảo
#
#                     province  wardCode wardType ward
# 3582     Thành phố Hải Phòng       NaN      NaN  NaN
# 5794          Tỉnh Quảng Trị       NaN      NaN  NaN
# 5975       Thành phố Đà Nẵng       NaN      NaN  NaN
# 6379         Tỉnh Quảng Ngãi       NaN      NaN  NaN
# 8196  Tỉnh Bà Rịa - Vũng Tàu       NaN      NaN  NaN

# %% [markdown]
# 5 cái đảo không có ward nên file ward không có.

# %% [markdown]
# # Sáp nhập province

# %%
df_sapnhap_province = pd.read_csv('data/sapnhap.bando.com.vn_province.csv')

# %%
df_sapnhap_province['isMergedProvince'] = np.where(df_sapnhap_province['truocsapnhap']=='không sáp nhập', False, True)

# %%
df_sapnhap_province['truocsapnhap'] = df_sapnhap_province['truocsapnhap'].str.replace(' và ', ', ')
df_sapnhap_province['truocsapnhap'] = df_sapnhap_province['truocsapnhap'].str.split(',\s*')
df_sapnhap_province = df_sapnhap_province.explode('truocsapnhap').reset_index(drop=True)

# %%
df_sapnhap_province['truocsapnhap'] = np.where(df_sapnhap_province['isMergedProvince']==True, df_sapnhap_province['truocsapnhap'], df_sapnhap_province['tentinh'])

# %%
df_sapnhap_province['truocsapnhap'] = df_sapnhap_province['truocsapnhap'].apply(cap_first)
df_sapnhap_province['tentinh'] = df_sapnhap_province['tentinh'].apply(cap_first)

# %%
df_sapnhap_province[~df_sapnhap_province['truocsapnhap'].isin(df_danhmuc['province'])]
# Out:
#     id  mahc                tentinh dientichkm2  dansonguoi    trungtamhc  \
# 0    1     1          Thủ đô Hà Nội    3.359,80   8.718.000    giữ nguyên
# 14  11    12           Tỉnh Phú Thọ    9.361,38   4.022.638  Phú Thọ (cũ)
# 48  29    29  Thành phố Hồ Chí Minh    6.772,59  14.002.598  Tp. HCM (cũ)
#
#      kinhdo     vido   truocsapnhap  \
# 0   105.698  21.0001  Thủ đô Hà Nội
# 14  105.333  20.7065  Tỉnh Hòa Bình
# 48  106.638  10.9926          TPHCM
#
#                                             con  isMergedProvince
# 0                126 ĐVHC (51 phường và 75 xã)             False
# 14                 148 ĐVHC (15 phường, 133 xã)              True
# 48  168 ĐVHC (01 đặc khu, 113 phường, 54 xã)              True

# %%
df_sapnhap_province.loc[df_sapnhap_province['truocsapnhap']=='Thủ đô Hà Nội', 'truocsapnhap'] = 'Thành phố Hà Nội'
df_sapnhap_province.loc[df_sapnhap_province['truocsapnhap']=='TPHCM', 'truocsapnhap'] = 'Thành phố Hồ Chí Minh'
df_sapnhap_province.loc[df_sapnhap_province['truocsapnhap']=='Tỉnh Hòa Bình', 'truocsapnhap'] = 'Tỉnh Hoà Bình'

# %%
rename_cols = {
    'truocsapnhap': 'province',
    'mahc': 'newProvinceCode',
    'tentinh': 'newProvince',
    'isMergedProvince': 'isMergedProvince',
}
df_sapnhap_province = df_sapnhap_province.rename(columns=rename_cols)[rename_cols.values()]

# %%
df_sapnhap_province
# Out:
#              province  newProvinceCode        newProvince  isMergedProvince
# 0    Thành phố Hà Nội                1      Thủ đô Hà Nội             False
# 1       Tỉnh Cao Bằng                7      Tỉnh Cao Bằng             False
# 2       Tỉnh Hà Giang                8   Tỉnh Tuyên Quang              True
# 3    Tỉnh Tuyên Quang                8   Tỉnh Tuyên Quang              True
# 4        Tỉnh Yên Bái                9       Tỉnh Lào Cai              True
# ..                ...              ...                ...               ...
# 58  Thành phố Cần Thơ               33  Thành phố Cần Thơ              True
# 59     Tỉnh Sóc Trăng               33  Thành phố Cần Thơ              True
# 60     Tỉnh Hậu Giang               33  Thành phố Cần Thơ              True
# 61      Tỉnh Bạc Liêu               34        Tỉnh Cà Mau              True
# 62        Tỉnh Cà Mau               34        Tỉnh Cà Mau              True
#
# [63 rows x 4 columns]

# %%
df_danhmuc = pd.merge(df_danhmuc, df_sapnhap_province, on='province', how='left')

# %%
df_danhmuc[df_danhmuc['newProvince'].isna()]
# Out:
# Empty DataFrame
# Columns: [districtCode, provinceCode, districtType, district, province, wardCode, wardType, ward, newProvinceCode, newProvince, isMergedProvince]
# Index: []

# %%
if df_danhmuc['newProvince'].isna().sum():
    raise Exception('Còn sót province')

# %% [markdown]
# # Sáp nhập ward

# %% [markdown]
# ## Unpivot

# %%
df_sapnhap_ward = pd.read_csv('data/sapnhap.bando.com.vn_ward.csv')

# %%
# Preview text trong dấu ngoặc
df_sapnhap_ward[df_sapnhap_ward['truocsapnhap'].str.contains('\(')]['truocsapnhap']
# Out:
# 0       Xã Đông La, Phường Dương Nội (phần còn lại sau...
# 1       Phường Quán Thánh, Phường Trúc Bạch, Phường Cử...
# 2       Xã Ba Vì, Xã Khánh Thượng, Xã Minh Quang (phần...
# 3       Phường Bạch Mai, Phường Bách Khoa, Phường Quỳn...
# 5       Xã Kim Đức, Phường Cự Khối (phần còn lại sau k...
#                               ...
# 3288    Thị trấn U Minh, Xã Nguyễn Phích, Xã Khánh Thu...
# 3299    Thị trấn Sông Đốc (bao gồm cụm đảo Hòn Chuối),...
# 3305    Phường 5 (thành phố Cà Mau), Phường Tân Thành,...
# 3311    Thị trấn Trần Văn Thời, Xã Khánh Lộc, Xã Phong...
# 3320         Phường 5 (thành phố Bạc Liêu), Xã Vĩnh Trạch
# Name: truocsapnhap, Length: 612, dtype: object

# %%
# Remove và replace text
removed_texts = [
    ', Trường bắn TB1',
    ', Khu vực bãi bồi ven biển \(do huyện Kim Sơn quản lý\)',
    '\(phần còn lại.*\)',
    '\(bao gồm.*\)',
    '\(một phần.*\)',
    '\(do huyện.*\)',
]


replaced_texts = [
    (' và ', ', '),
    ('(thuộc huyện ', '(huyện '),
    ('(huyện Châu Thành, tỉnh Bến Tre)', '(Huyện Châu Thành - Tỉnh Bến Tre)'), # Tạm giữ lại để tính isDividedWard co đúng, Chú ý khi bỏ tỉnh rồi thì merge sẽ bị duplicate Thị trấn Châu Thành, Huyện Châu Thành
    ('(huyện Châu Thành, tỉnh Trà Vinh)', '(Huyện Châu Thành - Tỉnh Trà Vinh)') # Tạm giữ lại để tính isDividedWard co đúng, Chú ý khi bỏ tỉnh rồi thì merge sẽ bị duplicate Thị trấn Châu Thành, Huyện Châu
]

for text in removed_texts:
    df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].str.replace(text, '', regex=True).str.strip()

for old, new in replaced_texts:
    df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].str.replace(old, new, regex=False).str.strip()

# %%
# Thêm isMergedWard
df_sapnhap_ward['isMergedWard'] = np.where(df_sapnhap_ward['truocsapnhap']=='Không sáp nhập', False, True)

# %%
# Unpivot
df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].apply(fill_district)
df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].str.split(',\s*')
df_sapnhap_ward = df_sapnhap_ward.explode('truocsapnhap').reset_index(drop=True)

# %%
df_sapnhap_ward
# Out:
#          id  matinh    ma        tentinh    loai         tenhc        cay  \
# 0         2       1     2  Thủ đô Hà Nội      xã      An Khánh     1.0002
# 1         2       1     2  Thủ đô Hà Nội      xã      An Khánh     1.0002
# 2         3       1     3  Thủ đô Hà Nội  phường       Ba Đình     1.0003
# 3         3       1     3  Thủ đô Hà Nội  phường       Ba Đình     1.0003
# 4         3       1     3  Thủ đô Hà Nội  phường       Ba Đình     1.0003
# ...     ...     ...   ...            ...     ...           ...        ...
# 10426  3353      34  3353    tỉnh Cà Mau      xã  Vĩnh Phước  3291.3353
# 10427  3354      34  3354    tỉnh Cà Mau      xã   Vĩnh Thanh  3291.3354
# 10428  3354      34  3354    tỉnh Cà Mau      xã   Vĩnh Thanh  3291.3354
# 10429  3355      34  3355    tỉnh Cà Mau  phường  Vĩnh Trạch  3291.3355
# 10430  3355      34  3355    tỉnh Cà Mau  phường  Vĩnh Trạch  3291.3355
#
#        dientichkm2 dansonguoi                           trungtamhc   kinhdo  \
# 0            28.69     102136           Thôn Lũng Vân, xã An Khánh  105.708
# 1            28.69     102136           Thôn Lũng Vân, xã An Khánh  105.708
# 2             2.97      65023  Số 2, phố Trúc Bạch, phường Ba Đình  105.838
# 3             2.97      65023  Số 2, phố Trúc Bạch, phường Ba Đình  105.838
# 4             2.97      65023  Số 2, phố Trúc Bạch, phường Ba Đình  105.838
# ...            ...        ...                                  ...      ...
# 10426        75.50      20014                        đang cập nhật  105.410
# 10427        37.37      19291                        đang cập nhật  105.519
# 10428        37.37      19291                        đang cập nhật  105.519
# 10429        10.22      23085                        đang cập nhật  105.774
# 10430        10.22      23085                        đang cập nhật  105.774
#
#            vido                   truocsapnhap  maxa            khoa  \
# 0      20.98760                     Xã Đông La  1290       1An Khánh
# 1      20.98760               Phường Dương Nội  1290       1An Khánh
# 2      21.03860              Phường Quán Thánh   994        1Ba Đình
# 3      21.03860               Phường Trúc Bạch   994        1Ba Đình
# 4      21.03860                 Phường Cửa Nam   994        1Ba Đình
# ...         ...                            ...   ...             ...
# 10426   9.39891                Xã Vĩnh Phú Tây   160  34Vĩnh Phước
# 10427   9.35997                    Xã Hưng Phú   161   34Vĩnh Thanh
# 10428   9.35997                  Xã Vĩnh Thanh   161   34Vĩnh Thanh
# 10429   9.29729  Phường 5 (thành phố Bạc Liêu)   151  34Vĩnh Trạch
# 10430   9.29729                  Xã Vĩnh Trạch   151  34Vĩnh Trạch
#
#        isMergedWard
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 10426          True
# 10427          True
# 10428          True
# 10429          True
# 10430          True
#
# [10431 rows x 16 columns]

# %%
# Thêm isDividedWard vào df_sapnhap_ward
count_truocsapnhap = df_sapnhap_ward.groupby(['tentinh', 'truocsapnhap'])['truocsapnhap'].count().reset_index(name='count_truocsapnhap')
count_truocsapnhap['isDividedWard'] = np.where(count_truocsapnhap['count_truocsapnhap'] > 1, True, False)
df_sapnhap_ward = pd.merge(df_sapnhap_ward, count_truocsapnhap, on=['tentinh', 'truocsapnhap'], how='left')

# %%
# Viết hoa chữ đầu
df_sapnhap_ward['tentinh'] = df_sapnhap_ward['tentinh'].apply(cap_first)

# %%
# Lúc merge mới biết nên quay lại đây để sửa
df_sapnhap_ward['tentinh'].replace('Tỉnh Ninh BÌnh', 'Tỉnh Ninh Bình', inplace=True)

# %%
# Tách truocsapnhap thành: ward, district, province
df_sapnhap_ward['province'] = df_sapnhap_ward['truocsapnhap'].apply(extract_province)
df_sapnhap_ward['district'] = df_sapnhap_ward['truocsapnhap'].apply(extract_district)
df_sapnhap_ward['ward'] = df_sapnhap_ward['truocsapnhap'].apply(extract_ward)
# Fill ward cũ cho những ward không sáp nhập
df_sapnhap_ward['ward'] = np.where(df_sapnhap_ward['isMergedWard']==False, df_sapnhap_ward['loai'].str.capitalize() + ' ' + df_sapnhap_ward['tenhc'], df_sapnhap_ward['ward'])

# %%
df_sapnhap_ward[df_sapnhap_ward['ward'].str.contains('^Huyện')]
# Out:
#         id  matinh    ma                tentinh     loai         tenhc  \
# 1223  1050       4  1050    Thành phố Hải Phòng  đặc khu  Bạch Long Vĩ
# 5834  1764      19  1764         Tỉnh Quảng Trị  đặc khu        Cồn Cỏ
# 6289  1904      21  1904      Thành phố Đà Nẵng  đặc khu      Hoàng Sa
# 6608  2015      22  2015        Tỉnh Quảng Ngãi  đặc khu        Lý Sơn
# 8680  2741      29  2741  Thành phố Hồ Chí Minh  đặc khu       Côn Đảo
# 9804  3125      32  3125          Tỉnh An Giang  đặc khu      Kiên Hải
#
#             cay  dientichkm2 dansonguoi  \
# 1223  1034.1050         3.07        686
# 5834  1752.1764         2.30        139
# 6289  1872.1904       305.00       9741
# 6608  1967.2015        10.39      22000
# 8680  2687.2741        75.79       6502
# 9804  3084.3125        21.81      17644
#
#                                              trungtamhc  ...      vido  \
# 1223               Trụ sở huyện Bạch Long Vĩ hiện trạng  ...  20.13460
# 5834                         UBND huyện đảo Cồn Cỏ (cũ)  ...  17.15925
# 6289                     Đường Hoàng Sa, phường Sơn Trà  ...  16.56800
# 6608             Trung tâm hành chính huyện Lý Sơn (cũ)  ...  15.38500
# 8680  28 đường Tôn Đức Thắng, huyện Côn Đảo, tỉnh Bà...  ...   8.69810
# 9804          UBND huyện Kiên Hải (xã Hòn Tre hiện nay)  ...   9.80000
#
#             truocsapnhap  maxa           khoa isMergedWard  \
# 1223  Huyện Bạch Long Vĩ  3309  4Bạch Long Vĩ         True
# 5834        Huyện Cồn Cỏ  3310       19Cồn Cỏ         True
# 6289      Huyện Hoàng Sa  3312     21Hoàng Sa         True
# 6608        Huyện Lý Sơn  3314       22Lý Sơn         True
# 8680       Huyện Côn Đảo  3311      29Côn Đảo         True
# 9804      Huyện Kiên Hải  3315     32Kiên Hải         True
#
#       count_truocsapnhap  isDividedWard  province district                ward
# 1223                   1          False       NaN      NaN  Huyện Bạch Long Vĩ
# 5834                   1          False       NaN      NaN        Huyện Cồn Cỏ
# 6289                   1          False       NaN      NaN      Huyện Hoàng Sa
# 6608                   1          False       NaN      NaN        Huyện Lý Sơn
# 8680                   1          False       NaN      NaN       Huyện Côn Đảo
# 9804                   1          False       NaN      NaN      Huyện Kiên Hải
#
# [6 rows x 21 columns]

# %%
# Đem các huyện nằm ở ward qua district
df_sapnhap_ward['district'] = np.where(df_sapnhap_ward['ward'].str.contains('^Huyện'), df_sapnhap_ward['ward'], df_sapnhap_ward['district'])
df_sapnhap_ward['ward'] = np.where(df_sapnhap_ward['ward'].str.contains('^Huyện'), np.nan, df_sapnhap_ward['ward'])

# %%
# Kiểm tra 2 province có Huyện Châu Thành
df_sapnhap_ward[~df_sapnhap_ward['province'].isna()]
# Out:
#         id  matinh    ma         tentinh loai        tenhc        cay  \
# 9095  2880      30  2880  Tỉnh Vĩnh Long   xã  Châu Thành  2856.2880
# 9247  2934      30  2934  Tỉnh Vĩnh Long   xã      Phú Túc  2856.2934
#
#       dientichkm2 dansonguoi             trungtamhc  ...      vido  \
# 9095        47.71      39104          đang cập nhật  ...   9.83937
# 9247        63.14      62073  UBND huyện Châu Thành  ...  10.30100
#
#                                            truocsapnhap  maxa           khoa  \
# 9095  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  2645  30Châu Thành
# 9247  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  2587      30Phú Túc
#
#      isMergedWard  count_truocsapnhap  isDividedWard         province  \
# 9095         True                   1          False  Tỉnh Trà Vinh
# 9247         True                   1          False   Tỉnh Bến Tre
#
#                 district                 ward
# 9095  Huyện Châu Thành  Thị trấn Châu Thành
# 9247  Huyện Châu Thành  Thị trấn Châu Thành
#
# [2 rows x 21 columns]

# %%
# Rename cho bước tiếp theo
rename_cols = {
    'province': 'province',
    'district': 'district',
    'ward': 'ward',
    'isMergedWard': 'isMergedWard',
    'isDividedWard': 'isDividedWard',

    'tenhc': 'newWard',
    'tentinh': 'newProvince',
    'maxa': 'newWardCode',
    'loai': 'newWardType',
    'kinhdo': 'newWardLon',
    'vido': 'newWardLat',
    'dientichkm2': 'newWardAreaKm2',
    'truocsapnhap': 'truocsapnhap',

}

df_sapnhap_ward = df_sapnhap_ward.rename(columns=rename_cols)[rename_cols.values()]

# %%
df_sapnhap_ward
# Out:
#       province            district               ward  isMergedWard  \
# 0          NaN                 NaN         Xã Đông La          True
# 1          NaN                 NaN   Phường Dương Nội          True
# 2          NaN                 NaN  Phường Quán Thánh          True
# 3          NaN                 NaN   Phường Trúc Bạch          True
# 4          NaN                 NaN     Phường Cửa Nam          True
# ...        ...                 ...                ...           ...
# 10426      NaN                 NaN    Xã Vĩnh Phú Tây          True
# 10427      NaN                 NaN        Xã Hưng Phú          True
# 10428      NaN                 NaN      Xã Vĩnh Thanh          True
# 10429      NaN  thành phố Bạc Liêu           Phường 5          True
# 10430      NaN                 NaN      Xã Vĩnh Trạch          True
#
#        isDividedWard       newWard    newProvince  newWardCode newWardType  \
# 0              False      An Khánh  Thủ đô Hà Nội         1290          xã
# 1               True      An Khánh  Thủ đô Hà Nội         1290          xã
# 2              False       Ba Đình  Thủ đô Hà Nội          994      phường
# 3              False       Ba Đình  Thủ đô Hà Nội          994      phường
# 4               True       Ba Đình  Thủ đô Hà Nội          994      phường
# ...              ...           ...            ...          ...         ...
# 10426          False  Vĩnh Phước    Tỉnh Cà Mau          160          xã
# 10427          False   Vĩnh Thanh    Tỉnh Cà Mau          161          xã
# 10428          False   Vĩnh Thanh    Tỉnh Cà Mau          161          xã
# 10429          False  Vĩnh Trạch    Tỉnh Cà Mau          151      phường
# 10430          False  Vĩnh Trạch    Tỉnh Cà Mau          151      phường
#
#        newWardLon  newWardLat  newWardAreaKm2                   truocsapnhap
# 0         105.708    20.98760           28.69                     Xã Đông La
# 1         105.708    20.98760           28.69               Phường Dương Nội
# 2         105.838    21.03860            2.97              Phường Quán Thánh
# 3         105.838    21.03860            2.97               Phường Trúc Bạch
# 4         105.838    21.03860            2.97                 Phường Cửa Nam
# ...           ...         ...             ...                            ...
# 10426     105.410     9.39891           75.50                Xã Vĩnh Phú Tây
# 10427     105.519     9.35997           37.37                    Xã Hưng Phú
# 10428     105.519     9.35997           37.37                  Xã Vĩnh Thanh
# 10429     105.774     9.29729           10.22  Phường 5 (thành phố Bạc Liêu)
# 10430     105.774     9.29729           10.22                  Xã Vĩnh Trạch
#
# [10431 rows x 13 columns]

# %% [markdown]
# ## Kiểm tra chính tả 2 bên
#
# Vòng lặp kiểm tra như sau:
# - Bước 1: Kiểm tra tìm unit không khớp của bảng df_sapnhap_ward
# - Bước 2: Sửa chính tả ở bảng df_sapnhap_ward hoặc df_danhmuc.
# - Quay lại Bước 1

# %%
def correct_spelling_basic(text):
    spelling_basic = [
        ('Hoà', 'Hòa'),
        ('Hoè', 'Hòe'),
        ('Hoá', 'Hóa'),
        ('Khoá', 'Khóa'),
        ('Thuỵ' ,'Thụy'),
        ('Thuỷ', 'Thủy'),
        ('Đắk', 'Đăk'),
        ('\' ', "'")
    ]

    if isinstance(text, str):
        for wrong, right in spelling_basic:
            pattern = r'\b' + wrong + r'\b'
            text = re.sub(pattern, right, text)
    return text

# %%
for col in ['province', 'district', 'ward']:
    df_danhmuc[col] = df_danhmuc[col].apply(unicode_normalize)
    df_sapnhap_ward[col] = df_sapnhap_ward[col].apply(unicode_normalize)
    df_danhmuc[col] = df_danhmuc[col].apply(correct_spelling_basic)
    df_sapnhap_ward[col] = df_sapnhap_ward[col].apply(correct_spelling_basic)


spelling_danhmuc = [
    # newProvince, ward, correct ward
    ('Tỉnh Hưng Yên', 'Xã An Quí', 'Xã An Quý'),
    ('Tỉnh Hưng Yên', 'Xã Kim Chung', 'Xã Kim Trung'),
    ('Tỉnh Hưng Yên', 'Xã Vũ Quí', 'Xã Vũ Quý'),
    ('Tỉnh Tuyên Quang', 'Xã Quí Quân', 'Xã Quý Quân'),
    ('Tỉnh Tuyên Quang', 'Xã Sán Xả Hồ', 'Xã Sán Sả Hồ'),
    ('Tỉnh Tuyên Quang', 'Xã Xà Phìn', 'Xã Sà Phìn'),
    ('Tỉnh Tuyên Quang', 'Xã Sủng Tráng', 'Xã Sủng Cháng'),
    ('Tỉnh Lào Cai', 'Xã Hát Lìu', 'Xã Hát Lừu'),
    ('Tỉnh Lào Cai', 'Thị trấn NT Liên Sơn', 'Thị trấn Nông trường Liên Sơn'),
    ('Tỉnh Lào Cai', 'Xã Nậm Rạng', 'Xã Nậm Dạng'),
    ('Tỉnh Thái Nguyên', 'Xã Sĩ Bình', 'Xã Sỹ Bình'),
    ('Tỉnh Lạng Sơn', 'Thị trấn NT Thái Bình', 'Thị trấn Nông trường Thái Bình'),
    ('Tỉnh Phú Thọ', 'Xã Săm Khóe', 'Xã Xăm Khòe'),
    ('Tỉnh Điện Biên', 'Xã Xá Tổng', 'Xã Sá Tổng'),
    ('Tỉnh Điện Biên', 'Xã Huổi Lếnh', 'Xã Huổi Lếch'),
    ('Tỉnh Điện Biên', 'Xã Sáng Nhè', 'Xã Xá Nhè'),
    ('Tỉnh Điện Biên', 'Xã Xín Chải', 'Xã Sín Chải'),
    ('Tỉnh Lai Châu', 'Xã Tông Qua Lìn', 'Xã Tung Qua Lìn'),
    ('Tỉnh Lai Châu', 'Xã Lả Nhì Thàng', 'Xã Lản Nhì Thàng'),
    ('Tỉnh Lai Châu', 'Xã Hua Bun', 'Xã Hua Bum'),
    ('Tỉnh Lai Châu', 'Xã Ma Ly Pho', 'Xã Ma Li Pho'),
    ('Tỉnh Sơn La', 'Xã Pú Pẩu', 'Xã Pú Bẩu'),
    ('Tỉnh Sơn La', 'Xã Noong Lay', 'Xã Nong Lay'),
    ('Tỉnh Nghệ An', 'Phường Thu Thuỷ', 'Phường Thu Thủy'),
    ('Tỉnh Nghệ An', 'Xã Hưng Yên', 'Xã Hưng Yên Nam'),
    ('Tỉnh Quảng Trị', 'Xã Đa Krông', 'Xã Đakrông'),
    ('Tỉnh Quảng Trị', 'Thị trấn NT Lệ Ninh', 'Thị trấn Nông trường Lệ Ninh'),
    ('Tỉnh Quảng Trị', 'Thị trấn NT Việt Trung', 'Thị trấn Nông trường Việt Trung'),
    ('Thành phố Đà Nẵng', 'Xã Bha Lê', 'Xã Bha Lêê'),
    ('Thành phố Đà Nẵng', 'Xã Tà Bhinh', 'Xã Tà Bhing'),
    ('Thành phố Đà Nẵng', 'Xã Mà Cooi', 'Xã Mà Cooih'),
    ('Thành phố Đà Nẵng', 'Thị trấn P Rao', 'Thị Trấn Prao'),
    ('Thành phố Đà Nẵng', 'Xã Laêê', 'Xã La Êê'),
    ('Thành phố Đà Nẵng', 'Xã Zuôich', 'Xã Zuôih'),
    ('Tỉnh Quảng Ngãi', 'Xã Bờ Y', 'Xã Pờ Y'),
    ('Tỉnh Quảng Ngãi', 'Xã Măng Buk', 'Xã Măng Bút'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngọc Yêu', 'Xã Ngọk Yêu'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngọc Lây', 'Xã Ngọk Lây'),
    ('Tỉnh Gia Lai', 'Xã Đăk Roong', 'Xã Đăk Rong'),
    ('Tỉnh Gia Lai', 'Xã H Bông', 'Xã HBông'),
    ('Tỉnh Gia Lai', 'Xã Ia Ma Rơn', 'Xã Ia Mrơn'),
    ('Tỉnh Gia Lai', "Xã K'Dang", 'Xã KDang'),
    ('Tỉnh Gia Lai', "Xã H'Neng", 'Xã Hneng'),
    ('Tỉnh Đắk Lắk', "Xã Ea H'đinh", "Xã Ea H'đing"),
    ('Tỉnh Đắk Lắk', 'Xã Cư K Róa', 'Xã Cư Króa'),
    ('Tỉnh Đắk Lắk', 'Xã Cư Jang', 'Xã Cư Yang'),
    ('Tỉnh Đắk Lắk', 'Xã EaBia', 'Xã Ea Bia'),
    ('Tỉnh Đắk Lắk', 'Xã Ealy', 'Xã Ea Ly'),
    ('Tỉnh Đắk Lắk', 'Xã Cư Ê Wi', 'Xã Cư Êwi'),
    ('Tỉnh Đắk Lắk', "Xã Ea R'Bin", 'Xã Ea Rbin'),
    ('Tỉnh Đắk Lắk', 'Xã EaTrol', 'Xã Ea Trol'),
    ('Tỉnh Đắk Lắk', 'Xã Eachà Rang', 'Xã Ea Chà Rang'),
    ('Tỉnh Lào Cai', 'Thị trấn N.T Phong Hải', 'Thị trấn Nông trường Phong Hải'),
    ('Tỉnh Lào Cai', 'Xã Dế Su Phình', 'Xã Dế Xu Phình'),
    ('Tỉnh Lào Cai', 'Xã Nàn Xín', 'Xã Nàn Sín'),
    ('Tỉnh Lào Cai', 'Thị trấn NT Trần Phú', 'Thị trấn Nông trường Trần Phú'),
    ('Tỉnh Lâm Đồng', 'Xã Đạm Bri', "Xã Đamb'ri"),
    ('Tỉnh Lâm Đồng', "Xã Đắk N'Dung", "Xã Đắk N'Drung"),
    ('Tỉnh Lâm Đồng', "Xã Đắk DRông", "Xã Đắk D'rông"),
    ('Tỉnh Lâm Đồng', 'Xã Thuận Quí', 'Xã Thuận Quý'),
    ('Thành phố Hồ Chí Minh', 'Xã Quy Đức', 'Xã Qui Đức'),
    ('Tỉnh Vĩnh Long', 'Xã An Quy', 'Xã An Qui'),
    ('Tỉnh Vĩnh Long', 'Xã Lục Sỹ Thành', 'Xã Lục Sĩ Thành'),
    ('Tỉnh An Giang', 'Xã Ô Long Vỹ', 'Xã Ô Long Vĩ'),
    ('Thành phố Cần Thơ', 'Xã Hòa Tú II', 'Xã Hòa Tú 2'),
    ('Tỉnh Đắk Lắk', 'Xã EaBar', 'Xã Ea Bar'),
    ('Tỉnh Đắk Lắk', "Xã Ea D'rơng", 'Xã Ea Drơng'),
    ('Thủ đô Hà Nội', 'Phường Phương Liên - Trung Tự', 'Phường Phương Liên Trung Tự'),
    ('Thủ đô Hà Nội', 'Phường Văn Miếu - Quốc Tử Giám', 'Phường Văn Miếu Quốc Tử Giám'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Rơ Ông', 'Xã Đăk Rơ Ông'),
    ('Tỉnh Cao Bằng', 'Xã Phong Nậm', 'Xã Phong Nặm'),
    ('Tỉnh Tuyên Quang', 'Xã Nậm Tỵ', 'Xã Nậm Ty'),
    ('Tỉnh Tuyên Quang', 'Thị trấn Phó Bảng', 'Thị trấn Phố Bảng'),
    ('Tỉnh Tuyên Quang', 'Xã Khau Tinh', 'Xã Khâu Tinh'),
    ('Tỉnh Lào Cai', 'Thị trấn Mù Căng Chải', 'Thị trấn Mù Cang Chải'),
    ('Tỉnh Lào Cai', 'Xã Nậm Chầy', 'Xã Nậm Chày'),
    ('Tỉnh Lào Cai', 'Xã Tả Ngải Chồ', 'Xã Tả Ngài Chồ'),
    ('Tỉnh Thái Nguyên', 'Phường Quán Triều', 'Phường Quan Triều'),
    ('Tỉnh Phú Thọ', 'Xã Mi Hòa', 'Xã Mỵ Hòa'),
    ('Tỉnh Điện Biên', 'Xã Luân Giới', 'Xã Luân Giói'),
    ('Tỉnh Điện Biên', 'Xã Pú Nhi', 'Xã Pu Nhi'),
    ('Tỉnh Điện Biên', 'Xã Noọng Hẹt', 'Xã Noong Hẹt'),
    ('Tỉnh Lai Châu', 'Xã Pa Vệ Sử', 'Xã Pa Vệ Sủ'),
    ('Tỉnh Lai Châu', 'Xã Tà Gia', 'Xã Ta Gia'),
    ('Tỉnh Sơn La', 'Xã Nậm Ét', 'Xã Nặm Ét'),
    ('Tỉnh Sơn La' , 'Xã Nà Ơt', 'Xã Nà Ớt'),
    ('Tỉnh Thanh Hóa', 'Xã Vân Âm', 'Xã Vân Am'),
    ('Tỉnh Thanh Hóa', 'Xã Văn Sơn', 'Xã Vân Sơn'),
    ('Tỉnh Nghệ An', 'Xã Lưỡng Minh', 'Xã Lượng Minh'),
    ('Tỉnh Nghệ An', 'Xã Căm Muộn', 'Xã Cắm Muộn'),
    ('Tỉnh Hà Tĩnh', 'Xã Cỗ Đạm', 'Xã Cổ Đạm'),
    ('Thành phố Đà Nẵng', 'Xã Ka Dăng', 'Xã Kà Dăng'),
    ('Thành phố Đà Nẵng', 'Xã Za Hung', 'Xã Zà Hung'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngok Tem', 'Xã Ngọc Tem'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngok Wang', 'Xã Ngọk Wang'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngok Réo', 'Xã Ngọk Réo'),
    ('Tỉnh Quảng Ngãi', 'Xã Rơ Kơi', 'Xã Rờ Kơi'),
    ('Tỉnh Gia Lai', 'Xã Chư Đăng Ya', 'Xã Chư Đang Ya'),
    ('Tỉnh Gia Lai', 'Xã Chư Krêy', 'Xã Chư Krey'),
    ('Tỉnh Gia Lai', 'Thị trấn Đăk Đoa', 'Thị trấn Đak Đoa'),
    ('Tỉnh Gia Lai', 'Xã Đăk Sơmei', 'Xã Đak Sơmei'),
    ('Tỉnh Gia Lai', 'Xã Ia KRai', 'Xã Ia Krăi'),








]

# Có vẽ các lỗi sai thường là: qui - quy, s - x, \bch - \btr, nt - nong truong, 2 - II, 4 - IV (Số la mã), ngok - ngoc. Sau này sẽ tạo key cho tính năng parse_address

spelling_sapnhap = [
    # newProvince, ward, correct ward
    ('Tỉnh Ninh Bình', 'Phường Tiên Sơn', 'Xã Tiên Sơn'),
    ('Tỉnh Thái Nguyên', 'Xã Đắc Sơn', 'Phường Đắc Sơn'),
    ('Tỉnh Lai Châu', 'Xã Can Hồ', 'Xã Kan Hồ'),
    ('Tỉnh Sơn La', 'Phường Thảo Ngu Yên', 'Phường Thảo Nguyên'),
    ('Tỉnh Sơn La', 'Xã Xí M Vàng', 'Xã Xím Vàng'),
    ('Tỉnh Nghệ An', 'Xã Thu Thủy', 'Phường Thu Thủy'),
    ('Thành phố Huế', 'Phường Đúc', 'Phường Phường Đúc'),
    ('Thành phố Đà Nẵng', 'Xã Bhalêê', 'Xã Bha Lêê'),
    ('Thành phố Đà Nẵng', 'Xã Avương', 'Xã A Vương'),
    ('Thành phố Đà Nẵng', 'Xã Gari', 'Xã Ga Ri'),
    ('Thành phố Đà Nẵng', 'Xã Axan', 'Xã A Xan'),
    ('Thành phố Đà Nẵng', 'Xã Atiêng', 'Xã A Tiêng'),
    ('Thành phố Đà Nẵng', 'Xã Anông', 'Xã A Nông'),
    ('Tỉnh Quảng Ngãi', 'Lê Lợi', 'Phường Lê Lợi'),
    ('Tỉnh Quảng Ngãi', 'Nguyễn Trãi', 'Phường Nguyễn Trãi'),
    ('Tỉnh Quảng Ngãi', 'Xã Đăk Plô', 'Xã Đăk Blô'),
    ('Tỉnh Quảng Ngãi', 'Phổ Hòa', 'Phường Phổ Hòa'),
    ('Tỉnh Quảng Ngãi', 'Phổ Minh', 'Phường Phổ Minh'),
    ('Tỉnh Quảng Ngãi', 'Phổ Vinh', 'Phường Phổ Vinh'),
    ('Tỉnh Quảng Ngãi', 'Phổ Ninh', 'Phường Phổ Ninh'),
    ('Tỉnh Gia Lai', 'Xã Chơ GLong', 'Xã Chơ Long'),
    ('Tỉnh Gia Lai', 'Xã Adơk', 'Xã A Dơk'),
    ('Tỉnh Gia Lai', 'Xã Ia Dreh', 'Ia HDreh'),
    ('Tỉnh Đắk Lắk', 'Krông Na', 'Xã Krông Na'),
    ('Tỉnh Đắk Lắk', 'Xã Cư Dliê Mnông', "Xã Cư Dliê M'nông"),
    ('Tỉnh Lâm Đồng', 'Xã ĐamBri', "Xã Đamb'ri"),
    ('Tỉnh Lâm Đồng', "Xã Cư K'nia", 'Xã Cư Knia'),
    ('Tỉnh Lâm Đồng', 'Thị trấn Mađaguôi', 'Thị trấn Ma Đa Guôi'),
    ('Tỉnh Lâm Đồng', 'Xã Mađaguôi', 'Xã Ma Đa Guôi'),
    ('Tỉnh Lào Cai', 'Xã Tà Xi Láng', 'Xã Tà Si Láng'),
    ('Tỉnh Gia Lai', 'Ia HDreh', 'Xã Ia HDreh'),
    ('Tỉnh Lâm Đồng', "Xã Đưng K'Nớ", 'Xã Đưng KNớ'),
    ('Tỉnh Lâm Đồng', "Xã N' Thôn Hạ", "Xã N'Thol Hạ"),
    ('Tỉnh Tây Ninh', 'Thủ Thừa', 'Thị trấn Thủ Thừa'),
    ('Tỉnh Tây Ninh', 'Phường IV', 'Phường 4'),
    ('Tỉnh Đồng Nai', 'Xã Xuân An', 'Phường Xuân An'),
    ('Tỉnh Đồng Nai', 'Xã Xuân Bình', 'Phường Xuân Bình'),
    ('Thành phố Hồ Chí Minh', 'Rạch Ông', 'Phường Rạch Ông'),
    ('Tỉnh Đồng Tháp', 'Xã Mỹ Quí', 'Xã Mỹ Quý'),
    ('Thành phố Cần Thơ', 'Xã Tân Lộc', 'Phường Tân Lộc'),
    ('Tỉnh Lào Cai', 'Xã Thẳm Dương', 'Xã Thẩm Dương'),
    ('Tỉnh Sơn La', 'Xã Nặm Păm', 'Xã Nậm Păm'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngọk Tem', 'Xã Ngọc Tem'),
    ('Tỉnh Gia Lai', 'Xã Ia Drang', 'Xã Ia Drăng'),
    ('Tỉnh Gia Lai', 'Xã Đak Rong', 'Xã Đăk Rong'),
    ('Tỉnh Gia Lai', 'Xã Ia Krái', 'Xã Ia Krăi'),
    ('Tỉnh Gia Lai', 'Xã Ia Trôk', 'Xã Ia Trok'),




]


for s in spelling_danhmuc:
    newProvince, ward, WardCorrect = s
    df_danhmuc.loc[(df_danhmuc['newProvince']==newProvince) & (df_danhmuc['ward'].fillna('').str.lower()==ward.lower()), 'ward'] = WardCorrect

for s in spelling_sapnhap:
    newProvince, ward, WardCorrect = s
    df_sapnhap_ward.loc[(df_sapnhap_ward['newProvince']==newProvince) & (df_sapnhap_ward['ward'].fillna('').str.lower()==ward.lower()), 'ward'] = WardCorrect

# %%
for col in ['district', 'ward']:
    df_danhmuc[f'{col}Ud'] = df_danhmuc[col].apply(unidecode_pro)
    df_sapnhap_ward[f'{col}Ud'] = df_sapnhap_ward[col].apply(unidecode_pro)

    df_danhmuc[f'{col}Lower'] = df_danhmuc[col].apply(lower_safely)
    df_sapnhap_ward[f'{col}Lower'] = df_sapnhap_ward[col].apply(lower_safely)

# %%
key1 = 'keyNewProvinceProvinceDistrictWard' # Đặc biệt, chỉ có 2 province ^_^
key2 = 'keyNewProvinceDistrictWard' # Trường hợp này sẽ sai nhiều vì dùng fill_district chưa chắc đúng. Cứ kiểm tra chính tả cho key3 key4 thôi là được. Sau đó khi merge bằng key2 phần nào không match chính là key4b
key3 = 'keyNewProvinceDistrict'
key4 = 'keyNewProvinceWard' # key4a


# # Mục đích để check chính tả sẽ khác mục đích dể merge
# for df in [df_sapnhap_ward, df_danhmuc]:
#     df[key1] = np.where((~df['province'].isna()) & (~df['district'].isna()) & (~df['ward'].isna()), df['newProvince'] + '_' + df['province'] + '_' + df['districtUd'] + '_' + df['wardUd'], np.nan)
#
# for df in [df_sapnhap_ward, df_danhmuc]:
#     df[key2] = np.where((~df['district'].isna()) & (~df['ward'].isna()), df['newProvince'] + '_' + df['districtUd'] + '_' + df['wardUd'], np.nan)
#
# for df in [df_sapnhap_ward, df_danhmuc]:
#     df[key3] = np.where((~df['district'].isna()), df['newProvince'] + '_' + df['districtUd'], np.nan) # Khi merge cần thêm điều kiện ward là nan
#
# for df in [df_sapnhap_ward, df_danhmuc]:
#     df[key4] = np.where((~df['ward'].isna()), df['newProvince'] + '_' + df['wardUd'], np.nan) # Khi merge cần thêm điều kiện district là nan


for df in [df_sapnhap_ward, df_danhmuc]:
    df[key1] = np.where((~df['province'].isna()) & (~df['district'].isna()) & (~df['ward'].isna()), df['newProvince'] + '_' + df['province'] + '_' + df['districtLower'] + '_' + df['wardLower'], np.nan)

df_danhmuc[key2] = np.where((~df_danhmuc['district'].isna()) & (~df_danhmuc['ward'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['districtLower'] + '_' + df_danhmuc['wardLower'], np.nan)
df_sapnhap_ward[key2] = np.where((~df_sapnhap_ward['district'].isna()) & (~df_sapnhap_ward['ward'].isna()) & (df_sapnhap_ward['province'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtLower'] + '_' + df_sapnhap_ward['wardLower'], np.nan) # Khi merge thêm province là nan

df_danhmuc[key3] = np.where((~df_danhmuc['district'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['districtLower'], np.nan)
df_sapnhap_ward[key3] = np.where((~df_sapnhap_ward['district'].isna()) & (df_sapnhap_ward['ward'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtLower'], np.nan) # Khi merge cần thêm điều kiện ward là nan

df_danhmuc[key4] = np.where((~df_danhmuc['ward'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['wardLower'], np.nan)
df_sapnhap_ward[key4] = np.where((~df_sapnhap_ward['ward'].isna()) & (df_sapnhap_ward['district'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['wardLower'], np.nan) # Khi merge cần thêm điều kiện district là nan

# %%
# Preview (2 province duy nhất trong dataset này)
df_sapnhap_ward[~df_sapnhap_ward[key1].isna()]
# Out:
#            province          district                 ward  isMergedWard  \
# 9095  Tỉnh Trà Vinh  Huyện Châu Thành  Thị trấn Châu Thành          True
# 9247   Tỉnh Bến Tre  Huyện Châu Thành  Thị trấn Châu Thành          True
#
#       isDividedWard      newWard     newProvince  newWardCode newWardType  \
# 9095          False  Châu Thành  Tỉnh Vĩnh Long         2645          xã
# 9247          False      Phú Túc  Tỉnh Vĩnh Long         2587          xã
#
#       newWardLon  ...  newWardAreaKm2  \
# 9095     106.337  ...           47.71
# 9247     106.318  ...           63.14
#
#                                            truocsapnhap        districtUd  \
# 9095  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
# 9247  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
#
#          districtLower               wardUd            wardLower  \
# 9095  huyện châu thành  thi tran chau thanh  thị trấn châu thành
# 9247  huyện châu thành  thi tran chau thanh  thị trấn châu thành
#
#                      keyNewProvinceProvinceDistrictWard  \
# 9095  Tỉnh Vĩnh Long_Tỉnh Trà Vinh_huyện châu thành_...
# 9247  Tỉnh Vĩnh Long_Tỉnh Bến Tre_huyện châu thành_t...
#
#      keyNewProvinceDistrictWard keyNewProvinceDistrict keyNewProvinceWard
# 9095                        NaN                    NaN                NaN
# 9247                        NaN                    NaN                NaN
#
# [2 rows x 21 columns]

# %%
# Preview (Các đảo thì không có ward)
df_danhmuc[df_danhmuc[key1].isna()]
# Out:
#       districtCode  provinceCode districtType            district  \
# 3582           318            31        Huyện  Huyện Bạch Long Vĩ
# 5794           471            45        Huyện        Huyện Cồn Cỏ
# 5975           498            48        Huyện      Huyện Hoàng Sa
# 6379           536            51        Huyện        Huyện Lý Sơn
# 8196           755            77        Huyện       Huyện Côn Đảo
#
#                     province  wardCode wardType ward  newProvinceCode  \
# 3582     Thành phố Hải Phòng       NaN      NaN  NaN                4
# 5794          Tỉnh Quảng Trị       NaN      NaN  NaN               19
# 5975       Thành phố Đà Nẵng       NaN      NaN  NaN               21
# 6379         Tỉnh Quảng Ngãi       NaN      NaN  NaN               22
# 8196  Tỉnh Bà Rịa - Vũng Tàu       NaN      NaN  NaN               29
#
#                 newProvince  isMergedProvince          districtUd  \
# 3582    Thành phố Hải Phòng              True  huyen bach long vi
# 5794         Tỉnh Quảng Trị              True        huyen con co
# 5975      Thành phố Đà Nẵng              True      huyen hoang sa
# 6379        Tỉnh Quảng Ngãi              True        huyen ly son
# 8196  Thành phố Hồ Chí Minh              True       huyen con dao
#
#            districtLower wardUd wardLower keyNewProvinceProvinceDistrictWard  \
# 3582  huyện bạch long vĩ    NaN       NaN                                NaN
# 5794        huyện cồn cỏ    NaN       NaN                                NaN
# 5975      huyện hoàng sa    NaN       NaN                                NaN
# 6379        huyện lý sơn    NaN       NaN                                NaN
# 8196       huyện côn đảo    NaN       NaN                                NaN
#
#      keyNewProvinceDistrictWard                  keyNewProvinceDistrict  \
# 3582                        NaN  Thành phố Hải Phòng_huyện bạch long vĩ
# 5794                        NaN             Tỉnh Quảng Trị_huyện cồn cỏ
# 5975                        NaN        Thành phố Đà Nẵng_huyện hoàng sa
# 6379                        NaN            Tỉnh Quảng Ngãi_huyện lý sơn
# 8196                        NaN     Thành phố Hồ Chí Minh_huyện côn đảo
#
#      keyNewProvinceWard
# 3582                NaN
# 5794                NaN
# 5975                NaN
# 6379                NaN
# 8196                NaN

# %%
# Check Key 1
df_sapnhap_ward[~df_sapnhap_ward[key1].isin(df_danhmuc[key1])]
# Key 1 is valid fully
# Out:
# Empty DataFrame
# Columns: [province, district, ward, isMergedWard, isDividedWard, newWard, newProvince, newWardCode, newWardType, newWardLon, newWardLat, newWardAreaKm2, truocsapnhap, districtUd, districtLower, wardUd, wardLower, keyNewProvinceProvinceDistrictWard, keyNewProvinceDistrictWard, keyNewProvinceDistrict, keyNewProvinceWard]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Check Key 3
df_sapnhap_ward[~df_sapnhap_ward[key3].isin(df_danhmuc[key3]) & (~df_sapnhap_ward[key3].isna())][['newProvince', 'district', 'districtUd']].drop_duplicates()
# Key 3 is valid fully
# Out:
# Empty DataFrame
# Columns: [newProvince, district, districtUd]
# Index: []

# %%
# Check key 4
df_sapnhap_ward[~df_sapnhap_ward[key4].isin(df_danhmuc[key4]) & (~df_sapnhap_ward[key4].isna())][['newProvince', 'district', 'ward', 'wardUd', 'isMergedWard']].drop_duplicates()
# Chỉ còn "Xã Tân Phước" là không tồn tại ở Tỉnh Tuyên Quang và Tỉnh Hà Giang. Có lẽ dữ liệu của sapnhap bị sai chổ này
# Out:
#              newProvince district               ward             wardUd  \
# 2612    Tỉnh Tuyên Quang      NaN       Xã Tân Phước       xa tan phuoc
# 6595     Tỉnh Quảng Ngãi      NaN        Xã Ngọk Tem        xa ngok tem
# 6646     Tỉnh Quảng Ngãi      NaN       Xã Ngọk Wang       xa ngok wang
# 6647     Tỉnh Quảng Ngãi      NaN        Xã Ngọk Réo        xa ngok reo
# 6655     Tỉnh Quảng Ngãi      NaN          Xã Rờ Kơi          xa ro koi
# 7012        Tỉnh Gia Lai      NaN     Xã Chư Đang Ya     xa chu dang ya
# 7053        Tỉnh Gia Lai      NaN        Xã Chư Krey        xa chu krey
# 7060        Tỉnh Gia Lai      NaN        Xã Ia Drang        xa ia drang
# 7073        Tỉnh Gia Lai      NaN   Thị trấn Đak Đoa   thi tran dak doa
# 7081        Tỉnh Gia Lai      NaN        Xã Đak Rong        xa dak rong
# 7083        Tỉnh Gia Lai      NaN       Xã Đak Sơmei       xa dak somei
# 7159        Tỉnh Gia Lai      NaN         Xã Ia Krái         xa ia krai
# 7175        Tỉnh Gia Lai      NaN         Xã Ia Trôk         xa ia trok
# 7206        Tỉnh Gia Lai      NaN        Xã Đak Trôi        xa dak troi
# 7208        Tỉnh Gia Lai      NaN       Xã Đak Krong       xa dak krong
# 7224        Tỉnh Gia Lai      NaN      Xã Đak Djrăng      xa dak djrang
# 7253        Tỉnh Gia Lai      NaN         Xã Ia Mlah         xa ia mlah
# 7365        Tỉnh Đắk Lắk      NaN       Xã Cuôr Đăng       xa cuor dang
# 7376        Tỉnh Đắk Lắk      NaN         Xã Dliê Ya         xa dlie ya
# 7416        Tỉnh Đắk Lắk      NaN         Xã Ea Khăl         xa ea khal
# 7427        Tỉnh Đắk Lắk      NaN        Xã Ea Knuếc        xa ea knuec
# 7436        Tỉnh Đắk Lắk      NaN       Xã Ea M'Droh       xa ea m droh
# 7499        Tỉnh Đắk Lắk      NaN         Xã Chứ Kbô         xa chu kbo
# 7511        Tỉnh Đắk Lắk      NaN    Thị trấn M'Drắk    thi tran m drak
# 7530        Tỉnh Đắk Lắk      NaN          Xã Ea Púk          xa ea puk
# 7712       Tỉnh Lâm Đồng      NaN       Xã Đạ M'Rông       xa da m rong
# 7738       Tỉnh Lâm Đồng      NaN     Xã Đăk N'Drung     xa dak n drung
# 7830       Tỉnh Lâm Đồng      NaN      Xã Buôn Choáh      xa buon choah
# 7833       Tỉnh Lâm Đồng      NaN      Xã Đăk D'rông      xa dak d rong
# 7913       Tỉnh Lâm Đồng      NaN       Xã N'Thôn Hạ       xa n thon ha
# 8315       Tỉnh Đồng Nai      NaN         Xã Đak Lua         xa dak lua
# 8318       Tỉnh Đồng Nai      NaN           Xã Đăk Ơ           xa dak o
# 9123      Tỉnh Vĩnh Long      NaN        Xã Quới Sơn        xa quoi son
# 9374      Tỉnh Vĩnh Long      NaN        Xã Vinh Kim        xa vinh kim
# 9727       Tỉnh An Giang      NaN  Phường Vĩnh Nguơn  phuong vinh nguon
# 10044  Thành phố Cần Thơ      NaN        Xã Hỏa Tiến        xa hoa tien
# 10045  Thành phố Cần Thơ      NaN         Xã Hỏa Lựu         xa hoa luu
# 10163  Thành phố Cần Thơ      NaN  Thị trấn Thạnh An  thi tran thanh an
#
#        isMergedWard
# 2612           True
# 6595           True
# 6646           True
# 6647           True
# 6655          False
# 7012           True
# 7053           True
# 7060           True
# 7073           True
# 7081           True
# 7083           True
# 7159           True
# 7175           True
# 7206           True
# 7208           True
# 7224           True
# 7253           True
# 7365           True
# 7376           True
# 7416           True
# 7427           True
# 7436           True
# 7499           True
# 7511           True
# 7530           True
# 7712           True
# 7738           True
# 7830           True
# 7833           True
# 7913           True
# 8315          False
# 8318          False
# 9123           True
# 9374           True
# 9727           True
# 10044          True
# 10045          True
# 10163          True

# %%
condition1 = (df_danhmuc['newProvince'] == 'Tỉnh Gia Lai')
condition2 = (df_danhmuc['wardUd'].fillna('').str.contains('ia trok'))
df_danhmuc[condition1 & condition2][['newProvince', 'province', 'district', 'ward', 'wardUd']].drop_duplicates()
# Out:
#        newProvince      province     district        ward      wardUd
# 7242  Tỉnh Gia Lai  Tỉnh Gia Lai  Huyện Ia Pa  Xã Ia Trok  xa ia trok

# %% [markdown]
# ## Kiểm tra trước khi merge

# %%
for df in [df_sapnhap_ward, df_danhmuc]:
    df[key1] = np.where((~df['province'].isna()) & (~df['district'].isna()) & (~df['ward'].isna()), df['newProvince'] + '_' + df['province'] + '_' + df['districtUd'] + '_' + df['wardUd'], np.nan)

df_danhmuc[key2] = np.where((~df_danhmuc['district'].isna()) & (~df_danhmuc['ward'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['districtUd'] + '_' + df_danhmuc['wardUd'], np.nan)
df_sapnhap_ward[key2] = np.where((~df_sapnhap_ward['district'].isna()) & (~df_sapnhap_ward['ward'].isna()) & (df_sapnhap_ward['province'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtUd'] + '_' + df_sapnhap_ward['wardUd'], np.nan) # Khi merge thêm province là nan

df_danhmuc[key3] = np.where((~df_danhmuc['district'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['districtUd'], np.nan)
df_sapnhap_ward[key3] = np.where((~df_sapnhap_ward['district'].isna()) & (df_sapnhap_ward['ward'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtUd'], np.nan) # Khi merge cần thêm điều kiện ward là nan

df_danhmuc[key4] = np.where((~df_danhmuc['ward'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['wardUd'], np.nan)
df_sapnhap_ward[key4] = np.where((~df_sapnhap_ward['ward'].isna()) & (df_sapnhap_ward['district'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['wardUd'], np.nan) # Khi merge cần thêm điều kiện district là nan

# %%
sapnhap1 = df_sapnhap_ward[~df_sapnhap_ward[key1].isna()]
sapnhap1
# Out:
#            province          district                 ward  isMergedWard  \
# 9095  Tỉnh Trà Vinh  Huyện Châu Thành  Thị trấn Châu Thành          True
# 9247   Tỉnh Bến Tre  Huyện Châu Thành  Thị trấn Châu Thành          True
#
#       isDividedWard      newWard     newProvince  newWardCode newWardType  \
# 9095          False  Châu Thành  Tỉnh Vĩnh Long         2645          xã
# 9247          False      Phú Túc  Tỉnh Vĩnh Long         2587          xã
#
#       newWardLon  ...  newWardAreaKm2  \
# 9095     106.337  ...           47.71
# 9247     106.318  ...           63.14
#
#                                            truocsapnhap        districtUd  \
# 9095  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
# 9247  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
#
#          districtLower               wardUd            wardLower  \
# 9095  huyện châu thành  thi tran chau thanh  thị trấn châu thành
# 9247  huyện châu thành  thi tran chau thanh  thị trấn châu thành
#
#                      keyNewProvinceProvinceDistrictWard  \
# 9095  Tỉnh Vĩnh Long_Tỉnh Trà Vinh_huyen chau thanh_...
# 9247  Tỉnh Vĩnh Long_Tỉnh Bến Tre_huyen chau thanh_t...
#
#      keyNewProvinceDistrictWard keyNewProvinceDistrict keyNewProvinceWard
# 9095                        NaN                    NaN                NaN
# 9247                        NaN                    NaN                NaN
#
# [2 rows x 21 columns]

# %%
sapnhap3 = df_sapnhap_ward[~df_sapnhap_ward[key3].isna()]
sapnhap3
# Out:
#      province            district ward  isMergedWard  isDividedWard  \
# 1223      NaN  Huyện Bạch Long Vĩ  NaN          True          False
# 5834      NaN        Huyện Cồn Cỏ  NaN          True          False
# 6289      NaN      Huyện Hoàng Sa  NaN          True          False
# 6608      NaN        Huyện Lý Sơn  NaN          True          False
# 8680      NaN       Huyện Côn Đảo  NaN          True          False
# 9804      NaN      Huyện Kiên Hải  NaN          True          False
#
#            newWard            newProvince  newWardCode newWardType  \
# 1223  Bạch Long Vĩ    Thành phố Hải Phòng         3309     đặc khu
# 5834        Cồn Cỏ         Tỉnh Quảng Trị         3310     đặc khu
# 6289      Hoàng Sa      Thành phố Đà Nẵng         3312     đặc khu
# 6608        Lý Sơn        Tỉnh Quảng Ngãi         3314     đặc khu
# 8680       Côn Đảo  Thành phố Hồ Chí Minh         3311     đặc khu
# 9804      Kiên Hải          Tỉnh An Giang         3315     đặc khu
#
#       newWardLon  ...  newWardAreaKm2        truocsapnhap          districtUd  \
# 1223    107.7307  ...            3.07  Huyện Bạch Long Vĩ  huyen bach long vi
# 5834    107.3390  ...            2.30        Huyện Cồn Cỏ        huyen con co
# 6289    112.1350  ...          305.00      Huyện Hoàng Sa      huyen hoang sa
# 6608    109.1150  ...           10.39        Huyện Lý Sơn        huyen ly son
# 8680    106.6115  ...           75.79       Huyện Côn Đảo       huyen con dao
# 9804    104.6320  ...           21.81      Huyện Kiên Hải      huyen kien hai
#
#            districtLower wardUd wardLower keyNewProvinceProvinceDistrictWard  \
# 1223  huyện bạch long vĩ    NaN       NaN                                NaN
# 5834        huyện cồn cỏ    NaN       NaN                                NaN
# 6289      huyện hoàng sa    NaN       NaN                                NaN
# 6608        huyện lý sơn    NaN       NaN                                NaN
# 8680       huyện côn đảo    NaN       NaN                                NaN
# 9804      huyện kiên hải    NaN       NaN                                NaN
#
#      keyNewProvinceDistrictWard                  keyNewProvinceDistrict  \
# 1223                        NaN  Thành phố Hải Phòng_huyen bach long vi
# 5834                        NaN             Tỉnh Quảng Trị_huyen con co
# 6289                        NaN        Thành phố Đà Nẵng_huyen hoang sa
# 6608                        NaN            Tỉnh Quảng Ngãi_huyen ly son
# 8680                        NaN     Thành phố Hồ Chí Minh_huyen con dao
# 9804                        NaN            Tỉnh An Giang_huyen kien hai
#
#      keyNewProvinceWard
# 1223                NaN
# 5834                NaN
# 6289                NaN
# 6608                NaN
# 8680                NaN
# 9804                NaN
#
# [6 rows x 21 columns]

# %%
sapnhap4a = df_sapnhap_ward[~df_sapnhap_ward[key4].isna()]
sapnhap4a
# Out:
#       province district               ward  isMergedWard  isDividedWard  \
# 0          NaN      NaN         Xã Đông La          True          False
# 1          NaN      NaN   Phường Dương Nội          True           True
# 2          NaN      NaN  Phường Quán Thánh          True          False
# 3          NaN      NaN   Phường Trúc Bạch          True          False
# 4          NaN      NaN     Phường Cửa Nam          True           True
# ...        ...      ...                ...           ...            ...
# 10425      NaN      NaN      Xã Phước Long          True          False
# 10426      NaN      NaN    Xã Vĩnh Phú Tây          True          False
# 10427      NaN      NaN        Xã Hưng Phú          True          False
# 10428      NaN      NaN      Xã Vĩnh Thanh          True          False
# 10430      NaN      NaN      Xã Vĩnh Trạch          True          False
#
#             newWard    newProvince  newWardCode newWardType  newWardLon  ...  \
# 0          An Khánh  Thủ đô Hà Nội         1290          xã     105.708  ...
# 1          An Khánh  Thủ đô Hà Nội         1290          xã     105.708  ...
# 2           Ba Đình  Thủ đô Hà Nội          994      phường     105.838  ...
# 3           Ba Đình  Thủ đô Hà Nội          994      phường     105.838  ...
# 4           Ba Đình  Thủ đô Hà Nội          994      phường     105.838  ...
# ...             ...            ...          ...         ...         ...  ...
# 10425  Vĩnh Phước    Tỉnh Cà Mau          160          xã     105.410  ...
# 10426  Vĩnh Phước    Tỉnh Cà Mau          160          xã     105.410  ...
# 10427   Vĩnh Thanh    Tỉnh Cà Mau          161          xã     105.519  ...
# 10428   Vĩnh Thanh    Tỉnh Cà Mau          161          xã     105.519  ...
# 10430  Vĩnh Trạch    Tỉnh Cà Mau          151      phường     105.774  ...
#
#        newWardAreaKm2       truocsapnhap districtUd districtLower  \
# 0               28.69         Xã Đông La        NaN           NaN
# 1               28.69   Phường Dương Nội        NaN           NaN
# 2                2.97  Phường Quán Thánh        NaN           NaN
# 3                2.97   Phường Trúc Bạch        NaN           NaN
# 4                2.97     Phường Cửa Nam        NaN           NaN
# ...               ...                ...        ...           ...
# 10425           75.50      Xã Phước Long        NaN           NaN
# 10426           75.50    Xã Vĩnh Phú Tây        NaN           NaN
# 10427           37.37        Xã Hưng Phú        NaN           NaN
# 10428           37.37      Xã Vĩnh Thanh        NaN           NaN
# 10430           10.22      Xã Vĩnh Trạch        NaN           NaN
#
#                   wardUd          wardLower  \
# 0             xa dong la         xã đông la
# 1       phuong duong noi   phường dương nội
# 2      phuong quan thanh  phường quán thánh
# 3       phuong truc bach   phường trúc bạch
# 4         phuong cua nam     phường cửa nam
# ...                  ...                ...
# 10425      xa phuoc long      xã phước long
# 10426    xa vinh phu tay    xã vĩnh phú tây
# 10427        xa hung phu        xã hưng phú
# 10428      xa vinh thanh      xã vĩnh thanh
# 10430      xa vinh trach      xã vĩnh trạch
#
#       keyNewProvinceProvinceDistrictWard keyNewProvinceDistrictWard  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                                    NaN                        NaN
# 4                                    NaN                        NaN
# ...                                  ...                        ...
# 10425                                NaN                        NaN
# 10426                                NaN                        NaN
# 10427                                NaN                        NaN
# 10428                                NaN                        NaN
# 10430                                NaN                        NaN
#
#       keyNewProvinceDistrict               keyNewProvinceWard
# 0                        NaN         Thủ đô Hà Nội_xa dong la
# 1                        NaN   Thủ đô Hà Nội_phuong duong noi
# 2                        NaN  Thủ đô Hà Nội_phuong quan thanh
# 3                        NaN   Thủ đô Hà Nội_phuong truc bach
# 4                        NaN     Thủ đô Hà Nội_phuong cua nam
# ...                      ...                              ...
# 10425                    NaN        Tỉnh Cà Mau_xa phuoc long
# 10426                    NaN      Tỉnh Cà Mau_xa vinh phu tay
# 10427                    NaN          Tỉnh Cà Mau_xa hung phu
# 10428                    NaN        Tỉnh Cà Mau_xa vinh thanh
# 10430                    NaN        Tỉnh Cà Mau_xa vinh trach
#
# [9487 rows x 21 columns]

# %%
sapnhap2 = df_sapnhap_ward[(~df_sapnhap_ward[key2].isna()) & (df_sapnhap_ward[key2].isin(df_danhmuc[key2]))]
sapnhap2
# Out:
#       province            district              ward  isMergedWard  \
# 14         NaN   quận Hai Bà Trưng   Phường Bạch Mai          True
# 15         NaN   quận Hai Bà Trưng  Phường Bách Khoa          True
# 16         NaN   quận Hai Bà Trưng  Phường Quỳnh Mai          True
# 17         NaN   quận Hai Bà Trưng  Phường Minh Khai          True
# 62         NaN     huyện Phú Xuyên        Xã Tân Dân          True
# ...        ...                 ...               ...           ...
# 10386      NaN    thành phố Cà Mau          Phường 5          True
# 10387      NaN    thành phố Cà Mau  Phường Tân Thành          True
# 10388      NaN    thành phố Cà Mau      Xã Tân Thành          True
# 10389      NaN    thành phố Cà Mau          Phường 7          True
# 10429      NaN  thành phố Bạc Liêu          Phường 5          True
#
#        isDividedWard       newWard    newProvince  newWardCode newWardType  \
# 14             False      Bạch Mai  Thủ đô Hà Nội          967      phường
# 15             False      Bạch Mai  Thủ đô Hà Nội          967      phường
# 16             False      Bạch Mai  Thủ đô Hà Nội          967      phường
# 17             False      Bạch Mai  Thủ đô Hà Nội          967      phường
# 62             False     Chuyên Mỹ  Thủ đô Hà Nội         1342          xã
# ...              ...           ...            ...          ...         ...
# 10386          False    Tân Thành    Tỉnh Cà Mau          184      phường
# 10387          False    Tân Thành    Tỉnh Cà Mau          184      phường
# 10388          False    Tân Thành    Tỉnh Cà Mau          184      phường
# 10389           True    Tân Thành    Tỉnh Cà Mau          184      phường
# 10429          False  Vĩnh Trạch    Tỉnh Cà Mau          151      phường
#
#        newWardLon  ...  newWardAreaKm2                          truocsapnhap  \
# 14        105.852  ...            2.95   Phường Bạch Mai (quận Hai Bà Trưng)
# 15        105.852  ...            2.95  Phường Bách Khoa (quận Hai Bà Trưng)
# 16        105.852  ...            2.95  Phường Quỳnh Mai (quận Hai Bà Trưng)
# 17        105.852  ...            2.95  Phường Minh Khai (quận Hai Bà Trưng)
# 62        105.884  ...           35.54          Xã Tân Dân (huyện Phú Xuyên)
# ...           ...  ...             ...                                   ...
# 10386     105.217  ...           48.42           Phường 5 (thành phố Cà Mau)
# 10387     105.217  ...           48.42   Phường Tân Thành (thành phố Cà Mau)
# 10388     105.217  ...           48.42       Xã Tân Thành (thành phố Cà Mau)
# 10389     105.217  ...           48.42           Phường 7 (thành phố Cà Mau)
# 10429     105.774  ...           10.22         Phường 5 (thành phố Bạc Liêu)
#
#                districtUd       districtLower            wardUd  \
# 14      quan hai ba trung   quận hai bà trưng   phuong bach mai
# 15      quan hai ba trung   quận hai bà trưng  phuong bach khoa
# 16      quan hai ba trung   quận hai bà trưng  phuong quynh mai
# 17      quan hai ba trung   quận hai bà trưng  phuong minh khai
# 62        huyen phu xuyen     huyện phú xuyên        xa tan dan
# ...                   ...                 ...               ...
# 10386    thanh pho ca mau    thành phố cà mau          phuong 5
# 10387    thanh pho ca mau    thành phố cà mau  phuong tan thanh
# 10388    thanh pho ca mau    thành phố cà mau      xa tan thanh
# 10389    thanh pho ca mau    thành phố cà mau          phuong 7
# 10429  thanh pho bac lieu  thành phố bạc liêu          phuong 5
#
#               wardLower keyNewProvinceProvinceDistrictWard  \
# 14      phường bạch mai                                NaN
# 15     phường bách khoa                                NaN
# 16     phường quỳnh mai                                NaN
# 17     phường minh khai                                NaN
# 62           xã tân dân                                NaN
# ...                 ...                                ...
# 10386          phường 5                                NaN
# 10387  phường tân thành                                NaN
# 10388      xã tân thành                                NaN
# 10389          phường 7                                NaN
# 10429          phường 5                                NaN
#
#                              keyNewProvinceDistrictWard  \
# 14      Thủ đô Hà Nội_quan hai ba trung_phuong bach mai
# 15     Thủ đô Hà Nội_quan hai ba trung_phuong bach khoa
# 16     Thủ đô Hà Nội_quan hai ba trung_phuong quynh mai
# 17     Thủ đô Hà Nội_quan hai ba trung_phuong minh khai
# 62             Thủ đô Hà Nội_huyen phu xuyen_xa tan dan
# ...                                                 ...
# 10386             Tỉnh Cà Mau_thanh pho ca mau_phuong 5
# 10387     Tỉnh Cà Mau_thanh pho ca mau_phuong tan thanh
# 10388         Tỉnh Cà Mau_thanh pho ca mau_xa tan thanh
# 10389             Tỉnh Cà Mau_thanh pho ca mau_phuong 7
# 10429           Tỉnh Cà Mau_thanh pho bac lieu_phuong 5
#
#       keyNewProvinceDistrict keyNewProvinceWard
# 14                       NaN                NaN
# 15                       NaN                NaN
# 16                       NaN                NaN
# 17                       NaN                NaN
# 62                       NaN                NaN
# ...                      ...                ...
# 10386                    NaN                NaN
# 10387                    NaN                NaN
# 10388                    NaN                NaN
# 10389                    NaN                NaN
# 10429                    NaN                NaN
#
# [887 rows x 21 columns]

# %%
sapnhap4b = df_sapnhap_ward[(~df_sapnhap_ward[key2].isna()) & (~df_sapnhap_ward[key2].isin(df_danhmuc[key2]))]
sapnhap4b['district'] = np.nan
sapnhap4b['districtUd'] = np.nan
sapnhap4b[key4] = np.where((~sapnhap4b['ward'].isna()) & (sapnhap4b['district'].isna()), sapnhap4b['newProvince'] + '_' + sapnhap4b['wardUd'], np.nan)
sapnhap4b
# Out:
#      province  district                  ward  isMergedWard  isDividedWard  \
# 152       NaN       NaN      Phường Thạch Bàn          True          False
# 209       NaN       NaN        Phường Tây Tựu          True           True
# 210       NaN       NaN            Xã Tân Lập          True          False
# 226       NaN       NaN     Phường Hoàng Liệt          True          False
# 315       NaN       NaN            Xã Văn Khê          True          False
# 316       NaN       NaN            Xã Mê Linh          True          False
# 317       NaN       NaN          Xã Đại Thịnh          True          False
# 501       NaN       NaN        Phường Tây Tựu          True           True
# 531       NaN       NaN           Xã Đại Mạch          True          False
# 532       NaN       NaN             Xã Kim Nỗ          True          False
# 639       NaN       NaN    Phường Phương Canh          True          False
# 640       NaN       NaN    Phường Xuân Phương          True          False
# 641       NaN       NaN         Phường Đại Mỗ          True          False
# 642       NaN       NaN         Phường Tây Mỗ          True          False
# 643       NaN       NaN           Xã Vân Canh          True          False
# 1266      NaN       NaN          Xã Thanh Hải          True          False
# 1487      NaN       NaN   Thị trấn Trường Sơn          True          False
# 1880      NaN       NaN  Phường Lê Hồng Phong          True          False
# 1881      NaN       NaN       Phường Bồ Xuyên          True          False
# 1882      NaN       NaN     Phường Tiền Phong          True          False
# 1974      NaN       NaN      Phường Phú Khánh          True          False
# 7533      NaN       NaN       Phường Phú Đông          True          False
# 7534      NaN       NaN        Phường Phú Lâm          True          False
# 7535      NaN       NaN      Phường Phú Thạnh          True          False
# 7598      NaN       NaN              Phường 1          True          False
# 7599      NaN       NaN              Phường 2          True          False
# 7600      NaN       NaN              Phường 4          True          False
# 7601      NaN       NaN              Phường 5          True          False
# 7602      NaN       NaN              Phường 7          True          False
# 7603      NaN       NaN              Phường 9          True          False
# 8066      NaN       NaN              Phường 4          True          False
# 8067      NaN       NaN              Phường 5          True          False
# 8068      NaN       NaN              Phường 6          True          False
# 8069      NaN       NaN      Xã Hướng Thọ Phú          True          False
# 8183      NaN       NaN            Xã Mỏ Công          True          False
# 8184      NaN       NaN           Xã Trà Vong          True          False
# 8185      NaN       NaN          Xã Tân Phong          True          False
# 8280      NaN       NaN         Phường An Lộc          True          False
# 8281      NaN       NaN     Phường Hưng Chiến          True          False
# 8282      NaN       NaN        Phường Phú Đức          True          False
# 8422      NaN       NaN     Phường Long Phước          True          False
# 8423      NaN       NaN     Phường Phước Bình          True          False
# 8594      NaN       NaN         Xã An Phú Tây          True          False
# 8605      NaN       NaN          Xã Phong Phú          True          False
# 8606      NaN       NaN          Xã Bình Hưng          True          False
# 8898      NaN       NaN      Thị trấn Tân Túc          True          False
# 8899      NaN       NaN           Xã Tân Nhựt          True          False
# 8900      NaN       NaN      Phường Tân Tạo A          True          False
# 8901      NaN       NaN           Xã Tân Kiên          True          False
#
#           newWard            newProvince  newWardCode newWardType  newWardLon  \
# 152       Gia Lâm          Thủ đô Hà Nội         1132          xã     105.949
# 209      Hoài Đức          Thủ đô Hà Nội         1162          xã     105.705
# 210      Hoài Đức          Thủ đô Hà Nội         1162          xã     105.705
# 226    Hoàng Liệt          Thủ đô Hà Nội         1041      phường     105.832
# 315       Mê Linh          Thủ đô Hà Nội         1163          xã     105.733
# 316       Mê Linh          Thủ đô Hà Nội         1163          xã     105.733
# 317       Mê Linh          Thủ đô Hà Nội         1163          xã     105.733
# 501       Tây Tựu          Thủ đô Hà Nội         1100      phường     105.739
# 531     Thiên Lộc          Thủ đô Hà Nội         1241          xã     105.771
# 532     Thiên Lộc          Thủ đô Hà Nội         1241          xã     105.771
# 639   Xuân Phương          Thủ đô Hà Nội         1123      phường     105.745
# 640   Xuân Phương          Thủ đô Hà Nội         1123      phường     105.745
# 641   Xuân Phương          Thủ đô Hà Nội         1123      phường     105.745
# 642   Xuân Phương          Thủ đô Hà Nội         1123      phường     105.745
# 643   Xuân Phương          Thủ đô Hà Nội         1123      phường     105.745
# 1266      Đại Sơn    Thành phố Hải Phòng          923          xã     106.378
# 1487     Phù Liễn    Thành phố Hải Phòng         1085      phường     106.636
# 1880    Thái Bình          Tỉnh Hưng Yên          716      phường     106.314
# 1881    Thái Bình          Tỉnh Hưng Yên          716      phường     106.314
# 1882    Thái Bình          Tỉnh Hưng Yên          716      phường     106.314
# 1974      Vũ Phúc          Tỉnh Hưng Yên          738      phường     106.308
# 7533      Phú Yên           Tỉnh Đắk Lắk         3039      phường     109.315
# 7534      Phú Yên           Tỉnh Đắk Lắk         3039      phường     109.315
# 7535      Phú Yên           Tỉnh Đắk Lắk         3039      phường     109.315
# 7598      Tuy Hòa           Tỉnh Đắk Lắk         3038      phường     109.289
# 7599      Tuy Hòa           Tỉnh Đắk Lắk         3038      phường     109.289
# 7600      Tuy Hòa           Tỉnh Đắk Lắk         3038      phường     109.289
# 7601      Tuy Hòa           Tỉnh Đắk Lắk         3038      phường     109.289
# 7602      Tuy Hòa           Tỉnh Đắk Lắk         3038      phường     109.289
# 7603      Tuy Hòa           Tỉnh Đắk Lắk         3038      phường     109.289
# 8066      Long An          Tỉnh Tây Ninh         1109      phường     106.405
# 8067      Long An          Tỉnh Tây Ninh         1109      phường     106.405
# 8068      Long An          Tỉnh Tây Ninh         1109      phường     106.405
# 8069      Long An          Tỉnh Tây Ninh         1109      phường     106.405
# 8183      Tân Phú          Tỉnh Tây Ninh         2899          xã     106.162
# 8184      Tân Phú          Tỉnh Tây Ninh         2899          xã     106.162
# 8185      Tân Phú          Tỉnh Tây Ninh         2899          xã     106.162
# 8280    Bình Long          Tỉnh Đồng Nai         2436      phường     106.598
# 8281    Bình Long          Tỉnh Đồng Nai         2436      phường     106.598
# 8282    Bình Long          Tỉnh Đồng Nai         2436      phường     106.598
# 8422   Phước Bình          Tỉnh Đồng Nai         2421      phường     106.940
# 8423   Phước Bình          Tỉnh Đồng Nai         2421      phường     106.940
# 8594    Bình Đông  Thành phố Hồ Chí Minh          205      phường     106.612
# 8605    Bình Hưng  Thành phố Hồ Chí Minh          138          xã     106.660
# 8606    Bình Hưng  Thành phố Hồ Chí Minh          138          xã     106.660
# 8898     Tân Nhựt  Thành phố Hồ Chí Minh          134          xã     106.562
# 8899     Tân Nhựt  Thành phố Hồ Chí Minh          134          xã     106.562
# 8900     Tân Nhựt  Thành phố Hồ Chí Minh          134          xã     106.562
# 8901     Tân Nhựt  Thành phố Hồ Chí Minh          134          xã     106.562
#
#       ...  newWardAreaKm2                           truocsapnhap districtUd  \
# 152   ...           25.72       Phường Thạch Bàn (huyện Gia Lâm)        NaN
# 209   ...           16.73        Phường Tây Tựu (huyện Hoài Đức)        NaN
# 210   ...           16.73            Xã Tân Lập (huyện Hoài Đức)        NaN
# 226   ...            4.04    Phường Hoàng Liệt (huyện Thanh Trì)        NaN
# 315   ...           34.97          Xã Văn Khê (huyện Đan Phượng)        NaN
# 316   ...           34.97          Xã Mê Linh (huyện Đan Phượng)        NaN
# 317   ...           34.97        Xã Đại Thịnh (huyện Đan Phượng)        NaN
# 501   ...            7.54        Phường Tây Tựu (huyện Hoài Đức)        NaN
# 531   ...           27.96            Xã Đại Mạch (huyện Mê Linh)        NaN
# 532   ...           27.96              Xã Kim Nỗ (huyện Mê Linh)        NaN
# 639   ...           10.81  Phường Phương Canh (quận Bắc Từ Liêm)        NaN
# 640   ...           10.81  Phường Xuân Phương (quận Bắc Từ Liêm)        NaN
# 641   ...           10.81       Phường Đại Mỗ (quận Bắc Từ Liêm)        NaN
# 642   ...           10.81       Phường Tây Mỗ (quận Bắc Từ Liêm)        NaN
# 643   ...           10.81         Xã Vân Canh (quận Bắc Từ Liêm)        NaN
# 1266  ...           22.99             Xã Thanh Hải (huyện Tứ Kỳ)        NaN
# 1487  ...           18.46     Thị trấn Trường Sơn (quận Kiến An)        NaN
# 1880  ...           28.03  Phường Lê Hồng Phong (huyện Vũ Thư)        NaN
# 1881  ...           28.03       Phường Bồ Xuyên (huyện Vũ Thư)        NaN
# 1882  ...           28.03     Phường Tiền Phong (huyện Vũ Thư)        NaN
# 1974  ...           23.99      Phường Phú Khánh (huyện Vũ Thư)        NaN
# 7533  ...           44.04      Phường Phú Đông (thị xã Đông Hòa)        NaN
# 7534  ...           44.04       Phường Phú Lâm (thị xã Đông Hòa)        NaN
# 7535  ...           44.04     Phường Phú Thạnh (thị xã Đông Hòa)        NaN
# 7598  ...           33.77               Phường 1 (huyện Phú Hòa)        NaN
# 7599  ...           33.77               Phường 2 (huyện Phú Hòa)        NaN
# 7600  ...           33.77               Phường 4 (huyện Phú Hòa)        NaN
# 7601  ...           33.77               Phường 5 (huyện Phú Hòa)        NaN
# 7602  ...           33.77               Phường 7 (huyện Phú Hòa)        NaN
# 7603  ...           33.77               Phường 9 (huyện Phú Hòa)        NaN
# 8066  ...           34.90           Phường 4 (huyện Thủ Thừa)        NaN
# 8067  ...           34.90           Phường 5 (huyện Thủ Thừa)        NaN
# 8068  ...           34.90           Phường 6 (huyện Thủ Thừa)        NaN
# 8069  ...           34.90   Xã Hướng Thọ Phú (huyện Thủ Thừa)        NaN
# 8183  ...           38.60           Xã Mỏ Công (huyện Tân Châu)        NaN
# 8184  ...           38.60          Xã Trà Vong (huyện Tân Châu)        NaN
# 8185  ...           38.60         Xã Tân Phong (huyện Tân Châu)        NaN
# 8280  ...           49.10         Phường An Lộc (huyện Hớn Quản)        NaN
# 8281  ...           49.10     Phường Hưng Chiến (huyện Hớn Quản)        NaN
# 8282  ...           49.10        Phường Phú Đức (huyện Hớn Quản)        NaN
# 8422  ...           72.60    Phường Long Phước (huyện Phú Riềng)        NaN
# 8423  ...           72.60    Phường Phước Bình (huyện Phú Riềng)        NaN
# 8594  ...            8.93                Xã An Phú Tây (Quận 8)        NaN
# 8605  ...           32.63                  Xã Phong Phú (Quận 8)        NaN
# 8606  ...           32.63                  Xã Bình Hưng (Quận 8)        NaN
# 8898  ...           43.67              Thị trấn Tân Túc (Quận 8)        NaN
# 8899  ...           43.67                   Xã Tân Nhựt (Quận 8)        NaN
# 8900  ...           43.67              Phường Tân Tạo A (Quận 8)        NaN
# 8901  ...           43.67                   Xã Tân Kiên (Quận 8)        NaN
#
#          districtLower                wardUd             wardLower  \
# 152      huyện gia lâm      phuong thach ban      phường thạch bàn
# 209     huyện hoài đức        phuong tay tuu        phường tây tựu
# 210     huyện hoài đức            xa tan lap            xã tân lập
# 226    huyện thanh trì     phuong hoang liet     phường hoàng liệt
# 315   huyện đan phượng            xa van khe            xã văn khê
# 316   huyện đan phượng            xa me linh            xã mê linh
# 317   huyện đan phượng          xa dai thinh          xã đại thịnh
# 501     huyện hoài đức        phuong tay tuu        phường tây tựu
# 531      huyện mê linh           xa dai mach           xã đại mạch
# 532      huyện mê linh             xa kim no             xã kim nỗ
# 639   quận bắc từ liêm    phuong phuong canh    phường phương canh
# 640   quận bắc từ liêm    phuong xuan phuong    phường xuân phương
# 641   quận bắc từ liêm         phuong dai mo         phường đại mỗ
# 642   quận bắc từ liêm         phuong tay mo         phường tây mỗ
# 643   quận bắc từ liêm           xa van canh           xã vân canh
# 1266       huyện tứ kỳ          xa thanh hai          xã thanh hải
# 1487      quận kiến an   thi tran truong son   thị trấn trường sơn
# 1880      huyện vũ thư  phuong le hong phong  phường lê hồng phong
# 1881      huyện vũ thư       phuong bo xuyen       phường bồ xuyên
# 1882      huyện vũ thư     phuong tien phong     phường tiền phong
# 1974      huyện vũ thư      phuong phu khanh      phường phú khánh
# 7533   thị xã đông hòa       phuong phu dong       phường phú đông
# 7534   thị xã đông hòa        phuong phu lam        phường phú lâm
# 7535   thị xã đông hòa      phuong phu thanh      phường phú thạnh
# 7598     huyện phú hòa              phuong 1              phường 1
# 7599     huyện phú hòa              phuong 2              phường 2
# 7600     huyện phú hòa              phuong 4              phường 4
# 7601     huyện phú hòa              phuong 5              phường 5
# 7602     huyện phú hòa              phuong 7              phường 7
# 7603     huyện phú hòa              phuong 9              phường 9
# 8066    huyện thủ thừa              phuong 4              phường 4
# 8067    huyện thủ thừa              phuong 5              phường 5
# 8068    huyện thủ thừa              phuong 6              phường 6
# 8069    huyện thủ thừa      xa huong tho phu      xã hướng thọ phú
# 8183    huyện tân châu            xa mo cong            xã mỏ công
# 8184    huyện tân châu           xa tra vong           xã trà vong
# 8185    huyện tân châu          xa tan phong          xã tân phong
# 8280    huyện hớn quản         phuong an loc         phường an lộc
# 8281    huyện hớn quản     phuong hung chien     phường hưng chiến
# 8282    huyện hớn quản        phuong phu duc        phường phú đức
# 8422   huyện phú riềng     phuong long phuoc     phường long phước
# 8423   huyện phú riềng     phuong phuoc binh     phường phước bình
# 8594            quận 8         xa an phu tay         xã an phú tây
# 8605            quận 8          xa phong phu          xã phong phú
# 8606            quận 8          xa binh hung          xã bình hưng
# 8898            quận 8      thi tran tan tuc      thị trấn tân túc
# 8899            quận 8           xa tan nhut           xã tân nhựt
# 8900            quận 8      phuong tan tao a      phường tân tạo a
# 8901            quận 8           xa tan kien           xã tân kiên
#
#      keyNewProvinceProvinceDistrictWard  \
# 152                                 NaN
# 209                                 NaN
# 210                                 NaN
# 226                                 NaN
# 315                                 NaN
# 316                                 NaN
# 317                                 NaN
# 501                                 NaN
# 531                                 NaN
# 532                                 NaN
# 639                                 NaN
# 640                                 NaN
# 641                                 NaN
# 642                                 NaN
# 643                                 NaN
# 1266                                NaN
# 1487                                NaN
# 1880                                NaN
# 1881                                NaN
# 1882                                NaN
# 1974                                NaN
# 7533                                NaN
# 7534                                NaN
# 7535                                NaN
# 7598                                NaN
# 7599                                NaN
# 7600                                NaN
# 7601                                NaN
# 7602                                NaN
# 7603                                NaN
# 8066                                NaN
# 8067                                NaN
# 8068                                NaN
# 8069                                NaN
# 8183                                NaN
# 8184                                NaN
# 8185                                NaN
# 8280                                NaN
# 8281                                NaN
# 8282                                NaN
# 8422                                NaN
# 8423                                NaN
# 8594                                NaN
# 8605                                NaN
# 8606                                NaN
# 8898                                NaN
# 8899                                NaN
# 8900                                NaN
# 8901                                NaN
#
#                              keyNewProvinceDistrictWard  \
# 152        Thủ đô Hà Nội_huyen gia lam_phuong thach ban
# 209         Thủ đô Hà Nội_huyen hoai duc_phuong tay tuu
# 210             Thủ đô Hà Nội_huyen hoai duc_xa tan lap
# 226     Thủ đô Hà Nội_huyen thanh tri_phuong hoang liet
# 315           Thủ đô Hà Nội_huyen dan phuong_xa van khe
# 316           Thủ đô Hà Nội_huyen dan phuong_xa me linh
# 317         Thủ đô Hà Nội_huyen dan phuong_xa dai thinh
# 501         Thủ đô Hà Nội_huyen hoai duc_phuong tay tuu
# 531             Thủ đô Hà Nội_huyen me linh_xa dai mach
# 532               Thủ đô Hà Nội_huyen me linh_xa kim no
# 639   Thủ đô Hà Nội_quan bac tu liem_phuong phuong canh
# 640   Thủ đô Hà Nội_quan bac tu liem_phuong xuan phuong
# 641        Thủ đô Hà Nội_quan bac tu liem_phuong dai mo
# 642        Thủ đô Hà Nội_quan bac tu liem_phuong tay mo
# 643          Thủ đô Hà Nội_quan bac tu liem_xa van canh
# 1266       Thành phố Hải Phòng_huyen tu ky_xa thanh hai
# 1487  Thành phố Hải Phòng_quan kien an_thi tran truo...
# 1880    Tỉnh Hưng Yên_huyen vu thu_phuong le hong phong
# 1881         Tỉnh Hưng Yên_huyen vu thu_phuong bo xuyen
# 1882       Tỉnh Hưng Yên_huyen vu thu_phuong tien phong
# 1974        Tỉnh Hưng Yên_huyen vu thu_phuong phu khanh
# 7533       Tỉnh Đắk Lắk_thi xa dong hoa_phuong phu dong
# 7534        Tỉnh Đắk Lắk_thi xa dong hoa_phuong phu lam
# 7535      Tỉnh Đắk Lắk_thi xa dong hoa_phuong phu thanh
# 7598                Tỉnh Đắk Lắk_huyen phu hoa_phuong 1
# 7599                Tỉnh Đắk Lắk_huyen phu hoa_phuong 2
# 7600                Tỉnh Đắk Lắk_huyen phu hoa_phuong 4
# 7601                Tỉnh Đắk Lắk_huyen phu hoa_phuong 5
# 7602                Tỉnh Đắk Lắk_huyen phu hoa_phuong 7
# 7603                Tỉnh Đắk Lắk_huyen phu hoa_phuong 9
# 8066              Tỉnh Tây Ninh_huyen thu thua_phuong 4
# 8067              Tỉnh Tây Ninh_huyen thu thua_phuong 5
# 8068              Tỉnh Tây Ninh_huyen thu thua_phuong 6
# 8069      Tỉnh Tây Ninh_huyen thu thua_xa huong tho phu
# 8183            Tỉnh Tây Ninh_huyen tan chau_xa mo cong
# 8184           Tỉnh Tây Ninh_huyen tan chau_xa tra vong
# 8185          Tỉnh Tây Ninh_huyen tan chau_xa tan phong
# 8280         Tỉnh Đồng Nai_huyen hon quan_phuong an loc
# 8281     Tỉnh Đồng Nai_huyen hon quan_phuong hung chien
# 8282        Tỉnh Đồng Nai_huyen hon quan_phuong phu duc
# 8422    Tỉnh Đồng Nai_huyen phu rieng_phuong long phuoc
# 8423    Tỉnh Đồng Nai_huyen phu rieng_phuong phuoc binh
# 8594         Thành phố Hồ Chí Minh_quan 8_xa an phu tay
# 8605          Thành phố Hồ Chí Minh_quan 8_xa phong phu
# 8606          Thành phố Hồ Chí Minh_quan 8_xa binh hung
# 8898      Thành phố Hồ Chí Minh_quan 8_thi tran tan tuc
# 8899           Thành phố Hồ Chí Minh_quan 8_xa tan nhut
# 8900      Thành phố Hồ Chí Minh_quan 8_phuong tan tao a
# 8901           Thành phố Hồ Chí Minh_quan 8_xa tan kien
#
#      keyNewProvinceDistrict                       keyNewProvinceWard
# 152                     NaN           Thủ đô Hà Nội_phuong thach ban
# 209                     NaN             Thủ đô Hà Nội_phuong tay tuu
# 210                     NaN                 Thủ đô Hà Nội_xa tan lap
# 226                     NaN          Thủ đô Hà Nội_phuong hoang liet
# 315                     NaN                 Thủ đô Hà Nội_xa van khe
# 316                     NaN                 Thủ đô Hà Nội_xa me linh
# 317                     NaN               Thủ đô Hà Nội_xa dai thinh
# 501                     NaN             Thủ đô Hà Nội_phuong tay tuu
# 531                     NaN                Thủ đô Hà Nội_xa dai mach
# 532                     NaN                  Thủ đô Hà Nội_xa kim no
# 639                     NaN         Thủ đô Hà Nội_phuong phuong canh
# 640                     NaN         Thủ đô Hà Nội_phuong xuan phuong
# 641                     NaN              Thủ đô Hà Nội_phuong dai mo
# 642                     NaN              Thủ đô Hà Nội_phuong tay mo
# 643                     NaN                Thủ đô Hà Nội_xa van canh
# 1266                    NaN         Thành phố Hải Phòng_xa thanh hai
# 1487                    NaN  Thành phố Hải Phòng_thi tran truong son
# 1880                    NaN       Tỉnh Hưng Yên_phuong le hong phong
# 1881                    NaN            Tỉnh Hưng Yên_phuong bo xuyen
# 1882                    NaN          Tỉnh Hưng Yên_phuong tien phong
# 1974                    NaN           Tỉnh Hưng Yên_phuong phu khanh
# 7533                    NaN             Tỉnh Đắk Lắk_phuong phu dong
# 7534                    NaN              Tỉnh Đắk Lắk_phuong phu lam
# 7535                    NaN            Tỉnh Đắk Lắk_phuong phu thanh
# 7598                    NaN                    Tỉnh Đắk Lắk_phuong 1
# 7599                    NaN                    Tỉnh Đắk Lắk_phuong 2
# 7600                    NaN                    Tỉnh Đắk Lắk_phuong 4
# 7601                    NaN                    Tỉnh Đắk Lắk_phuong 5
# 7602                    NaN                    Tỉnh Đắk Lắk_phuong 7
# 7603                    NaN                    Tỉnh Đắk Lắk_phuong 9
# 8066                    NaN                   Tỉnh Tây Ninh_phuong 4
# 8067                    NaN                   Tỉnh Tây Ninh_phuong 5
# 8068                    NaN                   Tỉnh Tây Ninh_phuong 6
# 8069                    NaN           Tỉnh Tây Ninh_xa huong tho phu
# 8183                    NaN                 Tỉnh Tây Ninh_xa mo cong
# 8184                    NaN                Tỉnh Tây Ninh_xa tra vong
# 8185                    NaN               Tỉnh Tây Ninh_xa tan phong
# 8280                    NaN              Tỉnh Đồng Nai_phuong an loc
# 8281                    NaN          Tỉnh Đồng Nai_phuong hung chien
# 8282                    NaN             Tỉnh Đồng Nai_phuong phu duc
# 8422                    NaN          Tỉnh Đồng Nai_phuong long phuoc
# 8423                    NaN          Tỉnh Đồng Nai_phuong phuoc binh
# 8594                    NaN      Thành phố Hồ Chí Minh_xa an phu tay
# 8605                    NaN       Thành phố Hồ Chí Minh_xa phong phu
# 8606                    NaN       Thành phố Hồ Chí Minh_xa binh hung
# 8898                    NaN   Thành phố Hồ Chí Minh_thi tran tan tuc
# 8899                    NaN        Thành phố Hồ Chí Minh_xa tan nhut
# 8900                    NaN   Thành phố Hồ Chí Minh_phuong tan tao a
# 8901                    NaN        Thành phố Hồ Chí Minh_xa tan kien
#
# [49 rows x 21 columns]

# %%
if not (sapnhap1.shape[0] + sapnhap2.shape[0] + sapnhap3.shape[0] + sapnhap4a.shape[0] + sapnhap4b.shape[0]) == df_sapnhap_ward.shape[0]:
    raise Exception('Chia tệp chưa MECE')

# %% [markdown]
# ## Tiến hành merge

# %%
df_convert1 = pd.merge(df_danhmuc, sapnhap1, on=['newProvince', 'province', 'districtUd', 'wardUd'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert2 = pd.merge(df_danhmuc, sapnhap2, on=['newProvince', 'districtUd', 'wardUd'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert3 = pd.merge(df_danhmuc, sapnhap3, on=['newProvince', 'districtUd'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert4a = pd.merge(df_danhmuc, sapnhap4a, on=['newProvince', 'wardUd'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert4b = pd.merge(df_danhmuc, sapnhap4b, on=['newProvince', 'wardUd'], how='inner', suffixes=('', '_DUPLICATED'))

# %%
print(df_convert1.shape[0], sapnhap1.shape[0])
print(df_convert2.shape[0], sapnhap2.shape[0])
print(df_convert3.shape[0], sapnhap3.shape[0])
print(df_convert4a.shape[0], sapnhap4a.shape[0])
print(df_convert4b.shape[0], sapnhap4b.shape[0])
# Out:
# 2 2
# 888 887
# 9 6
# 9735 9487
# 50 49

# %%
df_convert = pd.concat([df_convert1, df_convert2, df_convert3, df_convert4a, df_convert4b], ignore_index=True).drop_duplicates()
df_convert.drop(columns=[col for col in df_convert.columns if '_DUPLICATED' in col or 'key' in col], inplace=True)
df_convert.drop_duplicates(inplace=True)

# %%
df_convert
# Out:
#        districtCode  provinceCode districtType           district  \
# 0               831            83        Huyện   Huyện Châu Thành
# 1               847            84        Huyện   Huyện Châu Thành
# 2                 6             1         Quận       Quận Đống Đa
# 3                 6             1         Quận       Quận Đống Đa
# 4                 7             1         Quận  Quận Hai Bà Trưng
# ...             ...           ...          ...                ...
# 10679           785            79        Huyện   Huyện Bình Chánh
# 10680           794            80    Thành phố   Thành phố Tân An
# 10681           794            80    Thành phố   Thành phố Tân An
# 10682           794            80    Thành phố   Thành phố Tân An
# 10683           794            80    Thành phố   Thành phố Tân An
#
#                     province  wardCode  wardType                 ward  \
# 0               Tỉnh Bến Tre   28810.0  Thị trấn  Thị trấn Châu Thành
# 1              Tỉnh Trà Vinh   29374.0  Thị trấn  Thị trấn Châu Thành
# 2           Thành phố Hà Nội     214.0    Phường   Phường Quang Trung
# 3           Thành phố Hà Nội     235.0    Phường   Phường Thịnh Quang
# 4           Thành phố Hà Nội     277.0    Phường     Phường Bách Khoa
# ...                      ...       ...       ...                  ...
# 10679  Thành phố Hồ Chí Minh   27625.0        Xã        Xã An Phú Tây
# 10680           Tỉnh Long An   27685.0    Phường             Phường 5
# 10681           Tỉnh Long An   27691.0    Phường             Phường 4
# 10682           Tỉnh Long An   27700.0    Phường             Phường 6
# 10683           Tỉnh Long An   27703.0        Xã     Xã Hướng Thọ Phú
#
#        newProvinceCode            newProvince  ...            wardLower  \
# 0                   30         Tỉnh Vĩnh Long  ...  thị trấn châu thành
# 1                   30         Tỉnh Vĩnh Long  ...  thị trấn châu thành
# 2                    1          Thủ đô Hà Nội  ...   phường quang trung
# 3                    1          Thủ đô Hà Nội  ...   phường thịnh quang
# 4                    1          Thủ đô Hà Nội  ...     phường bách khoa
# ...                ...                    ...  ...                  ...
# 10679               29  Thành phố Hồ Chí Minh  ...        xã an phú tây
# 10680               27          Tỉnh Tây Ninh  ...             phường 5
# 10681               27          Tỉnh Tây Ninh  ...             phường 4
# 10682               27          Tỉnh Tây Ninh  ...             phường 6
# 10683               27          Tỉnh Tây Ninh  ...     xã hướng thọ phú
#
#       isMergedWard isDividedWard      newWard newWardCode  newWardType  \
# 0             True         False      Phú Túc        2587           xã
# 1             True         False  Châu Thành        2645           xã
# 2             True         False      Đống Đa         922       phường
# 3             True         False      Đống Đa         922       phường
# 4             True         False     Bạch Mai         967       phường
# ...            ...           ...          ...         ...          ...
# 10679         True         False    Bình Đông         205       phường
# 10680         True         False      Long An        1109       phường
# 10681         True         False      Long An        1109       phường
# 10682         True         False      Long An        1109       phường
# 10683         True         False      Long An        1109       phường
#
#        newWardLon newWardLat  newWardAreaKm2  \
# 0         106.318   10.30100           63.14
# 1         106.337    9.83937           47.71
# 2         105.822   21.01190            2.07
# 3         105.822   21.01190            2.07
# 4         105.852   21.00220            2.95
# ...           ...        ...             ...
# 10679     106.612   10.70120            8.93
# 10680     106.405   10.54760           34.90
# 10681     106.405   10.54760           34.90
# 10682     106.405   10.54760           34.90
# 10683     106.405   10.54760           34.90
#
#                                             truocsapnhap
# 0      Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...
# 1      Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...
# 2                      Phường Quang Trung (quận Đống Đa)
# 3                      Phường Thịnh Quang (quận Đống Đa)
# 4                   Phường Bách Khoa (quận Hai Bà Trưng)
# ...                                                  ...
# 10679                            Xã An Phú Tây (Quận 8)
# 10680                       Phường 5 (huyện Thủ Thừa)
# 10681                       Phường 4 (huyện Thủ Thừa)
# 10682                       Phường 6 (huyện Thủ Thừa)
# 10683               Xã Hướng Thọ Phú (huyện Thủ Thừa)
#
# [10684 rows x 24 columns]

# %%
df_convert[df_convert['wardUd'].fillna('').str.contains('phuong 15') & df_convert['districtUd'].fillna('').str.contains('tan binh')]
# Out:
#      districtCode  provinceCode districtType       district  \
# 586           766            79         Quận  Quận Tân Bình
# 587           766            79         Quận  Quận Tân Bình
#
#                   province  wardCode wardType       ward  newProvinceCode  \
# 586  Thành phố Hồ Chí Minh   27007.0   Phường  Phường 15               29
# 587  Thành phố Hồ Chí Minh   27007.0   Phường  Phường 15               29
#
#                newProvince  ...  wardLower isMergedWard isDividedWard  \
# 586  Thành phố Hồ Chí Minh  ...  phường 15         True          True
# 587  Thành phố Hồ Chí Minh  ...  phường 15         True          True
#
#       newWard newWardCode  newWardType  newWardLon newWardLat  newWardAreaKm2  \
# 586  Tân Bình         104       phường     106.642    10.8006            2.12
# 587   Tân Sơn         106       phường     106.650    10.8224           10.12
#
#                   truocsapnhap
# 586  Phường 15 (quận Tân Bình)
# 587  Phường 15 (quận Tân Bình)
#
# [2 rows x 24 columns]

# %%
df_convert_full = pd.merge(df_danhmuc, df_convert, on=['newProvince', 'province', 'districtUd', 'wardUd'], how='left', suffixes=('', '_DUPLICATED')).drop_duplicates()
df_convert_full .drop(columns=[col for col in df_convert_full.columns if '_DUPLICATED' in col or 'key' in col], inplace=True)
df_convert_full.drop_duplicates(inplace=True)

# %%
df_convert_full
# Out:
#        districtCode  provinceCode districtType         district  \
# 0                 1             1         Quận     Quận Ba Đình
# 1                 1             1         Quận     Quận Ba Đình
# 2                 1             1         Quận     Quận Ba Đình
# 3                 1             1         Quận     Quận Ba Đình
# 4                 1             1         Quận     Quận Ba Đình
# ...             ...           ...          ...              ...
# 10775           973            96        Huyện  Huyện Ngọc Hiển
# 10776           973            96        Huyện  Huyện Ngọc Hiển
# 10777           973            96        Huyện  Huyện Ngọc Hiển
# 10778           973            96        Huyện  Huyện Ngọc Hiển
# 10779           973            96        Huyện  Huyện Ngọc Hiển
#
#                province  wardCode  wardType               ward  \
# 0      Thành phố Hà Nội       1.0    Phường     Phường Phúc Xá
# 1      Thành phố Hà Nội       4.0    Phường   Phường Trúc Bạch
# 2      Thành phố Hà Nội       6.0    Phường   Phường Vĩnh Phúc
# 3      Thành phố Hà Nội       7.0    Phường     Phường Cống Vị
# 4      Thành phố Hà Nội       7.0    Phường     Phường Cống Vị
# ...                 ...       ...       ...                ...
# 10775       Tỉnh Cà Mau   32242.0        Xã         Xã Viên An
# 10776       Tỉnh Cà Mau   32244.0  Thị trấn  Thị trấn Rạch Gốc
# 10777       Tỉnh Cà Mau   32245.0        Xã          Xã Tân Ân
# 10778       Tỉnh Cà Mau   32245.0        Xã          Xã Tân Ân
# 10779       Tỉnh Cà Mau   32248.0        Xã         Xã Đất Mũi
#
#        newProvinceCode    newProvince  ...          wardLower isMergedWard  \
# 0                    1  Thủ đô Hà Nội  ...     phường phúc xá         True
# 1                    1  Thủ đô Hà Nội  ...   phường trúc bạch         True
# 2                    1  Thủ đô Hà Nội  ...   phường vĩnh phúc         True
# 3                    1  Thủ đô Hà Nội  ...     phường cống vị         True
# 4                    1  Thủ đô Hà Nội  ...     phường cống vị         True
# ...                ...            ...  ...                ...          ...
# 10775               34    Tỉnh Cà Mau  ...         xã viên an         True
# 10776               34    Tỉnh Cà Mau  ...  thị trấn rạch gốc         True
# 10777               34    Tỉnh Cà Mau  ...          xã tân ân         True
# 10778               34    Tỉnh Cà Mau  ...          xã tân ân         True
# 10779               34    Tỉnh Cà Mau  ...         xã đất mũi         True
#
#       isDividedWard           newWard newWardCode newWardType newWardLon  \
# 0             False           Hồng Hà      1147.0      phường    105.845
# 1             False           Ba Đình       994.0      phường    105.838
# 2             False           Ngọc Hà       942.0      phường    105.816
# 3              True          Giảng Võ       966.0      phường    105.814
# 4              True           Ngọc Hà       942.0      phường    105.816
# ...             ...               ...         ...         ...        ...
# 10775          True         Đất Mũi       230.0          xã    104.820
# 10776         False  Phan Ngọc Hiển       229.0          xã    104.943
# 10777          True         Đất Mũi       230.0          xã    104.820
# 10778          True  Phan Ngọc Hiển       229.0          xã    104.943
# 10779         False         Đất Mũi       230.0          xã    104.820
#
#       newWardLat  newWardAreaKm2       truocsapnhap
# 0       21.05670           15.09     Phường Phúc Xá
# 1       21.03860            2.97   Phường Trúc Bạch
# 2       21.03810            2.68   Phường Vĩnh Phúc
# 3       21.02750            2.60     Phường Cống Vị
# 4       21.03810            2.68     Phường Cống Vị
# ...          ...             ...                ...
# 10775    8.63765          271.20         Xã Viên An
# 10776    8.64616          237.70  Thị trấn Rạch Gốc
# 10777    8.63765          271.20          Xã Tân Ân
# 10778    8.64616          237.70          Xã Tân Ân
# 10779    8.63765          271.20         Xã Đất Mũi
#
# [10692 rows x 24 columns]

# %%
df_convert_full[df_convert_full['newWard'].isna()]
# Out:
#        districtCode  provinceCode districtType              district  \
# 850              34             2        Huyện       Huyện Bắc Quang
# 1251             75             8        Huyện         Huyện Yên Sơn
# 8012            662            67        Huyện          Huyện Cư Jút
# 8045            665            67        Huyện        Huyện Đăk Song
# 8137            678            68        Huyện       Huyện Đức Trọng
# 8565            732            75    Thành phố  Thành phố Long Khánh
# 8566            732            75    Thành phố  Thành phố Long Khánh
# 10709           968            96        Huyện   Huyện Trần Văn Thời
#
#                province  wardCode wardType                   ward  \
# 850       Tỉnh Hà Giang    1174.0       Xã         Xã Thượng Bình
# 1251   Tỉnh Tuyên Quang    2488.0       Xã           Xã Trung Môn
# 8012      Tỉnh Đăk Nông   24652.0       Xã           Xã Đăk DRông
# 8045      Tỉnh Đăk Nông   24727.0       Xã          Xã Đăk N'Dung
# 8137      Tỉnh Lâm Đồng   24973.0       Xã           Xã N'Thol Hạ
# 8565      Tỉnh Đồng Nai   26083.0   Phường        Phường Xuân Hòa
# 8566      Tỉnh Đồng Nai   26086.0   Phường        Phường Phú Bình
# 10709       Tỉnh Cà Mau   32101.0       Xã  Xã Khánh Bình Tây Bắc
#
#        newProvinceCode       newProvince  ...              wardLower  \
# 850                  8  Tỉnh Tuyên Quang  ...         xã thượng bình
# 1251                 8  Tỉnh Tuyên Quang  ...           xã trung môn
# 8012                26     Tỉnh Lâm Đồng  ...           xã đăk drông
# 8045                26     Tỉnh Lâm Đồng  ...          xã đăk n'dung
# 8137                26     Tỉnh Lâm Đồng  ...           xã n'thol hạ
# 8565                28     Tỉnh Đồng Nai  ...        phường xuân hòa
# 8566                28     Tỉnh Đồng Nai  ...        phường phú bình
# 10709               34       Tỉnh Cà Mau  ...  xã khánh bình tây bắc
#
#       isMergedWard isDividedWard newWard newWardCode newWardType newWardLon  \
# 850            NaN           NaN     NaN         NaN         NaN        NaN
# 1251           NaN           NaN     NaN         NaN         NaN        NaN
# 8012           NaN           NaN     NaN         NaN         NaN        NaN
# 8045           NaN           NaN     NaN         NaN         NaN        NaN
# 8137           NaN           NaN     NaN         NaN         NaN        NaN
# 8565           NaN           NaN     NaN         NaN         NaN        NaN
# 8566           NaN           NaN     NaN         NaN         NaN        NaN
# 10709          NaN           NaN     NaN         NaN         NaN        NaN
#
#       newWardLat  newWardAreaKm2 truocsapnhap
# 850          NaN             NaN          NaN
# 1251         NaN             NaN          NaN
# 8012         NaN             NaN          NaN
# 8045         NaN             NaN          NaN
# 8137         NaN             NaN          NaN
# 8565         NaN             NaN          NaN
# 8566         NaN             NaN          NaN
# 10709        NaN             NaN          NaN
#
# [8 rows x 24 columns]

# %%
not_exist = [
    'Xã Thượng Bình',
    'Xã Trung Môn'
             ]
exist = [
    "Xã Mi Hòa", # "Xã Mỹ Hòa" hay "Xã Mỵ Hòa" đây
    "Xã Ea D'Rơng", # "Xã Ea Drơng" có luôn
    "Phường Xuân Hoà" # " Xã Xuân Hòa"
    "Phường Phú Bình" # "Xã Phú Bình"
    "Xã Khánh Bình Tây Bắc" # "Xã Khánh Bình Tây Bắc" có luôn
]

# %%
df_sapnhap_ward[df_sapnhap_ward['wardUd'].fillna('').str.contains('ea drong')]
# Out:
#      province district         ward  isMergedWard  isDividedWard    newWard  \
# 7364      NaN      NaN  Xã Ea Drơng          True          False  Cuôr Đăng
# 7402      NaN      NaN  Xã Ea Drông          True          False   Ea Drông
#
#        newProvince  newWardCode newWardType  newWardLon  ...  newWardAreaKm2  \
# 7364  Tỉnh Đắk Lắk         2990          xã     108.168  ...          102.84
# 7402  Tỉnh Đắk Lắk         2993          xã     108.321  ...          111.13
#
#       truocsapnhap districtUd districtLower       wardUd    wardLower  \
# 7364   Xã Ea Drơng        NaN           NaN  xa ea drong  xã ea drơng
# 7402   Xã Ea Drông        NaN           NaN  xa ea drong  xã ea drông
#
#      keyNewProvinceProvinceDistrictWard keyNewProvinceDistrictWard  \
# 7364                                NaN                        NaN
# 7402                                NaN                        NaN
#
#      keyNewProvinceDistrict        keyNewProvinceWard
# 7364                    NaN  Tỉnh Đắk Lắk_xa ea drong
# 7402                    NaN  Tỉnh Đắk Lắk_xa ea drong
#
# [2 rows x 21 columns]

# %%
df_danhmuc[df_danhmuc['wardUd'].fillna('').str.contains('ea d rong')]
# Out:
# Empty DataFrame
# Columns: [districtCode, provinceCode, districtType, district, province, wardCode, wardType, ward, newProvinceCode, newProvince, isMergedProvince, districtUd, districtLower, wardUd, wardLower, keyNewProvinceProvinceDistrictWard, keyNewProvinceDistrictWard, keyNewProvinceDistrict, keyNewProvinceWard]
# Index: []
