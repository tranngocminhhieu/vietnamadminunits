# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from unidecode import unidecode
import re
import unicodedata

# %%
def fill_district(truocsapnhap):
    parts = truocsapnhap.split(', ')
    current_district = None
    filled = []

    # Loop từ phải qua trái
    for part in reversed(parts):
        # Tìm district trong ngoặc
        m = re.search(r'\((.*?)\)', part)
        if m:
            current_district = m.group(1)
        # Nếu chưa có district thì bỏ qua
        if current_district:
            # Bỏ ngoặc cũ nếu có
            part = re.sub(r'\(.*?\)', '', part).strip()
            part = f"{part} ({current_district})"
        filled.append(part)

    # Đảo lại đúng thứ tự ban đầu
    filled = list(reversed(filled))
    return ', '.join(filled)

def extract_district(truocsapnhap):
    unit = truocsapnhap.split(' (')
    district = np.nan
    if len(unit) > 1:
        district = unit[1][:-1]
        if ' - Tỉnh ' in district:
            district = district.split(' - Tỉnh ')[0]
    return district

def extract_province(truocsapnhap):
    unit = truocsapnhap.split(' (')
    province = np.nan
    if len(unit) > 1:
        district = unit[1][:-1]
        if ' - Tỉnh ' in district:
            province = district.split(' - ')[1]
    return province

def extract_ward(truocsapnhap):
    unit = truocsapnhap.split(' (')
    ward = unit[0]
    return ward

def cap_first(text):
    if isinstance(text, str):
        split_text = text.split()
        split_text = [i[0].capitalize() + i[1:] if split_text.index(i)==0 else i for i in split_text]
        return ' '.join(split_text)
    return np.nan

def title_safely(text):
    if isinstance(text, str):
        split_text = text.split()
        split_text = [i[0].capitalize() + i[1:] for i in split_text]
        text = ' '.join(split_text)
        split_text = text.split("'")
        split_text = [i[0].capitalize() + i[1:] for i in split_text]
        return "'".join(split_text)
    return np.nan

def lower_safely(text):
    if isinstance(text, str):
        return text.lower()
    return np.nan

def normalize_quotes(text):
    if isinstance(text, str):
        return text.replace("’", "'").replace("‘", "'").replace("“", '"').replace("”", '"')
    return np.nan

def unidecode_pro(text):
    if isinstance(text, str):
        text = unidecode(text)
        text = re.sub(r'[^a-zA-Z0-9]+', ' ', text)  # chỉ giữ a-z, A-Z, 0-9, thay phần còn lại bằng khoảng trắng
        text = re.sub(r'\s+', ' ', text)
        return text.strip().lower()
    return np.nan

def unicode_normalize(text):
    '''
    Chuyển Unicode tổ hợp sang Unicode dựng sẵn
    :param text:
    :return:
    '''
    if isinstance(text, str):
        text = unicodedata.normalize('NFC', text)
        text = normalize_quotes(text).strip()
        return text
    return np.nan

# %%
title_safely('ha nOi')
# Out:
# 'Ha NOi'

# %%
title_safely("Thị Trấn Ea T'ling")
# Out:
# "Thị Trấn Ea T'Ling"

# %%
unicode_normalize("Cư K’nia")
# Out:
# "Cư K'nia"

# %% [markdown]
# # Chuẩn bị danh mục

# %%
df_danhmuc_district = pd.read_csv('data/danhmuchanhchinh.gso.gov.vn_district_2025-07-18.csv')

# %%
df_danhmuc_ward = pd.read_csv('data/danhmuchanhchinh.gso.gov.vn_2025-07-18.csv')

# %%
rename_cols = {
    'Mã': 'wardCode',
    'Mã QH': 'districtCode',
    'Mã TP': 'provinceCode',
    'Cấp': 'wardType',
    'Tên': 'ward',
    'Quận Huyện': 'district',
    'Tỉnh / Thành Phố': 'province'
}
df_danhmuc_ward = df_danhmuc_ward.rename(columns=rename_cols)[rename_cols.values()]

# %%
rename_cols = {
    'Mã': 'districtCode',
    'Mã TP': 'provinceCode',
    'Cấp': 'districtType',
    'Tên': 'district',
    'Tỉnh / Thành Phố': 'province'
}

df_danhmuc_district = df_danhmuc_district.rename(columns=rename_cols)[rename_cols.values()]

# %%
df_danhmuc_ward.shape
# Out:
# (10035, 7)

# %%
df_danhmuc_district.shape
# Out:
# (696, 5)

# %%
common = list(set(df_danhmuc_ward.columns.tolist()) & set(df_danhmuc_district.columns.tolist()))
df_danhmuc = pd.merge(df_danhmuc_district, df_danhmuc_ward, on=common, how='left')

# %%
df_danhmuc
# Out:
#        districtCode  provinceCode districtType         district  \
# 0                 1             1         Quận     Quận Ba Đình
# 1                 1             1         Quận     Quận Ba Đình
# 2                 1             1         Quận     Quận Ba Đình
# 3                 1             1         Quận     Quận Ba Đình
# 4                 1             1         Quận     Quận Ba Đình
# ...             ...           ...          ...              ...
# 10035           973            96        Huyện  Huyện Ngọc Hiển
# 10036           973            96        Huyện  Huyện Ngọc Hiển
# 10037           973            96        Huyện  Huyện Ngọc Hiển
# 10038           973            96        Huyện  Huyện Ngọc Hiển
# 10039           973            96        Huyện  Huyện Ngọc Hiển
#
#                province  wardCode  wardType               ward
# 0      Thành phố Hà Nội       1.0    Phường     Phường Phúc Xá
# 1      Thành phố Hà Nội       4.0    Phường   Phường Trúc Bạch
# 2      Thành phố Hà Nội       6.0    Phường   Phường Vĩnh Phúc
# 3      Thành phố Hà Nội       7.0    Phường     Phường Cống Vị
# 4      Thành phố Hà Nội       8.0    Phường   Phường Liễu Giai
# ...                 ...       ...       ...                ...
# 10035       Tỉnh Cà Mau   32239.0        Xã    Xã Viên An Đông
# 10036       Tỉnh Cà Mau   32242.0        Xã         Xã Viên An
# 10037       Tỉnh Cà Mau   32244.0  Thị trấn  Thị trấn Rạch Gốc
# 10038       Tỉnh Cà Mau   32245.0        Xã          Xã Tân Ân
# 10039       Tỉnh Cà Mau   32248.0        Xã         Xã Đất Mũi
#
# [10040 rows x 8 columns]

# %%
df_danhmuc[df_danhmuc['ward'].isna()]
# Out:
#       districtCode  provinceCode districtType            district  \
# 3582           318            31        Huyện  Huyện Bạch Long Vĩ
# 5794           471            45        Huyện        Huyện Cồn Cỏ
# 5975           498            48        Huyện      Huyện Hoàng Sa
# 6379           536            51        Huyện        Huyện Lý Sơn
# 8196           755            77        Huyện       Huyện Côn Đảo
#
#                     province  wardCode wardType ward
# 3582     Thành phố Hải Phòng       NaN      NaN  NaN
# 5794          Tỉnh Quảng Trị       NaN      NaN  NaN
# 5975       Thành phố Đà Nẵng       NaN      NaN  NaN
# 6379         Tỉnh Quảng Ngãi       NaN      NaN  NaN
# 8196  Tỉnh Bà Rịa - Vũng Tàu       NaN      NaN  NaN

# %% [markdown]
# 5 cái đảo không có ward nên file ward không có.

# %% [markdown]
# # Sáp nhập province

# %%
df_sapnhap_province = pd.read_csv('data/sapnhap.bando.com.vn_province.csv')

# %%
df_sapnhap_province['isMergedProvince'] = np.where(df_sapnhap_province['truocsapnhap']=='không sáp nhập', False, True)

# %%
df_sapnhap_province['truocsapnhap'] = df_sapnhap_province['truocsapnhap'].str.replace(' và ', ', ')
df_sapnhap_province['truocsapnhap'] = df_sapnhap_province['truocsapnhap'].str.split(',\s*')
df_sapnhap_province = df_sapnhap_province.explode('truocsapnhap').reset_index(drop=True)

# %%
df_sapnhap_province['truocsapnhap'] = np.where(df_sapnhap_province['isMergedProvince']==True, df_sapnhap_province['truocsapnhap'], df_sapnhap_province['tentinh'])

# %%
df_sapnhap_province['truocsapnhap'] = df_sapnhap_province['truocsapnhap'].apply(cap_first)
df_sapnhap_province['tentinh'] = df_sapnhap_province['tentinh'].apply(cap_first)

# %%
df_sapnhap_province[~df_sapnhap_province['truocsapnhap'].isin(df_danhmuc['province'])]
# Out:
#     id  mahc                tentinh dientichkm2  dansonguoi    trungtamhc  \
# 0    1     1          Thủ đô Hà Nội    3.359,80   8.718.000    giữ nguyên
# 14  11    12           Tỉnh Phú Thọ    9.361,38   4.022.638  Phú Thọ (cũ)
# 48  29    29  Thành phố Hồ Chí Minh    6.772,59  14.002.598  Tp. HCM (cũ)
#
#      kinhdo     vido   truocsapnhap  \
# 0   105.698  21.0001  Thủ đô Hà Nội
# 14  105.333  20.7065  Tỉnh Hòa Bình
# 48  106.638  10.9926          TPHCM
#
#                                             con  isMergedProvince
# 0                126 ĐVHC (51 phường và 75 xã)             False
# 14                 148 ĐVHC (15 phường, 133 xã)              True
# 48  168 ĐVHC (01 đặc khu, 113 phường, 54 xã)              True

# %%
df_sapnhap_province.loc[df_sapnhap_province['truocsapnhap']=='Thủ đô Hà Nội', 'truocsapnhap'] = 'Thành phố Hà Nội'
df_sapnhap_province.loc[df_sapnhap_province['truocsapnhap']=='TPHCM', 'truocsapnhap'] = 'Thành phố Hồ Chí Minh'
df_sapnhap_province.loc[df_sapnhap_province['truocsapnhap']=='Tỉnh Hòa Bình', 'truocsapnhap'] = 'Tỉnh Hoà Bình'

# %%
rename_cols = {
    'truocsapnhap': 'province',
    'mahc': 'newProvinceCode',
    'tentinh': 'newProvince',
    'isMergedProvince': 'isMergedProvince',
}
df_sapnhap_province = df_sapnhap_province.rename(columns=rename_cols)[rename_cols.values()]

# %%
df_sapnhap_province
# Out:
#              province  newProvinceCode        newProvince  isMergedProvince
# 0    Thành phố Hà Nội                1      Thủ đô Hà Nội             False
# 1       Tỉnh Cao Bằng                7      Tỉnh Cao Bằng             False
# 2       Tỉnh Hà Giang                8   Tỉnh Tuyên Quang              True
# 3    Tỉnh Tuyên Quang                8   Tỉnh Tuyên Quang              True
# 4        Tỉnh Yên Bái                9       Tỉnh Lào Cai              True
# ..                ...              ...                ...               ...
# 58  Thành phố Cần Thơ               33  Thành phố Cần Thơ              True
# 59     Tỉnh Sóc Trăng               33  Thành phố Cần Thơ              True
# 60     Tỉnh Hậu Giang               33  Thành phố Cần Thơ              True
# 61      Tỉnh Bạc Liêu               34        Tỉnh Cà Mau              True
# 62        Tỉnh Cà Mau               34        Tỉnh Cà Mau              True
#
# [63 rows x 4 columns]

# %%
df_danhmuc = pd.merge(df_danhmuc, df_sapnhap_province, on='province', how='left')

# %%
df_danhmuc[df_danhmuc['newProvince'].isna()]
# Out:
# Empty DataFrame
# Columns: [districtCode, provinceCode, districtType, district, province, wardCode, wardType, ward, newProvinceCode, newProvince, isMergedProvince]
# Index: []

# %%
if df_danhmuc['newProvince'].isna().sum():
    raise Exception('Còn sót province')

# %% [markdown]
# # Sáp nhập ward

# %% [markdown]
# ## Unpivot

# %%
df_sapnhap_ward = pd.read_csv('data/sapnhap.bando.com.vn_ward.csv')

# %%
df_sapnhap_ward['maxa'].drop_duplicates()
# Out:
# 0       1290
# 1        994
# 2       1179
# 3        967
# 4       1441
#         ...
# 3316     164
# 3317     168
# 3318     160
# 3319     161
# 3320     151
# Name: maxa, Length: 3312, dtype: int64

# %%
# Preview text trong dấu ngoặc
df_sapnhap_ward[df_sapnhap_ward['truocsapnhap'].str.contains('\(')]['truocsapnhap']
# Out:
# 0       Xã Đông La, Phường Dương Nội (phần còn lại sau...
# 1       Phường Quán Thánh, Phường Trúc Bạch, Phường Cử...
# 2       Xã Ba Vì, Xã Khánh Thượng, Xã Minh Quang (phần...
# 3       Phường Bạch Mai, Phường Bách Khoa, Phường Quỳn...
# 5       Xã Kim Đức, Phường Cự Khối (phần còn lại sau k...
#                               ...
# 3288    Thị trấn U Minh, Xã Nguyễn Phích, Xã Khánh Thu...
# 3299    Thị trấn Sông Đốc (bao gồm cụm đảo Hòn Chuối),...
# 3305    Phường 5 (thành phố Cà Mau), Phường Tân Thành,...
# 3311    Thị trấn Trần Văn Thời, Xã Khánh Lộc, Xã Phong...
# 3320         Phường 5 (thành phố Bạc Liêu), Xã Vĩnh Trạch
# Name: truocsapnhap, Length: 612, dtype: object

# %%
df_sapnhap_ward[df_sapnhap_ward['truocsapnhap'].str.contains('Khánh Bình Tây')]['truocsapnhap']
# Out:
# 3264    Xã Khánh Bình Tây (bao gồm Hòn Đá Bạc), Xã Khá...
# Name: truocsapnhap, dtype: object

# %%
# Remove và replace text
removed_texts = [
    ', Trường bắn TB1',
    ', Khu vực bãi bồi ven biển \(do huyện Kim Sơn quản lý\)',
    '\(phần còn lại.*?\)',
    '\(bao gồm.*?\)',
    '\(một phần.*?\)',
    '\(do huyện.*?\)',
]


replaced_texts = [
    (' và ', ', '),
    ('(thuộc huyện ', '(huyện '),
    ('(huyện Châu Thành, tỉnh Bến Tre)', '(Huyện Châu Thành - Tỉnh Bến Tre)'), # Tạm giữ lại để tính isDividedWard co đúng, Chú ý khi bỏ tỉnh rồi thì merge sẽ bị duplicate Thị trấn Châu Thành, Huyện Châu Thành
    ('(huyện Châu Thành, tỉnh Trà Vinh)', '(Huyện Châu Thành - Tỉnh Trà Vinh)') # Tạm giữ lại để tính isDividedWard co đúng, Chú ý khi bỏ tỉnh rồi thì merge sẽ bị duplicate Thị trấn Châu Thành, Huyện Châu
]

for text in removed_texts:
    df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].str.replace(text, '', regex=True).str.strip()

for old, new in replaced_texts:
    df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].str.replace(old, new, regex=False).str.strip()

# %%
# Thêm isMergedWard
df_sapnhap_ward['isMergedWard'] = np.where(df_sapnhap_ward['truocsapnhap']=='Không sáp nhập', False, True)

# %%
# Unpivot
df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].apply(fill_district)
df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].str.split(',\s*')
df_sapnhap_ward = df_sapnhap_ward.explode('truocsapnhap').reset_index(drop=True)

# %%
df_sapnhap_ward
# Out:
#          id  matinh    ma        tentinh    loai         tenhc        cay  \
# 0         2       1     2  Thủ đô Hà Nội      xã      An Khánh     1.0002
# 1         2       1     2  Thủ đô Hà Nội      xã      An Khánh     1.0002
# 2         2       1     2  Thủ đô Hà Nội      xã      An Khánh     1.0002
# 3         2       1     2  Thủ đô Hà Nội      xã      An Khánh     1.0002
# 4         2       1     2  Thủ đô Hà Nội      xã      An Khánh     1.0002
# ...     ...     ...   ...            ...     ...           ...        ...
# 10562  3353      34  3353    tỉnh Cà Mau      xã  Vĩnh Phước  3291.3353
# 10563  3354      34  3354    tỉnh Cà Mau      xã   Vĩnh Thanh  3291.3354
# 10564  3354      34  3354    tỉnh Cà Mau      xã   Vĩnh Thanh  3291.3354
# 10565  3355      34  3355    tỉnh Cà Mau  phường  Vĩnh Trạch  3291.3355
# 10566  3355      34  3355    tỉnh Cà Mau  phường  Vĩnh Trạch  3291.3355
#
#        dientichkm2 dansonguoi                  trungtamhc   kinhdo      vido  \
# 0            28.69     102136  Thôn Lũng Vân, xã An Khánh  105.708  20.98760
# 1            28.69     102136  Thôn Lũng Vân, xã An Khánh  105.708  20.98760
# 2            28.69     102136  Thôn Lũng Vân, xã An Khánh  105.708  20.98760
# 3            28.69     102136  Thôn Lũng Vân, xã An Khánh  105.708  20.98760
# 4            28.69     102136  Thôn Lũng Vân, xã An Khánh  105.708  20.98760
# ...            ...        ...                         ...      ...       ...
# 10562        75.50      20014               đang cập nhật  105.410   9.39891
# 10563        37.37      19291               đang cập nhật  105.519   9.35997
# 10564        37.37      19291               đang cập nhật  105.519   9.35997
# 10565        10.22      23085               đang cập nhật  105.774   9.29729
# 10566        10.22      23085               đang cập nhật  105.774   9.29729
#
#                         truocsapnhap  maxa            khoa  isMergedWard
# 0                         Xã Đông La  1290       1An Khánh          True
# 1                  Phường Dương Nội   1290       1An Khánh          True
# 2                       Xã An Khánh   1290       1An Khánh          True
# 3                         Xã La Phù   1290       1An Khánh          True
# 4                    Xã Song Phương   1290       1An Khánh          True
# ...                              ...   ...             ...           ...
# 10562                Xã Vĩnh Phú Tây   160  34Vĩnh Phước          True
# 10563                    Xã Hưng Phú   161   34Vĩnh Thanh          True
# 10564                  Xã Vĩnh Thanh   161   34Vĩnh Thanh          True
# 10565  Phường 5 (thành phố Bạc Liêu)   151  34Vĩnh Trạch          True
# 10566                  Xã Vĩnh Trạch   151  34Vĩnh Trạch          True
#
# [10567 rows x 16 columns]

# %%
# Thêm isDividedWard vào df_sapnhap_ward
count_truocsapnhap = df_sapnhap_ward.groupby(['tentinh', 'truocsapnhap'])['truocsapnhap'].count().reset_index(name='count_truocsapnhap')
count_truocsapnhap['isDividedWard'] = np.where(count_truocsapnhap['count_truocsapnhap'] > 1, True, False)
df_sapnhap_ward = pd.merge(df_sapnhap_ward, count_truocsapnhap, on=['tentinh', 'truocsapnhap'], how='left')

# %%
# Viết hoa chữ đầu
df_sapnhap_ward['tentinh'] = df_sapnhap_ward['tentinh'].apply(cap_first)

# %%
# Lúc merge mới biết nên quay lại đây để sửa
df_sapnhap_ward['tentinh'].replace('Tỉnh Ninh BÌnh', 'Tỉnh Ninh Bình', inplace=True)

# %%
# Tách truocsapnhap thành: ward, district, province
df_sapnhap_ward['province'] = df_sapnhap_ward['truocsapnhap'].apply(extract_province)
df_sapnhap_ward['district'] = df_sapnhap_ward['truocsapnhap'].apply(extract_district)
df_sapnhap_ward['ward'] = df_sapnhap_ward['truocsapnhap'].apply(extract_ward)
# Fill ward cũ cho những ward không sáp nhập
df_sapnhap_ward['ward'] = np.where(df_sapnhap_ward['isMergedWard']==False, df_sapnhap_ward['loai'].str.capitalize() + ' ' + df_sapnhap_ward['tenhc'], df_sapnhap_ward['ward'])

# %%
df_sapnhap_ward[df_sapnhap_ward['ward'].str.contains('^Huyện')]
# Out:
#         id  matinh    ma                tentinh     loai         tenhc  \
# 1349  1050       4  1050    Thành phố Hải Phòng  đặc khu  Bạch Long Vĩ
# 5960  1764      19  1764         Tỉnh Quảng Trị  đặc khu        Cồn Cỏ
# 6415  1904      21  1904      Thành phố Đà Nẵng  đặc khu      Hoàng Sa
# 6734  2015      22  2015        Tỉnh Quảng Ngãi  đặc khu        Lý Sơn
# 8807  2741      29  2741  Thành phố Hồ Chí Minh  đặc khu       Côn Đảo
# 9931  3125      32  3125          Tỉnh An Giang  đặc khu      Kiên Hải
#
#             cay  dientichkm2 dansonguoi  \
# 1349  1034.1050         3.07        686
# 5960  1752.1764         2.30        139
# 6415  1872.1904       305.00       9741
# 6734  1967.2015        10.39      22000
# 8807  2687.2741        75.79       6502
# 9931  3084.3125        21.81      17644
#
#                                              trungtamhc  ...      vido  \
# 1349               Trụ sở huyện Bạch Long Vĩ hiện trạng  ...  20.13460
# 5960                         UBND huyện đảo Cồn Cỏ (cũ)  ...  17.15925
# 6415                     Đường Hoàng Sa, phường Sơn Trà  ...  16.56800
# 6734             Trung tâm hành chính huyện Lý Sơn (cũ)  ...  15.38500
# 8807  28 đường Tôn Đức Thắng, huyện Côn Đảo, tỉnh Bà...  ...   8.69810
# 9931          UBND huyện Kiên Hải (xã Hòn Tre hiện nay)  ...   9.80000
#
#             truocsapnhap  maxa           khoa isMergedWard  \
# 1349  Huyện Bạch Long Vĩ  3309  4Bạch Long Vĩ         True
# 5960        Huyện Cồn Cỏ  3310       19Cồn Cỏ         True
# 6415      Huyện Hoàng Sa  3312     21Hoàng Sa         True
# 6734        Huyện Lý Sơn  3314       22Lý Sơn         True
# 8807       Huyện Côn Đảo  3311      29Côn Đảo         True
# 9931      Huyện Kiên Hải  3315     32Kiên Hải         True
#
#       count_truocsapnhap  isDividedWard  province district                ward
# 1349                   1          False       NaN      NaN  Huyện Bạch Long Vĩ
# 5960                   1          False       NaN      NaN        Huyện Cồn Cỏ
# 6415                   1          False       NaN      NaN      Huyện Hoàng Sa
# 6734                   1          False       NaN      NaN        Huyện Lý Sơn
# 8807                   1          False       NaN      NaN       Huyện Côn Đảo
# 9931                   1          False       NaN      NaN      Huyện Kiên Hải
#
# [6 rows x 21 columns]

# %%
# Đem các huyện nằm ở ward qua district
df_sapnhap_ward['district'] = np.where(df_sapnhap_ward['ward'].str.contains('^Huyện'), df_sapnhap_ward['ward'], df_sapnhap_ward['district'])
df_sapnhap_ward['ward'] = np.where(df_sapnhap_ward['ward'].str.contains('^Huyện'), np.nan, df_sapnhap_ward['ward'])

# %%
# Kiểm tra 2 province có Huyện Châu Thành
df_sapnhap_ward[~df_sapnhap_ward['province'].isna()]
# Out:
#         id  matinh    ma         tentinh loai        tenhc        cay  \
# 9222  2880      30  2880  Tỉnh Vĩnh Long   xã  Châu Thành  2856.2880
# 9374  2934      30  2934  Tỉnh Vĩnh Long   xã      Phú Túc  2856.2934
#
#       dientichkm2 dansonguoi             trungtamhc  ...      vido  \
# 9222        47.71      39104          đang cập nhật  ...   9.83937
# 9374        63.14      62073  UBND huyện Châu Thành  ...  10.30100
#
#                                            truocsapnhap  maxa           khoa  \
# 9222  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  2645  30Châu Thành
# 9374  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  2587      30Phú Túc
#
#      isMergedWard  count_truocsapnhap  isDividedWard         province  \
# 9222         True                   1          False  Tỉnh Trà Vinh
# 9374         True                   1          False   Tỉnh Bến Tre
#
#                 district                 ward
# 9222  Huyện Châu Thành  Thị trấn Châu Thành
# 9374  Huyện Châu Thành  Thị trấn Châu Thành
#
# [2 rows x 21 columns]

# %%
# Rename cho bước tiếp theo
rename_cols = {
    'province': 'province',
    'district': 'district',
    'ward': 'ward',
    'isMergedWard': 'isMergedWard',
    'isDividedWard': 'isDividedWard',

    'tenhc': 'newWard',
    'tentinh': 'newProvince',
    'ma': 'newWardCode',
    'loai': 'newWardType',
    'kinhdo': 'newWardLon',
    'vido': 'newWardLat',
    'dientichkm2': 'newWardAreaKm2',
    'truocsapnhap': 'truocsapnhap',

}

df_sapnhap_ward = df_sapnhap_ward.rename(columns=rename_cols)[rename_cols.values()]

# %%
df_sapnhap_ward
# Out:
#       province            district               ward  isMergedWard  \
# 0          NaN                 NaN         Xã Đông La          True
# 1          NaN                 NaN  Phường Dương Nội           True
# 2          NaN                 NaN       Xã An Khánh           True
# 3          NaN                 NaN         Xã La Phù           True
# 4          NaN                 NaN    Xã Song Phương           True
# ...        ...                 ...                ...           ...
# 10562      NaN                 NaN    Xã Vĩnh Phú Tây          True
# 10563      NaN                 NaN        Xã Hưng Phú          True
# 10564      NaN                 NaN      Xã Vĩnh Thanh          True
# 10565      NaN  thành phố Bạc Liêu           Phường 5          True
# 10566      NaN                 NaN      Xã Vĩnh Trạch          True
#
#        isDividedWard       newWard    newProvince  newWardCode newWardType  \
# 0              False      An Khánh  Thủ đô Hà Nội            2          xã
# 1              False      An Khánh  Thủ đô Hà Nội            2          xã
# 2              False      An Khánh  Thủ đô Hà Nội            2          xã
# 3              False      An Khánh  Thủ đô Hà Nội            2          xã
# 4              False      An Khánh  Thủ đô Hà Nội            2          xã
# ...              ...           ...            ...          ...         ...
# 10562          False  Vĩnh Phước    Tỉnh Cà Mau         3353          xã
# 10563          False   Vĩnh Thanh    Tỉnh Cà Mau         3354          xã
# 10564          False   Vĩnh Thanh    Tỉnh Cà Mau         3354          xã
# 10565          False  Vĩnh Trạch    Tỉnh Cà Mau         3355      phường
# 10566          False  Vĩnh Trạch    Tỉnh Cà Mau         3355      phường
#
#        newWardLon  newWardLat  newWardAreaKm2                   truocsapnhap
# 0         105.708    20.98760           28.69                     Xã Đông La
# 1         105.708    20.98760           28.69              Phường Dương Nội
# 2         105.708    20.98760           28.69                   Xã An Khánh
# 3         105.708    20.98760           28.69                     Xã La Phù
# 4         105.708    20.98760           28.69                Xã Song Phương
# ...           ...         ...             ...                            ...
# 10562     105.410     9.39891           75.50                Xã Vĩnh Phú Tây
# 10563     105.519     9.35997           37.37                    Xã Hưng Phú
# 10564     105.519     9.35997           37.37                  Xã Vĩnh Thanh
# 10565     105.774     9.29729           10.22  Phường 5 (thành phố Bạc Liêu)
# 10566     105.774     9.29729           10.22                  Xã Vĩnh Trạch
#
# [10567 rows x 13 columns]

# %% [markdown]
# ## Kiểm tra chính tả 2 bên
#
# Vòng lặp kiểm tra như sau:
# - Bước 1: Kiểm tra tìm unit không khớp của bảng df_sapnhap_ward
# - Bước 2: Sửa chính tả ở bảng df_sapnhap_ward hoặc df_danhmuc.
# - Quay lại Bước 1

# %%
def correct_spelling_basic(text):
    spelling_basic = [
        ('Hoà', 'Hòa'),
        ('Hoè', 'Hòe'),
        ('Hoá', 'Hóa'),
        ('Hoả', 'Hỏa'),
        ('Khoá', 'Khóa'),
        ('Thuỵ' ,'Thụy'),
        ('Thuỷ', 'Thủy'),
        ('\' ', "'")
    ]

    if isinstance(text, str):
        for wrong, right in spelling_basic:
            pattern = r'\b' + wrong + r'\b'
            text = re.sub(pattern, right, text)
    return text

# %%
for col in ['province', 'district', 'ward']:
    df_danhmuc[col] = df_danhmuc[col].apply(unicode_normalize)
    df_sapnhap_ward[col] = df_sapnhap_ward[col].apply(unicode_normalize)
    df_danhmuc[col] = df_danhmuc[col].apply(correct_spelling_basic)
    df_sapnhap_ward[col] = df_sapnhap_ward[col].apply(correct_spelling_basic)


spelling_danhmuc = [
    # newProvince, ward, correct ward
    ('Tỉnh Hưng Yên', 'Xã An Quí', 'Xã An Quý'),
    ('Tỉnh Hưng Yên', 'Xã Kim Chung', 'Xã Kim Trung'),
    ('Tỉnh Hưng Yên', 'Xã Vũ Quí', 'Xã Vũ Quý'),
    ('Tỉnh Tuyên Quang', 'Xã Quí Quân', 'Xã Quý Quân'),
    ('Tỉnh Tuyên Quang', 'Xã Sán Xả Hồ', 'Xã Sán Sả Hồ'),
    ('Tỉnh Tuyên Quang', 'Xã Xà Phìn', 'Xã Sà Phìn'),
    ('Tỉnh Tuyên Quang', 'Xã Sủng Tráng', 'Xã Sủng Cháng'),
    ('Tỉnh Lào Cai', 'Xã Hát Lìu', 'Xã Hát Lừu'),
    ('Tỉnh Lào Cai', 'Thị trấn NT Liên Sơn', 'Thị trấn Nông trường Liên Sơn'),
    ('Tỉnh Lào Cai', 'Xã Nậm Rạng', 'Xã Nậm Dạng'),
    ('Tỉnh Thái Nguyên', 'Xã Sĩ Bình', 'Xã Sỹ Bình'),
    ('Tỉnh Lạng Sơn', 'Thị trấn NT Thái Bình', 'Thị trấn Nông trường Thái Bình'),
    ('Tỉnh Phú Thọ', 'Xã Săm Khóe', 'Xã Xăm Khòe'),
    ('Tỉnh Điện Biên', 'Xã Xá Tổng', 'Xã Sá Tổng'),
    ('Tỉnh Điện Biên', 'Xã Huổi Lếnh', 'Xã Huổi Lếch'),
    ('Tỉnh Điện Biên', 'Xã Sáng Nhè', 'Xã Xá Nhè'),
    ('Tỉnh Điện Biên', 'Xã Xín Chải', 'Xã Sín Chải'),
    ('Tỉnh Lai Châu', 'Xã Tông Qua Lìn', 'Xã Tung Qua Lìn'),
    ('Tỉnh Lai Châu', 'Xã Lả Nhì Thàng', 'Xã Lản Nhì Thàng'),
    ('Tỉnh Lai Châu', 'Xã Hua Bun', 'Xã Hua Bum'),
    ('Tỉnh Lai Châu', 'Xã Ma Ly Pho', 'Xã Ma Li Pho'),
    ('Tỉnh Sơn La', 'Xã Pú Pẩu', 'Xã Pú Bẩu'),
    ('Tỉnh Sơn La', 'Xã Noong Lay', 'Xã Nong Lay'),
    ('Tỉnh Nghệ An', 'Phường Thu Thuỷ', 'Phường Thu Thủy'),
    ('Tỉnh Nghệ An', 'Xã Hưng Yên', 'Xã Hưng Yên Nam'),
    ('Tỉnh Quảng Trị', 'Xã Đa Krông', 'Xã Đakrông'),
    ('Tỉnh Quảng Trị', 'Thị trấn NT Lệ Ninh', 'Thị trấn Nông trường Lệ Ninh'),
    ('Tỉnh Quảng Trị', 'Thị trấn NT Việt Trung', 'Thị trấn Nông trường Việt Trung'),
    ('Thành phố Đà Nẵng', 'Xã Bha Lê', 'Xã Bha Lêê'),
    ('Thành phố Đà Nẵng', 'Xã Tà Bhinh', 'Xã Tà Bhing'),
    ('Thành phố Đà Nẵng', 'Xã Mà Cooi', 'Xã Mà Cooih'),
    ('Thành phố Đà Nẵng', 'Thị trấn P Rao', 'Thị Trấn Prao'),
    ('Thành phố Đà Nẵng', 'Xã Laêê', 'Xã La Êê'),
    ('Thành phố Đà Nẵng', 'Xã Zuôich', 'Xã Zuôih'),
    ('Tỉnh Quảng Ngãi', 'Xã Bờ Y', 'Xã Pờ Y'),
    ('Tỉnh Quảng Ngãi', 'Xã Măng Buk', 'Xã Măng Bút'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngọc Yêu', 'Xã Ngọk Yêu'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngọc Lây', 'Xã Ngọk Lây'),
    ('Tỉnh Gia Lai', 'Xã Đăk Roong', 'Xã Đăk Rong'),
    ('Tỉnh Gia Lai', 'Xã H Bông', 'Xã HBông'),
    ('Tỉnh Gia Lai', 'Xã Ia Ma Rơn', 'Xã Ia Mrơn'),
    ('Tỉnh Gia Lai', "Xã K'Dang", 'Xã KDang'),
    ('Tỉnh Gia Lai', "Xã H'Neng", 'Xã Hneng'),
    ('Tỉnh Đắk Lắk', "Xã Ea H'đinh", "Xã Ea H'đing"),
    ('Tỉnh Đắk Lắk', 'Xã Cư K Róa', 'Xã Cư Króa'),
    ('Tỉnh Đắk Lắk', 'Xã Cư Jang', 'Xã Cư Yang'),
    ('Tỉnh Đắk Lắk', 'Xã EaBia', 'Xã Ea Bia'),
    ('Tỉnh Đắk Lắk', 'Xã Ealy', 'Xã Ea Ly'),
    ('Tỉnh Đắk Lắk', 'Xã Cư Ê Wi', 'Xã Cư Êwi'),
    ('Tỉnh Đắk Lắk', "Xã Ea R'Bin", 'Xã Ea Rbin'),
    ('Tỉnh Đắk Lắk', 'Xã EaTrol', 'Xã Ea Trol'),
    ('Tỉnh Đắk Lắk', 'Xã Eachà Rang', 'Xã Ea Chà Rang'),
    ('Tỉnh Lào Cai', 'Thị trấn N.T Phong Hải', 'Thị trấn Nông trường Phong Hải'),
    ('Tỉnh Lào Cai', 'Xã Dế Su Phình', 'Xã Dế Xu Phình'),
    ('Tỉnh Lào Cai', 'Xã Nàn Xín', 'Xã Nàn Sín'),
    ('Tỉnh Lào Cai', 'Thị trấn NT Trần Phú', 'Thị trấn Nông trường Trần Phú'),
    ('Tỉnh Lâm Đồng', 'Xã Đạm Bri', "Xã Đamb'ri"),
    ('Tỉnh Lâm Đồng', "Xã Đắk N'Dung", "Xã Đắk N'Drung"),
    ('Tỉnh Lâm Đồng', "Xã Đắk DRông", "Xã Đắk D'rông"),
    ('Tỉnh Lâm Đồng', 'Xã Thuận Quí', 'Xã Thuận Quý'),
    ('Thành phố Hồ Chí Minh', 'Xã Quy Đức', 'Xã Qui Đức'),
    ('Tỉnh Vĩnh Long', 'Xã An Quy', 'Xã An Qui'),
    ('Tỉnh Vĩnh Long', 'Xã Lục Sỹ Thành', 'Xã Lục Sĩ Thành'),
    ('Tỉnh An Giang', 'Xã Ô Long Vỹ', 'Xã Ô Long Vĩ'),
    ('Thành phố Cần Thơ', 'Xã Hòa Tú II', 'Xã Hòa Tú 2'),
    ('Tỉnh Đắk Lắk', 'Xã EaBar', 'Xã Ea Bar'),
    ('Tỉnh Đắk Lắk', "Xã Ea D'rơng", 'Xã Ea Drơng'),
    ('Thủ đô Hà Nội', 'Phường Phương Liên - Trung Tự', 'Phường Phương Liên Trung Tự'),
    ('Thủ đô Hà Nội', 'Phường Văn Miếu - Quốc Tử Giám', 'Phường Văn Miếu Quốc Tử Giám'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Rơ Ông', 'Xã Đăk Rơ Ông'),
    ('Tỉnh Cao Bằng', 'Xã Phong Nậm', 'Xã Phong Nặm'),
    ('Tỉnh Tuyên Quang', 'Xã Nậm Tỵ', 'Xã Nậm Ty'),
    ('Tỉnh Tuyên Quang', 'Thị trấn Phó Bảng', 'Thị trấn Phố Bảng'),
    ('Tỉnh Tuyên Quang', 'Xã Khau Tinh', 'Xã Khâu Tinh'),
    ('Tỉnh Lào Cai', 'Thị trấn Mù Căng Chải', 'Thị trấn Mù Cang Chải'),
    ('Tỉnh Lào Cai', 'Xã Nậm Chầy', 'Xã Nậm Chày'),
    ('Tỉnh Lào Cai', 'Xã Tả Ngải Chồ', 'Xã Tả Ngài Chồ'),
    ('Tỉnh Thái Nguyên', 'Phường Quán Triều', 'Phường Quan Triều'),
    ('Tỉnh Phú Thọ', 'Xã Mi Hòa', 'Xã Mỵ Hòa'),
    ('Tỉnh Điện Biên', 'Xã Luân Giới', 'Xã Luân Giói'),
    ('Tỉnh Điện Biên', 'Xã Pú Nhi', 'Xã Pu Nhi'),
    ('Tỉnh Điện Biên', 'Xã Noọng Hẹt', 'Xã Noong Hẹt'),
    ('Tỉnh Lai Châu', 'Xã Pa Vệ Sử', 'Xã Pa Vệ Sủ'),
    ('Tỉnh Lai Châu', 'Xã Tà Gia', 'Xã Ta Gia'),
    ('Tỉnh Sơn La', 'Xã Nậm Ét', 'Xã Nặm Ét'),
    ('Tỉnh Sơn La' , 'Xã Nà Ơt', 'Xã Nà Ớt'),
    ('Tỉnh Thanh Hóa', 'Xã Vân Âm', 'Xã Vân Am'),
    ('Tỉnh Thanh Hóa', 'Xã Văn Sơn', 'Xã Vân Sơn'),
    ('Tỉnh Nghệ An', 'Xã Lưỡng Minh', 'Xã Lượng Minh'),
    ('Tỉnh Nghệ An', 'Xã Căm Muộn', 'Xã Cắm Muộn'),
    ('Tỉnh Hà Tĩnh', 'Xã Cỗ Đạm', 'Xã Cổ Đạm'),
    ('Thành phố Đà Nẵng', 'Xã Ka Dăng', 'Xã Kà Dăng'),
    ('Thành phố Đà Nẵng', 'Xã Za Hung', 'Xã Zà Hung'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngok Tem', 'Xã Ngọc Tem'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngok Wang', 'Xã Ngọk Wang'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngok Réo', 'Xã Ngọk Réo'),
    ('Tỉnh Quảng Ngãi', 'Xã Rơ Kơi', 'Xã Rờ Kơi'),
    ('Tỉnh Gia Lai', 'Xã Chư Đăng Ya', 'Xã Chư Đang Ya'),
    ('Tỉnh Gia Lai', 'Xã Chư Krêy', 'Xã Chư Krey'),
    ('Tỉnh Gia Lai', 'Thị trấn Đăk Đoa', 'Thị trấn Đak Đoa'),
    ('Tỉnh Gia Lai', 'Xã Đăk Sơmei', 'Xã Đak Sơmei'),
    ('Tỉnh Gia Lai', 'Xã Ia KRai', 'Xã Ia Krăi'),
    ('Tỉnh Gia Lai', 'Xã Đăk Krong', 'Xã Đak Krong'),
    ('Tỉnh Gia Lai', 'Xã Đăk Djrăng', 'Xã Đak Djrăng'),
    ('Tỉnh Gia Lai', 'Xã Ia Mláh', 'Xã Ia Mlăh'),
    ('Tỉnh Đắk Lắk', 'Xã Cuor Đăng', 'Xã Cuôr Đăng'),
    ('Tỉnh Đắk Lắk', 'Xã ĐLiê Ya', 'Xã Dliê Ya'),
    ('Tỉnh Đắk Lắk', 'Xã Ea KNuec', 'Xã Ea Knuếc'),
    ('Tỉnh Đắk Lắk', "Xã Ea M'DRóh", "Xã Ea M'Droh"),
    ('Tỉnh Đắk Lắk', "Xã Chư KBô", "Xã Chứ Kbô"),
    ('Tỉnh Đắk Lắk', "Thị trấn M'Đrắk", "Thị trấn M'Drắk"),
    ('Tỉnh Đắk Lắk', "Xã Ea Puk", "Xã Ea Púk"),
    ('Tỉnh Lâm Đồng', "Xã Đạ M'Rong", "Xã Đạ M'Rông"),
    ('Tỉnh Lâm Đồng', "Xã Buôn Choah", "Xã Buôn Choáh"),
    ('Tỉnh Lâm Đồng', "Xã Đăk DRông", "Xã Đăk D'rông"),
    ('Tỉnh Đồng Nai', "Xã Dak Lua", "Xã Đắc Lua"),
    ('Tỉnh Vĩnh Long', "Xã Qưới Sơn", "Xã Quới Sơn"),
    ('Tỉnh Vĩnh Long', "Xã Vĩnh Kim", "Xã Vinh Kim"),
    ('Tỉnh An Giang', "Phường Vĩnh Ngươn", "Phường Vĩnh Nguơn"),
    ('Thành phố Cần Thơ', "Thị trấn Thanh An", "Thị trấn Thạnh An"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Xú", "Xã Đăk Xú"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Cấm", "Xã Đăk Cấm"),
    ('Tỉnh Quảng Ngãi', "Thị trấn Đắk Hà", "Thị trấn Đăk Hà"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk La", "Xã Đăk La"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Tơ Lung", "Xã Đăk Tơ Lung"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Kôi", "Xã Đăk Kôi"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Hring", "Xã Đăk Hring"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Mar", "Xã Đăk Mar"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Kroong", "Xã Đăk Kroong"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Môn", "Xã Đăk Môn"),
    ('Tỉnh Quảng Ngãi', "Thị trấn Đắk Glei", "Thị trấn Đăk Glei"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Pék", "Xã Đăk Pék"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Nhoong", "Xã Đăk Nhoong"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Man", "Xã Đăk Man"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Blô", "Xã Đăk Blô"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Pxi", "Xã Đăk Pxi"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Blà", "Xã Đăk Blà"),



    ('Tỉnh Quảng Ngãi', 'Xã Đắk Rơ Wa', 'Xã Đăk Rơ Wa'),
    ('Tỉnh Quảng Ngãi', 'Thị trấn Đắk Rve', 'Thị trấn Đăk Rve'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Pne', 'Xã Đăk Pne'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Na', 'Xã Đăk Na'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Sao', 'Xã Đăk Sao'),
    ('Tỉnh Quảng Ngãi', 'Thị trấn Đắk Tô', 'Thị trấn Đăk Tô'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Tờ Kan', 'Xã Đăk Tờ Kan'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Ui', 'Xã Đăk Ui'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Ang', 'Xã Đăk Ang'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Dục', 'Xã Đăk Dục'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Nông', 'Xã Đăk Nông'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Tờ Re', 'Xã Đăk Tờ Re'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Ruồng', 'Xã Đăk Ruồng'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Trăm', 'Xã Đăk Trăm'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Nên', 'Xã Đăk Nên'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Ring', 'Xã Đăk Ring'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Tăng', 'Xã Đăk Tăng'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Rơ Nga', 'Xã Đăk Rơ Nga'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Kan', 'Xã Đăk Kan'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Hà', 'Xã Đăk Hà'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Choong', 'Xã Đăk Choong'),
    ('Tỉnh Gia Lai', 'Xã Đắk Kơ Ning', 'Xã Đăk Kơ Ning'),
    ('Tỉnh Lâm Đồng', "Xã Đăk R'Moan", "Xã Đắk R'Moan")



]

# Có vẽ các lỗi sai thường là: qui - quy, s - x, \bch - \btr, nt - nong truong, 2 - II, 4 - IV (Số la mã), ngok - ngoc. Sau này sẽ tạo key cho tính năng parse_address

spelling_sapnhap = [
    # newProvince, ward, correct ward
    ('Tỉnh Ninh Bình', 'Phường Tiên Sơn', 'Xã Tiên Sơn'),
    ('Tỉnh Thái Nguyên', 'Xã Đắc Sơn', 'Phường Đắc Sơn'),
    ('Tỉnh Lai Châu', 'Xã Can Hồ', 'Xã Kan Hồ'),
    ('Tỉnh Sơn La', 'Phường Thảo Ngu Yên', 'Phường Thảo Nguyên'),
    ('Tỉnh Sơn La', 'Xã Xí M Vàng', 'Xã Xím Vàng'),
    ('Tỉnh Nghệ An', 'Xã Thu Thủy', 'Phường Thu Thủy'),
    ('Thành phố Huế', 'Phường Đúc', 'Phường Phường Đúc'),
    ('Thành phố Đà Nẵng', 'Xã Bhalêê', 'Xã Bha Lêê'),
    ('Thành phố Đà Nẵng', 'Xã Avương', 'Xã A Vương'),
    ('Thành phố Đà Nẵng', 'Xã Gari', 'Xã Ga Ri'),
    ('Thành phố Đà Nẵng', 'Xã Axan', 'Xã A Xan'),
    ('Thành phố Đà Nẵng', 'Xã Atiêng', 'Xã A Tiêng'),
    ('Thành phố Đà Nẵng', 'Xã Anông', 'Xã A Nông'),
    ('Tỉnh Quảng Ngãi', 'Lê Lợi', 'Phường Lê Lợi'),
    ('Tỉnh Quảng Ngãi', 'Nguyễn Trãi', 'Phường Nguyễn Trãi'),
    ('Tỉnh Quảng Ngãi', 'Xã Đăk Plô', 'Xã Đăk Blô'),
    ('Tỉnh Quảng Ngãi', 'Phổ Hòa', 'Phường Phổ Hòa'),
    ('Tỉnh Quảng Ngãi', 'Phổ Minh', 'Phường Phổ Minh'),
    ('Tỉnh Quảng Ngãi', 'Phổ Vinh', 'Phường Phổ Vinh'),
    ('Tỉnh Quảng Ngãi', 'Phổ Ninh', 'Phường Phổ Ninh'),
    ('Tỉnh Gia Lai', 'Xã Chơ GLong', 'Xã Chơ Long'),
    ('Tỉnh Gia Lai', 'Xã Adơk', 'Xã A Dơk'),
    ('Tỉnh Gia Lai', 'Xã Ia Dreh', 'Ia HDreh'),
    ('Tỉnh Đắk Lắk', 'Krông Na', 'Xã Krông Na'),
    ('Tỉnh Đắk Lắk', 'Xã Cư Dliê Mnông', "Xã Cư Dliê M'nông"),
    ('Tỉnh Lâm Đồng', 'Xã ĐamBri', "Xã Đamb'ri"),
    ('Tỉnh Lâm Đồng', "Xã Cư K'nia", 'Xã Cư Knia'),
    ('Tỉnh Lâm Đồng', 'Thị trấn Mađaguôi', 'Thị trấn Ma Đa Guôi'),
    ('Tỉnh Lâm Đồng', 'Xã Mađaguôi', 'Xã Ma Đa Guôi'),
    ('Tỉnh Lào Cai', 'Xã Tà Xi Láng', 'Xã Tà Si Láng'),
    ('Tỉnh Gia Lai', 'Ia HDreh', 'Xã Ia HDreh'),
    ('Tỉnh Lâm Đồng', "Xã Đưng K'Nớ", 'Xã Đưng KNớ'),
    ('Tỉnh Lâm Đồng', "Xã N'Thôn Hạ", "Xã N'Thol Hạ"),
    ('Tỉnh Tây Ninh', 'Thủ Thừa', 'Thị trấn Thủ Thừa'),
    ('Tỉnh Tây Ninh', 'Phường IV', 'Phường 4'),
    ('Tỉnh Đồng Nai', 'Xã Xuân An', 'Phường Xuân An'),
    ('Tỉnh Đồng Nai', 'Xã Xuân Bình', 'Phường Xuân Bình'),
    ('Thành phố Hồ Chí Minh', 'Rạch Ông', 'Phường Rạch Ông'),
    ('Tỉnh Đồng Tháp', 'Xã Mỹ Quí', 'Xã Mỹ Quý'),
    ('Thành phố Cần Thơ', 'Xã Tân Lộc', 'Phường Tân Lộc'),
    ('Tỉnh Lào Cai', 'Xã Thẳm Dương', 'Xã Thẩm Dương'),
    ('Tỉnh Sơn La', 'Xã Nặm Păm', 'Xã Nậm Păm'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngọk Tem', 'Xã Ngọc Tem'),
    ('Tỉnh Gia Lai', 'Xã Ia Drang', 'Xã Ia Drăng'),
    ('Tỉnh Gia Lai', 'Xã Đak Rong', 'Xã Đăk Rong'),
    ('Tỉnh Gia Lai', 'Xã Ia Krái', 'Xã Ia Krăi'),
    ('Tỉnh Gia Lai', 'Xã Ia Trôk', 'Xã Ia Trok'),
    ('Tỉnh Gia Lai', 'Xã Đak Trôi', 'Xã Đăk Trôi'),
    ('Tỉnh Gia Lai', 'Xã Ia Mlah', 'Xã Ia Mlăh'),
    ('Tỉnh Đắk Lắk', 'Xã Ea Khăl', 'Xã Ea Khal'),
    ('Tỉnh Đồng Nai', "Xã Đak Lua", "Xã Đắc Lua"),
    ('Tỉnh Đồng Nai', "Xã Đăk Ơ", "Xã Đak Ơ"),




]


for s in spelling_danhmuc:
    newProvince, ward, WardCorrect = s
    df_danhmuc.loc[(df_danhmuc['newProvince']==newProvince) & (df_danhmuc['ward'].fillna('').str.lower()==ward.lower()), 'ward'] = WardCorrect

for s in spelling_sapnhap:
    newProvince, ward, WardCorrect = s
    df_sapnhap_ward.loc[(df_sapnhap_ward['newProvince']==newProvince) & (df_sapnhap_ward['ward'].fillna('').str.lower()==ward.lower()), 'ward'] = WardCorrect

# %%
# Case đặc biệt, phải JOIN vào rồi mới thấy thiếu
df_sapnhap_ward.loc[(df_sapnhap_ward['newProvince']=='Tỉnh Đồng Nai') & (df_sapnhap_ward['newWard']=='Long Khánh') & (df_sapnhap_ward['ward']=='Xã Xuân Hòa'), 'ward'] = 'Phường Xuân Hòa'
df_sapnhap_ward.loc[(df_sapnhap_ward['newProvince']=='Tỉnh Đồng Nai') & (df_sapnhap_ward['newWard']=='Long Khánh') & (df_sapnhap_ward['ward']=='Xã Phú Bình'), 'ward'] = 'Phường Phú Bình'

# %%
for col in ['district', 'ward']:
    df_danhmuc[f'{col}Ud'] = df_danhmuc[col].apply(unidecode_pro)
    df_sapnhap_ward[f'{col}Ud'] = df_sapnhap_ward[col].apply(unidecode_pro)

    df_danhmuc[f'{col}Lower'] = df_danhmuc[col].apply(lower_safely)
    df_sapnhap_ward[f'{col}Lower'] = df_sapnhap_ward[col].apply(lower_safely)

# %%
key1 = 'keyNewProvinceProvinceDistrictWard' # Đặc biệt, chỉ có 2 province ^_^
key2 = 'keyNewProvinceDistrictWard' # Trường hợp này sẽ sai nhiều vì dùng fill_district chưa chắc đúng. Cứ kiểm tra chính tả cho key3 key4 thôi là được. Sau đó khi merge bằng key2 phần nào không match chính là key4b
key3 = 'keyNewProvinceDistrict'
key4 = 'keyNewProvinceWard' # key4a


# # Mục đích để check chính tả sẽ khác mục đích dể merge
# for df in [df_sapnhap_ward, df_danhmuc]:
#     df[key1] = np.where((~df['province'].isna()) & (~df['district'].isna()) & (~df['ward'].isna()), df['newProvince'] + '_' + df['province'] + '_' + df['districtUd'] + '_' + df['wardUd'], np.nan)
#
# for df in [df_sapnhap_ward, df_danhmuc]:
#     df[key2] = np.where((~df['district'].isna()) & (~df['ward'].isna()), df['newProvince'] + '_' + df['districtUd'] + '_' + df['wardUd'], np.nan)
#
# for df in [df_sapnhap_ward, df_danhmuc]:
#     df[key3] = np.where((~df['district'].isna()), df['newProvince'] + '_' + df['districtUd'], np.nan) # Khi merge cần thêm điều kiện ward là nan
#
# for df in [df_sapnhap_ward, df_danhmuc]:
#     df[key4] = np.where((~df['ward'].isna()), df['newProvince'] + '_' + df['wardUd'], np.nan) # Khi merge cần thêm điều kiện district là nan


for df in [df_sapnhap_ward, df_danhmuc]:
    df[key1] = np.where((~df['province'].isna()) & (~df['district'].isna()) & (~df['ward'].isna()), df['newProvince'] + '_' + df['province'] + '_' + df['districtLower'] + '_' + df['wardLower'], np.nan)

df_danhmuc[key2] = np.where((~df_danhmuc['district'].isna()) & (~df_danhmuc['ward'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['districtLower'] + '_' + df_danhmuc['wardLower'], np.nan)
df_sapnhap_ward[key2] = np.where((~df_sapnhap_ward['district'].isna()) & (~df_sapnhap_ward['ward'].isna()) & (df_sapnhap_ward['province'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtLower'] + '_' + df_sapnhap_ward['wardLower'], np.nan) # Khi merge thêm province là nan

df_danhmuc[key3] = np.where((~df_danhmuc['district'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['districtLower'], np.nan)
df_sapnhap_ward[key3] = np.where((~df_sapnhap_ward['district'].isna()) & (df_sapnhap_ward['ward'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtLower'], np.nan) # Khi merge cần thêm điều kiện ward là nan

df_danhmuc[key4] = np.where((~df_danhmuc['ward'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['wardLower'], np.nan)
df_sapnhap_ward[key4] = np.where((~df_sapnhap_ward['ward'].isna()) & (df_sapnhap_ward['district'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['wardLower'], np.nan) # Khi merge cần thêm điều kiện district là nan

# %%
# Preview (2 province duy nhất trong dataset này)
df_sapnhap_ward[~df_sapnhap_ward[key1].isna()]
# Out:
#            province          district                 ward  isMergedWard  \
# 9222  Tỉnh Trà Vinh  Huyện Châu Thành  Thị trấn Châu Thành          True
# 9374   Tỉnh Bến Tre  Huyện Châu Thành  Thị trấn Châu Thành          True
#
#       isDividedWard      newWard     newProvince  newWardCode newWardType  \
# 9222          False  Châu Thành  Tỉnh Vĩnh Long         2880          xã
# 9374          False      Phú Túc  Tỉnh Vĩnh Long         2934          xã
#
#       newWardLon  ...  newWardAreaKm2  \
# 9222     106.337  ...           47.71
# 9374     106.318  ...           63.14
#
#                                            truocsapnhap        districtUd  \
# 9222  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
# 9374  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
#
#          districtLower               wardUd            wardLower  \
# 9222  huyện châu thành  thi tran chau thanh  thị trấn châu thành
# 9374  huyện châu thành  thi tran chau thanh  thị trấn châu thành
#
#                      keyNewProvinceProvinceDistrictWard  \
# 9222  Tỉnh Vĩnh Long_Tỉnh Trà Vinh_huyện châu thành_...
# 9374  Tỉnh Vĩnh Long_Tỉnh Bến Tre_huyện châu thành_t...
#
#      keyNewProvinceDistrictWard keyNewProvinceDistrict keyNewProvinceWard
# 9222                        NaN                    NaN                NaN
# 9374                        NaN                    NaN                NaN
#
# [2 rows x 21 columns]

# %%
# Preview (Các đảo thì không có ward)
df_danhmuc[df_danhmuc[key1].isna()]
# Out:
#       districtCode  provinceCode districtType            district  \
# 3582           318            31        Huyện  Huyện Bạch Long Vĩ
# 5794           471            45        Huyện        Huyện Cồn Cỏ
# 5975           498            48        Huyện      Huyện Hoàng Sa
# 6379           536            51        Huyện        Huyện Lý Sơn
# 8196           755            77        Huyện       Huyện Côn Đảo
#
#                     province  wardCode wardType ward  newProvinceCode  \
# 3582     Thành phố Hải Phòng       NaN      NaN  NaN                4
# 5794          Tỉnh Quảng Trị       NaN      NaN  NaN               19
# 5975       Thành phố Đà Nẵng       NaN      NaN  NaN               21
# 6379         Tỉnh Quảng Ngãi       NaN      NaN  NaN               22
# 8196  Tỉnh Bà Rịa - Vũng Tàu       NaN      NaN  NaN               29
#
#                 newProvince  isMergedProvince          districtUd  \
# 3582    Thành phố Hải Phòng              True  huyen bach long vi
# 5794         Tỉnh Quảng Trị              True        huyen con co
# 5975      Thành phố Đà Nẵng              True      huyen hoang sa
# 6379        Tỉnh Quảng Ngãi              True        huyen ly son
# 8196  Thành phố Hồ Chí Minh              True       huyen con dao
#
#            districtLower wardUd wardLower keyNewProvinceProvinceDistrictWard  \
# 3582  huyện bạch long vĩ    NaN       NaN                                NaN
# 5794        huyện cồn cỏ    NaN       NaN                                NaN
# 5975      huyện hoàng sa    NaN       NaN                                NaN
# 6379        huyện lý sơn    NaN       NaN                                NaN
# 8196       huyện côn đảo    NaN       NaN                                NaN
#
#      keyNewProvinceDistrictWard                  keyNewProvinceDistrict  \
# 3582                        NaN  Thành phố Hải Phòng_huyện bạch long vĩ
# 5794                        NaN             Tỉnh Quảng Trị_huyện cồn cỏ
# 5975                        NaN        Thành phố Đà Nẵng_huyện hoàng sa
# 6379                        NaN            Tỉnh Quảng Ngãi_huyện lý sơn
# 8196                        NaN     Thành phố Hồ Chí Minh_huyện côn đảo
#
#      keyNewProvinceWard
# 3582                NaN
# 5794                NaN
# 5975                NaN
# 6379                NaN
# 8196                NaN

# %%
# Check Key 1
df_sapnhap_ward[~df_sapnhap_ward[key1].isin(df_danhmuc[key1])]
# Key 1 is valid fully
# Out:
# Empty DataFrame
# Columns: [province, district, ward, isMergedWard, isDividedWard, newWard, newProvince, newWardCode, newWardType, newWardLon, newWardLat, newWardAreaKm2, truocsapnhap, districtUd, districtLower, wardUd, wardLower, keyNewProvinceProvinceDistrictWard, keyNewProvinceDistrictWard, keyNewProvinceDistrict, keyNewProvinceWard]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Check Key 3
df_sapnhap_ward[~df_sapnhap_ward[key3].isin(df_danhmuc[key3]) & (~df_sapnhap_ward[key3].isna())][['newProvince', 'district', 'districtUd']].drop_duplicates()
# Key 3 is valid fully
# Out:
# Empty DataFrame
# Columns: [newProvince, district, districtUd]
# Index: []

# %%
# Check key 4
df_sapnhap_ward[~df_sapnhap_ward[key4].isin(df_danhmuc[key4]) & (~df_sapnhap_ward[key4].isna())][['newProvince', 'district', 'ward', 'wardUd', 'isMergedWard']].drop_duplicates()
# Chỉ còn "Xã Tân Phước" là không tồn tại ở Tỉnh Tuyên Quang và Tỉnh Hà Giang. Có lẽ dữ liệu của sapnhap bị sai chổ này
# Out:
#            newProvince district          ward        wardUd  isMergedWard
# 2738  Tỉnh Tuyên Quang      NaN  Xã Tân Phước  xa tan phuoc          True

# %%
condition1 = (df_danhmuc['newProvince'] == 'Tỉnh Tuyên Quang')
condition2 = (df_danhmuc['wardUd'].fillna('').str.contains('\b.a. phu'))
df_danhmuc[condition1 & condition2][['newProvince', 'province', 'district', 'ward', 'wardUd']].drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [newProvince, province, district, ward, wardUd]
# Index: []

# %% [markdown]
# ## Kiểm tra trước khi merge

# %%
for df in [df_sapnhap_ward, df_danhmuc]:
    df[key1] = np.where((~df['province'].isna()) & (~df['district'].isna()) & (~df['ward'].isna()), df['newProvince'] + '_' + df['province'] + '_' + df['districtUd'] + '_' + df['wardUd'], np.nan)

df_danhmuc[key2] = np.where((~df_danhmuc['district'].isna()) & (~df_danhmuc['ward'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['districtUd'] + '_' + df_danhmuc['wardUd'], np.nan)
df_sapnhap_ward[key2] = np.where((~df_sapnhap_ward['district'].isna()) & (~df_sapnhap_ward['ward'].isna()) & (df_sapnhap_ward['province'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtUd'] + '_' + df_sapnhap_ward['wardUd'], np.nan) # Khi merge thêm province là nan

df_danhmuc[key3] = np.where((~df_danhmuc['district'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['districtUd'], np.nan)
df_sapnhap_ward[key3] = np.where((~df_sapnhap_ward['district'].isna()) & (df_sapnhap_ward['ward'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtUd'], np.nan) # Khi merge cần thêm điều kiện ward là nan

df_danhmuc[key4] = np.where((~df_danhmuc['ward'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['wardUd'], np.nan)
df_sapnhap_ward[key4] = np.where((~df_sapnhap_ward['ward'].isna()) & (df_sapnhap_ward['district'].isna()), df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['wardUd'], np.nan) # Khi merge cần thêm điều kiện district là nan

# %%
sapnhap1 = df_sapnhap_ward[~df_sapnhap_ward[key1].isna()]
sapnhap1
# Out:
#            province          district                 ward  isMergedWard  \
# 9222  Tỉnh Trà Vinh  Huyện Châu Thành  Thị trấn Châu Thành          True
# 9374   Tỉnh Bến Tre  Huyện Châu Thành  Thị trấn Châu Thành          True
#
#       isDividedWard      newWard     newProvince  newWardCode newWardType  \
# 9222          False  Châu Thành  Tỉnh Vĩnh Long         2880          xã
# 9374          False      Phú Túc  Tỉnh Vĩnh Long         2934          xã
#
#       newWardLon  ...  newWardAreaKm2  \
# 9222     106.337  ...           47.71
# 9374     106.318  ...           63.14
#
#                                            truocsapnhap        districtUd  \
# 9222  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
# 9374  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
#
#          districtLower               wardUd            wardLower  \
# 9222  huyện châu thành  thi tran chau thanh  thị trấn châu thành
# 9374  huyện châu thành  thi tran chau thanh  thị trấn châu thành
#
#                      keyNewProvinceProvinceDistrictWard  \
# 9222  Tỉnh Vĩnh Long_Tỉnh Trà Vinh_huyen chau thanh_...
# 9374  Tỉnh Vĩnh Long_Tỉnh Bến Tre_huyen chau thanh_t...
#
#      keyNewProvinceDistrictWard keyNewProvinceDistrict keyNewProvinceWard
# 9222                        NaN                    NaN                NaN
# 9374                        NaN                    NaN                NaN
#
# [2 rows x 21 columns]

# %%
sapnhap3 = df_sapnhap_ward[~df_sapnhap_ward[key3].isna()]
sapnhap3
# Out:
#      province            district ward  isMergedWard  isDividedWard  \
# 1349      NaN  Huyện Bạch Long Vĩ  NaN          True          False
# 5960      NaN        Huyện Cồn Cỏ  NaN          True          False
# 6415      NaN      Huyện Hoàng Sa  NaN          True          False
# 6734      NaN        Huyện Lý Sơn  NaN          True          False
# 8807      NaN       Huyện Côn Đảo  NaN          True          False
# 9931      NaN      Huyện Kiên Hải  NaN          True          False
#
#            newWard            newProvince  newWardCode newWardType  \
# 1349  Bạch Long Vĩ    Thành phố Hải Phòng         1050     đặc khu
# 5960        Cồn Cỏ         Tỉnh Quảng Trị         1764     đặc khu
# 6415      Hoàng Sa      Thành phố Đà Nẵng         1904     đặc khu
# 6734        Lý Sơn        Tỉnh Quảng Ngãi         2015     đặc khu
# 8807       Côn Đảo  Thành phố Hồ Chí Minh         2741     đặc khu
# 9931      Kiên Hải          Tỉnh An Giang         3125     đặc khu
#
#       newWardLon  ...  newWardAreaKm2        truocsapnhap          districtUd  \
# 1349    107.7307  ...            3.07  Huyện Bạch Long Vĩ  huyen bach long vi
# 5960    107.3390  ...            2.30        Huyện Cồn Cỏ        huyen con co
# 6415    112.1350  ...          305.00      Huyện Hoàng Sa      huyen hoang sa
# 6734    109.1150  ...           10.39        Huyện Lý Sơn        huyen ly son
# 8807    106.6115  ...           75.79       Huyện Côn Đảo       huyen con dao
# 9931    104.6320  ...           21.81      Huyện Kiên Hải      huyen kien hai
#
#            districtLower wardUd wardLower keyNewProvinceProvinceDistrictWard  \
# 1349  huyện bạch long vĩ    NaN       NaN                                NaN
# 5960        huyện cồn cỏ    NaN       NaN                                NaN
# 6415      huyện hoàng sa    NaN       NaN                                NaN
# 6734        huyện lý sơn    NaN       NaN                                NaN
# 8807       huyện côn đảo    NaN       NaN                                NaN
# 9931      huyện kiên hải    NaN       NaN                                NaN
#
#      keyNewProvinceDistrictWard                  keyNewProvinceDistrict  \
# 1349                        NaN  Thành phố Hải Phòng_huyen bach long vi
# 5960                        NaN             Tỉnh Quảng Trị_huyen con co
# 6415                        NaN        Thành phố Đà Nẵng_huyen hoang sa
# 6734                        NaN            Tỉnh Quảng Ngãi_huyen ly son
# 8807                        NaN     Thành phố Hồ Chí Minh_huyen con dao
# 9931                        NaN            Tỉnh An Giang_huyen kien hai
#
#      keyNewProvinceWard
# 1349                NaN
# 5960                NaN
# 6415                NaN
# 6734                NaN
# 8807                NaN
# 9931                NaN
#
# [6 rows x 21 columns]

# %%
sapnhap4a = df_sapnhap_ward[~df_sapnhap_ward[key4].isna()]
sapnhap4a
# Out:
#       province district              ward  isMergedWard  isDividedWard  \
# 0          NaN      NaN        Xã Đông La          True          False
# 1          NaN      NaN  Phường Dương Nội          True          False
# 2          NaN      NaN       Xã An Khánh          True          False
# 3          NaN      NaN         Xã La Phù          True          False
# 4          NaN      NaN    Xã Song Phương          True          False
# ...        ...      ...               ...           ...            ...
# 10561      NaN      NaN     Xã Phước Long          True          False
# 10562      NaN      NaN   Xã Vĩnh Phú Tây          True          False
# 10563      NaN      NaN       Xã Hưng Phú          True          False
# 10564      NaN      NaN     Xã Vĩnh Thanh          True          False
# 10566      NaN      NaN     Xã Vĩnh Trạch          True          False
#
#             newWard    newProvince  newWardCode newWardType  newWardLon  ...  \
# 0          An Khánh  Thủ đô Hà Nội            2          xã     105.708  ...
# 1          An Khánh  Thủ đô Hà Nội            2          xã     105.708  ...
# 2          An Khánh  Thủ đô Hà Nội            2          xã     105.708  ...
# 3          An Khánh  Thủ đô Hà Nội            2          xã     105.708  ...
# 4          An Khánh  Thủ đô Hà Nội            2          xã     105.708  ...
# ...             ...            ...          ...         ...         ...  ...
# 10561  Vĩnh Phước    Tỉnh Cà Mau         3353          xã     105.410  ...
# 10562  Vĩnh Phước    Tỉnh Cà Mau         3353          xã     105.410  ...
# 10563   Vĩnh Thanh    Tỉnh Cà Mau         3354          xã     105.519  ...
# 10564   Vĩnh Thanh    Tỉnh Cà Mau         3354          xã     105.519  ...
# 10566  Vĩnh Trạch    Tỉnh Cà Mau         3355      phường     105.774  ...
#
#        newWardAreaKm2       truocsapnhap districtUd districtLower  \
# 0               28.69         Xã Đông La        NaN           NaN
# 1               28.69  Phường Dương Nội         NaN           NaN
# 2               28.69       Xã An Khánh         NaN           NaN
# 3               28.69         Xã La Phù         NaN           NaN
# 4               28.69    Xã Song Phương         NaN           NaN
# ...               ...                ...        ...           ...
# 10561           75.50      Xã Phước Long        NaN           NaN
# 10562           75.50    Xã Vĩnh Phú Tây        NaN           NaN
# 10563           37.37        Xã Hưng Phú        NaN           NaN
# 10564           37.37      Xã Vĩnh Thanh        NaN           NaN
# 10566           10.22      Xã Vĩnh Trạch        NaN           NaN
#
#                  wardUd         wardLower keyNewProvinceProvinceDistrictWard  \
# 0            xa dong la        xã đông la                                NaN
# 1      phuong duong noi  phường dương nội                                NaN
# 2           xa an khanh       xã an khánh                                NaN
# 3             xa la phu         xã la phù                                NaN
# 4        xa song phuong    xã song phương                                NaN
# ...                 ...               ...                                ...
# 10561     xa phuoc long     xã phước long                                NaN
# 10562   xa vinh phu tay   xã vĩnh phú tây                                NaN
# 10563       xa hung phu       xã hưng phú                                NaN
# 10564     xa vinh thanh     xã vĩnh thanh                                NaN
# 10566     xa vinh trach     xã vĩnh trạch                                NaN
#
#       keyNewProvinceDistrictWard keyNewProvinceDistrict  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 10561                        NaN                    NaN
# 10562                        NaN                    NaN
# 10563                        NaN                    NaN
# 10564                        NaN                    NaN
# 10566                        NaN                    NaN
#
#                    keyNewProvinceWard
# 0            Thủ đô Hà Nội_xa dong la
# 1      Thủ đô Hà Nội_phuong duong noi
# 2           Thủ đô Hà Nội_xa an khanh
# 3             Thủ đô Hà Nội_xa la phu
# 4        Thủ đô Hà Nội_xa song phuong
# ...                               ...
# 10561       Tỉnh Cà Mau_xa phuoc long
# 10562     Tỉnh Cà Mau_xa vinh phu tay
# 10563         Tỉnh Cà Mau_xa hung phu
# 10564       Tỉnh Cà Mau_xa vinh thanh
# 10566       Tỉnh Cà Mau_xa vinh trach
#
# [9604 rows x 21 columns]

# %%
sapnhap2 = df_sapnhap_ward[(~df_sapnhap_ward[key2].isna()) & (df_sapnhap_ward[key2].isin(df_danhmuc[key2]))]
sapnhap2
# Out:
#       province            district              ward  isMergedWard  \
# 20         NaN   quận Hai Bà Trưng   Phường Bạch Mai          True
# 21         NaN   quận Hai Bà Trưng  Phường Bách Khoa          True
# 22         NaN   quận Hai Bà Trưng  Phường Quỳnh Mai          True
# 23         NaN   quận Hai Bà Trưng  Phường Minh Khai          True
# 75         NaN     huyện Phú Xuyên        Xã Tân Dân          True
# ...        ...                 ...               ...           ...
# 10521      NaN    thành phố Cà Mau          Phường 5          True
# 10522      NaN    thành phố Cà Mau  Phường Tân Thành          True
# 10523      NaN    thành phố Cà Mau      Xã Tân Thành          True
# 10524      NaN    thành phố Cà Mau          Phường 7          True
# 10565      NaN  thành phố Bạc Liêu          Phường 5          True
#
#        isDividedWard       newWard    newProvince  newWardCode newWardType  \
# 20             False      Bạch Mai  Thủ đô Hà Nội            5      phường
# 21             False      Bạch Mai  Thủ đô Hà Nội            5      phường
# 22             False      Bạch Mai  Thủ đô Hà Nội            5      phường
# 23              True      Bạch Mai  Thủ đô Hà Nội            5      phường
# 75             False     Chuyên Mỹ  Thủ đô Hà Nội           13          xã
# ...              ...           ...            ...          ...         ...
# 10521          False    Tân Thành    Tỉnh Cà Mau         3340      phường
# 10522          False    Tân Thành    Tỉnh Cà Mau         3340      phường
# 10523          False    Tân Thành    Tỉnh Cà Mau         3340      phường
# 10524           True    Tân Thành    Tỉnh Cà Mau         3340      phường
# 10565          False  Vĩnh Trạch    Tỉnh Cà Mau         3355      phường
#
#        newWardLon  ...  newWardAreaKm2                          truocsapnhap  \
# 20        105.852  ...            2.95   Phường Bạch Mai (quận Hai Bà Trưng)
# 21        105.852  ...            2.95  Phường Bách Khoa (quận Hai Bà Trưng)
# 22        105.852  ...            2.95  Phường Quỳnh Mai (quận Hai Bà Trưng)
# 23        105.852  ...            2.95  Phường Minh Khai (quận Hai Bà Trưng)
# 75        105.884  ...           35.54          Xã Tân Dân (huyện Phú Xuyên)
# ...           ...  ...             ...                                   ...
# 10521     105.217  ...           48.42           Phường 5 (thành phố Cà Mau)
# 10522     105.217  ...           48.42   Phường Tân Thành (thành phố Cà Mau)
# 10523     105.217  ...           48.42       Xã Tân Thành (thành phố Cà Mau)
# 10524     105.217  ...           48.42           Phường 7 (thành phố Cà Mau)
# 10565     105.774  ...           10.22         Phường 5 (thành phố Bạc Liêu)
#
#                districtUd       districtLower            wardUd  \
# 20      quan hai ba trung   quận hai bà trưng   phuong bach mai
# 21      quan hai ba trung   quận hai bà trưng  phuong bach khoa
# 22      quan hai ba trung   quận hai bà trưng  phuong quynh mai
# 23      quan hai ba trung   quận hai bà trưng  phuong minh khai
# 75        huyen phu xuyen     huyện phú xuyên        xa tan dan
# ...                   ...                 ...               ...
# 10521    thanh pho ca mau    thành phố cà mau          phuong 5
# 10522    thanh pho ca mau    thành phố cà mau  phuong tan thanh
# 10523    thanh pho ca mau    thành phố cà mau      xa tan thanh
# 10524    thanh pho ca mau    thành phố cà mau          phuong 7
# 10565  thanh pho bac lieu  thành phố bạc liêu          phuong 5
#
#               wardLower keyNewProvinceProvinceDistrictWard  \
# 20      phường bạch mai                                NaN
# 21     phường bách khoa                                NaN
# 22     phường quỳnh mai                                NaN
# 23     phường minh khai                                NaN
# 75           xã tân dân                                NaN
# ...                 ...                                ...
# 10521          phường 5                                NaN
# 10522  phường tân thành                                NaN
# 10523      xã tân thành                                NaN
# 10524          phường 7                                NaN
# 10565          phường 5                                NaN
#
#                              keyNewProvinceDistrictWard  \
# 20      Thủ đô Hà Nội_quan hai ba trung_phuong bach mai
# 21     Thủ đô Hà Nội_quan hai ba trung_phuong bach khoa
# 22     Thủ đô Hà Nội_quan hai ba trung_phuong quynh mai
# 23     Thủ đô Hà Nội_quan hai ba trung_phuong minh khai
# 75             Thủ đô Hà Nội_huyen phu xuyen_xa tan dan
# ...                                                 ...
# 10521             Tỉnh Cà Mau_thanh pho ca mau_phuong 5
# 10522     Tỉnh Cà Mau_thanh pho ca mau_phuong tan thanh
# 10523         Tỉnh Cà Mau_thanh pho ca mau_xa tan thanh
# 10524             Tỉnh Cà Mau_thanh pho ca mau_phuong 7
# 10565           Tỉnh Cà Mau_thanh pho bac lieu_phuong 5
#
#       keyNewProvinceDistrict keyNewProvinceWard
# 20                       NaN                NaN
# 21                       NaN                NaN
# 22                       NaN                NaN
# 23                       NaN                NaN
# 75                       NaN                NaN
# ...                      ...                ...
# 10521                    NaN                NaN
# 10522                    NaN                NaN
# 10523                    NaN                NaN
# 10524                    NaN                NaN
# 10565                    NaN                NaN
#
# [903 rows x 21 columns]

# %%
sapnhap4b = df_sapnhap_ward[(~df_sapnhap_ward[key2].isna()) & (~df_sapnhap_ward[key2].isin(df_danhmuc[key2]))]
sapnhap4b['district'] = np.nan
sapnhap4b['districtUd'] = np.nan
sapnhap4b[key4] = np.where((~sapnhap4b['ward'].isna()) & (sapnhap4b['district'].isna()), sapnhap4b['newProvince'] + '_' + sapnhap4b['wardUd'], np.nan)
sapnhap4b
# Out:
#      province  district                  ward  isMergedWard  isDividedWard  \
# 181       NaN       NaN      Phường Thạch Bàn          True          False
# 242       NaN       NaN        Phường Tây Tựu          True           True
# 243       NaN       NaN            Xã Tân Lập          True          False
# 259       NaN       NaN     Phường Hoàng Liệt          True          False
# 357       NaN       NaN            Xã Văn Khê          True          False
# 358       NaN       NaN            Xã Mê Linh          True          False
# 359       NaN       NaN          Xã Đại Thịnh          True          False
# 584       NaN       NaN        Phường Tây Tựu          True           True
# 620       NaN       NaN           Xã Đại Mạch          True          False
# 621       NaN       NaN             Xã Kim Nỗ          True          False
# 687       NaN       NaN       Phường Giáp Bát          True          False
# 688       NaN       NaN    Phường Phương Liệt          True          False
# 689       NaN       NaN       Phường Mai Động          True          False
# 758       NaN       NaN    Phường Phương Canh          True          False
# 759       NaN       NaN    Phường Xuân Phương          True          False
# 760       NaN       NaN         Phường Đại Mỗ          True          False
# 761       NaN       NaN         Phường Tây Mỗ          True          False
# 762       NaN       NaN           Xã Vân Canh          True          False
# 1392      NaN       NaN          Xã Thanh Hải          True          False
# 1613      NaN       NaN   Thị trấn Trường Sơn          True          False
# 2006      NaN       NaN  Phường Lê Hồng Phong          True          False
# 2007      NaN       NaN       Phường Bồ Xuyên          True          False
# 2008      NaN       NaN     Phường Tiền Phong          True          False
# 2100      NaN       NaN      Phường Phú Khánh          True          False
# 7659      NaN       NaN       Phường Phú Đông          True          False
# 7660      NaN       NaN        Phường Phú Lâm          True          False
# 7661      NaN       NaN      Phường Phú Thạnh          True          False
# 7724      NaN       NaN              Phường 1          True          False
# 7725      NaN       NaN              Phường 2          True          False
# 7726      NaN       NaN              Phường 4          True          False
# 7727      NaN       NaN              Phường 5          True          False
# 7728      NaN       NaN              Phường 7          True          False
# 7729      NaN       NaN              Phường 9          True          False
# 8193      NaN       NaN              Phường 4          True          False
# 8194      NaN       NaN              Phường 5          True          False
# 8195      NaN       NaN              Phường 6          True          False
# 8196      NaN       NaN      Xã Hướng Thọ Phú          True          False
# 8310      NaN       NaN            Xã Mỏ Công          True          False
# 8311      NaN       NaN           Xã Trà Vong          True          False
# 8312      NaN       NaN          Xã Tân Phong          True          False
# 8407      NaN       NaN         Phường An Lộc          True          False
# 8408      NaN       NaN     Phường Hưng Chiến          True          False
# 8409      NaN       NaN        Phường Phú Đức          True          False
# 8549      NaN       NaN     Phường Long Phước          True          False
# 8550      NaN       NaN     Phường Phước Bình          True          False
# 8721      NaN       NaN         Xã An Phú Tây          True          False
# 8732      NaN       NaN          Xã Phong Phú          True          False
# 8733      NaN       NaN          Xã Bình Hưng          True          False
# 9025      NaN       NaN      Thị trấn Tân Túc          True          False
# 9026      NaN       NaN           Xã Tân Nhựt          True          False
# 9027      NaN       NaN      Phường Tân Tạo A          True          False
# 9028      NaN       NaN           Xã Tân Kiên          True          False
#
#           newWard            newProvince  newWardCode newWardType  newWardLon  \
# 181       Gia Lâm          Thủ đô Hà Nội           29          xã     105.949
# 242      Hoài Đức          Thủ đô Hà Nội           38          xã     105.705
# 243      Hoài Đức          Thủ đô Hà Nội           38          xã     105.705
# 259    Hoàng Liệt          Thủ đô Hà Nội           40      phường     105.832
# 357       Mê Linh          Thủ đô Hà Nội           56          xã     105.733
# 358       Mê Linh          Thủ đô Hà Nội           56          xã     105.733
# 359       Mê Linh          Thủ đô Hà Nội           56          xã     105.733
# 584       Tây Tựu          Thủ đô Hà Nội           92      phường     105.739
# 620     Thiên Lộc          Thủ đô Hà Nội           98          xã     105.771
# 621     Thiên Lộc          Thủ đô Hà Nội           98          xã     105.771
# 687     Tương Mai          Thủ đô Hà Nội          109      phường     105.854
# 688     Tương Mai          Thủ đô Hà Nội          109      phường     105.854
# 689     Tương Mai          Thủ đô Hà Nội          109      phường     105.854
# 758   Xuân Phương          Thủ đô Hà Nội          121      phường     105.745
# 759   Xuân Phương          Thủ đô Hà Nội          121      phường     105.745
# 760   Xuân Phương          Thủ đô Hà Nội          121      phường     105.745
# 761   Xuân Phương          Thủ đô Hà Nội          121      phường     105.745
# 762   Xuân Phương          Thủ đô Hà Nội          121      phường     105.745
# 1392      Đại Sơn    Thành phố Hải Phòng         1059          xã     106.378
# 1613     Phù Liễn    Thành phố Hải Phòng         1114      phường     106.636
# 2006    Thái Bình          Tỉnh Hưng Yên         1224      phường     106.314
# 2007    Thái Bình          Tỉnh Hưng Yên         1224      phường     106.314
# 2008    Thái Bình          Tỉnh Hưng Yên         1224      phường     106.314
# 2100      Vũ Phúc          Tỉnh Hưng Yên         1248      phường     106.308
# 7659      Phú Yên           Tỉnh Đắk Lắk         2340      phường     109.315
# 7660      Phú Yên           Tỉnh Đắk Lắk         2340      phường     109.315
# 7661      Phú Yên           Tỉnh Đắk Lắk         2340      phường     109.315
# 7724      Tuy Hòa           Tỉnh Đắk Lắk         2359      phường     109.289
# 7725      Tuy Hòa           Tỉnh Đắk Lắk         2359      phường     109.289
# 7726      Tuy Hòa           Tỉnh Đắk Lắk         2359      phường     109.289
# 7727      Tuy Hòa           Tỉnh Đắk Lắk         2359      phường     109.289
# 7728      Tuy Hòa           Tỉnh Đắk Lắk         2359      phường     109.289
# 7729      Tuy Hòa           Tỉnh Đắk Lắk         2359      phường     109.289
# 8193      Long An          Tỉnh Tây Ninh         2529      phường     106.405
# 8194      Long An          Tỉnh Tây Ninh         2529      phường     106.405
# 8195      Long An          Tỉnh Tây Ninh         2529      phường     106.405
# 8196      Long An          Tỉnh Tây Ninh         2529      phường     106.405
# 8310      Tân Phú          Tỉnh Tây Ninh         2567          xã     106.162
# 8311      Tân Phú          Tỉnh Tây Ninh         2567          xã     106.162
# 8312      Tân Phú          Tỉnh Tây Ninh         2567          xã     106.162
# 8407    Bình Long          Tỉnh Đồng Nai         2600      phường     106.598
# 8408    Bình Long          Tỉnh Đồng Nai         2600      phường     106.598
# 8409    Bình Long          Tỉnh Đồng Nai         2600      phường     106.598
# 8549   Phước Bình          Tỉnh Đồng Nai         2651      phường     106.940
# 8550   Phước Bình          Tỉnh Đồng Nai         2651      phường     106.940
# 8721    Bình Đông  Thành phố Hồ Chí Minh         2711      phường     106.612
# 8732    Bình Hưng  Thành phố Hồ Chí Minh         2715          xã     106.660
# 8733    Bình Hưng  Thành phố Hồ Chí Minh         2715          xã     106.660
# 9025     Tân Nhựt  Thành phố Hồ Chí Minh         2816          xã     106.562
# 9026     Tân Nhựt  Thành phố Hồ Chí Minh         2816          xã     106.562
# 9027     Tân Nhựt  Thành phố Hồ Chí Minh         2816          xã     106.562
# 9028     Tân Nhựt  Thành phố Hồ Chí Minh         2816          xã     106.562
#
#       ...  newWardAreaKm2                            truocsapnhap districtUd  \
# 181   ...           25.72        Phường Thạch Bàn (huyện Gia Lâm)        NaN
# 242   ...           16.73         Phường Tây Tựu (huyện Hoài Đức)        NaN
# 243   ...           16.73             Xã Tân Lập (huyện Hoài Đức)        NaN
# 259   ...            4.04     Phường Hoàng Liệt (huyện Thanh Trì)        NaN
# 357   ...           34.97           Xã Văn Khê (huyện Đan Phượng)        NaN
# 358   ...           34.97           Xã Mê Linh (huyện Đan Phượng)        NaN
# 359   ...           34.97         Xã Đại Thịnh (huyện Đan Phượng)        NaN
# 584   ...            7.54         Phường Tây Tựu (huyện Hoài Đức)        NaN
# 620   ...           27.96             Xã Đại Mạch (huyện Mê Linh)        NaN
# 621   ...           27.96               Xã Kim Nỗ (huyện Mê Linh)        NaN
# 687   ...            3.56     Phường Giáp Bát (quận Hai Bà Trưng)        NaN
# 688   ...            3.56  Phường Phương Liệt (quận Hai Bà Trưng)        NaN
# 689   ...            3.56     Phường Mai Động (quận Hai Bà Trưng)        NaN
# 758   ...           10.81   Phường Phương Canh (quận Bắc Từ Liêm)        NaN
# 759   ...           10.81   Phường Xuân Phương (quận Bắc Từ Liêm)        NaN
# 760   ...           10.81        Phường Đại Mỗ (quận Bắc Từ Liêm)        NaN
# 761   ...           10.81        Phường Tây Mỗ (quận Bắc Từ Liêm)        NaN
# 762   ...           10.81          Xã Vân Canh (quận Bắc Từ Liêm)        NaN
# 1392  ...           22.99              Xã Thanh Hải (huyện Tứ Kỳ)        NaN
# 1613  ...           18.46      Thị trấn Trường Sơn (quận Kiến An)        NaN
# 2006  ...           28.03   Phường Lê Hồng Phong (huyện Vũ Thư)        NaN
# 2007  ...           28.03        Phường Bồ Xuyên (huyện Vũ Thư)        NaN
# 2008  ...           28.03      Phường Tiền Phong (huyện Vũ Thư)        NaN
# 2100  ...           23.99       Phường Phú Khánh (huyện Vũ Thư)        NaN
# 7659  ...           44.04       Phường Phú Đông (thị xã Đông Hòa)        NaN
# 7660  ...           44.04        Phường Phú Lâm (thị xã Đông Hòa)        NaN
# 7661  ...           44.04      Phường Phú Thạnh (thị xã Đông Hòa)        NaN
# 7724  ...           33.77                Phường 1 (huyện Phú Hòa)        NaN
# 7725  ...           33.77                Phường 2 (huyện Phú Hòa)        NaN
# 7726  ...           33.77                Phường 4 (huyện Phú Hòa)        NaN
# 7727  ...           33.77                Phường 5 (huyện Phú Hòa)        NaN
# 7728  ...           33.77                Phường 7 (huyện Phú Hòa)        NaN
# 7729  ...           33.77                Phường 9 (huyện Phú Hòa)        NaN
# 8193  ...           34.90            Phường 4 (huyện Thủ Thừa)        NaN
# 8194  ...           34.90            Phường 5 (huyện Thủ Thừa)        NaN
# 8195  ...           34.90            Phường 6 (huyện Thủ Thừa)        NaN
# 8196  ...           34.90    Xã Hướng Thọ Phú (huyện Thủ Thừa)        NaN
# 8310  ...           38.60            Xã Mỏ Công (huyện Tân Châu)        NaN
# 8311  ...           38.60           Xã Trà Vong (huyện Tân Châu)        NaN
# 8312  ...           38.60          Xã Tân Phong (huyện Tân Châu)        NaN
# 8407  ...           49.10          Phường An Lộc (huyện Hớn Quản)        NaN
# 8408  ...           49.10      Phường Hưng Chiến (huyện Hớn Quản)        NaN
# 8409  ...           49.10         Phường Phú Đức (huyện Hớn Quản)        NaN
# 8549  ...           72.60     Phường Long Phước (huyện Phú Riềng)        NaN
# 8550  ...           72.60     Phường Phước Bình (huyện Phú Riềng)        NaN
# 8721  ...            8.93                 Xã An Phú Tây (Quận 8)        NaN
# 8732  ...           32.63                   Xã Phong Phú (Quận 8)        NaN
# 8733  ...           32.63                   Xã Bình Hưng (Quận 8)        NaN
# 9025  ...           43.67               Thị trấn Tân Túc (Quận 8)        NaN
# 9026  ...           43.67                    Xã Tân Nhựt (Quận 8)        NaN
# 9027  ...           43.67               Phường Tân Tạo A (Quận 8)        NaN
# 9028  ...           43.67                    Xã Tân Kiên (Quận 8)        NaN
#
#           districtLower                wardUd             wardLower  \
# 181       huyện gia lâm      phuong thach ban      phường thạch bàn
# 242      huyện hoài đức        phuong tay tuu        phường tây tựu
# 243      huyện hoài đức            xa tan lap            xã tân lập
# 259     huyện thanh trì     phuong hoang liet     phường hoàng liệt
# 357    huyện đan phượng            xa van khe            xã văn khê
# 358    huyện đan phượng            xa me linh            xã mê linh
# 359    huyện đan phượng          xa dai thinh          xã đại thịnh
# 584      huyện hoài đức        phuong tay tuu        phường tây tựu
# 620       huyện mê linh           xa dai mach           xã đại mạch
# 621       huyện mê linh             xa kim no             xã kim nỗ
# 687   quận hai bà trưng       phuong giap bat       phường giáp bát
# 688   quận hai bà trưng    phuong phuong liet    phường phương liệt
# 689   quận hai bà trưng       phuong mai dong       phường mai động
# 758    quận bắc từ liêm    phuong phuong canh    phường phương canh
# 759    quận bắc từ liêm    phuong xuan phuong    phường xuân phương
# 760    quận bắc từ liêm         phuong dai mo         phường đại mỗ
# 761    quận bắc từ liêm         phuong tay mo         phường tây mỗ
# 762    quận bắc từ liêm           xa van canh           xã vân canh
# 1392        huyện tứ kỳ          xa thanh hai          xã thanh hải
# 1613       quận kiến an   thi tran truong son   thị trấn trường sơn
# 2006       huyện vũ thư  phuong le hong phong  phường lê hồng phong
# 2007       huyện vũ thư       phuong bo xuyen       phường bồ xuyên
# 2008       huyện vũ thư     phuong tien phong     phường tiền phong
# 2100       huyện vũ thư      phuong phu khanh      phường phú khánh
# 7659    thị xã đông hòa       phuong phu dong       phường phú đông
# 7660    thị xã đông hòa        phuong phu lam        phường phú lâm
# 7661    thị xã đông hòa      phuong phu thanh      phường phú thạnh
# 7724      huyện phú hòa              phuong 1              phường 1
# 7725      huyện phú hòa              phuong 2              phường 2
# 7726      huyện phú hòa              phuong 4              phường 4
# 7727      huyện phú hòa              phuong 5              phường 5
# 7728      huyện phú hòa              phuong 7              phường 7
# 7729      huyện phú hòa              phuong 9              phường 9
# 8193     huyện thủ thừa              phuong 4              phường 4
# 8194     huyện thủ thừa              phuong 5              phường 5
# 8195     huyện thủ thừa              phuong 6              phường 6
# 8196     huyện thủ thừa      xa huong tho phu      xã hướng thọ phú
# 8310     huyện tân châu            xa mo cong            xã mỏ công
# 8311     huyện tân châu           xa tra vong           xã trà vong
# 8312     huyện tân châu          xa tan phong          xã tân phong
# 8407     huyện hớn quản         phuong an loc         phường an lộc
# 8408     huyện hớn quản     phuong hung chien     phường hưng chiến
# 8409     huyện hớn quản        phuong phu duc        phường phú đức
# 8549    huyện phú riềng     phuong long phuoc     phường long phước
# 8550    huyện phú riềng     phuong phuoc binh     phường phước bình
# 8721             quận 8         xa an phu tay         xã an phú tây
# 8732             quận 8          xa phong phu          xã phong phú
# 8733             quận 8          xa binh hung          xã bình hưng
# 9025             quận 8      thi tran tan tuc      thị trấn tân túc
# 9026             quận 8           xa tan nhut           xã tân nhựt
# 9027             quận 8      phuong tan tao a      phường tân tạo a
# 9028             quận 8           xa tan kien           xã tân kiên
#
#      keyNewProvinceProvinceDistrictWard  \
# 181                                 NaN
# 242                                 NaN
# 243                                 NaN
# 259                                 NaN
# 357                                 NaN
# 358                                 NaN
# 359                                 NaN
# 584                                 NaN
# 620                                 NaN
# 621                                 NaN
# 687                                 NaN
# 688                                 NaN
# 689                                 NaN
# 758                                 NaN
# 759                                 NaN
# 760                                 NaN
# 761                                 NaN
# 762                                 NaN
# 1392                                NaN
# 1613                                NaN
# 2006                                NaN
# 2007                                NaN
# 2008                                NaN
# 2100                                NaN
# 7659                                NaN
# 7660                                NaN
# 7661                                NaN
# 7724                                NaN
# 7725                                NaN
# 7726                                NaN
# 7727                                NaN
# 7728                                NaN
# 7729                                NaN
# 8193                                NaN
# 8194                                NaN
# 8195                                NaN
# 8196                                NaN
# 8310                                NaN
# 8311                                NaN
# 8312                                NaN
# 8407                                NaN
# 8408                                NaN
# 8409                                NaN
# 8549                                NaN
# 8550                                NaN
# 8721                                NaN
# 8732                                NaN
# 8733                                NaN
# 9025                                NaN
# 9026                                NaN
# 9027                                NaN
# 9028                                NaN
#
#                              keyNewProvinceDistrictWard  \
# 181        Thủ đô Hà Nội_huyen gia lam_phuong thach ban
# 242         Thủ đô Hà Nội_huyen hoai duc_phuong tay tuu
# 243             Thủ đô Hà Nội_huyen hoai duc_xa tan lap
# 259     Thủ đô Hà Nội_huyen thanh tri_phuong hoang liet
# 357           Thủ đô Hà Nội_huyen dan phuong_xa van khe
# 358           Thủ đô Hà Nội_huyen dan phuong_xa me linh
# 359         Thủ đô Hà Nội_huyen dan phuong_xa dai thinh
# 584         Thủ đô Hà Nội_huyen hoai duc_phuong tay tuu
# 620             Thủ đô Hà Nội_huyen me linh_xa dai mach
# 621               Thủ đô Hà Nội_huyen me linh_xa kim no
# 687     Thủ đô Hà Nội_quan hai ba trung_phuong giap bat
# 688   Thủ đô Hà Nội_quan hai ba trung_phuong phuong ...
# 689     Thủ đô Hà Nội_quan hai ba trung_phuong mai dong
# 758   Thủ đô Hà Nội_quan bac tu liem_phuong phuong canh
# 759   Thủ đô Hà Nội_quan bac tu liem_phuong xuan phuong
# 760        Thủ đô Hà Nội_quan bac tu liem_phuong dai mo
# 761        Thủ đô Hà Nội_quan bac tu liem_phuong tay mo
# 762          Thủ đô Hà Nội_quan bac tu liem_xa van canh
# 1392       Thành phố Hải Phòng_huyen tu ky_xa thanh hai
# 1613  Thành phố Hải Phòng_quan kien an_thi tran truo...
# 2006    Tỉnh Hưng Yên_huyen vu thu_phuong le hong phong
# 2007         Tỉnh Hưng Yên_huyen vu thu_phuong bo xuyen
# 2008       Tỉnh Hưng Yên_huyen vu thu_phuong tien phong
# 2100        Tỉnh Hưng Yên_huyen vu thu_phuong phu khanh
# 7659       Tỉnh Đắk Lắk_thi xa dong hoa_phuong phu dong
# 7660        Tỉnh Đắk Lắk_thi xa dong hoa_phuong phu lam
# 7661      Tỉnh Đắk Lắk_thi xa dong hoa_phuong phu thanh
# 7724                Tỉnh Đắk Lắk_huyen phu hoa_phuong 1
# 7725                Tỉnh Đắk Lắk_huyen phu hoa_phuong 2
# 7726                Tỉnh Đắk Lắk_huyen phu hoa_phuong 4
# 7727                Tỉnh Đắk Lắk_huyen phu hoa_phuong 5
# 7728                Tỉnh Đắk Lắk_huyen phu hoa_phuong 7
# 7729                Tỉnh Đắk Lắk_huyen phu hoa_phuong 9
# 8193              Tỉnh Tây Ninh_huyen thu thua_phuong 4
# 8194              Tỉnh Tây Ninh_huyen thu thua_phuong 5
# 8195              Tỉnh Tây Ninh_huyen thu thua_phuong 6
# 8196      Tỉnh Tây Ninh_huyen thu thua_xa huong tho phu
# 8310            Tỉnh Tây Ninh_huyen tan chau_xa mo cong
# 8311           Tỉnh Tây Ninh_huyen tan chau_xa tra vong
# 8312          Tỉnh Tây Ninh_huyen tan chau_xa tan phong
# 8407         Tỉnh Đồng Nai_huyen hon quan_phuong an loc
# 8408     Tỉnh Đồng Nai_huyen hon quan_phuong hung chien
# 8409        Tỉnh Đồng Nai_huyen hon quan_phuong phu duc
# 8549    Tỉnh Đồng Nai_huyen phu rieng_phuong long phuoc
# 8550    Tỉnh Đồng Nai_huyen phu rieng_phuong phuoc binh
# 8721         Thành phố Hồ Chí Minh_quan 8_xa an phu tay
# 8732          Thành phố Hồ Chí Minh_quan 8_xa phong phu
# 8733          Thành phố Hồ Chí Minh_quan 8_xa binh hung
# 9025      Thành phố Hồ Chí Minh_quan 8_thi tran tan tuc
# 9026           Thành phố Hồ Chí Minh_quan 8_xa tan nhut
# 9027      Thành phố Hồ Chí Minh_quan 8_phuong tan tao a
# 9028           Thành phố Hồ Chí Minh_quan 8_xa tan kien
#
#      keyNewProvinceDistrict                       keyNewProvinceWard
# 181                     NaN           Thủ đô Hà Nội_phuong thach ban
# 242                     NaN             Thủ đô Hà Nội_phuong tay tuu
# 243                     NaN                 Thủ đô Hà Nội_xa tan lap
# 259                     NaN          Thủ đô Hà Nội_phuong hoang liet
# 357                     NaN                 Thủ đô Hà Nội_xa van khe
# 358                     NaN                 Thủ đô Hà Nội_xa me linh
# 359                     NaN               Thủ đô Hà Nội_xa dai thinh
# 584                     NaN             Thủ đô Hà Nội_phuong tay tuu
# 620                     NaN                Thủ đô Hà Nội_xa dai mach
# 621                     NaN                  Thủ đô Hà Nội_xa kim no
# 687                     NaN            Thủ đô Hà Nội_phuong giap bat
# 688                     NaN         Thủ đô Hà Nội_phuong phuong liet
# 689                     NaN            Thủ đô Hà Nội_phuong mai dong
# 758                     NaN         Thủ đô Hà Nội_phuong phuong canh
# 759                     NaN         Thủ đô Hà Nội_phuong xuan phuong
# 760                     NaN              Thủ đô Hà Nội_phuong dai mo
# 761                     NaN              Thủ đô Hà Nội_phuong tay mo
# 762                     NaN                Thủ đô Hà Nội_xa van canh
# 1392                    NaN         Thành phố Hải Phòng_xa thanh hai
# 1613                    NaN  Thành phố Hải Phòng_thi tran truong son
# 2006                    NaN       Tỉnh Hưng Yên_phuong le hong phong
# 2007                    NaN            Tỉnh Hưng Yên_phuong bo xuyen
# 2008                    NaN          Tỉnh Hưng Yên_phuong tien phong
# 2100                    NaN           Tỉnh Hưng Yên_phuong phu khanh
# 7659                    NaN             Tỉnh Đắk Lắk_phuong phu dong
# 7660                    NaN              Tỉnh Đắk Lắk_phuong phu lam
# 7661                    NaN            Tỉnh Đắk Lắk_phuong phu thanh
# 7724                    NaN                    Tỉnh Đắk Lắk_phuong 1
# 7725                    NaN                    Tỉnh Đắk Lắk_phuong 2
# 7726                    NaN                    Tỉnh Đắk Lắk_phuong 4
# 7727                    NaN                    Tỉnh Đắk Lắk_phuong 5
# 7728                    NaN                    Tỉnh Đắk Lắk_phuong 7
# 7729                    NaN                    Tỉnh Đắk Lắk_phuong 9
# 8193                    NaN                   Tỉnh Tây Ninh_phuong 4
# 8194                    NaN                   Tỉnh Tây Ninh_phuong 5
# 8195                    NaN                   Tỉnh Tây Ninh_phuong 6
# 8196                    NaN           Tỉnh Tây Ninh_xa huong tho phu
# 8310                    NaN                 Tỉnh Tây Ninh_xa mo cong
# 8311                    NaN                Tỉnh Tây Ninh_xa tra vong
# 8312                    NaN               Tỉnh Tây Ninh_xa tan phong
# 8407                    NaN              Tỉnh Đồng Nai_phuong an loc
# 8408                    NaN          Tỉnh Đồng Nai_phuong hung chien
# 8409                    NaN             Tỉnh Đồng Nai_phuong phu duc
# 8549                    NaN          Tỉnh Đồng Nai_phuong long phuoc
# 8550                    NaN          Tỉnh Đồng Nai_phuong phuoc binh
# 8721                    NaN      Thành phố Hồ Chí Minh_xa an phu tay
# 8732                    NaN       Thành phố Hồ Chí Minh_xa phong phu
# 8733                    NaN       Thành phố Hồ Chí Minh_xa binh hung
# 9025                    NaN   Thành phố Hồ Chí Minh_thi tran tan tuc
# 9026                    NaN        Thành phố Hồ Chí Minh_xa tan nhut
# 9027                    NaN   Thành phố Hồ Chí Minh_phuong tan tao a
# 9028                    NaN        Thành phố Hồ Chí Minh_xa tan kien
#
# [52 rows x 21 columns]

# %%
if not (sapnhap1.shape[0] + sapnhap2.shape[0] + sapnhap3.shape[0] + sapnhap4a.shape[0] + sapnhap4b.shape[0]) == df_sapnhap_ward.shape[0]:
    raise Exception('Chia tệp chưa MECE')

# %% [markdown]
# ## Tiến hành merge

# %%
df_convert1 = pd.merge(df_danhmuc, sapnhap1, on=['newProvince', 'province', 'districtUd', 'wardUd'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert2 = pd.merge(df_danhmuc, sapnhap2, on=['newProvince', 'districtUd', 'wardUd'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert3 = pd.merge(df_danhmuc, sapnhap3, on=['newProvince', 'districtUd'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert4a = pd.merge(df_danhmuc, sapnhap4a, on=['newProvince', 'wardUd'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert4b = pd.merge(df_danhmuc, sapnhap4b, on=['newProvince', 'wardUd'], how='inner', suffixes=('', '_DUPLICATED'))

# %%
print(df_convert1.shape[0], sapnhap1.shape[0])
print(df_convert2.shape[0], sapnhap2.shape[0])
print(df_convert3.shape[0], sapnhap3.shape[0])
print(df_convert4a.shape[0], sapnhap4a.shape[0])
print(df_convert4b.shape[0], sapnhap4b.shape[0])
# Out:
# 2 2
# 904 903
# 9 6
# 9856 9604
# 53 52

# %%
df_convert = pd.concat([df_convert1, df_convert2, df_convert3, df_convert4a, df_convert4b], ignore_index=True).drop_duplicates()
df_convert.drop(columns=[col for col in df_convert.columns if '_DUPLICATED' in col or 'key' in col], inplace=True)
df_convert.drop_duplicates(inplace=True)

# %%
df_convert[df_convert['wardUd'].fillna('').str.contains('phuong 15') & df_convert['districtUd'].fillna('').str.contains('tan binh')]
# Out:
#      districtCode  provinceCode districtType       district  \
# 602           766            79         Quận  Quận Tân Bình
# 603           766            79         Quận  Quận Tân Bình
#
#                   province  wardCode wardType       ward  newProvinceCode  \
# 602  Thành phố Hồ Chí Minh   27007.0   Phường  Phường 15               29
# 603  Thành phố Hồ Chí Minh   27007.0   Phường  Phường 15               29
#
#                newProvince  ...  wardLower isMergedWard isDividedWard  \
# 602  Thành phố Hồ Chí Minh  ...  phường 15         True          True
# 603  Thành phố Hồ Chí Minh  ...  phường 15         True          True
#
#       newWard newWardCode  newWardType  newWardLon newWardLat  newWardAreaKm2  \
# 602  Tân Bình        2807       phường     106.642    10.8006            2.12
# 603   Tân Sơn        2819       phường     106.650    10.8224           10.12
#
#                   truocsapnhap
# 602  Phường 15 (quận Tân Bình)
# 603  Phường 15 (quận Tân Bình)
#
# [2 rows x 24 columns]

# %%
df_convert_full = pd.merge(df_danhmuc, df_convert, on=['newProvince', 'province', 'districtUd', 'wardUd'], how='left', suffixes=('', '_DUPLICATED')).drop_duplicates()
df_convert_full .drop(columns=[col for col in df_convert_full.columns if '_DUPLICATED' in col or 'key' in col], inplace=True)
df_convert_full.drop_duplicates(inplace=True)

# %%
df_convert_full[df_convert_full['newWard'].isna()]
# Out:
#       districtCode  provinceCode districtType         district  \
# 977             34             2        Huyện  Huyện Bắc Quang
# 1378            75             8        Huyện    Huyện Yên Sơn
#
#               province  wardCode wardType            ward  newProvinceCode  \
# 977      Tỉnh Hà Giang    1174.0       Xã  Xã Thượng Bình                8
# 1378  Tỉnh Tuyên Quang    2488.0       Xã    Xã Trung Môn                8
#
#            newProvince  ...       wardLower isMergedWard isDividedWard  \
# 977   Tỉnh Tuyên Quang  ...  xã thượng bình          NaN           NaN
# 1378  Tỉnh Tuyên Quang  ...    xã trung môn          NaN           NaN
#
#      newWard newWardCode newWardType newWardLon newWardLat  newWardAreaKm2  \
# 977      NaN         NaN         NaN        NaN        NaN             NaN
# 1378     NaN         NaN         NaN        NaN        NaN             NaN
#
#      truocsapnhap
# 977           NaN
# 1378          NaN
#
# [2 rows x 24 columns]

# %%
df_sapnhap_ward[df_sapnhap_ward['wardUd'].fillna('').str.contains('xuan hoa')]

# %%
not_exist_in_sapnhap = [
    'Xã Thượng Bình', # newProvince = "Tỉnh Tuyên Quang" -> newWard = "Xã Đồng Tâm" https://address-converter.io.vn/
    'Xã Trung Môn', # newProvince = "Tỉnh Tuyên Quang" -> newWard = "Phường Minh Xuân" https://address-converter.io.vn/
]
exist_in_sapnhap = [
    'Phường Xuân Hòa', # ward = 'Xã Xuân Hòa' newWard = 'Long Khánh', newProvince = 'Tỉnh Đồng Nai'
    'Phường Phú Bình', # ward = 'Xã Phú Bình' newWard = 'Long Khánh', newProvince = 'Tỉnh Đồng Nai'
]

# %%
fill_map = [
    {
        'province': 'Tỉnh Hà Giang',
        'district': 'Huyện Bắc Quang',
        'ward': 'Xã Thượng Bình',
        'newProvince': 'Tỉnh Tuyên Quang',
        'newWard': 'Đồng Tâm'
    },
    {
        'province': 'Tỉnh Tuyên Quang',
        'district': 'Huyện Yên Sơn',
        'ward': 'Xã Trung Môn',
        'newProvince': 'Tỉnh Tuyên Quang',
        'newWard': 'Minh Xuân'
    },
]
fill_cols = ['isMergedWard', 'isDividedWard', 'newWard', 'newWardCode', 'newWardType', 'newWardLon', 'newWardLat', 'newWardAreaKm2']
for record in fill_map:
    miss_condition = (df_convert_full['province'] == record['province']) & (df_convert_full['district'] == record['district']) & (df_convert_full['ward'] == record['ward'])
    fill_condition = (df_convert_full['newProvince'] == record['newProvince']) & (df_convert_full['newWard'] == record['newWard'])

    fill_values = df_convert_full.loc[fill_condition, fill_cols].iloc[0]
    df_convert_full.loc[miss_condition, fill_cols] = fill_values.values

# %%
df_convert_full.to_csv('data/danhmuc_and_sapnhap.csv', index=False)

# %%
df_convert_full['newWardCode']
