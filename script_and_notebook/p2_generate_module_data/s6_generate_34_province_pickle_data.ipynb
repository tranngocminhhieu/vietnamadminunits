# %%
import pandas as pd
import numpy as np
import json
import re

from pathlib import Path
import sys
BASE_DIR = Path().resolve().parent.parent
sys.path.append((BASE_DIR / 'vietnamadminunits/parser').as_posix())

from utils import key_normalize

import warnings
warnings.filterwarnings('ignore')

# %%
def create_sort(text, level=1):
    if isinstance(text, str):
        if level == 1:
            text = re.sub(r'^Tỉnh\s|Thành phố\s|Thủ đô\s', '', text, flags=re.IGNORECASE)
        else:
            text = re.sub(r'^Phường\s|Đặc khu\s|Xã\s', '', text, flags=re.IGNORECASE)

        return text.strip()
    return text

district_type_acronym = {
    'Quận': 'q',
    'Thị xã': 'tx',
    'Thành phố': 'tp',
    'Huyện': 'h',
}
ward_type_acronym = {
    'Phường': 'p',
    'Đặc khu': 'dk',
    'Xã': 'x'
}
def create_keywords(row, level=1):
    keywords = []
    if level == 1:
        keywords.append(row['provinceKey'])
        keywords.append(row['provinceShortKey'])
        if pd.notnull(row['provinceAlias']):
            aliases = json.loads(row['provinceAlias'])
            for a in aliases:
                keywords.append(key_normalize(a))

    else:
        keywords.append(row['wardKey'])
        if not row['wardShortKeyDuplicated']:
            keywords.append(row['wardShortKey'])
        else:
            keywords.append(key_normalize(f"{row['wardShortKey']} {row['wardType']}"))
            keywords.append(key_normalize(f"{ward_type_acronym[row['wardType']]} {row['wardShortKey']}"))

        if pd.notnull(row['wardAlias']):
            aliases = json.loads(row['wardAlias'])
            for a in aliases:
                keywords.append(key_normalize(a))

    keywords = list(set(keywords))
    keywords = sorted(keywords, key=len, reverse=True)
    return json.dumps(keywords)

# %%
df_convert = pd.read_csv(BASE_DIR / 'data/danhmuc_and_sapnhap_has_default_new_ward.csv')
col_name_map = {
    'newProvinceCode': 'provinceCode',
    'newWardCode': 'wardCode',
    'newWardType': 'wardType',

    'newProvinceLat': 'provinceLat',
    'newProvinceLon': 'provinceLon',

    'newWardLat': 'wardLat',
    'newWardLon': 'wardLon',

    'newProvince': 'province',
    'newWard': 'wardShort',
}
df = df_convert[col_name_map.keys()].drop_duplicates().reset_index(drop=True).rename(columns=col_name_map)

df['wardType'] = df['wardType'].str.capitalize()
df['ward'] = df['wardType'] + ' ' + df['wardShort']

# %%
# ENRICH DATA
unit_cols = ['province', 'ward']
level_map = {
    'province': 1,
    'ward': 2
}

for col in unit_cols:
    # Create short version
    level = level_map[col]
    df[f"{col}Short"] = df[col].apply(create_sort, args=(level,))

    # Create key
    df[f"{col}Key"] = df[f"{col}"].apply(key_normalize)

    # Create short key
    df[f"{col}ShortKey"] = df[f"{col}Short"].apply(key_normalize)

# %%
# -- CREATE ALIAS
# Khởi tạo cột alias rỗng
for col in ['province', 'ward']:
    df[f"{col}Alias"] = np.nan

# Province alias data
province_alias_data = {
    'thudohanoi': ['hn'],
    'thanhphohochiminh': ['hcm'],
}

# Ward alias data (theo từng province)
ward_alias_data = {
    # 'thanhphohochiminh': {
    #     'wardkey': ['quan9', 'quan2']
    # }
}


# Gán provinceAlias
for key, value in province_alias_data.items():
    df.loc[df['provinceKey'] == key, 'provinceAlias'] = json.dumps(value)

# Gán wardAlias
for province_key, ward_data in ward_alias_data.items():
    for ward_key, value in ward_data.items():
        df.loc[
            (df['provinceKey'] == province_key) & (df['wardKey'] == ward_key), 'wardAlias'] = json.dumps(value)

# %%
# Check ward key
count_ward_key = df.groupby(['province', 'wardKey']).size().reset_index(name='count').sort_values(by=['count'], ascending=False)
duplicated_ward_key = count_ward_key[count_ward_key['count']>1].copy()
duplicated_ward_key['wardKeyDuplicated'] = True
duplicated_ward_key.drop(columns=['count'], inplace=True)

df = pd.merge(df, duplicated_ward_key, on=['province', 'wardKey'], how='left')
df['wardKeyDuplicated'].fillna(False, inplace=True)

# %%
duplicated_ward_key
# Out:
#                    province     wardKey  wardKeyDuplicated
# 416   Thành phố Hồ Chí Minh   xathanhan               True
# 199     Thành phố Hải Phòng  xacamgiang               True
# 2618       Tỉnh Thái Nguyên   xavanlang               True
# 2140        Tỉnh Quảng Ngãi     xasonha               True
# 2829          Tỉnh Tây Ninh  xatanthanh               True
# 3168          Tỉnh Đồng Nai  xalocthanh               True
# 2084        Tỉnh Quảng Ngãi      xabato               True
# 3299         Tỉnh Đồng Tháp  xatanthanh               True

# %%
df['wardKey'] = np.where(df['wardKeyDuplicated']==True, df['ward'].apply(key_normalize, args=([], False)), df['wardKey'])
df['wardShortKey'] = np.where(df['wardKeyDuplicated']==True, df['wardShort'].apply(key_normalize, args=([], False)), df['wardShortKey'])

# %%
df[df['wardKeyDuplicated']==True]
# Out:
#       provinceCode  wardCode wardType  provinceLat  provinceLon  wardLat  \
# 287             10     652.0       Xã      22.0239      105.824  22.2586
# 671             10     653.0       Xã      22.0239      105.824  21.7857
# 1059             4    1052.0       Xã      20.8759      106.470  20.9687
# 1060             4    1053.0       Xã      20.8759      106.470  20.9631
# 1969            22    2037.0       Xã      14.7688      108.143  15.0449
# 1970            22    2038.0       Xã      14.7688      108.143  15.0928
# 1992            22    1973.0       Xã      14.7688      108.143  14.7378
# 1998            22    1972.0       Xã      14.7688      108.143  14.6470
# 2478            28    2630.0       Xã      11.4369      107.034  11.9365
# 2482            28    2629.0       Xã      11.4369      107.034  11.7661
# 2521            27    2570.0       Xã      10.6941      106.123  11.5098
# 2557            29    2833.0       Xã      10.9926      106.638  11.2442
# 2766            29    2834.0       Xã      10.9926      106.638  10.5464
# 2781            27    2571.0       Xã      10.6941      106.123  10.5834
# 3017            31    3065.0       Xã      10.4293      105.999  10.8964
# 3041            31    3066.0       Xã      10.4293      105.999  10.6051
#
#       wardLon               province  wardShort          ward provinceShort  \
# 287   106.061       Tỉnh Thái Nguyên   Văn Lang   Xã Văn Lang   Thái Nguyên
# 671   105.829       Tỉnh Thái Nguyên   Văn Lăng   Xã Văn Lăng   Thái Nguyên
# 1059  106.210    Thành phố Hải Phòng  Cẩm Giang  Xã Cẩm Giang     Hải Phòng
# 1060  106.157    Thành phố Hải Phòng  Cẩm Giàng  Xã Cẩm Giàng     Hải Phòng
# 1969  108.434        Tỉnh Quảng Ngãi     Sơn Hà     Xã Sơn Hà    Quảng Ngãi
# 1970  108.538        Tỉnh Quảng Ngãi     Sơn Hạ     Xã Sơn Hạ    Quảng Ngãi
# 1992  108.738        Tỉnh Quảng Ngãi      Ba Tơ      Xã Ba Tơ    Quảng Ngãi
# 1998  108.660        Tỉnh Quảng Ngãi      Ba Tô      Xã Ba Tô    Quảng Ngãi
# 2478  106.576          Tỉnh Đồng Nai  Lộc Thạnh  Xã Lộc Thạnh      Đồng Nai
# 2482  106.494          Tỉnh Đồng Nai  Lộc Thành  Xã Lộc Thành      Đồng Nai
# 2521  106.269          Tỉnh Tây Ninh  Tân Thành  Xã Tân Thành      Tây Ninh
# 2557  106.434  Thành phố Hồ Chí Minh   Thanh An   Xã Thanh An   Hồ Chí Minh
# 2766  106.975  Thành phố Hồ Chí Minh   Thạnh An   Xã Thạnh An   Hồ Chí Minh
# 2781  106.054          Tỉnh Tây Ninh  Tân Thạnh  Xã Tân Thạnh      Tây Ninh
# 3017  105.529         Tỉnh Đồng Tháp  Tân Thành  Xã Tân Thành     Đồng Tháp
# 3041  105.468         Tỉnh Đồng Tháp  Tân Thạnh  Xã Tân Thạnh     Đồng Tháp
#
#             provinceKey provinceShortKey     wardKey wardShortKey  \
# 287      tinhthainguyen       thainguyen   xãvănlang      vănlang
# 671      tinhthainguyen       thainguyen   xãvănlăng      vănlăng
# 1059   thanhphohaiphong         haiphong  xãcẩmgiang     cẩmgiang
# 1060   thanhphohaiphong         haiphong  xãcẩmgiàng     cẩmgiàng
# 1969      tinhquangngai        quangngai     xãsơnhà        sơnhà
# 1970      tinhquangngai        quangngai     xãsơnhạ        sơnhạ
# 1992      tinhquangngai        quangngai      xãbatơ         batơ
# 1998      tinhquangngai        quangngai      xãbatô         batô
# 2478        tinhdongnai          dongnai  xãlộcthạnh     lộcthạnh
# 2482        tinhdongnai          dongnai  xãlộcthành     lộcthành
# 2521        tinhtayninh          tayninh  xãtânthành     tânthành
# 2557  thanhphohochiminh        hochiminh   xãthanhan      thanhan
# 2766  thanhphohochiminh        hochiminh   xãthạnhan      thạnhan
# 2781        tinhtayninh          tayninh  xãtânthạnh     tânthạnh
# 3017       tinhdongthap         dongthap  xãtânthành     tânthành
# 3041       tinhdongthap         dongthap  xãtânthạnh     tânthạnh
#
#      provinceAlias  wardAlias  wardKeyDuplicated
# 287            NaN        NaN               True
# 671            NaN        NaN               True
# 1059           NaN        NaN               True
# 1060           NaN        NaN               True
# 1969           NaN        NaN               True
# 1970           NaN        NaN               True
# 1992           NaN        NaN               True
# 1998           NaN        NaN               True
# 2478           NaN        NaN               True
# 2482           NaN        NaN               True
# 2521           NaN        NaN               True
# 2557       ["hcm"]        NaN               True
# 2766       ["hcm"]        NaN               True
# 2781           NaN        NaN               True
# 3017           NaN        NaN               True
# 3041           NaN        NaN               True

# %%
# Check ward short key
count_ward_short_key = df.groupby(['province', 'wardShortKey']).size().reset_index(name='count').sort_values(by=['count'], ascending=False)
duplicated_ward_short_key = count_ward_short_key[count_ward_short_key['count']>1].copy()
duplicated_ward_short_key['wardShortKeyDuplicated'] = True
duplicated_ward_short_key.drop(columns=['count'], inplace=True)

df = pd.merge(df, duplicated_ward_short_key, on=['province', 'wardShortKey'], how='left')
df['wardShortKeyDuplicated'].fillna(False, inplace=True)

# %%
duplicated_ward_short_key
# Out:
#             province wardShortKey  wardShortKeyDuplicated
# 2398  Tỉnh Thanh Hóa     dongtien                    True
# 3269  Tỉnh Đồng Tháp        mytho                    True

# %%
# Create keywords
for col in unit_cols:
    level = level_map[col]
    df[f"{col}Keywords"] = df.apply(lambda row: create_keywords(row, level=level), axis=1)

# %%
df
# Out:
#       provinceCode  wardCode wardType  provinceLat  provinceLon   wardLat  \
# 0                1      42.0   Phường      21.0001      105.698  21.05670
# 1                1       3.0   Phường      21.0001      105.698  21.03860
# 2                1      61.0   Phường      21.0001      105.698  21.03810
# 3                1      30.0   Phường      21.0001      105.698  21.02750
# 4                1      39.0   Phường      21.0001      105.698  21.03200
# ...            ...       ...      ...          ...          ...       ...
# 3316            34    3331.0       Xã       9.1362      105.182   8.92852
# 3317            34    3324.0       Xã       9.1362      105.182   8.86914
# 3318            34    3337.0       Xã       9.1362      105.182   8.72769
# 3319            34    3327.0       Xã       9.1362      105.182   8.64616
# 3320            34    3302.0       Xã       9.1362      105.182   8.63765
#
#       wardLon       province            wardShort                    ward  \
# 0     105.845  Thủ đô Hà Nội              Hồng Hà          Phường Hồng Hà
# 1     105.838  Thủ đô Hà Nội              Ba Đình          Phường Ba Đình
# 2     105.816  Thủ đô Hà Nội              Ngọc Hà          Phường Ngọc Hà
# 3     105.814  Thủ đô Hà Nội             Giảng Võ         Phường Giảng Võ
# 4     105.850  Thủ đô Hà Nội            Hoàn Kiếm        Phường Hoàn Kiếm
# ...       ...            ...                  ...                     ...
# 3316  104.846    Tỉnh Cà Mau             Phú Tân             Xã Phú Tân
# 3317  104.930    Tỉnh Cà Mau  Nguyễn Việt Khái  Xã Nguyễn Việt Khái
# 3318  105.078    Tỉnh Cà Mau               Tân Ân               Xã Tân Ân
# 3319  104.943    Tỉnh Cà Mau     Phan Ngọc Hiển     Xã Phan Ngọc Hiển
# 3320  104.820    Tỉnh Cà Mau            Đất Mũi            Xã Đất Mũi
#
#       ... provinceKey provinceShortKey           wardKey    wardShortKey  \
# 0     ...  thudohanoi            hanoi      phuonghongha          hongha
# 1     ...  thudohanoi            hanoi      phuongbadinh          badinh
# 2     ...  thudohanoi            hanoi      phuongngocha          ngocha
# 3     ...  thudohanoi            hanoi     phuonggiangvo         giangvo
# 4     ...  thudohanoi            hanoi    phuonghoankiem        hoankiem
# ...   ...         ...              ...               ...             ...
# 3316  ...   tinhcamau            camau          xaphutan          phutan
# 3317  ...   tinhcamau            camau  xanguyenvietkhai  nguyenvietkhai
# 3318  ...   tinhcamau            camau           xatanan           tanan
# 3319  ...   tinhcamau            camau    xaphanngochien    phanngochien
# 3320  ...   tinhcamau            camau          xadatmui          datmui
#
#      provinceAlias wardAlias  wardKeyDuplicated  wardShortKeyDuplicated  \
# 0           ["hn"]       NaN              False                   False
# 1           ["hn"]       NaN              False                   False
# 2           ["hn"]       NaN              False                   False
# 3           ["hn"]       NaN              False                   False
# 4           ["hn"]       NaN              False                   False
# ...            ...       ...                ...                     ...
# 3316           NaN       NaN              False                   False
# 3317           NaN       NaN              False                   False
# 3318           NaN       NaN              False                   False
# 3319           NaN       NaN              False                   False
# 3320           NaN       NaN              False                   False
#
#                    provinceKeywords                            wardKeywords
# 0     ["thudohanoi", "hanoi", "hn"]              ["phuonghongha", "hongha"]
# 1     ["thudohanoi", "hanoi", "hn"]              ["phuongbadinh", "badinh"]
# 2     ["thudohanoi", "hanoi", "hn"]              ["phuongngocha", "ngocha"]
# 3     ["thudohanoi", "hanoi", "hn"]            ["phuonggiangvo", "giangvo"]
# 4     ["thudohanoi", "hanoi", "hn"]          ["phuonghoankiem", "hoankiem"]
# ...                             ...                                     ...
# 3316         ["tinhcamau", "camau"]                  ["xaphutan", "phutan"]
# 3317         ["tinhcamau", "camau"]  ["xanguyenvietkhai", "nguyenvietkhai"]
# 3318         ["tinhcamau", "camau"]                    ["xatanan", "tanan"]
# 3319         ["tinhcamau", "camau"]      ["xaphanngochien", "phanngochien"]
# 3320         ["tinhcamau", "camau"]                  ["xadatmui", "datmui"]
#
# [3321 rows x 21 columns]

# %%
# Province map
df_province = df[['provinceKey', 'provinceKeywords', 'province', 'provinceShort', 'provinceLat', 'provinceLon']].drop_duplicates().reset_index(drop=True)
DICT_PROVINCE = {}
for _, row in df_province.iterrows():
    DICT_PROVINCE[row['provinceKey']] = {
        'provinceKeywords': json.loads(row['provinceKeywords']),
        'province': row['province'],
        'provinceShort': row['provinceShort'],
        'provinceLat': row['provinceLat'],
        'provinceLon': row['provinceLon'],
    }

# %%
def build_province_ward_dict(df):
    result = {}

    # Nhóm theo provinceKey
    grouped = df.groupby('provinceKey')

    for province_key, group in grouped:
        ward_dict = {}

        for _, row in group.iterrows():
            ward_key = row['wardKey']
            ward_keywords = json.loads(row['wardKeywords']) if pd.notnull(row['wardKeywords']) else []
            ward_dict[ward_key] = {
                'wardKeywords': ward_keywords,
                'ward': row['ward'],
                'wardType': row['wardType'],
                'wardShort': row['wardShort'],
                'wardLat': row['wardLat'],
                'wardLon': row['wardLon'],
            }

        result[province_key] = ward_dict

    return result

df_ward_no_accented = df[df['wardKeyDuplicated'] == False]
df_ward_accented = df[df['wardKeyDuplicated'] == True]

DICT_PROVINCE_WARD_NO_ACCENTED = build_province_ward_dict(df_ward_no_accented)
DICT_PROVINCE_WARD_ACCENTED = build_province_ward_dict(df_ward_accented)

# %%
df_ward_no_accented
# Out:
#       provinceCode  wardCode wardType  provinceLat  provinceLon   wardLat  \
# 0                1      42.0   Phường      21.0001      105.698  21.05670
# 1                1       3.0   Phường      21.0001      105.698  21.03860
# 2                1      61.0   Phường      21.0001      105.698  21.03810
# 3                1      30.0   Phường      21.0001      105.698  21.02750
# 4                1      39.0   Phường      21.0001      105.698  21.03200
# ...            ...       ...      ...          ...          ...       ...
# 3316            34    3331.0       Xã       9.1362      105.182   8.92852
# 3317            34    3324.0       Xã       9.1362      105.182   8.86914
# 3318            34    3337.0       Xã       9.1362      105.182   8.72769
# 3319            34    3327.0       Xã       9.1362      105.182   8.64616
# 3320            34    3302.0       Xã       9.1362      105.182   8.63765
#
#       wardLon       province            wardShort                    ward  \
# 0     105.845  Thủ đô Hà Nội              Hồng Hà          Phường Hồng Hà
# 1     105.838  Thủ đô Hà Nội              Ba Đình          Phường Ba Đình
# 2     105.816  Thủ đô Hà Nội              Ngọc Hà          Phường Ngọc Hà
# 3     105.814  Thủ đô Hà Nội             Giảng Võ         Phường Giảng Võ
# 4     105.850  Thủ đô Hà Nội            Hoàn Kiếm        Phường Hoàn Kiếm
# ...       ...            ...                  ...                     ...
# 3316  104.846    Tỉnh Cà Mau             Phú Tân             Xã Phú Tân
# 3317  104.930    Tỉnh Cà Mau  Nguyễn Việt Khái  Xã Nguyễn Việt Khái
# 3318  105.078    Tỉnh Cà Mau               Tân Ân               Xã Tân Ân
# 3319  104.943    Tỉnh Cà Mau     Phan Ngọc Hiển     Xã Phan Ngọc Hiển
# 3320  104.820    Tỉnh Cà Mau            Đất Mũi            Xã Đất Mũi
#
#       ... provinceKey provinceShortKey           wardKey    wardShortKey  \
# 0     ...  thudohanoi            hanoi      phuonghongha          hongha
# 1     ...  thudohanoi            hanoi      phuongbadinh          badinh
# 2     ...  thudohanoi            hanoi      phuongngocha          ngocha
# 3     ...  thudohanoi            hanoi     phuonggiangvo         giangvo
# 4     ...  thudohanoi            hanoi    phuonghoankiem        hoankiem
# ...   ...         ...              ...               ...             ...
# 3316  ...   tinhcamau            camau          xaphutan          phutan
# 3317  ...   tinhcamau            camau  xanguyenvietkhai  nguyenvietkhai
# 3318  ...   tinhcamau            camau           xatanan           tanan
# 3319  ...   tinhcamau            camau    xaphanngochien    phanngochien
# 3320  ...   tinhcamau            camau          xadatmui          datmui
#
#      provinceAlias wardAlias  wardKeyDuplicated  wardShortKeyDuplicated  \
# 0           ["hn"]       NaN              False                   False
# 1           ["hn"]       NaN              False                   False
# 2           ["hn"]       NaN              False                   False
# 3           ["hn"]       NaN              False                   False
# 4           ["hn"]       NaN              False                   False
# ...            ...       ...                ...                     ...
# 3316           NaN       NaN              False                   False
# 3317           NaN       NaN              False                   False
# 3318           NaN       NaN              False                   False
# 3319           NaN       NaN              False                   False
# 3320           NaN       NaN              False                   False
#
#                    provinceKeywords                            wardKeywords
# 0     ["thudohanoi", "hanoi", "hn"]              ["phuonghongha", "hongha"]
# 1     ["thudohanoi", "hanoi", "hn"]              ["phuongbadinh", "badinh"]
# 2     ["thudohanoi", "hanoi", "hn"]              ["phuongngocha", "ngocha"]
# 3     ["thudohanoi", "hanoi", "hn"]            ["phuonggiangvo", "giangvo"]
# 4     ["thudohanoi", "hanoi", "hn"]          ["phuonghoankiem", "hoankiem"]
# ...                             ...                                     ...
# 3316         ["tinhcamau", "camau"]                  ["xaphutan", "phutan"]
# 3317         ["tinhcamau", "camau"]  ["xanguyenvietkhai", "nguyenvietkhai"]
# 3318         ["tinhcamau", "camau"]                    ["xatanan", "tanan"]
# 3319         ["tinhcamau", "camau"]      ["xaphanngochien", "phanngochien"]
# 3320         ["tinhcamau", "camau"]                  ["xadatmui", "datmui"]
#
# [3305 rows x 21 columns]

# %%
df
# Out:
#       provinceCode  wardCode wardType  provinceLat  provinceLon   wardLat  \
# 0                1      42.0   Phường      21.0001      105.698  21.05670
# 1                1       3.0   Phường      21.0001      105.698  21.03860
# 2                1      61.0   Phường      21.0001      105.698  21.03810
# 3                1      30.0   Phường      21.0001      105.698  21.02750
# 4                1      39.0   Phường      21.0001      105.698  21.03200
# ...            ...       ...      ...          ...          ...       ...
# 3316            34    3331.0       Xã       9.1362      105.182   8.92852
# 3317            34    3324.0       Xã       9.1362      105.182   8.86914
# 3318            34    3337.0       Xã       9.1362      105.182   8.72769
# 3319            34    3327.0       Xã       9.1362      105.182   8.64616
# 3320            34    3302.0       Xã       9.1362      105.182   8.63765
#
#       wardLon       province            wardShort                    ward  \
# 0     105.845  Thủ đô Hà Nội              Hồng Hà          Phường Hồng Hà
# 1     105.838  Thủ đô Hà Nội              Ba Đình          Phường Ba Đình
# 2     105.816  Thủ đô Hà Nội              Ngọc Hà          Phường Ngọc Hà
# 3     105.814  Thủ đô Hà Nội             Giảng Võ         Phường Giảng Võ
# 4     105.850  Thủ đô Hà Nội            Hoàn Kiếm        Phường Hoàn Kiếm
# ...       ...            ...                  ...                     ...
# 3316  104.846    Tỉnh Cà Mau             Phú Tân             Xã Phú Tân
# 3317  104.930    Tỉnh Cà Mau  Nguyễn Việt Khái  Xã Nguyễn Việt Khái
# 3318  105.078    Tỉnh Cà Mau               Tân Ân               Xã Tân Ân
# 3319  104.943    Tỉnh Cà Mau     Phan Ngọc Hiển     Xã Phan Ngọc Hiển
# 3320  104.820    Tỉnh Cà Mau            Đất Mũi            Xã Đất Mũi
#
#       ... provinceKey provinceShortKey           wardKey    wardShortKey  \
# 0     ...  thudohanoi            hanoi      phuonghongha          hongha
# 1     ...  thudohanoi            hanoi      phuongbadinh          badinh
# 2     ...  thudohanoi            hanoi      phuongngocha          ngocha
# 3     ...  thudohanoi            hanoi     phuonggiangvo         giangvo
# 4     ...  thudohanoi            hanoi    phuonghoankiem        hoankiem
# ...   ...         ...              ...               ...             ...
# 3316  ...   tinhcamau            camau          xaphutan          phutan
# 3317  ...   tinhcamau            camau  xanguyenvietkhai  nguyenvietkhai
# 3318  ...   tinhcamau            camau           xatanan           tanan
# 3319  ...   tinhcamau            camau    xaphanngochien    phanngochien
# 3320  ...   tinhcamau            camau          xadatmui          datmui
#
#      provinceAlias wardAlias  wardKeyDuplicated  wardShortKeyDuplicated  \
# 0           ["hn"]       NaN              False                   False
# 1           ["hn"]       NaN              False                   False
# 2           ["hn"]       NaN              False                   False
# 3           ["hn"]       NaN              False                   False
# 4           ["hn"]       NaN              False                   False
# ...            ...       ...                ...                     ...
# 3316           NaN       NaN              False                   False
# 3317           NaN       NaN              False                   False
# 3318           NaN       NaN              False                   False
# 3319           NaN       NaN              False                   False
# 3320           NaN       NaN              False                   False
#
#                    provinceKeywords                            wardKeywords
# 0     ["thudohanoi", "hanoi", "hn"]              ["phuonghongha", "hongha"]
# 1     ["thudohanoi", "hanoi", "hn"]              ["phuongbadinh", "badinh"]
# 2     ["thudohanoi", "hanoi", "hn"]              ["phuongngocha", "ngocha"]
# 3     ["thudohanoi", "hanoi", "hn"]            ["phuonggiangvo", "giangvo"]
# 4     ["thudohanoi", "hanoi", "hn"]          ["phuonghoankiem", "hoankiem"]
# ...                             ...                                     ...
# 3316         ["tinhcamau", "camau"]                  ["xaphutan", "phutan"]
# 3317         ["tinhcamau", "camau"]  ["xanguyenvietkhai", "nguyenvietkhai"]
# 3318         ["tinhcamau", "camau"]                    ["xatanan", "tanan"]
# 3319         ["tinhcamau", "camau"]      ["xaphanngochien", "phanngochien"]
# 3320         ["tinhcamau", "camau"]                  ["xadatmui", "datmui"]
#
# [3321 rows x 21 columns]

# %%
# Lấy danh sách các wardShortKey không trùng với bất kỳ hàng nào khác (trừ chính nó) và không trùng provinceShortKey
province_short_keys = set(df['provinceShortKey'].unique())
ward_short_key_counts = df['wardShortKey'].value_counts()

# Điều kiện wardUnique: xuất hiện đúng 1 lần và không nằm trong province_short_keys
df['wardUnique'] = df['wardShortKey'].map(ward_short_key_counts) == 1
df['wardUnique'] &= ~df['wardShortKey'].isin(province_short_keys)

# Chia nhỏ theo wardKeyDuplicated
df_ward_unique = df[df['wardUnique']]
df_ward_unique_accented = df_ward_unique[df_ward_unique['wardKeyDuplicated']]
df_ward_unique_no_accented = df_ward_unique[~df_ward_unique['wardKeyDuplicated']]

# Tạo dict bằng dictionary comprehension
DICT_UNIQUE_WARD_PROVINCE_NO_ACCENTED = {
    row['wardKey']: {
        'wardKeywords': json.loads(row['wardKeywords']),
        'provinceKey': row['provinceKey']
    }
    for _, row in df_ward_unique_no_accented.iterrows()
}

DICT_UNIQUE_WARD_PROVINCE_ACCENTED = {
    row['wardKey']: {
        'wardKeywords': json.loads(row['wardKeywords']),
        'provinceKey': row['provinceKey']
    }
    for _, row in df_ward_unique_accented.iterrows()
}

# %%
pickle_data = {
    'DICT_PROVINCE': DICT_PROVINCE,
    'DICT_PROVINCE_WARD_NO_ACCENTED': DICT_PROVINCE_WARD_NO_ACCENTED,
    'DICT_PROVINCE_WARD_ACCENTED': DICT_PROVINCE_WARD_ACCENTED,
    'DICT_UNIQUE_WARD_PROVINCE_NO_ACCENTED': DICT_UNIQUE_WARD_PROVINCE_NO_ACCENTED,
    'DICT_UNIQUE_WARD_PROVINCE_ACCENTED': DICT_UNIQUE_WARD_PROVINCE_ACCENTED
}

# %%
with open(BASE_DIR / 'vietnamadminunits/data/parser_34.json', 'w') as f:
    json.dump(pickle_data, f)
