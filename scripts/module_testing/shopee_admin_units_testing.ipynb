# %%
from vietnamadminunits.pandas import standardize_admin_unit_columns
from vietnamadminunits.database import get_data
import pandas as pd

# %%
df = pd.read_csv('data/shopee_admin_units.csv')

# %%
standardized_df = standardize_admin_unit_columns(df, province='province', district='district', ward='ward', parse_mode='LEGACY')
# Out:
# Standardizing unique administrative units: 100%|██████████| 10690/10690 [00:01<00:00, 8588.13it/s]

# %%
standardized_df
# Out:
#                     ward          district         province  \
# 0             Xã An Hiệp  Huyện Châu Thành        Đồng Tháp
# 1                Xã Laêê   Huyện Nam Giang        Quảng Nam
# 2           Xã Kiến Quốc  Huyện Ninh Giang        Hải Dương
# 3         Xã Quảng Phong      Huyện Hải Hà       Quảng Ninh
# 4      Xã Điện Thắng Nam   Thị Xã Điện Bàn        Quảng Nam
# ...                  ...               ...              ...
# 10685          Phường 12       Quận Gò Vấp  TP. Hồ Chí Minh
# 10686      Xã Linh Thông    Huyện Định Hóa      Thái Nguyên
# 10687       Xã Bằng Luân   Huyện Đoan Hùng          Phú Thọ
# 10688         Xã Cẩm Yên  Huyện Thạch Thất           Hà Nội
# 10689       Xã Quỳnh Tam   Huyện Quỳnh Lưu          Nghệ An
#
#       standardized_province standardized_district standardized_ward
# 0                 Đồng Tháp            Châu Thành           An Hiệp
# 1                 Quảng Nam             Nam Giang             La Êê
# 2                 Hải Dương            Ninh Giang              None
# 3                Quảng Ninh                Hải Hà       Quảng Phong
# 4                 Quảng Nam              Điện Bàn    Điện Thắng Nam
# ...                     ...                   ...               ...
# 10685           Hồ Chí Minh                Gò Vấp         Phường 12
# 10686           Thái Nguyên              Định Hóa        Linh Thông
# 10687               Phú Thọ             Đoan Hùng         Bằng Luân
# 10688                Hà Nội            Thạch Thất           Cẩm Yên
# 10689               Nghệ An             Quỳnh Lưu         Quỳnh Tam
#
# [10690 rows x 6 columns]

# %%
standardized_df.to_excel('tmp/shopee_admin_units.xlsx', index=False)

# %%
df = pd.DataFrame(get_data(table='admin_units_legacy'))

# %%
df[(df['provinceKey'].str.contains('binhphuoc')) & (df['districtKey'].str.contains('chonthanh'))][['province', 'district', 'districtShort', 'provinceKey', 'districtKey', 'ward', 'wardKey', 'wardKeywords']].drop_duplicates()
# Out:
#              province           district districtShort    provinceKey  \
# 7756  Tỉnh Bình Phước  Thị xã Chơn Thành    Chơn Thành  tinhbinhphuoc
# 7757  Tỉnh Bình Phước  Thị xã Chơn Thành    Chơn Thành  tinhbinhphuoc
# 7758  Tỉnh Bình Phước  Thị xã Chơn Thành    Chơn Thành  tinhbinhphuoc
# 7759  Tỉnh Bình Phước  Thị xã Chơn Thành    Chơn Thành  tinhbinhphuoc
# 7760  Tỉnh Bình Phước  Thị xã Chơn Thành    Chơn Thành  tinhbinhphuoc
# 7761  Tỉnh Bình Phước  Thị xã Chơn Thành    Chơn Thành  tinhbinhphuoc
# 7762  Tỉnh Bình Phước  Thị xã Chơn Thành    Chơn Thành  tinhbinhphuoc
# 7763  Tỉnh Bình Phước  Thị xã Chơn Thành    Chơn Thành  tinhbinhphuoc
# 7764  Tỉnh Bình Phước  Thị xã Chơn Thành    Chơn Thành  tinhbinhphuoc
#
#          districtKey               ward          wardKey  \
# 7756  thixachonthanh   Phường Hưng Long   phuonghunglong
# 7757  thixachonthanh   Phường Thành Tâm   phuongthanhtam
# 7758  thixachonthanh        Xã Minh Lập        xaminhlap
# 7759  thixachonthanh      Xã Quang Minh      xaquangminh
# 7760  thixachonthanh   Phường Minh Hưng   phuongminhhung
# 7761  thixachonthanh   Phường Minh Long   phuongminhlong
# 7762  thixachonthanh  Phường Minh Thành  phuongminhthanh
# 7763  thixachonthanh        Xã Nha Bích        xanhabich
# 7764  thixachonthanh      Xã Minh Thắng      xaminhthang
#
#                           wardKeywords
# 7756    ["phuonghunglong", "hunglong"]
# 7757    ["phuongthanhtam", "thanhtam"]
# 7758          ["xaminhlap", "minhlap"]
# 7759      ["xaquangminh", "quangminh"]
# 7760    ["phuongminhhung", "minhhung"]
# 7761    ["phuongminhlong", "minhlong"]
# 7762  ["phuongminhthanh", "minhthanh"]
# 7763          ["xanhabich", "nhabich"]
# 7764      ["xaminhthang", "minhthang"]
