# %%
import pandas as pd
import numpy as np
from unidecode import unidecode
import re
import unicodedata
from pathlib import Path

import warnings
warnings.filterwarnings('ignore')

BASE_DIR = Path().resolve().parent.parent

# %%
def fill_district(truocsapnhap):
    parts = truocsapnhap.split(', ')
    current_district = None
    filled = []

    # Loop từ phải qua trái
    for part in reversed(parts):
        # Tìm district trong ngoặc
        m = re.search(r'\((.*?)\)', part)
        if m:
            current_district = m.group(1)
        # Nếu chưa có district thì bỏ qua
        if current_district:
            # Bỏ ngoặc cũ nếu có
            part = re.sub(r'\(.*?\)', '', part).strip()
            part = f"{part} ({current_district})"
        filled.append(part)

    # Đảo lại đúng thứ tự ban đầu
    filled = list(reversed(filled))
    return ', '.join(filled)


def extract_district(truocsapnhap):
    unit = truocsapnhap.split(' (')
    district = np.nan
    if len(unit) > 1:
        district = unit[1][:-1]
        if ' - Tỉnh ' in district:
            district = district.split(' - Tỉnh ')[0]
    return district


def extract_province(truocsapnhap):
    unit = truocsapnhap.split(' (')
    province = np.nan
    if len(unit) > 1:
        district = unit[1][:-1]
        if ' - Tỉnh ' in district:
            province = district.split(' - ')[1]
    return province


def extract_ward(truocsapnhap):
    unit = truocsapnhap.split(' (')
    ward = unit[0]
    return ward


def cap_first(text):
    '''
    Capitalize the first character of a string
    :param text: str
    :return: str or np.nan
    '''
    if isinstance(text, str):
        split_text = text.split()
        split_text = [i[0].capitalize() + i[1:] if split_text.index(i) == 0 else i for i in split_text]
        return ' '.join(split_text)
    return np.nan


def lower_safely(text):
    '''
    Lower string ignore NaN
    :param text:
    :return:
    '''
    if isinstance(text, str):
        return text.lower()
    return np.nan


def unidecode_pro(text):
    '''
    Xóa dấu tiếng Việt và các ký tự ngoài số và chữ
    :param text: str
    :return: str or np.nan
    '''
    if isinstance(text, str):
        text = unidecode(text)
        text = re.sub(r'[^a-zA-Z0-9\,]+', ' ', text)  # Chỉ giữ a-z, A-Z, 0-9 và dấu phẩy, thay phần còn lại bằng khoảng trắng
        text = re.sub(r'\s+', ' ', text) # Strip double space
        return text.strip().lower()
    return np.nan


def unicode_normalize(text):
    '''
    Chuyển Unicode tổ hợp sang Unicode dựng sẵn, fix lỗi gõ dấu bằng ký tự đặc biệt
    :param text: str
    :return: str or np.nan
    '''
    if isinstance(text, str):
        text = unicodedata.normalize('NFC', text)
        text = text.replace("’", "'").replace("‘", "'").replace("“", '"').replace("”", '"').strip() # Normalize quotes
        return text
    return text

# %% [markdown]
# # Chuẩn bị danh mục 63 tỉnh thành

# %%
# Ward level is not includes 5 islands
df_danhmuc_ward = pd.read_csv(BASE_DIR /'data/danhmuchanhchinh.gso.gov.vn_2025-07-18.csv')
rename_cols = {
    'Mã': 'wardCode',
    'Mã QH': 'districtCode',
    'Mã TP': 'provinceCode',
    'Cấp': 'wardType',
    'Tên': 'ward',
    'Quận Huyện': 'district',
    'Tỉnh / Thành Phố': 'province'
}
df_danhmuc_ward = df_danhmuc_ward.rename(columns=rename_cols)[rename_cols.values()]

# %%
# District level includes 5 islands
df_danhmuc_district = pd.read_csv(BASE_DIR / 'data/danhmuchanhchinh.gso.gov.vn_district_2025-07-18.csv')
rename_cols = {
    'Mã': 'districtCode',
    'Mã TP': 'provinceCode',
    'Cấp': 'districtType',
    'Tên': 'district',
    'Tỉnh / Thành Phố': 'province'
}

df_danhmuc_district = df_danhmuc_district.rename(columns=rename_cols)[rename_cols.values()]

# %%
# 63 provinces units
common = list(set(df_danhmuc_ward.columns.tolist()) & set(df_danhmuc_district.columns.tolist()))
df_danhmuc = pd.merge(df_danhmuc_district, df_danhmuc_ward, on=common, how='left')

# %%
print('df_danhmuc_ward.shape:', df_danhmuc_ward.shape)
print('df_danhmuc_district.shape:', df_danhmuc_district.shape)
print('df_danhmuc.shape:', df_danhmuc.shape)
# Out:
# df_danhmuc_ward.shape: (10035, 7)
# df_danhmuc_district.shape: (696, 5)
# df_danhmuc.shape: (10040, 8)

# %%
# Check NaN wards, It would be an island district
df_danhmuc[df_danhmuc['ward'].isna()]
# Out:
#       districtCode  provinceCode districtType            district  \
# 3582           318            31        Huyện  Huyện Bạch Long Vĩ
# 5794           471            45        Huyện        Huyện Cồn Cỏ
# 5975           498            48        Huyện      Huyện Hoàng Sa
# 6379           536            51        Huyện        Huyện Lý Sơn
# 8196           755            77        Huyện       Huyện Côn Đảo
#
#                     province  wardCode wardType ward
# 3582     Thành phố Hải Phòng       NaN      NaN  NaN
# 5794          Tỉnh Quảng Trị       NaN      NaN  NaN
# 5975       Thành phố Đà Nẵng       NaN      NaN  NaN
# 6379         Tỉnh Quảng Ngãi       NaN      NaN  NaN
# 8196  Tỉnh Bà Rịa - Vũng Tàu       NaN      NaN  NaN

# %% [markdown]
# # Sáp nhập province

# %%
df_sapnhap_province = pd.read_csv(BASE_DIR / 'data/sapnhap.bando.com.vn_province.csv')

# Enrich data
df_sapnhap_province['isMergedProvince'] = np.where(df_sapnhap_province['truocsapnhap']=='không sáp nhập', False, True)

# Unpivot
df_sapnhap_province['truocsapnhap'] = df_sapnhap_province['truocsapnhap'].str.replace(' và ', ', ')
df_sapnhap_province['truocsapnhap'] = df_sapnhap_province['truocsapnhap'].str.split(',\s*')
df_sapnhap_province = df_sapnhap_province.explode('truocsapnhap').reset_index(drop=True)

# Fill un-merged province name for truocsapnhap
df_sapnhap_province['truocsapnhap'] = np.where(df_sapnhap_province['isMergedProvince']==True, df_sapnhap_province['truocsapnhap'], df_sapnhap_province['tentinh'])

# Capitalize the first character
df_sapnhap_province['truocsapnhap'] = df_sapnhap_province['truocsapnhap'].apply(cap_first)
df_sapnhap_province['tentinh'] = df_sapnhap_province['tentinh'].apply(cap_first)

# %%
df_sapnhap_province
# Out:
#     id  mahc            tentinh dientichkm2 dansonguoi        trungtamhc  \
# 0    1     1      Thủ đô Hà Nội    3.359,80  8.718.000        giữ nguyên
# 1    2     7      Tỉnh Cao Bằng    6.700,40    555.809        giữ nguyên
# 2    3     8   Tỉnh Tuyên Quang   13.795,50  1.865.270  Tuyên Quang (cũ)
# 3    3     8   Tỉnh Tuyên Quang   13.795,50  1.865.270  Tuyên Quang (cũ)
# 4    4     9       Tỉnh Lào Cai   13.256,92  1.778.785      Yên Bái (cũ)
# ..  ..   ...                ...         ...        ...               ...
# 58  33    33  Thành phố Cần Thơ    6.360,83  4.199.824      Cần Thơ (cũ)
# 59  33    33  Thành phố Cần Thơ    6.360,83  4.199.824      Cần Thơ (cũ)
# 60  33    33  Thành phố Cần Thơ    6.360,83  4.199.824      Cần Thơ (cũ)
# 61  34    34        Tỉnh Cà Mau    7.942,39  2.606.672       Cà mau (cũ)
# 62  34    34        Tỉnh Cà Mau    7.942,39  2.606.672       Cà mau (cũ)
#
#      kinhdo      vido       truocsapnhap                             con  \
# 0   105.698  21.00010      Thủ đô Hà Nội  126 ĐVHC (51 phường và 75 xã)
# 1   106.083  22.74560      Tỉnh Cao Bằng      56 ĐVHC (03 phường, 53 xã)
# 2   105.099  22.48970      Tỉnh Hà Giang  124 ĐVHC (07 phường, 117 xã)\n
# 3   105.099  22.48970   Tỉnh Tuyên Quang  124 ĐVHC (07 phường, 117 xã)\n
# 4   104.347  22.06050       Tỉnh Yên Bái      99 ĐVHC (10 phường, 89 xã)
# ..      ...       ...                ...                             ...
# 58  105.757   9.74372  Thành phố Cần Thơ   103 ĐVHC (31 phường và 72 xã)
# 59  105.757   9.74372     Tỉnh Sóc Trăng   103 ĐVHC (31 phường và 72 xã)
# 60  105.757   9.74372     Tỉnh Hậu Giang   103 ĐVHC (31 phường và 72 xã)
# 61  105.182   9.13620      Tỉnh Bạc Liêu      64 ĐVHC (09 phường, 55 xã)
# 62  105.182   9.13620        Tỉnh Cà Mau      64 ĐVHC (09 phường, 55 xã)
#
#     isMergedProvince
# 0              False
# 1              False
# 2               True
# 3               True
# 4               True
# ..               ...
# 58              True
# 59              True
# 60              True
# 61              True
# 62              True
#
# [63 rows x 11 columns]

# %%
# Check missmatch province
df_sapnhap_province[~df_sapnhap_province['truocsapnhap'].isin(df_danhmuc['province'])]
# Out:
#     id  mahc                tentinh dientichkm2  dansonguoi    trungtamhc  \
# 0    1     1          Thủ đô Hà Nội    3.359,80   8.718.000    giữ nguyên
# 14  11    12           Tỉnh Phú Thọ    9.361,38   4.022.638  Phú Thọ (cũ)
# 48  29    29  Thành phố Hồ Chí Minh    6.772,59  14.002.598  Tp. HCM (cũ)
#
#      kinhdo     vido   truocsapnhap  \
# 0   105.698  21.0001  Thủ đô Hà Nội
# 14  105.333  20.7065  Tỉnh Hòa Bình
# 48  106.638  10.9926          TPHCM
#
#                                             con  isMergedProvince
# 0                126 ĐVHC (51 phường và 75 xã)             False
# 14                 148 ĐVHC (15 phường, 133 xã)              True
# 48  168 ĐVHC (01 đặc khu, 113 phường, 54 xã)              True

# %%
# Correct province name follow df_danhmuc
df_sapnhap_province.loc[df_sapnhap_province['truocsapnhap']=='Thủ đô Hà Nội', 'truocsapnhap'] = 'Thành phố Hà Nội'
df_sapnhap_province.loc[df_sapnhap_province['truocsapnhap']=='TPHCM', 'truocsapnhap'] = 'Thành phố Hồ Chí Minh'
df_sapnhap_province.loc[df_sapnhap_province['truocsapnhap']=='Tỉnh Hòa Bình', 'truocsapnhap'] = 'Tỉnh Hoà Bình'

# %%
# Merge to df_danhmuc
rename_cols = {
    'truocsapnhap': 'province',
    'mahc': 'newProvinceCode',
    'tentinh': 'newProvince',
    'vido': 'newProvinceLat',
    'kinhdo': 'newProvinceLon',
    'isMergedProvince': 'isMergedProvince',
}
df_sapnhap_province = df_sapnhap_province.rename(columns=rename_cols)[rename_cols.values()]

df_danhmuc = pd.merge(df_danhmuc, df_sapnhap_province, on='province', how='left')

# %%
df_danhmuc
# Out:
#        districtCode  provinceCode districtType         district  \
# 0                 1             1         Quận     Quận Ba Đình
# 1                 1             1         Quận     Quận Ba Đình
# 2                 1             1         Quận     Quận Ba Đình
# 3                 1             1         Quận     Quận Ba Đình
# 4                 1             1         Quận     Quận Ba Đình
# ...             ...           ...          ...              ...
# 10035           973            96        Huyện  Huyện Ngọc Hiển
# 10036           973            96        Huyện  Huyện Ngọc Hiển
# 10037           973            96        Huyện  Huyện Ngọc Hiển
# 10038           973            96        Huyện  Huyện Ngọc Hiển
# 10039           973            96        Huyện  Huyện Ngọc Hiển
#
#                province  wardCode  wardType               ward  \
# 0      Thành phố Hà Nội       1.0    Phường     Phường Phúc Xá
# 1      Thành phố Hà Nội       4.0    Phường   Phường Trúc Bạch
# 2      Thành phố Hà Nội       6.0    Phường   Phường Vĩnh Phúc
# 3      Thành phố Hà Nội       7.0    Phường     Phường Cống Vị
# 4      Thành phố Hà Nội       8.0    Phường   Phường Liễu Giai
# ...                 ...       ...       ...                ...
# 10035       Tỉnh Cà Mau   32239.0        Xã    Xã Viên An Đông
# 10036       Tỉnh Cà Mau   32242.0        Xã         Xã Viên An
# 10037       Tỉnh Cà Mau   32244.0  Thị trấn  Thị trấn Rạch Gốc
# 10038       Tỉnh Cà Mau   32245.0        Xã          Xã Tân Ân
# 10039       Tỉnh Cà Mau   32248.0        Xã         Xã Đất Mũi
#
#        newProvinceCode    newProvince  newProvinceLat  newProvinceLon  \
# 0                    1  Thủ đô Hà Nội         21.0001         105.698
# 1                    1  Thủ đô Hà Nội         21.0001         105.698
# 2                    1  Thủ đô Hà Nội         21.0001         105.698
# 3                    1  Thủ đô Hà Nội         21.0001         105.698
# 4                    1  Thủ đô Hà Nội         21.0001         105.698
# ...                ...            ...             ...             ...
# 10035               34    Tỉnh Cà Mau          9.1362         105.182
# 10036               34    Tỉnh Cà Mau          9.1362         105.182
# 10037               34    Tỉnh Cà Mau          9.1362         105.182
# 10038               34    Tỉnh Cà Mau          9.1362         105.182
# 10039               34    Tỉnh Cà Mau          9.1362         105.182
#
#        isMergedProvince
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 10035              True
# 10036              True
# 10037              True
# 10038              True
# 10039              True
#
# [10040 rows x 13 columns]

# %%
if df_danhmuc['newProvince'].isna().sum():
    raise Exception('There are mismatched provinces')

# %%
df_danhmuc
# Out:
#        districtCode  provinceCode districtType         district  \
# 0                 1             1         Quận     Quận Ba Đình
# 1                 1             1         Quận     Quận Ba Đình
# 2                 1             1         Quận     Quận Ba Đình
# 3                 1             1         Quận     Quận Ba Đình
# 4                 1             1         Quận     Quận Ba Đình
# ...             ...           ...          ...              ...
# 10035           973            96        Huyện  Huyện Ngọc Hiển
# 10036           973            96        Huyện  Huyện Ngọc Hiển
# 10037           973            96        Huyện  Huyện Ngọc Hiển
# 10038           973            96        Huyện  Huyện Ngọc Hiển
# 10039           973            96        Huyện  Huyện Ngọc Hiển
#
#                province  wardCode  wardType               ward  \
# 0      Thành phố Hà Nội       1.0    Phường     Phường Phúc Xá
# 1      Thành phố Hà Nội       4.0    Phường   Phường Trúc Bạch
# 2      Thành phố Hà Nội       6.0    Phường   Phường Vĩnh Phúc
# 3      Thành phố Hà Nội       7.0    Phường     Phường Cống Vị
# 4      Thành phố Hà Nội       8.0    Phường   Phường Liễu Giai
# ...                 ...       ...       ...                ...
# 10035       Tỉnh Cà Mau   32239.0        Xã    Xã Viên An Đông
# 10036       Tỉnh Cà Mau   32242.0        Xã         Xã Viên An
# 10037       Tỉnh Cà Mau   32244.0  Thị trấn  Thị trấn Rạch Gốc
# 10038       Tỉnh Cà Mau   32245.0        Xã          Xã Tân Ân
# 10039       Tỉnh Cà Mau   32248.0        Xã         Xã Đất Mũi
#
#        newProvinceCode    newProvince  newProvinceLat  newProvinceLon  \
# 0                    1  Thủ đô Hà Nội         21.0001         105.698
# 1                    1  Thủ đô Hà Nội         21.0001         105.698
# 2                    1  Thủ đô Hà Nội         21.0001         105.698
# 3                    1  Thủ đô Hà Nội         21.0001         105.698
# 4                    1  Thủ đô Hà Nội         21.0001         105.698
# ...                ...            ...             ...             ...
# 10035               34    Tỉnh Cà Mau          9.1362         105.182
# 10036               34    Tỉnh Cà Mau          9.1362         105.182
# 10037               34    Tỉnh Cà Mau          9.1362         105.182
# 10038               34    Tỉnh Cà Mau          9.1362         105.182
# 10039               34    Tỉnh Cà Mau          9.1362         105.182
#
#        isMergedProvince
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 10035              True
# 10036              True
# 10037              True
# 10038              True
# 10039              True
#
# [10040 rows x 13 columns]

# %% [markdown]
# # Sáp nhập ward

# %% [markdown]
# ## Unpivot

# %%
df_sapnhap_ward = pd.read_csv(BASE_DIR / 'data/sapnhap.bando.com.vn_ward.csv')

# Remove và replace text
# df_sapnhap_ward[df_sapnhap_ward['truocsapnhap'].str.contains('\(')]['truocsapnhap']
removed_texts = [
    ', Trường bắn TB1',
    ', Khu vực bãi bồi ven biển \(do huyện Kim Sơn quản lý\)',
    '\(phần còn lại.*?\)',
    '\(bao gồm.*?\)',
    '\(một phần.*?\)',
    '\(do huyện.*?\)',
]

replaced_texts = [
    (' và ', ', '),
    ('(thuộc huyện ', '(huyện '),

    # Chỉ có 2 huyện này có thông tin tỉnh
    # Nên giữ tỉnh thành để merge không bị duplicate Thị trấn Châu Thành, Huyện Châu Thành
    ('(huyện Châu Thành, tỉnh Bến Tre)', '(Huyện Châu Thành - Tỉnh Bến Tre)'),
    ('(huyện Châu Thành, tỉnh Trà Vinh)', '(Huyện Châu Thành - Tỉnh Trà Vinh)')
]

for text in removed_texts:
    df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].str.replace(text, '', regex=True).str.strip()

for old, new in replaced_texts:
    df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].str.replace(old, new, regex=False).str.strip()

# Capitalize the first character for province
df_sapnhap_ward['tentinh'] = df_sapnhap_ward['tentinh'].apply(cap_first)

# Correct name for province (Must do after capitalizing)
df_sapnhap_ward['tentinh'].replace('Tỉnh Ninh BÌnh', 'Tỉnh Ninh Bình', inplace=True)

# %%
# Add isMergedWard
df_sapnhap_ward['isMergedWard'] = np.where(df_sapnhap_ward['truocsapnhap']=='Không sáp nhập', False, True)

# Unpivot
df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].apply(fill_district)
df_sapnhap_ward['truocsapnhap'] = df_sapnhap_ward['truocsapnhap'].str.split(',\s*')
df_sapnhap_ward = df_sapnhap_ward.explode('truocsapnhap').reset_index(drop=True)

# %%
# Extract ward, district, province from truocsapnhap
df_sapnhap_ward['province'] = df_sapnhap_ward['truocsapnhap'].apply(extract_province)
df_sapnhap_ward['district'] = df_sapnhap_ward['truocsapnhap'].apply(extract_district)
df_sapnhap_ward['ward'] = df_sapnhap_ward['truocsapnhap'].apply(extract_ward)

# Fill un-merged ward name for truocsapnhap
df_sapnhap_ward['ward'] = np.where(df_sapnhap_ward['isMergedWard']==False, df_sapnhap_ward['loai'].str.capitalize() + ' ' + df_sapnhap_ward['tenhc'], df_sapnhap_ward['ward'])

# Capitalize the first character for ward and district
df_sapnhap_ward['ward'] = df_sapnhap_ward['ward'].apply(cap_first)
df_sapnhap_ward['district'] = df_sapnhap_ward['district'].apply(cap_first)

# %%
# Bring district value in ward column to district column
# df_sapnhap_ward[df_sapnhap_ward['ward'].str.contains('^Huyện')]
df_sapnhap_ward['district'] = np.where(df_sapnhap_ward['ward'].str.contains('^Huyện'), df_sapnhap_ward['ward'], df_sapnhap_ward['district'])
df_sapnhap_ward['ward'] = np.where(df_sapnhap_ward['ward'].str.contains('^Huyện'), np.nan, df_sapnhap_ward['ward'])

# %%
# Rename for next steps
rename_cols = {
    'province': 'province',
    'district': 'district',
    'ward': 'ward',
    'isMergedWard': 'isMergedWard',

    'tenhc': 'newWard',
    'tentinh': 'newProvince',
    'ma': 'newWardCode',
    'loai': 'newWardType',
    'kinhdo': 'newWardLon',
    'vido': 'newWardLat',
    'dientichkm2': 'newWardAreaKm2',
    'truocsapnhap': 'truocsapnhap',

}
df_sapnhap_ward = df_sapnhap_ward.rename(columns=rename_cols)[rename_cols.values()]

# %%
# Check 2 provinces have "Huyện Châu Thành"
df_sapnhap_ward[~df_sapnhap_ward['province'].isna()]
# Out:
#              province            district                 ward  isMergedWard  \
# 9222  Tỉnh Trà Vinh  Huyện Châu Thành  Thị trấn Châu Thành          True
# 9374   Tỉnh Bến Tre  Huyện Châu Thành  Thị trấn Châu Thành          True
#
#           newWard     newProvince  newWardCode newWardType  newWardLon  \
# 9222  Châu Thành  Tỉnh Vĩnh Long         2880          xã     106.337
# 9374      Phú Túc  Tỉnh Vĩnh Long         2934          xã     106.318
#
#       newWardLat  newWardAreaKm2  \
# 9222     9.83937           47.71
# 9374    10.30100           63.14
#
#                                            truocsapnhap
# 9222  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...
# 9374  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...

# %%
if df_sapnhap_ward[~df_sapnhap_ward['newProvince'].isin(df_danhmuc['newProvince'])].shape[0]:
    raise Exception('There are mismatched provinces')
# df_sapnhap_ward[~df_sapnhap_ward['newProvince'].isin(df_danhmuc['newProvince'])]['newProvince'].drop_duplicates()

# %%
df_sapnhap_ward
# Out:
#       province            district              ward  isMergedWard  \
# 0          NaN                 NaN        Xã Đông La          True
# 1          NaN                 NaN  Phường Dương Nội          True
# 2          NaN                 NaN       Xã An Khánh          True
# 3          NaN                 NaN         Xã La Phù          True
# 4          NaN                 NaN    Xã Song Phương          True
# ...        ...                 ...               ...           ...
# 10562      NaN                 NaN   Xã Vĩnh Phú Tây          True
# 10563      NaN                 NaN       Xã Hưng Phú          True
# 10564      NaN                 NaN     Xã Vĩnh Thanh          True
# 10565      NaN  Thành phố Bạc Liêu          Phường 5          True
# 10566      NaN                 NaN     Xã Vĩnh Trạch          True
#
#             newWard    newProvince  newWardCode newWardType  newWardLon  \
# 0          An Khánh  Thủ đô Hà Nội            2          xã     105.708
# 1          An Khánh  Thủ đô Hà Nội            2          xã     105.708
# 2          An Khánh  Thủ đô Hà Nội            2          xã     105.708
# 3          An Khánh  Thủ đô Hà Nội            2          xã     105.708
# 4          An Khánh  Thủ đô Hà Nội            2          xã     105.708
# ...             ...            ...          ...         ...         ...
# 10562  Vĩnh Phước    Tỉnh Cà Mau         3353          xã     105.410
# 10563   Vĩnh Thanh    Tỉnh Cà Mau         3354          xã     105.519
# 10564   Vĩnh Thanh    Tỉnh Cà Mau         3354          xã     105.519
# 10565  Vĩnh Trạch    Tỉnh Cà Mau         3355      phường     105.774
# 10566  Vĩnh Trạch    Tỉnh Cà Mau         3355      phường     105.774
#
#        newWardLat  newWardAreaKm2                   truocsapnhap
# 0        20.98760           28.69                     Xã Đông La
# 1        20.98760           28.69              Phường Dương Nội
# 2        20.98760           28.69                   Xã An Khánh
# 3        20.98760           28.69                     Xã La Phù
# 4        20.98760           28.69                Xã Song Phương
# ...           ...             ...                            ...
# 10562     9.39891           75.50                Xã Vĩnh Phú Tây
# 10563     9.35997           37.37                    Xã Hưng Phú
# 10564     9.35997           37.37                  Xã Vĩnh Thanh
# 10565     9.29729           10.22  Phường 5 (thành phố Bạc Liêu)
# 10566     9.29729           10.22                  Xã Vĩnh Trạch
#
# [10567 rows x 12 columns]

# %% [markdown]
# ## Kiểm tra chính tả 2 bên
#
# Vòng lặp kiểm tra như sau:
# - Bước 1: Kiểm tra tìm unit không khớp của bảng df_sapnhap_ward
# - Bước 2: Sửa chính tả ở bảng df_sapnhap_ward hoặc df_danhmuc.
# - Quay lại Bước 1

# %%
def correct_basic_spelling(text):
    basic_spelling = [
        ('Hoà', 'Hòa'),
        ('Hoè', 'Hòe'),
        ('Hoá', 'Hóa'),
        ('Hoả', 'Hỏa'),
        ('Khoá', 'Khóa'),
        ('Thuỵ' ,'Thụy'),
        ('Thuỷ', 'Thủy'),
        ('\' ', "'")
    ]

    if isinstance(text, str):
        for wrong, right in basic_spelling:
            pattern = r'\b' + wrong + r'\b'
            text = re.sub(pattern, right, text)
    return text

# %%
# Correct spelling
for col in ['province', 'district', 'ward']:
    # Convert Unicode
    df_danhmuc[col] = df_danhmuc[col].apply(unicode_normalize)
    df_sapnhap_ward[col] = df_sapnhap_ward[col].apply(unicode_normalize)
    # Correct basic spelling
    df_danhmuc[col] = df_danhmuc[col].apply(correct_basic_spelling)
    df_sapnhap_ward[col] = df_sapnhap_ward[col].apply(correct_basic_spelling)


spelling_danhmuc = [
    # newProvince, ward, correct ward
    ('Tỉnh Hưng Yên', 'Xã An Quí', 'Xã An Quý'),
    ('Tỉnh Hưng Yên', 'Xã Kim Chung', 'Xã Kim Trung'),
    ('Tỉnh Hưng Yên', 'Xã Vũ Quí', 'Xã Vũ Quý'),
    ('Tỉnh Tuyên Quang', 'Xã Quí Quân', 'Xã Quý Quân'),
    ('Tỉnh Tuyên Quang', 'Xã Sán Xả Hồ', 'Xã Sán Sả Hồ'),
    ('Tỉnh Tuyên Quang', 'Xã Xà Phìn', 'Xã Sà Phìn'),
    ('Tỉnh Tuyên Quang', 'Xã Sủng Tráng', 'Xã Sủng Cháng'),
    ('Tỉnh Lào Cai', 'Xã Hát Lìu', 'Xã Hát Lừu'),
    ('Tỉnh Lào Cai', 'Thị trấn NT Liên Sơn', 'Thị trấn Nông trường Liên Sơn'),
    ('Tỉnh Lào Cai', 'Xã Nậm Rạng', 'Xã Nậm Dạng'),
    ('Tỉnh Thái Nguyên', 'Xã Sĩ Bình', 'Xã Sỹ Bình'),
    ('Tỉnh Lạng Sơn', 'Thị trấn NT Thái Bình', 'Thị trấn Nông trường Thái Bình'),
    ('Tỉnh Phú Thọ', 'Xã Săm Khóe', 'Xã Xăm Khòe'),
    ('Tỉnh Điện Biên', 'Xã Xá Tổng', 'Xã Sá Tổng'),
    ('Tỉnh Điện Biên', 'Xã Huổi Lếnh', 'Xã Huổi Lếch'),
    ('Tỉnh Điện Biên', 'Xã Sáng Nhè', 'Xã Xá Nhè'),
    ('Tỉnh Điện Biên', 'Xã Xín Chải', 'Xã Sín Chải'),
    ('Tỉnh Lai Châu', 'Xã Tông Qua Lìn', 'Xã Tung Qua Lìn'),
    ('Tỉnh Lai Châu', 'Xã Lả Nhì Thàng', 'Xã Lản Nhì Thàng'),
    ('Tỉnh Lai Châu', 'Xã Hua Bun', 'Xã Hua Bum'),
    ('Tỉnh Lai Châu', 'Xã Ma Ly Pho', 'Xã Ma Li Pho'),
    ('Tỉnh Sơn La', 'Xã Pú Pẩu', 'Xã Pú Bẩu'),
    ('Tỉnh Sơn La', 'Xã Noong Lay', 'Xã Nong Lay'),
    ('Tỉnh Nghệ An', 'Phường Thu Thuỷ', 'Phường Thu Thủy'),
    ('Tỉnh Nghệ An', 'Xã Hưng Yên', 'Xã Hưng Yên Nam'),
    ('Tỉnh Quảng Trị', 'Xã Đa Krông', 'Xã Đakrông'),
    ('Tỉnh Quảng Trị', 'Thị trấn NT Lệ Ninh', 'Thị trấn Nông trường Lệ Ninh'),
    ('Tỉnh Quảng Trị', 'Thị trấn NT Việt Trung', 'Thị trấn Nông trường Việt Trung'),
    ('Thành phố Đà Nẵng', 'Xã Bha Lê', 'Xã Bha Lêê'),
    ('Thành phố Đà Nẵng', 'Xã Tà Bhinh', 'Xã Tà Bhing'),
    ('Thành phố Đà Nẵng', 'Xã Mà Cooi', 'Xã Mà Cooih'),
    ('Thành phố Đà Nẵng', 'Thị trấn P Rao', 'Thị Trấn Prao'),
    ('Thành phố Đà Nẵng', 'Xã Laêê', 'Xã La Êê'),
    ('Thành phố Đà Nẵng', 'Xã Zuôich', 'Xã Zuôih'),
    ('Tỉnh Quảng Ngãi', 'Xã Bờ Y', 'Xã Pờ Y'),
    ('Tỉnh Quảng Ngãi', 'Xã Măng Buk', 'Xã Măng Bút'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngọc Yêu', 'Xã Ngọk Yêu'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngọc Lây', 'Xã Ngọk Lây'),
    ('Tỉnh Gia Lai', 'Xã Đăk Roong', 'Xã Đăk Rong'),
    ('Tỉnh Gia Lai', 'Xã H Bông', 'Xã HBông'),
    ('Tỉnh Gia Lai', 'Xã Ia Ma Rơn', 'Xã Ia Mrơn'),
    ('Tỉnh Gia Lai', "Xã K'Dang", 'Xã KDang'),
    ('Tỉnh Gia Lai', "Xã H'Neng", 'Xã Hneng'),
    ('Tỉnh Đắk Lắk', "Xã Ea H'đinh", "Xã Ea H'đing"),
    ('Tỉnh Đắk Lắk', 'Xã Cư K Róa', 'Xã Cư Króa'),
    ('Tỉnh Đắk Lắk', 'Xã Cư Jang', 'Xã Cư Yang'),
    ('Tỉnh Đắk Lắk', 'Xã EaBia', 'Xã Ea Bia'),
    ('Tỉnh Đắk Lắk', 'Xã Ealy', 'Xã Ea Ly'),
    ('Tỉnh Đắk Lắk', 'Xã Cư Ê Wi', 'Xã Cư Êwi'),
    ('Tỉnh Đắk Lắk', "Xã Ea R'Bin", 'Xã Ea Rbin'),
    ('Tỉnh Đắk Lắk', 'Xã EaTrol', 'Xã Ea Trol'),
    ('Tỉnh Đắk Lắk', 'Xã Eachà Rang', 'Xã Ea Chà Rang'),
    ('Tỉnh Lào Cai', 'Thị trấn N.T Phong Hải', 'Thị trấn Nông trường Phong Hải'),
    ('Tỉnh Lào Cai', 'Xã Dế Su Phình', 'Xã Dế Xu Phình'),
    ('Tỉnh Lào Cai', 'Xã Nàn Xín', 'Xã Nàn Sín'),
    ('Tỉnh Lào Cai', 'Thị trấn NT Trần Phú', 'Thị trấn Nông trường Trần Phú'),
    ('Tỉnh Lâm Đồng', 'Xã Đạm Bri', "Xã Đamb'ri"),
    ('Tỉnh Lâm Đồng', "Xã Đắk N'Dung", "Xã Đắk N'Drung"),
    ('Tỉnh Lâm Đồng', "Xã Đắk DRông", "Xã Đắk D'rông"),
    ('Tỉnh Lâm Đồng', 'Xã Thuận Quí', 'Xã Thuận Quý'),
    ('Thành phố Hồ Chí Minh', 'Xã Quy Đức', 'Xã Qui Đức'),
    ('Tỉnh Vĩnh Long', 'Xã An Quy', 'Xã An Qui'),
    ('Tỉnh Vĩnh Long', 'Xã Lục Sỹ Thành', 'Xã Lục Sĩ Thành'),
    ('Tỉnh An Giang', 'Xã Ô Long Vỹ', 'Xã Ô Long Vĩ'),
    ('Thành phố Cần Thơ', 'Xã Hòa Tú II', 'Xã Hòa Tú 2'),
    ('Tỉnh Đắk Lắk', 'Xã EaBar', 'Xã Ea Bar'),
    ('Tỉnh Đắk Lắk', "Xã Ea D'rơng", 'Xã Ea Drơng'),
    ('Thủ đô Hà Nội', 'Phường Phương Liên - Trung Tự', 'Phường Phương Liên Trung Tự'),
    ('Thủ đô Hà Nội', 'Phường Văn Miếu - Quốc Tử Giám', 'Phường Văn Miếu Quốc Tử Giám'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Rơ Ông', 'Xã Đăk Rơ Ông'),
    ('Tỉnh Cao Bằng', 'Xã Phong Nậm', 'Xã Phong Nặm'),
    ('Tỉnh Tuyên Quang', 'Xã Nậm Tỵ', 'Xã Nậm Ty'),
    ('Tỉnh Tuyên Quang', 'Thị trấn Phó Bảng', 'Thị trấn Phố Bảng'),
    ('Tỉnh Tuyên Quang', 'Xã Khau Tinh', 'Xã Khâu Tinh'),
    ('Tỉnh Lào Cai', 'Thị trấn Mù Căng Chải', 'Thị trấn Mù Cang Chải'),
    ('Tỉnh Lào Cai', 'Xã Nậm Chầy', 'Xã Nậm Chày'),
    ('Tỉnh Lào Cai', 'Xã Tả Ngải Chồ', 'Xã Tả Ngài Chồ'),
    ('Tỉnh Thái Nguyên', 'Phường Quán Triều', 'Phường Quan Triều'),
    ('Tỉnh Phú Thọ', 'Xã Mi Hòa', 'Xã Mỵ Hòa'),
    ('Tỉnh Điện Biên', 'Xã Luân Giới', 'Xã Luân Giói'),
    ('Tỉnh Điện Biên', 'Xã Pú Nhi', 'Xã Pu Nhi'),
    ('Tỉnh Điện Biên', 'Xã Noọng Hẹt', 'Xã Noong Hẹt'),
    ('Tỉnh Lai Châu', 'Xã Pa Vệ Sử', 'Xã Pa Vệ Sủ'),
    ('Tỉnh Lai Châu', 'Xã Tà Gia', 'Xã Ta Gia'),
    ('Tỉnh Sơn La', 'Xã Nậm Ét', 'Xã Nặm Ét'),
    ('Tỉnh Sơn La' , 'Xã Nà Ơt', 'Xã Nà Ớt'),
    ('Tỉnh Thanh Hóa', 'Xã Vân Âm', 'Xã Vân Am'),
    ('Tỉnh Thanh Hóa', 'Xã Văn Sơn', 'Xã Vân Sơn'),
    ('Tỉnh Nghệ An', 'Xã Lưỡng Minh', 'Xã Lượng Minh'),
    ('Tỉnh Nghệ An', 'Xã Căm Muộn', 'Xã Cắm Muộn'),
    ('Tỉnh Hà Tĩnh', 'Xã Cỗ Đạm', 'Xã Cổ Đạm'),
    ('Thành phố Đà Nẵng', 'Xã Ka Dăng', 'Xã Kà Dăng'),
    ('Thành phố Đà Nẵng', 'Xã Za Hung', 'Xã Zà Hung'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngok Tem', 'Xã Ngọc Tem'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngok Wang', 'Xã Ngọk Wang'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngok Réo', 'Xã Ngọk Réo'),
    ('Tỉnh Quảng Ngãi', 'Xã Rơ Kơi', 'Xã Rờ Kơi'),
    ('Tỉnh Gia Lai', 'Xã Chư Đăng Ya', 'Xã Chư Đang Ya'),
    ('Tỉnh Gia Lai', 'Xã Chư Krêy', 'Xã Chư Krey'),
    ('Tỉnh Gia Lai', 'Thị trấn Đăk Đoa', 'Thị trấn Đak Đoa'),
    ('Tỉnh Gia Lai', 'Xã Đăk Sơmei', 'Xã Đak Sơmei'),
    ('Tỉnh Gia Lai', 'Xã Ia KRai', 'Xã Ia Krăi'),
    ('Tỉnh Gia Lai', 'Xã Đăk Krong', 'Xã Đak Krong'),
    ('Tỉnh Gia Lai', 'Xã Đăk Djrăng', 'Xã Đak Djrăng'),
    ('Tỉnh Gia Lai', 'Xã Ia Mláh', 'Xã Ia Mlăh'),
    ('Tỉnh Đắk Lắk', 'Xã Cuor Đăng', 'Xã Cuôr Đăng'),
    ('Tỉnh Đắk Lắk', 'Xã ĐLiê Ya', 'Xã Dliê Ya'),
    ('Tỉnh Đắk Lắk', 'Xã Ea KNuec', 'Xã Ea Knuếc'),
    ('Tỉnh Đắk Lắk', "Xã Ea M'DRóh", "Xã Ea M'Droh"),
    ('Tỉnh Đắk Lắk', "Xã Chư KBô", "Xã Chứ Kbô"),
    ('Tỉnh Đắk Lắk', "Thị trấn M'Đrắk", "Thị trấn M'Drắk"),
    ('Tỉnh Đắk Lắk', "Xã Ea Puk", "Xã Ea Púk"),
    ('Tỉnh Lâm Đồng', "Xã Đạ M'Rong", "Xã Đạ M'Rông"),
    ('Tỉnh Lâm Đồng', "Xã Buôn Choah", "Xã Buôn Choáh"),
    ('Tỉnh Lâm Đồng', "Xã Đăk DRông", "Xã Đăk D'rông"),
    ('Tỉnh Đồng Nai', "Xã Dak Lua", "Xã Đắc Lua"),
    ('Tỉnh Vĩnh Long', "Xã Qưới Sơn", "Xã Quới Sơn"),
    ('Tỉnh Vĩnh Long', "Xã Vĩnh Kim", "Xã Vinh Kim"),
    ('Tỉnh An Giang', "Phường Vĩnh Ngươn", "Phường Vĩnh Nguơn"),
    ('Thành phố Cần Thơ', "Thị trấn Thanh An", "Thị trấn Thạnh An"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Xú", "Xã Đăk Xú"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Cấm", "Xã Đăk Cấm"),
    ('Tỉnh Quảng Ngãi', "Thị trấn Đắk Hà", "Thị trấn Đăk Hà"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk La", "Xã Đăk La"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Tơ Lung", "Xã Đăk Tơ Lung"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Kôi", "Xã Đăk Kôi"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Hring", "Xã Đăk Hring"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Mar", "Xã Đăk Mar"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Kroong", "Xã Đăk Kroong"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Môn", "Xã Đăk Môn"),
    ('Tỉnh Quảng Ngãi', "Thị trấn Đắk Glei", "Thị trấn Đăk Glei"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Pék", "Xã Đăk Pék"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Nhoong", "Xã Đăk Nhoong"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Man", "Xã Đăk Man"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Blô", "Xã Đăk Blô"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Pxi", "Xã Đăk Pxi"),
    ('Tỉnh Quảng Ngãi', "Xã Đắk Blà", "Xã Đăk Blà"),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Rơ Wa', 'Xã Đăk Rơ Wa'),
    ('Tỉnh Quảng Ngãi', 'Thị trấn Đắk Rve', 'Thị trấn Đăk Rve'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Pne', 'Xã Đăk Pne'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Na', 'Xã Đăk Na'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Sao', 'Xã Đăk Sao'),
    ('Tỉnh Quảng Ngãi', 'Thị trấn Đắk Tô', 'Thị trấn Đăk Tô'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Tờ Kan', 'Xã Đăk Tờ Kan'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Ui', 'Xã Đăk Ui'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Ang', 'Xã Đăk Ang'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Dục', 'Xã Đăk Dục'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Nông', 'Xã Đăk Nông'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Tờ Re', 'Xã Đăk Tờ Re'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Ruồng', 'Xã Đăk Ruồng'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Trăm', 'Xã Đăk Trăm'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Nên', 'Xã Đăk Nên'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Ring', 'Xã Đăk Ring'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Tăng', 'Xã Đăk Tăng'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Rơ Nga', 'Xã Đăk Rơ Nga'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Kan', 'Xã Đăk Kan'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Hà', 'Xã Đăk Hà'),
    ('Tỉnh Quảng Ngãi', 'Xã Đắk Choong', 'Xã Đăk Choong'),
    ('Tỉnh Gia Lai', 'Xã Đắk Kơ Ning', 'Xã Đăk Kơ Ning'),
    ('Tỉnh Lâm Đồng', "Xã Đăk R'Moan", "Xã Đắk R'Moan"),
    ('Thành phố Hải Phòng', 'Xã Bình Lăng', 'Xã Bình Lãng'),

]

spelling_sapnhap = [
    # newProvince, ward, correct ward
    ('Tỉnh Ninh Bình', 'Phường Tiên Sơn', 'Xã Tiên Sơn'),
    ('Tỉnh Thái Nguyên', 'Xã Đắc Sơn', 'Phường Đắc Sơn'),
    ('Tỉnh Lai Châu', 'Xã Can Hồ', 'Xã Kan Hồ'),
    ('Tỉnh Sơn La', 'Phường Thảo Ngu Yên', 'Phường Thảo Nguyên'),
    ('Tỉnh Sơn La', 'Xã Xí M Vàng', 'Xã Xím Vàng'),
    ('Tỉnh Nghệ An', 'Xã Thu Thủy', 'Phường Thu Thủy'),
    ('Thành phố Huế', 'Phường Đúc', 'Phường Phường Đúc'),
    ('Thành phố Đà Nẵng', 'Xã Bhalêê', 'Xã Bha Lêê'),
    ('Thành phố Đà Nẵng', 'Xã Avương', 'Xã A Vương'),
    ('Thành phố Đà Nẵng', 'Xã Gari', 'Xã Ga Ri'),
    ('Thành phố Đà Nẵng', 'Xã Axan', 'Xã A Xan'),
    ('Thành phố Đà Nẵng', 'Xã Atiêng', 'Xã A Tiêng'),
    ('Thành phố Đà Nẵng', 'Xã Anông', 'Xã A Nông'),
    ('Tỉnh Quảng Ngãi', 'Lê Lợi', 'Phường Lê Lợi'),
    ('Tỉnh Quảng Ngãi', 'Nguyễn Trãi', 'Phường Nguyễn Trãi'),
    ('Tỉnh Quảng Ngãi', 'Xã Đăk Plô', 'Xã Đăk Blô'),
    ('Tỉnh Quảng Ngãi', 'Phổ Hòa', 'Phường Phổ Hòa'),
    ('Tỉnh Quảng Ngãi', 'Phổ Minh', 'Phường Phổ Minh'),
    ('Tỉnh Quảng Ngãi', 'Phổ Vinh', 'Phường Phổ Vinh'),
    ('Tỉnh Quảng Ngãi', 'Phổ Ninh', 'Phường Phổ Ninh'),
    ('Tỉnh Gia Lai', 'Xã Chơ GLong', 'Xã Chơ Long'),
    ('Tỉnh Gia Lai', 'Xã Adơk', 'Xã A Dơk'),
    ('Tỉnh Gia Lai', 'Xã Ia Dreh', 'Ia HDreh'),
    ('Tỉnh Đắk Lắk', 'Krông Na', 'Xã Krông Na'),
    ('Tỉnh Đắk Lắk', 'Xã Cư Dliê Mnông', "Xã Cư Dliê M'nông"),
    ('Tỉnh Lâm Đồng', 'Xã ĐamBri', "Xã Đamb'ri"),
    ('Tỉnh Lâm Đồng', "Xã Cư K'nia", 'Xã Cư Knia'),
    ('Tỉnh Lâm Đồng', 'Thị trấn Mađaguôi', 'Thị trấn Ma Đa Guôi'),
    ('Tỉnh Lâm Đồng', 'Xã Mađaguôi', 'Xã Ma Đa Guôi'),
    ('Tỉnh Lào Cai', 'Xã Tà Xi Láng', 'Xã Tà Si Láng'),
    ('Tỉnh Gia Lai', 'Ia HDreh', 'Xã Ia HDreh'),
    ('Tỉnh Lâm Đồng', "Xã Đưng K'Nớ", 'Xã Đưng KNớ'),
    ('Tỉnh Lâm Đồng', "Xã N'Thôn Hạ", "Xã N'Thol Hạ"),
    ('Tỉnh Tây Ninh', 'Thủ Thừa', 'Thị trấn Thủ Thừa'),
    ('Tỉnh Tây Ninh', 'Phường IV', 'Phường 4'),
    ('Tỉnh Đồng Nai', 'Xã Xuân An', 'Phường Xuân An'),
    ('Tỉnh Đồng Nai', 'Xã Xuân Bình', 'Phường Xuân Bình'),
    ('Thành phố Hồ Chí Minh', 'Rạch Ông', 'Phường Rạch Ông'),
    ('Tỉnh Đồng Tháp', 'Xã Mỹ Quí', 'Xã Mỹ Quý'),
    ('Thành phố Cần Thơ', 'Xã Tân Lộc', 'Phường Tân Lộc'),
    ('Tỉnh Lào Cai', 'Xã Thẳm Dương', 'Xã Thẩm Dương'),
    ('Tỉnh Sơn La', 'Xã Nặm Păm', 'Xã Nậm Păm'),
    ('Tỉnh Quảng Ngãi', 'Xã Ngọk Tem', 'Xã Ngọc Tem'),
    ('Tỉnh Gia Lai', 'Xã Ia Drang', 'Xã Ia Drăng'),
    ('Tỉnh Gia Lai', 'Xã Đak Rong', 'Xã Đăk Rong'),
    ('Tỉnh Gia Lai', 'Xã Ia Krái', 'Xã Ia Krăi'),
    ('Tỉnh Gia Lai', 'Xã Ia Trôk', 'Xã Ia Trok'),
    ('Tỉnh Gia Lai', 'Xã Đak Trôi', 'Xã Đăk Trôi'),
    ('Tỉnh Gia Lai', 'Xã Ia Mlah', 'Xã Ia Mlăh'),
    ('Tỉnh Đắk Lắk', 'Xã Ea Khăl', 'Xã Ea Khal'),
    ('Tỉnh Đồng Nai', "Xã Đak Lua", "Xã Đắc Lua"),
    ('Tỉnh Đồng Nai', "Xã Đăk Ơ", "Xã Đak Ơ"),

]

# Nhận thấy các lỗi sai thường là: qui - quy, s - x, \bch - \btr, nt - nong truong, 2 - II, 4 - IV (Số la mã), ngok - ngoc. Sau này sẽ tạo key cho tính năng parse address

for s in spelling_danhmuc:
    newProvince, ward, WardCorrect = s
    df_danhmuc.loc[(df_danhmuc['newProvince']==newProvince) & (df_danhmuc['ward'].fillna('').str.lower()==ward.lower()), 'ward'] = WardCorrect

for s in spelling_sapnhap:
    newProvince, ward, WardCorrect = s
    df_sapnhap_ward.loc[(df_sapnhap_ward['newProvince']==newProvince) & (df_sapnhap_ward['ward'].fillna('').str.lower()==ward.lower()), 'ward'] = WardCorrect

# %%
# Case đặc biệt: Sau khi merge xong mới kiểm tra ra, phải quay lại bổ sung ở bước này
df_sapnhap_ward.loc[(df_sapnhap_ward['newProvince']=='Tỉnh Đồng Nai') & (df_sapnhap_ward['newWard']=='Long Khánh') & (df_sapnhap_ward['ward']=='Xã Xuân Hòa'), 'ward'] = 'Phường Xuân Hòa'
df_sapnhap_ward.loc[(df_sapnhap_ward['newProvince']=='Tỉnh Đồng Nai') & (df_sapnhap_ward['newWard']=='Long Khánh') & (df_sapnhap_ward['ward']=='Xã Phú Bình'), 'ward'] = 'Phường Phú Bình'
df_danhmuc.loc[(df_danhmuc['province']=='Tỉnh Kon Tum') & (df_danhmuc['district']=='Huyện Đắk Glei') & (df_danhmuc['ward']=='Xã Đắk Long'), 'ward'] = 'Xã Đăk Long'

# %%
# Tạo các cột để tiện làm việc

def create_format_cols():
    for col in ['district', 'ward']:
        # Unidecode để tiện filter và kiểm tra
        df_danhmuc[f'{col}Ud'] = df_danhmuc[col].apply(unidecode_pro)
        df_sapnhap_ward[f'{col}Ud'] = df_sapnhap_ward[col].apply(unidecode_pro)

        # Lower giúp merge dễ hơn nhưng an toàn hơn unidecode. Vì có có những ward chỉ khác dấu tiếng Việt trong cùng một province hay một district
        df_danhmuc[f'{col}Lower'] = df_danhmuc[col].apply(lower_safely)
        df_sapnhap_ward[f'{col}Lower'] = df_sapnhap_ward[col].apply(lower_safely)


create_format_cols()

# %%
# Tạo bộ key để kiểm tra mismatched

# Case 1: Có newProvince, province, district, ward. Đã biết chỉ có 2 province.
key1 = 'keyNewProvinceProvinceDistrictWard'

# Case 2: Có newProvince, district, ward.
# Có sai nhiều do fill_district không phải luôn đúng, Vậy nên:
# - Kiểm tra mismached: Chỉ kiểm tra mismatched cho cho key3 và key4, không kiểm tra key2.
# - Merge: Một phần key2 sẽ match, phần còn lại sẽ bỏ district và đưa vào key4
key2 = 'keyNewProvinceDistrictWard'

# Case 3: Có newProvince, district.
key3 = 'keyNewProvinceDistrict'

# Case 4: Có newProvince, ward.
key4 = 'keyNewProvinceWard'

def create_key_cols(for_merging=False):
    '''
    Create a function for reusable after fixed mismatched ward and before merging
    '''
    # Case 1
    for df in [df_sapnhap_ward, df_danhmuc]:
        df[key1] = np.where((~df['province'].isna()) & (~df['district'].isna()) & (~df['ward'].isna()), df['newProvince'] + '_' + df['province'] + '_' + df['districtLower'] + '_' + df['wardLower'], np.nan)

    # Case 2
    ## danhmuc
    df_danhmuc[key2] = np.where((~df_danhmuc['district'].isna()) & (~df_danhmuc['ward'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['districtLower'] + '_' + df_danhmuc['wardLower'], np.nan)

    ## sapnhap
    if for_merging:
        df_sapnhap_ward[key2] = np.where((~df_sapnhap_ward['district'].isna()) & (~df_sapnhap_ward['ward'].isna())
                                         & (df_sapnhap_ward['province'].isna()), # Thêm province là nan
                                         df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtLower'] + '_' + df_sapnhap_ward['wardLower'], np.nan)
    else:
        df_sapnhap_ward[key2] = np.where((~df_sapnhap_ward['district'].isna()) & (~df_sapnhap_ward['ward'].isna()),
                                         df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtLower'] + '_' + df_sapnhap_ward['wardLower'], np.nan)

    # Case 3
    ## danh muc
    df_danhmuc[key3] = np.where((~df_danhmuc['district'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['districtLower'], np.nan)

    ## sapnhap
    if for_merging:
        df_sapnhap_ward[key3] = np.where((~df_sapnhap_ward['district'].isna())
                                         & (df_sapnhap_ward['ward'].isna()), # Thêm ward là nan
                                         df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtLower'], np.nan)
    else:
        df_sapnhap_ward[key3] = np.where((~df_sapnhap_ward['district'].isna()),
                                         df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['districtLower'], np.nan)

    ## Case 4
    ## danhmuc
    df_danhmuc[key4] = np.where((~df_danhmuc['ward'].isna()), df_danhmuc['newProvince'] + '_' + df_danhmuc['wardLower'], np.nan)

    ## sapnhap
    if for_merging:
        df_sapnhap_ward[key4] = np.where((~df_sapnhap_ward['ward'].isna())
                                         & (df_sapnhap_ward['district'].isna()), # Thêm district là nan
                                         df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['wardLower'], np.nan)
    else:
        df_sapnhap_ward[key4] = np.where((~df_sapnhap_ward['ward'].isna()),
                                         df_sapnhap_ward['newProvince'] + '_' + df_sapnhap_ward['wardLower'], np.nan)

# Thực hiện tạo key
# create_key_cols()

# %%
def create_key_cols(for_merging=False):
    """
    Tạo các cột key để phục vụ kiểm tra mismatched và merge dữ liệu.
    Gồm 4 case: key1, key2, key3, key4 với từng điều kiện khác nhau.
    """

    def gen_key(df, condition, columns, key_name):
        df[key_name] = np.where(condition, df[columns[0]], np.nan)
        for col in columns[1:]:
            df[key_name] = np.where(condition, df[key_name] + '_' + df[col], df[key_name])

    # --- Các key cần tạo ---
    keys = {
        key1: {
            'condition': lambda df: df['province'].notna() & df['district'].notna() & df['ward'].notna(),
            'columns': ['newProvince', 'province', 'districtLower', 'wardLower']
        },
        key2: {
            'condition': lambda df: df['district'].notna() & df['ward'].notna(),
            'columns': ['newProvince', 'districtLower', 'wardLower']
        },
        key3: {
            'condition': lambda df: df['district'].notna(),
            'columns': ['newProvince', 'districtLower']
        },
        key4: {
            'condition': lambda df: df['ward'].notna(),
            'columns': ['newProvince', 'wardLower']
        },
    }

    # --- df_danhmuc ---
    for key, conf in keys.items():
        gen_key(df_danhmuc, conf['condition'](df_danhmuc), conf['columns'], key)

    # --- df_sapnhap_ward ---
    for key, conf in keys.items():
        cond = conf['condition'](df_sapnhap_ward)

        # Xử lý riêng một số case trong chế độ for_merging
        if for_merging:
            if key == key2:
                cond = cond & df_sapnhap_ward['province'].isna()
            elif key == key3:
                cond = cond & df_sapnhap_ward['ward'].isna()
            elif key == key4:
                cond = cond & df_sapnhap_ward['district'].isna()

        gen_key(df_sapnhap_ward, cond, conf['columns'], key)


create_key_cols()

# %%
# Preview df_sapnhap_ward (2 province duy nhất trong dataset này)
df_sapnhap_ward[~df_sapnhap_ward[key1].isna()]
# Out:
#            province          district                 ward  isMergedWard  \
# 9222  Tỉnh Trà Vinh  Huyện Châu Thành  Thị trấn Châu Thành          True
# 9374   Tỉnh Bến Tre  Huyện Châu Thành  Thị trấn Châu Thành          True
#
#           newWard     newProvince  newWardCode newWardType  newWardLon  \
# 9222  Châu Thành  Tỉnh Vĩnh Long         2880          xã     106.337
# 9374      Phú Túc  Tỉnh Vĩnh Long         2934          xã     106.318
#
#       newWardLat  newWardAreaKm2  \
# 9222     9.83937           47.71
# 9374    10.30100           63.14
#
#                                            truocsapnhap        districtUd  \
# 9222  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
# 9374  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
#
#          districtLower               wardUd            wardLower  \
# 9222  huyện châu thành  thi tran chau thanh  thị trấn châu thành
# 9374  huyện châu thành  thi tran chau thanh  thị trấn châu thành
#
#                      keyNewProvinceProvinceDistrictWard  \
# 9222  Tỉnh Vĩnh Long_Tỉnh Trà Vinh_huyện châu thành_...
# 9374  Tỉnh Vĩnh Long_Tỉnh Bến Tre_huyện châu thành_t...
#
#                              keyNewProvinceDistrictWard  \
# 9222  Tỉnh Vĩnh Long_huyện châu thành_thị trấn châu ...
# 9374  Tỉnh Vĩnh Long_huyện châu thành_thị trấn châu ...
#
#                keyNewProvinceDistrict                  keyNewProvinceWard
# 9222  Tỉnh Vĩnh Long_huyện châu thành  Tỉnh Vĩnh Long_thị trấn châu thành
# 9374  Tỉnh Vĩnh Long_huyện châu thành  Tỉnh Vĩnh Long_thị trấn châu thành

# %%
# Preview df_danhmuc (Các đảo thì không có ward)
df_danhmuc[df_danhmuc[key1].isna()]
# Out:
#       districtCode  provinceCode districtType            district  \
# 3582           318            31        Huyện  Huyện Bạch Long Vĩ
# 5794           471            45        Huyện        Huyện Cồn Cỏ
# 5975           498            48        Huyện      Huyện Hoàng Sa
# 6379           536            51        Huyện        Huyện Lý Sơn
# 8196           755            77        Huyện       Huyện Côn Đảo
#
#                     province  wardCode wardType ward  newProvinceCode  \
# 3582     Thành phố Hải Phòng       NaN      NaN  NaN                4
# 5794          Tỉnh Quảng Trị       NaN      NaN  NaN               19
# 5975       Thành phố Đà Nẵng       NaN      NaN  NaN               21
# 6379         Tỉnh Quảng Ngãi       NaN      NaN  NaN               22
# 8196  Tỉnh Bà Rịa - Vũng Tàu       NaN      NaN  NaN               29
#
#                 newProvince  ...  newProvinceLon  isMergedProvince  \
# 3582    Thành phố Hải Phòng  ...         106.470              True
# 5794         Tỉnh Quảng Trị  ...         106.527              True
# 5975      Thành phố Đà Nẵng  ...         107.966              True
# 6379        Tỉnh Quảng Ngãi  ...         108.143              True
# 8196  Thành phố Hồ Chí Minh  ...         106.638              True
#
#               districtUd       districtLower wardUd wardLower  \
# 3582  huyen bach long vi  huyện bạch long vĩ    NaN       NaN
# 5794        huyen con co        huyện cồn cỏ    NaN       NaN
# 5975      huyen hoang sa      huyện hoàng sa    NaN       NaN
# 6379        huyen ly son        huyện lý sơn    NaN       NaN
# 8196       huyen con dao       huyện côn đảo    NaN       NaN
#
#      keyNewProvinceProvinceDistrictWard keyNewProvinceDistrictWard  \
# 3582                                NaN                        NaN
# 5794                                NaN                        NaN
# 5975                                NaN                        NaN
# 6379                                NaN                        NaN
# 8196                                NaN                        NaN
#
#                       keyNewProvinceDistrict keyNewProvinceWard
# 3582  Thành phố Hải Phòng_huyện bạch long vĩ                NaN
# 5794             Tỉnh Quảng Trị_huyện cồn cỏ                NaN
# 5975        Thành phố Đà Nẵng_huyện hoàng sa                NaN
# 6379            Tỉnh Quảng Ngãi_huyện lý sơn                NaN
# 8196     Thành phố Hồ Chí Minh_huyện côn đảo                NaN
#
# [5 rows x 21 columns]

# %%
# Check Key 1
df_sapnhap_ward[~df_sapnhap_ward[key1].isin(df_danhmuc[key1])]
# Key 1 is valid fully
# Out:
# Empty DataFrame
# Columns: [province, district, ward, isMergedWard, newWard, newProvince, newWardCode, newWardType, newWardLon, newWardLat, newWardAreaKm2, truocsapnhap, districtUd, districtLower, wardUd, wardLower, keyNewProvinceProvinceDistrictWard, keyNewProvinceDistrictWard, keyNewProvinceDistrict, keyNewProvinceWard]
# Index: []

# %%
# Check Key 3
df_sapnhap_ward[~df_sapnhap_ward[key3].isin(df_danhmuc[key3]) & (~df_sapnhap_ward[key3].isna())][['newProvince', 'district', 'districtUd']].drop_duplicates()
# Out:
#           newProvince       district     districtUd
# 6668  Tỉnh Quảng Ngãi   Huyện Đăk Hà   huyen dak ha
# 7250     Tỉnh Gia Lai  Huyện Đak Đoa  huyen dak doa

# %%
# Chổ để tìm ward bị mismatch trong df_danhmuc
condition1 = (df_danhmuc['newProvince'] == 'Tỉnh Gia Lai')
condition2 = (df_danhmuc['districtUd'].fillna('').str.contains('dak doa'))
df_danhmuc[condition1 & condition2][['newProvince', 'province', 'district', 'districtUd']].drop_duplicates()
# Out:
#        newProvince      province       district     districtUd
# 7111  Tỉnh Gia Lai  Tỉnh Gia Lai  Huyện Đăk Đoa  huyen dak doa

# %%
# Fix case 3 trực tiếp tại đây
df_danhmuc.loc[(df_danhmuc['province']=='Tỉnh Kon Tum') & (df_danhmuc['district']=='Huyện Đắk Hà'), 'district'] = 'Huyện Đăk Hà'
df_danhmuc.loc[(df_danhmuc['province']=='Tỉnh Gia Lai') & (df_danhmuc['district']=='Huyện Đăk Đoa'), 'district'] = 'Huyện Đak Đoa'

# %%
# Tạo lại các cột đẻ check lại key 3
create_format_cols()
create_key_cols()

# %%
# Check key 4
df_sapnhap_ward[~df_sapnhap_ward[key4].isin(df_danhmuc[key4]) & (~df_sapnhap_ward[key4].isna())][['newProvince', 'district', 'ward', 'wardUd', 'isMergedWard']].drop_duplicates()
# Chỉ còn "Xã Tân Phước" là không tồn tại ở Tỉnh Tuyên Quang và Tỉnh Hà Giang. Có lẽ dữ liệu của sapnhap bị sai chổ này
# Out:
#            newProvince district          ward        wardUd  isMergedWard
# 2738  Tỉnh Tuyên Quang      NaN  Xã Tân Phước  xa tan phuoc          True

# %%
# Chổ để tìm ward bị mismatch trong df_danhmuc
condition1 = (df_danhmuc['newProvince'] == 'Thành phố Hải Phòng')
condition2 = (df_danhmuc['wardUd'].fillna('').str.contains('binh lang'))
df_danhmuc[condition1 & condition2][['newProvince', 'province', 'district', 'ward', 'wardUd']].drop_duplicates()
# Out:
#               newProvince        province     district          ward  \
# 3365  Thành phố Hải Phòng  Tỉnh Hải Dương  Huyện Tứ Kỳ  Xã Bình Lãng
#
#             wardUd
# 3365  xa binh lang

# %% [markdown]
# ## Kiểm tra trước khi merge

# %%
# Thực hiện lại việc tạo key cho đã sửa chỉnh tả
create_format_cols()
create_key_cols(for_merging=True)

# %%
# Case 1
sapnhap1 = df_sapnhap_ward[~df_sapnhap_ward[key1].isna()]
sapnhap1
# Out:
#            province          district                 ward  isMergedWard  \
# 9222  Tỉnh Trà Vinh  Huyện Châu Thành  Thị trấn Châu Thành          True
# 9374   Tỉnh Bến Tre  Huyện Châu Thành  Thị trấn Châu Thành          True
#
#           newWard     newProvince  newWardCode newWardType  newWardLon  \
# 9222  Châu Thành  Tỉnh Vĩnh Long         2880          xã     106.337
# 9374      Phú Túc  Tỉnh Vĩnh Long         2934          xã     106.318
#
#       newWardLat  newWardAreaKm2  \
# 9222     9.83937           47.71
# 9374    10.30100           63.14
#
#                                            truocsapnhap        districtUd  \
# 9222  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
# 9374  Thị trấn Châu Thành (Huyện Châu Thành - Tỉn...  huyen chau thanh
#
#          districtLower               wardUd            wardLower  \
# 9222  huyện châu thành  thi tran chau thanh  thị trấn châu thành
# 9374  huyện châu thành  thi tran chau thanh  thị trấn châu thành
#
#                      keyNewProvinceProvinceDistrictWard  \
# 9222  Tỉnh Vĩnh Long_Tỉnh Trà Vinh_huyện châu thành_...
# 9374  Tỉnh Vĩnh Long_Tỉnh Bến Tre_huyện châu thành_t...
#
#      keyNewProvinceDistrictWard keyNewProvinceDistrict keyNewProvinceWard
# 9222                        NaN                    NaN                NaN
# 9374                        NaN                    NaN                NaN

# %%
# Case 2: Chỉ lấy phần có match, phần còn lại sẽ đưa vào Case 4b
sapnhap2 = df_sapnhap_ward[(~df_sapnhap_ward[key2].isna()) & (df_sapnhap_ward[key2].isin(df_danhmuc[key2]))]
sapnhap2
# Out:
#       province            district              ward  isMergedWard  \
# 20         NaN   Quận Hai Bà Trưng   Phường Bạch Mai          True
# 21         NaN   Quận Hai Bà Trưng  Phường Bách Khoa          True
# 22         NaN   Quận Hai Bà Trưng  Phường Quỳnh Mai          True
# 23         NaN   Quận Hai Bà Trưng  Phường Minh Khai          True
# 75         NaN     Huyện Phú Xuyên        Xã Tân Dân          True
# ...        ...                 ...               ...           ...
# 10521      NaN    Thành phố Cà Mau          Phường 5          True
# 10522      NaN    Thành phố Cà Mau  Phường Tân Thành          True
# 10523      NaN    Thành phố Cà Mau      Xã Tân Thành          True
# 10524      NaN    Thành phố Cà Mau          Phường 7          True
# 10565      NaN  Thành phố Bạc Liêu          Phường 5          True
#
#             newWard    newProvince  newWardCode newWardType  newWardLon  \
# 20         Bạch Mai  Thủ đô Hà Nội            5      phường     105.852
# 21         Bạch Mai  Thủ đô Hà Nội            5      phường     105.852
# 22         Bạch Mai  Thủ đô Hà Nội            5      phường     105.852
# 23         Bạch Mai  Thủ đô Hà Nội            5      phường     105.852
# 75        Chuyên Mỹ  Thủ đô Hà Nội           13          xã     105.884
# ...             ...            ...          ...         ...         ...
# 10521    Tân Thành    Tỉnh Cà Mau         3340      phường     105.217
# 10522    Tân Thành    Tỉnh Cà Mau         3340      phường     105.217
# 10523    Tân Thành    Tỉnh Cà Mau         3340      phường     105.217
# 10524    Tân Thành    Tỉnh Cà Mau         3340      phường     105.217
# 10565  Vĩnh Trạch    Tỉnh Cà Mau         3355      phường     105.774
#
#        newWardLat  newWardAreaKm2                          truocsapnhap  \
# 20       21.00220            2.95   Phường Bạch Mai (quận Hai Bà Trưng)
# 21       21.00220            2.95  Phường Bách Khoa (quận Hai Bà Trưng)
# 22       21.00220            2.95  Phường Quỳnh Mai (quận Hai Bà Trưng)
# 23       21.00220            2.95  Phường Minh Khai (quận Hai Bà Trưng)
# 75       20.71620           35.54          Xã Tân Dân (huyện Phú Xuyên)
# ...           ...             ...                                   ...
# 10521     9.18698           48.42           Phường 5 (thành phố Cà Mau)
# 10522     9.18698           48.42   Phường Tân Thành (thành phố Cà Mau)
# 10523     9.18698           48.42       Xã Tân Thành (thành phố Cà Mau)
# 10524     9.18698           48.42           Phường 7 (thành phố Cà Mau)
# 10565     9.29729           10.22         Phường 5 (thành phố Bạc Liêu)
#
#                districtUd       districtLower            wardUd  \
# 20      quan hai ba trung   quận hai bà trưng   phuong bach mai
# 21      quan hai ba trung   quận hai bà trưng  phuong bach khoa
# 22      quan hai ba trung   quận hai bà trưng  phuong quynh mai
# 23      quan hai ba trung   quận hai bà trưng  phuong minh khai
# 75        huyen phu xuyen     huyện phú xuyên        xa tan dan
# ...                   ...                 ...               ...
# 10521    thanh pho ca mau    thành phố cà mau          phuong 5
# 10522    thanh pho ca mau    thành phố cà mau  phuong tan thanh
# 10523    thanh pho ca mau    thành phố cà mau      xa tan thanh
# 10524    thanh pho ca mau    thành phố cà mau          phuong 7
# 10565  thanh pho bac lieu  thành phố bạc liêu          phuong 5
#
#               wardLower keyNewProvinceProvinceDistrictWard  \
# 20      phường bạch mai                                NaN
# 21     phường bách khoa                                NaN
# 22     phường quỳnh mai                                NaN
# 23     phường minh khai                                NaN
# 75           xã tân dân                                NaN
# ...                 ...                                ...
# 10521          phường 5                                NaN
# 10522  phường tân thành                                NaN
# 10523      xã tân thành                                NaN
# 10524          phường 7                                NaN
# 10565          phường 5                                NaN
#
#                              keyNewProvinceDistrictWard  \
# 20      Thủ đô Hà Nội_quận hai bà trưng_phường bạch mai
# 21     Thủ đô Hà Nội_quận hai bà trưng_phường bách khoa
# 22     Thủ đô Hà Nội_quận hai bà trưng_phường quỳnh mai
# 23     Thủ đô Hà Nội_quận hai bà trưng_phường minh khai
# 75             Thủ đô Hà Nội_huyện phú xuyên_xã tân dân
# ...                                                 ...
# 10521             Tỉnh Cà Mau_thành phố cà mau_phường 5
# 10522     Tỉnh Cà Mau_thành phố cà mau_phường tân thành
# 10523         Tỉnh Cà Mau_thành phố cà mau_xã tân thành
# 10524             Tỉnh Cà Mau_thành phố cà mau_phường 7
# 10565           Tỉnh Cà Mau_thành phố bạc liêu_phường 5
#
#       keyNewProvinceDistrict keyNewProvinceWard
# 20                       NaN                NaN
# 21                       NaN                NaN
# 22                       NaN                NaN
# 23                       NaN                NaN
# 75                       NaN                NaN
# ...                      ...                ...
# 10521                    NaN                NaN
# 10522                    NaN                NaN
# 10523                    NaN                NaN
# 10524                    NaN                NaN
# 10565                    NaN                NaN
#
# [903 rows x 20 columns]

# %%
# Case 3
sapnhap3 = df_sapnhap_ward[~df_sapnhap_ward[key3].isna()]
sapnhap3
# Out:
#      province            district ward  isMergedWard       newWard  \
# 1349      NaN  Huyện Bạch Long Vĩ  NaN          True  Bạch Long Vĩ
# 5960      NaN        Huyện Cồn Cỏ  NaN          True        Cồn Cỏ
# 6415      NaN      Huyện Hoàng Sa  NaN          True      Hoàng Sa
# 6734      NaN        Huyện Lý Sơn  NaN          True        Lý Sơn
# 8807      NaN       Huyện Côn Đảo  NaN          True       Côn Đảo
# 9931      NaN      Huyện Kiên Hải  NaN          True      Kiên Hải
#
#                 newProvince  newWardCode newWardType  newWardLon  newWardLat  \
# 1349    Thành phố Hải Phòng         1050     đặc khu    107.7307    20.13460
# 5960         Tỉnh Quảng Trị         1764     đặc khu    107.3390    17.15925
# 6415      Thành phố Đà Nẵng         1904     đặc khu    112.1350    16.56800
# 6734        Tỉnh Quảng Ngãi         2015     đặc khu    109.1150    15.38500
# 8807  Thành phố Hồ Chí Minh         2741     đặc khu    106.6115     8.69810
# 9931          Tỉnh An Giang         3125     đặc khu    104.6320     9.80000
#
#       newWardAreaKm2        truocsapnhap          districtUd  \
# 1349            3.07  Huyện Bạch Long Vĩ  huyen bach long vi
# 5960            2.30        Huyện Cồn Cỏ        huyen con co
# 6415          305.00      Huyện Hoàng Sa      huyen hoang sa
# 6734           10.39        Huyện Lý Sơn        huyen ly son
# 8807           75.79       Huyện Côn Đảo       huyen con dao
# 9931           21.81      Huyện Kiên Hải      huyen kien hai
#
#            districtLower wardUd wardLower keyNewProvinceProvinceDistrictWard  \
# 1349  huyện bạch long vĩ    NaN       NaN                                NaN
# 5960        huyện cồn cỏ    NaN       NaN                                NaN
# 6415      huyện hoàng sa    NaN       NaN                                NaN
# 6734        huyện lý sơn    NaN       NaN                                NaN
# 8807       huyện côn đảo    NaN       NaN                                NaN
# 9931      huyện kiên hải    NaN       NaN                                NaN
#
#      keyNewProvinceDistrictWard                  keyNewProvinceDistrict  \
# 1349                        NaN  Thành phố Hải Phòng_huyện bạch long vĩ
# 5960                        NaN             Tỉnh Quảng Trị_huyện cồn cỏ
# 6415                        NaN        Thành phố Đà Nẵng_huyện hoàng sa
# 6734                        NaN            Tỉnh Quảng Ngãi_huyện lý sơn
# 8807                        NaN     Thành phố Hồ Chí Minh_huyện côn đảo
# 9931                        NaN            Tỉnh An Giang_huyện kiên hải
#
#      keyNewProvinceWard
# 1349                NaN
# 5960                NaN
# 6415                NaN
# 6734                NaN
# 8807                NaN
# 9931                NaN

# %%
# Case 4a
sapnhap4a = df_sapnhap_ward[~df_sapnhap_ward[key4].isna()]
sapnhap4a
# Out:
#       province district              ward  isMergedWard       newWard  \
# 0          NaN      NaN        Xã Đông La          True      An Khánh
# 1          NaN      NaN  Phường Dương Nội          True      An Khánh
# 2          NaN      NaN       Xã An Khánh          True      An Khánh
# 3          NaN      NaN         Xã La Phù          True      An Khánh
# 4          NaN      NaN    Xã Song Phương          True      An Khánh
# ...        ...      ...               ...           ...           ...
# 10561      NaN      NaN     Xã Phước Long          True  Vĩnh Phước
# 10562      NaN      NaN   Xã Vĩnh Phú Tây          True  Vĩnh Phước
# 10563      NaN      NaN       Xã Hưng Phú          True   Vĩnh Thanh
# 10564      NaN      NaN     Xã Vĩnh Thanh          True   Vĩnh Thanh
# 10566      NaN      NaN     Xã Vĩnh Trạch          True  Vĩnh Trạch
#
#          newProvince  newWardCode newWardType  newWardLon  newWardLat  \
# 0      Thủ đô Hà Nội            2          xã     105.708    20.98760
# 1      Thủ đô Hà Nội            2          xã     105.708    20.98760
# 2      Thủ đô Hà Nội            2          xã     105.708    20.98760
# 3      Thủ đô Hà Nội            2          xã     105.708    20.98760
# 4      Thủ đô Hà Nội            2          xã     105.708    20.98760
# ...              ...          ...         ...         ...         ...
# 10561    Tỉnh Cà Mau         3353          xã     105.410     9.39891
# 10562    Tỉnh Cà Mau         3353          xã     105.410     9.39891
# 10563    Tỉnh Cà Mau         3354          xã     105.519     9.35997
# 10564    Tỉnh Cà Mau         3354          xã     105.519     9.35997
# 10566    Tỉnh Cà Mau         3355      phường     105.774     9.29729
#
#        newWardAreaKm2       truocsapnhap districtUd districtLower  \
# 0               28.69         Xã Đông La        NaN           NaN
# 1               28.69  Phường Dương Nội         NaN           NaN
# 2               28.69       Xã An Khánh         NaN           NaN
# 3               28.69         Xã La Phù         NaN           NaN
# 4               28.69    Xã Song Phương         NaN           NaN
# ...               ...                ...        ...           ...
# 10561           75.50      Xã Phước Long        NaN           NaN
# 10562           75.50    Xã Vĩnh Phú Tây        NaN           NaN
# 10563           37.37        Xã Hưng Phú        NaN           NaN
# 10564           37.37      Xã Vĩnh Thanh        NaN           NaN
# 10566           10.22      Xã Vĩnh Trạch        NaN           NaN
#
#                  wardUd         wardLower keyNewProvinceProvinceDistrictWard  \
# 0            xa dong la        xã đông la                                NaN
# 1      phuong duong noi  phường dương nội                                NaN
# 2           xa an khanh       xã an khánh                                NaN
# 3             xa la phu         xã la phù                                NaN
# 4        xa song phuong    xã song phương                                NaN
# ...                 ...               ...                                ...
# 10561     xa phuoc long     xã phước long                                NaN
# 10562   xa vinh phu tay   xã vĩnh phú tây                                NaN
# 10563       xa hung phu       xã hưng phú                                NaN
# 10564     xa vinh thanh     xã vĩnh thanh                                NaN
# 10566     xa vinh trach     xã vĩnh trạch                                NaN
#
#       keyNewProvinceDistrictWard keyNewProvinceDistrict  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 10561                        NaN                    NaN
# 10562                        NaN                    NaN
# 10563                        NaN                    NaN
# 10564                        NaN                    NaN
# 10566                        NaN                    NaN
#
#                    keyNewProvinceWard
# 0            Thủ đô Hà Nội_xã đông la
# 1      Thủ đô Hà Nội_phường dương nội
# 2           Thủ đô Hà Nội_xã an khánh
# 3             Thủ đô Hà Nội_xã la phù
# 4        Thủ đô Hà Nội_xã song phương
# ...                               ...
# 10561       Tỉnh Cà Mau_xã phước long
# 10562     Tỉnh Cà Mau_xã vĩnh phú tây
# 10563         Tỉnh Cà Mau_xã hưng phú
# 10564       Tỉnh Cà Mau_xã vĩnh thanh
# 10566       Tỉnh Cà Mau_xã vĩnh trạch
#
# [9604 rows x 20 columns]

# %%
# Case 4b: Là phần còn lại của Case 2. Phải replace value và tạo lại key
sapnhap4b = df_sapnhap_ward[(~df_sapnhap_ward[key2].isna()) & (~df_sapnhap_ward[key2].isin(df_danhmuc[key2]))]
sapnhap4b['district'] = np.nan
sapnhap4b['districtUd'] = np.nan
sapnhap4b[key4] = np.where((~sapnhap4b['ward'].isna()) & (sapnhap4b['district'].isna()), sapnhap4b['newProvince'] + '_' + sapnhap4b['wardLower'], np.nan)
sapnhap4b
# Out:
#      province  district                  ward  isMergedWard      newWard  \
# 181       NaN       NaN      Phường Thạch Bàn          True      Gia Lâm
# 242       NaN       NaN        Phường Tây Tựu          True     Hoài Đức
# 243       NaN       NaN            Xã Tân Lập          True     Hoài Đức
# 259       NaN       NaN     Phường Hoàng Liệt          True   Hoàng Liệt
# 357       NaN       NaN            Xã Văn Khê          True      Mê Linh
# 358       NaN       NaN            Xã Mê Linh          True      Mê Linh
# 359       NaN       NaN          Xã Đại Thịnh          True      Mê Linh
# 584       NaN       NaN        Phường Tây Tựu          True      Tây Tựu
# 620       NaN       NaN           Xã Đại Mạch          True    Thiên Lộc
# 621       NaN       NaN             Xã Kim Nỗ          True    Thiên Lộc
# 687       NaN       NaN       Phường Giáp Bát          True    Tương Mai
# 688       NaN       NaN    Phường Phương Liệt          True    Tương Mai
# 689       NaN       NaN       Phường Mai Động          True    Tương Mai
# 758       NaN       NaN    Phường Phương Canh          True  Xuân Phương
# 759       NaN       NaN    Phường Xuân Phương          True  Xuân Phương
# 760       NaN       NaN         Phường Đại Mỗ          True  Xuân Phương
# 761       NaN       NaN         Phường Tây Mỗ          True  Xuân Phương
# 762       NaN       NaN           Xã Vân Canh          True  Xuân Phương
# 1392      NaN       NaN          Xã Thanh Hải          True      Đại Sơn
# 1613      NaN       NaN   Thị trấn Trường Sơn          True     Phù Liễn
# 2006      NaN       NaN  Phường Lê Hồng Phong          True    Thái Bình
# 2007      NaN       NaN       Phường Bồ Xuyên          True    Thái Bình
# 2008      NaN       NaN     Phường Tiền Phong          True    Thái Bình
# 2100      NaN       NaN      Phường Phú Khánh          True      Vũ Phúc
# 7659      NaN       NaN       Phường Phú Đông          True      Phú Yên
# 7660      NaN       NaN        Phường Phú Lâm          True      Phú Yên
# 7661      NaN       NaN      Phường Phú Thạnh          True      Phú Yên
# 7724      NaN       NaN              Phường 1          True      Tuy Hòa
# 7725      NaN       NaN              Phường 2          True      Tuy Hòa
# 7726      NaN       NaN              Phường 4          True      Tuy Hòa
# 7727      NaN       NaN              Phường 5          True      Tuy Hòa
# 7728      NaN       NaN              Phường 7          True      Tuy Hòa
# 7729      NaN       NaN              Phường 9          True      Tuy Hòa
# 8193      NaN       NaN              Phường 4          True      Long An
# 8194      NaN       NaN              Phường 5          True      Long An
# 8195      NaN       NaN              Phường 6          True      Long An
# 8196      NaN       NaN      Xã Hướng Thọ Phú          True      Long An
# 8310      NaN       NaN            Xã Mỏ Công          True      Tân Phú
# 8311      NaN       NaN           Xã Trà Vong          True      Tân Phú
# 8312      NaN       NaN          Xã Tân Phong          True      Tân Phú
# 8407      NaN       NaN         Phường An Lộc          True    Bình Long
# 8408      NaN       NaN     Phường Hưng Chiến          True    Bình Long
# 8409      NaN       NaN        Phường Phú Đức          True    Bình Long
# 8549      NaN       NaN     Phường Long Phước          True   Phước Bình
# 8550      NaN       NaN     Phường Phước Bình          True   Phước Bình
# 8721      NaN       NaN         Xã An Phú Tây          True    Bình Đông
# 8732      NaN       NaN          Xã Phong Phú          True    Bình Hưng
# 8733      NaN       NaN          Xã Bình Hưng          True    Bình Hưng
# 9025      NaN       NaN      Thị trấn Tân Túc          True     Tân Nhựt
# 9026      NaN       NaN           Xã Tân Nhựt          True     Tân Nhựt
# 9027      NaN       NaN      Phường Tân Tạo A          True     Tân Nhựt
# 9028      NaN       NaN           Xã Tân Kiên          True     Tân Nhựt
#
#                 newProvince  newWardCode newWardType  newWardLon  newWardLat  \
# 181           Thủ đô Hà Nội           29          xã     105.949     21.0020
# 242           Thủ đô Hà Nội           38          xã     105.705     21.0620
# 243           Thủ đô Hà Nội           38          xã     105.705     21.0620
# 259           Thủ đô Hà Nội           40      phường     105.832     20.9615
# 357           Thủ đô Hà Nội           56          xã     105.733     21.1510
# 358           Thủ đô Hà Nội           56          xã     105.733     21.1510
# 359           Thủ đô Hà Nội           56          xã     105.733     21.1510
# 584           Thủ đô Hà Nội           92      phường     105.739     21.0642
# 620           Thủ đô Hà Nội           98          xã     105.771     21.1204
# 621           Thủ đô Hà Nội           98          xã     105.771     21.1204
# 687           Thủ đô Hà Nội          109      phường     105.854     20.9893
# 688           Thủ đô Hà Nội          109      phường     105.854     20.9893
# 689           Thủ đô Hà Nội          109      phường     105.854     20.9893
# 758           Thủ đô Hà Nội          121      phường     105.745     21.0296
# 759           Thủ đô Hà Nội          121      phường     105.745     21.0296
# 760           Thủ đô Hà Nội          121      phường     105.745     21.0296
# 761           Thủ đô Hà Nội          121      phường     105.745     21.0296
# 762           Thủ đô Hà Nội          121      phường     105.745     21.0296
# 1392    Thành phố Hải Phòng         1059          xã     106.378     20.8723
# 1613    Thành phố Hải Phòng         1114      phường     106.636     20.7916
# 2006          Tỉnh Hưng Yên         1224      phường     106.314     20.4817
# 2007          Tỉnh Hưng Yên         1224      phường     106.314     20.4817
# 2008          Tỉnh Hưng Yên         1224      phường     106.314     20.4817
# 2100          Tỉnh Hưng Yên         1248      phường     106.308     20.4127
# 7659           Tỉnh Đắk Lắk         2340      phường     109.315     13.0440
# 7660           Tỉnh Đắk Lắk         2340      phường     109.315     13.0440
# 7661           Tỉnh Đắk Lắk         2340      phường     109.315     13.0440
# 7724           Tỉnh Đắk Lắk         2359      phường     109.289     13.0799
# 7725           Tỉnh Đắk Lắk         2359      phường     109.289     13.0799
# 7726           Tỉnh Đắk Lắk         2359      phường     109.289     13.0799
# 7727           Tỉnh Đắk Lắk         2359      phường     109.289     13.0799
# 7728           Tỉnh Đắk Lắk         2359      phường     109.289     13.0799
# 7729           Tỉnh Đắk Lắk         2359      phường     109.289     13.0799
# 8193          Tỉnh Tây Ninh         2529      phường     106.405     10.5476
# 8194          Tỉnh Tây Ninh         2529      phường     106.405     10.5476
# 8195          Tỉnh Tây Ninh         2529      phường     106.405     10.5476
# 8196          Tỉnh Tây Ninh         2529      phường     106.405     10.5476
# 8310          Tỉnh Tây Ninh         2567          xã     106.162     11.4746
# 8311          Tỉnh Tây Ninh         2567          xã     106.162     11.4746
# 8312          Tỉnh Tây Ninh         2567          xã     106.162     11.4746
# 8407          Tỉnh Đồng Nai         2600      phường     106.598     11.6321
# 8408          Tỉnh Đồng Nai         2600      phường     106.598     11.6321
# 8409          Tỉnh Đồng Nai         2600      phường     106.598     11.6321
# 8549          Tỉnh Đồng Nai         2651      phường     106.940     11.8340
# 8550          Tỉnh Đồng Nai         2651      phường     106.940     11.8340
# 8721  Thành phố Hồ Chí Minh         2711      phường     106.612     10.7012
# 8732  Thành phố Hồ Chí Minh         2715          xã     106.660     10.7067
# 8733  Thành phố Hồ Chí Minh         2715          xã     106.660     10.7067
# 9025  Thành phố Hồ Chí Minh         2816          xã     106.562     10.7048
# 9026  Thành phố Hồ Chí Minh         2816          xã     106.562     10.7048
# 9027  Thành phố Hồ Chí Minh         2816          xã     106.562     10.7048
# 9028  Thành phố Hồ Chí Minh         2816          xã     106.562     10.7048
#
#       newWardAreaKm2                            truocsapnhap  districtUd  \
# 181            25.72        Phường Thạch Bàn (huyện Gia Lâm)         NaN
# 242            16.73         Phường Tây Tựu (huyện Hoài Đức)         NaN
# 243            16.73             Xã Tân Lập (huyện Hoài Đức)         NaN
# 259             4.04     Phường Hoàng Liệt (huyện Thanh Trì)         NaN
# 357            34.97           Xã Văn Khê (huyện Đan Phượng)         NaN
# 358            34.97           Xã Mê Linh (huyện Đan Phượng)         NaN
# 359            34.97         Xã Đại Thịnh (huyện Đan Phượng)         NaN
# 584             7.54         Phường Tây Tựu (huyện Hoài Đức)         NaN
# 620            27.96             Xã Đại Mạch (huyện Mê Linh)         NaN
# 621            27.96               Xã Kim Nỗ (huyện Mê Linh)         NaN
# 687             3.56     Phường Giáp Bát (quận Hai Bà Trưng)         NaN
# 688             3.56  Phường Phương Liệt (quận Hai Bà Trưng)         NaN
# 689             3.56     Phường Mai Động (quận Hai Bà Trưng)         NaN
# 758            10.81   Phường Phương Canh (quận Bắc Từ Liêm)         NaN
# 759            10.81   Phường Xuân Phương (quận Bắc Từ Liêm)         NaN
# 760            10.81        Phường Đại Mỗ (quận Bắc Từ Liêm)         NaN
# 761            10.81        Phường Tây Mỗ (quận Bắc Từ Liêm)         NaN
# 762            10.81          Xã Vân Canh (quận Bắc Từ Liêm)         NaN
# 1392           22.99              Xã Thanh Hải (huyện Tứ Kỳ)         NaN
# 1613           18.46      Thị trấn Trường Sơn (quận Kiến An)         NaN
# 2006           28.03   Phường Lê Hồng Phong (huyện Vũ Thư)         NaN
# 2007           28.03        Phường Bồ Xuyên (huyện Vũ Thư)         NaN
# 2008           28.03      Phường Tiền Phong (huyện Vũ Thư)         NaN
# 2100           23.99       Phường Phú Khánh (huyện Vũ Thư)         NaN
# 7659           44.04       Phường Phú Đông (thị xã Đông Hòa)         NaN
# 7660           44.04        Phường Phú Lâm (thị xã Đông Hòa)         NaN
# 7661           44.04      Phường Phú Thạnh (thị xã Đông Hòa)         NaN
# 7724           33.77                Phường 1 (huyện Phú Hòa)         NaN
# 7725           33.77                Phường 2 (huyện Phú Hòa)         NaN
# 7726           33.77                Phường 4 (huyện Phú Hòa)         NaN
# 7727           33.77                Phường 5 (huyện Phú Hòa)         NaN
# 7728           33.77                Phường 7 (huyện Phú Hòa)         NaN
# 7729           33.77                Phường 9 (huyện Phú Hòa)         NaN
# 8193           34.90            Phường 4 (huyện Thủ Thừa)         NaN
# 8194           34.90            Phường 5 (huyện Thủ Thừa)         NaN
# 8195           34.90            Phường 6 (huyện Thủ Thừa)         NaN
# 8196           34.90    Xã Hướng Thọ Phú (huyện Thủ Thừa)         NaN
# 8310           38.60            Xã Mỏ Công (huyện Tân Châu)         NaN
# 8311           38.60           Xã Trà Vong (huyện Tân Châu)         NaN
# 8312           38.60          Xã Tân Phong (huyện Tân Châu)         NaN
# 8407           49.10          Phường An Lộc (huyện Hớn Quản)         NaN
# 8408           49.10      Phường Hưng Chiến (huyện Hớn Quản)         NaN
# 8409           49.10         Phường Phú Đức (huyện Hớn Quản)         NaN
# 8549           72.60     Phường Long Phước (huyện Phú Riềng)         NaN
# 8550           72.60     Phường Phước Bình (huyện Phú Riềng)         NaN
# 8721            8.93                 Xã An Phú Tây (Quận 8)         NaN
# 8732           32.63                   Xã Phong Phú (Quận 8)         NaN
# 8733           32.63                   Xã Bình Hưng (Quận 8)         NaN
# 9025           43.67               Thị trấn Tân Túc (Quận 8)         NaN
# 9026           43.67                    Xã Tân Nhựt (Quận 8)         NaN
# 9027           43.67               Phường Tân Tạo A (Quận 8)         NaN
# 9028           43.67                    Xã Tân Kiên (Quận 8)         NaN
#
#           districtLower                wardUd             wardLower  \
# 181       huyện gia lâm      phuong thach ban      phường thạch bàn
# 242      huyện hoài đức        phuong tay tuu        phường tây tựu
# 243      huyện hoài đức            xa tan lap            xã tân lập
# 259     huyện thanh trì     phuong hoang liet     phường hoàng liệt
# 357    huyện đan phượng            xa van khe            xã văn khê
# 358    huyện đan phượng            xa me linh            xã mê linh
# 359    huyện đan phượng          xa dai thinh          xã đại thịnh
# 584      huyện hoài đức        phuong tay tuu        phường tây tựu
# 620       huyện mê linh           xa dai mach           xã đại mạch
# 621       huyện mê linh             xa kim no             xã kim nỗ
# 687   quận hai bà trưng       phuong giap bat       phường giáp bát
# 688   quận hai bà trưng    phuong phuong liet    phường phương liệt
# 689   quận hai bà trưng       phuong mai dong       phường mai động
# 758    quận bắc từ liêm    phuong phuong canh    phường phương canh
# 759    quận bắc từ liêm    phuong xuan phuong    phường xuân phương
# 760    quận bắc từ liêm         phuong dai mo         phường đại mỗ
# 761    quận bắc từ liêm         phuong tay mo         phường tây mỗ
# 762    quận bắc từ liêm           xa van canh           xã vân canh
# 1392        huyện tứ kỳ          xa thanh hai          xã thanh hải
# 1613       quận kiến an   thi tran truong son   thị trấn trường sơn
# 2006       huyện vũ thư  phuong le hong phong  phường lê hồng phong
# 2007       huyện vũ thư       phuong bo xuyen       phường bồ xuyên
# 2008       huyện vũ thư     phuong tien phong     phường tiền phong
# 2100       huyện vũ thư      phuong phu khanh      phường phú khánh
# 7659    thị xã đông hòa       phuong phu dong       phường phú đông
# 7660    thị xã đông hòa        phuong phu lam        phường phú lâm
# 7661    thị xã đông hòa      phuong phu thanh      phường phú thạnh
# 7724      huyện phú hòa              phuong 1              phường 1
# 7725      huyện phú hòa              phuong 2              phường 2
# 7726      huyện phú hòa              phuong 4              phường 4
# 7727      huyện phú hòa              phuong 5              phường 5
# 7728      huyện phú hòa              phuong 7              phường 7
# 7729      huyện phú hòa              phuong 9              phường 9
# 8193     huyện thủ thừa              phuong 4              phường 4
# 8194     huyện thủ thừa              phuong 5              phường 5
# 8195     huyện thủ thừa              phuong 6              phường 6
# 8196     huyện thủ thừa      xa huong tho phu      xã hướng thọ phú
# 8310     huyện tân châu            xa mo cong            xã mỏ công
# 8311     huyện tân châu           xa tra vong           xã trà vong
# 8312     huyện tân châu          xa tan phong          xã tân phong
# 8407     huyện hớn quản         phuong an loc         phường an lộc
# 8408     huyện hớn quản     phuong hung chien     phường hưng chiến
# 8409     huyện hớn quản        phuong phu duc        phường phú đức
# 8549    huyện phú riềng     phuong long phuoc     phường long phước
# 8550    huyện phú riềng     phuong phuoc binh     phường phước bình
# 8721             quận 8         xa an phu tay         xã an phú tây
# 8732             quận 8          xa phong phu          xã phong phú
# 8733             quận 8          xa binh hung          xã bình hưng
# 9025             quận 8      thi tran tan tuc      thị trấn tân túc
# 9026             quận 8           xa tan nhut           xã tân nhựt
# 9027             quận 8      phuong tan tao a      phường tân tạo a
# 9028             quận 8           xa tan kien           xã tân kiên
#
#      keyNewProvinceProvinceDistrictWard  \
# 181                                 NaN
# 242                                 NaN
# 243                                 NaN
# 259                                 NaN
# 357                                 NaN
# 358                                 NaN
# 359                                 NaN
# 584                                 NaN
# 620                                 NaN
# 621                                 NaN
# 687                                 NaN
# 688                                 NaN
# 689                                 NaN
# 758                                 NaN
# 759                                 NaN
# 760                                 NaN
# 761                                 NaN
# 762                                 NaN
# 1392                                NaN
# 1613                                NaN
# 2006                                NaN
# 2007                                NaN
# 2008                                NaN
# 2100                                NaN
# 7659                                NaN
# 7660                                NaN
# 7661                                NaN
# 7724                                NaN
# 7725                                NaN
# 7726                                NaN
# 7727                                NaN
# 7728                                NaN
# 7729                                NaN
# 8193                                NaN
# 8194                                NaN
# 8195                                NaN
# 8196                                NaN
# 8310                                NaN
# 8311                                NaN
# 8312                                NaN
# 8407                                NaN
# 8408                                NaN
# 8409                                NaN
# 8549                                NaN
# 8550                                NaN
# 8721                                NaN
# 8732                                NaN
# 8733                                NaN
# 9025                                NaN
# 9026                                NaN
# 9027                                NaN
# 9028                                NaN
#
#                              keyNewProvinceDistrictWard  \
# 181        Thủ đô Hà Nội_huyện gia lâm_phường thạch bàn
# 242         Thủ đô Hà Nội_huyện hoài đức_phường tây tựu
# 243             Thủ đô Hà Nội_huyện hoài đức_xã tân lập
# 259     Thủ đô Hà Nội_huyện thanh trì_phường hoàng liệt
# 357           Thủ đô Hà Nội_huyện đan phượng_xã văn khê
# 358           Thủ đô Hà Nội_huyện đan phượng_xã mê linh
# 359         Thủ đô Hà Nội_huyện đan phượng_xã đại thịnh
# 584         Thủ đô Hà Nội_huyện hoài đức_phường tây tựu
# 620             Thủ đô Hà Nội_huyện mê linh_xã đại mạch
# 621               Thủ đô Hà Nội_huyện mê linh_xã kim nỗ
# 687     Thủ đô Hà Nội_quận hai bà trưng_phường giáp bát
# 688   Thủ đô Hà Nội_quận hai bà trưng_phường phương ...
# 689     Thủ đô Hà Nội_quận hai bà trưng_phường mai động
# 758   Thủ đô Hà Nội_quận bắc từ liêm_phường phương canh
# 759   Thủ đô Hà Nội_quận bắc từ liêm_phường xuân phương
# 760        Thủ đô Hà Nội_quận bắc từ liêm_phường đại mỗ
# 761        Thủ đô Hà Nội_quận bắc từ liêm_phường tây mỗ
# 762          Thủ đô Hà Nội_quận bắc từ liêm_xã vân canh
# 1392       Thành phố Hải Phòng_huyện tứ kỳ_xã thanh hải
# 1613  Thành phố Hải Phòng_quận kiến an_thị trấn trườ...
# 2006    Tỉnh Hưng Yên_huyện vũ thư_phường lê hồng phong
# 2007         Tỉnh Hưng Yên_huyện vũ thư_phường bồ xuyên
# 2008       Tỉnh Hưng Yên_huyện vũ thư_phường tiền phong
# 2100        Tỉnh Hưng Yên_huyện vũ thư_phường phú khánh
# 7659       Tỉnh Đắk Lắk_thị xã đông hòa_phường phú đông
# 7660        Tỉnh Đắk Lắk_thị xã đông hòa_phường phú lâm
# 7661      Tỉnh Đắk Lắk_thị xã đông hòa_phường phú thạnh
# 7724                Tỉnh Đắk Lắk_huyện phú hòa_phường 1
# 7725                Tỉnh Đắk Lắk_huyện phú hòa_phường 2
# 7726                Tỉnh Đắk Lắk_huyện phú hòa_phường 4
# 7727                Tỉnh Đắk Lắk_huyện phú hòa_phường 5
# 7728                Tỉnh Đắk Lắk_huyện phú hòa_phường 7
# 7729                Tỉnh Đắk Lắk_huyện phú hòa_phường 9
# 8193              Tỉnh Tây Ninh_huyện thủ thừa_phường 4
# 8194              Tỉnh Tây Ninh_huyện thủ thừa_phường 5
# 8195              Tỉnh Tây Ninh_huyện thủ thừa_phường 6
# 8196      Tỉnh Tây Ninh_huyện thủ thừa_xã hướng thọ phú
# 8310            Tỉnh Tây Ninh_huyện tân châu_xã mỏ công
# 8311           Tỉnh Tây Ninh_huyện tân châu_xã trà vong
# 8312          Tỉnh Tây Ninh_huyện tân châu_xã tân phong
# 8407         Tỉnh Đồng Nai_huyện hớn quản_phường an lộc
# 8408     Tỉnh Đồng Nai_huyện hớn quản_phường hưng chiến
# 8409        Tỉnh Đồng Nai_huyện hớn quản_phường phú đức
# 8549    Tỉnh Đồng Nai_huyện phú riềng_phường long phước
# 8550    Tỉnh Đồng Nai_huyện phú riềng_phường phước bình
# 8721         Thành phố Hồ Chí Minh_quận 8_xã an phú tây
# 8732          Thành phố Hồ Chí Minh_quận 8_xã phong phú
# 8733          Thành phố Hồ Chí Minh_quận 8_xã bình hưng
# 9025      Thành phố Hồ Chí Minh_quận 8_thị trấn tân túc
# 9026           Thành phố Hồ Chí Minh_quận 8_xã tân nhựt
# 9027      Thành phố Hồ Chí Minh_quận 8_phường tân tạo a
# 9028           Thành phố Hồ Chí Minh_quận 8_xã tân kiên
#
#      keyNewProvinceDistrict                       keyNewProvinceWard
# 181                     NaN           Thủ đô Hà Nội_phường thạch bàn
# 242                     NaN             Thủ đô Hà Nội_phường tây tựu
# 243                     NaN                 Thủ đô Hà Nội_xã tân lập
# 259                     NaN          Thủ đô Hà Nội_phường hoàng liệt
# 357                     NaN                 Thủ đô Hà Nội_xã văn khê
# 358                     NaN                 Thủ đô Hà Nội_xã mê linh
# 359                     NaN               Thủ đô Hà Nội_xã đại thịnh
# 584                     NaN             Thủ đô Hà Nội_phường tây tựu
# 620                     NaN                Thủ đô Hà Nội_xã đại mạch
# 621                     NaN                  Thủ đô Hà Nội_xã kim nỗ
# 687                     NaN            Thủ đô Hà Nội_phường giáp bát
# 688                     NaN         Thủ đô Hà Nội_phường phương liệt
# 689                     NaN            Thủ đô Hà Nội_phường mai động
# 758                     NaN         Thủ đô Hà Nội_phường phương canh
# 759                     NaN         Thủ đô Hà Nội_phường xuân phương
# 760                     NaN              Thủ đô Hà Nội_phường đại mỗ
# 761                     NaN              Thủ đô Hà Nội_phường tây mỗ
# 762                     NaN                Thủ đô Hà Nội_xã vân canh
# 1392                    NaN         Thành phố Hải Phòng_xã thanh hải
# 1613                    NaN  Thành phố Hải Phòng_thị trấn trường sơn
# 2006                    NaN       Tỉnh Hưng Yên_phường lê hồng phong
# 2007                    NaN            Tỉnh Hưng Yên_phường bồ xuyên
# 2008                    NaN          Tỉnh Hưng Yên_phường tiền phong
# 2100                    NaN           Tỉnh Hưng Yên_phường phú khánh
# 7659                    NaN             Tỉnh Đắk Lắk_phường phú đông
# 7660                    NaN              Tỉnh Đắk Lắk_phường phú lâm
# 7661                    NaN            Tỉnh Đắk Lắk_phường phú thạnh
# 7724                    NaN                    Tỉnh Đắk Lắk_phường 1
# 7725                    NaN                    Tỉnh Đắk Lắk_phường 2
# 7726                    NaN                    Tỉnh Đắk Lắk_phường 4
# 7727                    NaN                    Tỉnh Đắk Lắk_phường 5
# 7728                    NaN                    Tỉnh Đắk Lắk_phường 7
# 7729                    NaN                    Tỉnh Đắk Lắk_phường 9
# 8193                    NaN                   Tỉnh Tây Ninh_phường 4
# 8194                    NaN                   Tỉnh Tây Ninh_phường 5
# 8195                    NaN                   Tỉnh Tây Ninh_phường 6
# 8196                    NaN           Tỉnh Tây Ninh_xã hướng thọ phú
# 8310                    NaN                 Tỉnh Tây Ninh_xã mỏ công
# 8311                    NaN                Tỉnh Tây Ninh_xã trà vong
# 8312                    NaN               Tỉnh Tây Ninh_xã tân phong
# 8407                    NaN              Tỉnh Đồng Nai_phường an lộc
# 8408                    NaN          Tỉnh Đồng Nai_phường hưng chiến
# 8409                    NaN             Tỉnh Đồng Nai_phường phú đức
# 8549                    NaN          Tỉnh Đồng Nai_phường long phước
# 8550                    NaN          Tỉnh Đồng Nai_phường phước bình
# 8721                    NaN      Thành phố Hồ Chí Minh_xã an phú tây
# 8732                    NaN       Thành phố Hồ Chí Minh_xã phong phú
# 8733                    NaN       Thành phố Hồ Chí Minh_xã bình hưng
# 9025                    NaN   Thành phố Hồ Chí Minh_thị trấn tân túc
# 9026                    NaN        Thành phố Hồ Chí Minh_xã tân nhựt
# 9027                    NaN   Thành phố Hồ Chí Minh_phường tân tạo a
# 9028                    NaN        Thành phố Hồ Chí Minh_xã tân kiên

# %%
total_sapnhap = sapnhap1.shape[0] + sapnhap2.shape[0] + sapnhap3.shape[0] + sapnhap4a.shape[0] + sapnhap4b.shape[0]
if total_sapnhap != df_sapnhap_ward.shape[0]:
    raise Exception('Chia tệp chưa MECE')

# %% [markdown]
# ## Tiến hành merge

# %%
df_convert1 = pd.merge(df_danhmuc, sapnhap1, on=['newProvince', 'province', 'districtLower', 'wardLower'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert2 = pd.merge(df_danhmuc, sapnhap2, on=['newProvince', 'districtLower', 'wardLower'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert3 = pd.merge(df_danhmuc, sapnhap3, on=['newProvince', 'districtLower'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert4a = pd.merge(df_danhmuc, sapnhap4a, on=['newProvince', 'wardLower'], how='inner', suffixes=('', '_DUPLICATED'))
df_convert4b = pd.merge(df_danhmuc, sapnhap4b, on=['newProvince', 'wardLower'], how='inner', suffixes=('', '_DUPLICATED'))

# %%
print(df_convert1.shape[0], sapnhap1.shape[0])
print(df_convert2.shape[0], sapnhap2.shape[0])
print(df_convert3.shape[0], sapnhap3.shape[0])
print(df_convert4a.shape[0], sapnhap4a.shape[0])
print(df_convert4b.shape[0], sapnhap4b.shape[0])
# Out:
# 2 2
# 903 903
# 9 6
# 9641 9604
# 53 52

# %%
df_convert = pd.concat([df_convert1, df_convert2, df_convert3, df_convert4a, df_convert4b], ignore_index=True).drop_duplicates()
df_convert.drop(columns=[col for col in df_convert.columns if '_DUPLICATED' in col or 'key' in col], inplace=True)
df_convert.drop_duplicates(inplace=True)

# %%
df_convert[df_convert['wardUd'].fillna('').str.contains('phuong 15') & df_convert['districtUd'].fillna('').str.contains('tan binh')]
# Out:
#      districtCode  provinceCode districtType       district  \
# 601           766            79         Quận  Quận Tân Bình
# 602           766            79         Quận  Quận Tân Bình
#
#                   province  wardCode wardType       ward  newProvinceCode  \
# 601  Thành phố Hồ Chí Minh   27007.0   Phường  Phường 15               29
# 602  Thành phố Hồ Chí Minh   27007.0   Phường  Phường 15               29
#
#                newProvince  ...     wardUd  wardLower  isMergedWard   newWard  \
# 601  Thành phố Hồ Chí Minh  ...  phuong 15  phường 15          True  Tân Bình
# 602  Thành phố Hồ Chí Minh  ...  phuong 15  phường 15          True   Tân Sơn
#
#     newWardCode newWardType newWardLon  newWardLat newWardAreaKm2  \
# 601        2807      phường    106.642     10.8006           2.12
# 602        2819      phường    106.650     10.8224          10.12
#
#                   truocsapnhap
# 601  Phường 15 (quận Tân Bình)
# 602  Phường 15 (quận Tân Bình)
#
# [2 rows x 25 columns]

# %%
df_convert[df_convert['newWardCode']==3257]
# Out:
#        districtCode  provinceCode districtType        district  \
# 10169           925            92        Huyện     Huyện Cờ Đỏ
# 10340           947            94        Huyện  Huyện Mỹ Xuyên
#
#                 province  wardCode wardType          ward  newProvinceCode  \
# 10169  Thành phố Cần Thơ   31249.0       Xã  Xã Thạnh Phú               33
# 10340     Tỉnh Sóc Trăng   31708.0       Xã  Xã Thạnh Phú               33
#
#              newProvince  ...        wardUd     wardLower  isMergedWard  \
# 10169  Thành phố Cần Thơ  ...  xa thanh phu  xã thạnh phú         False
# 10340  Thành phố Cần Thơ  ...  xa thanh phu  xã thạnh phú         False
#
#          newWard newWardCode newWardType newWardLon  newWardLat  \
# 10169  Thạnh Phú        3257          xã    105.405     10.1295
# 10340  Thạnh Phú        3257          xã    105.405     10.1295
#
#       newWardAreaKm2    truocsapnhap
# 10169          99.07  Không sáp nhập
# 10340          99.07  Không sáp nhập
#
# [2 rows x 25 columns]

# %%
df_convert_full = pd.merge(df_danhmuc, df_convert, on=['newProvince', 'province', 'districtLower', 'wardLower'], how='left', suffixes=('', '_DUPLICATED')).drop_duplicates()
df_convert_full .drop(columns=[col for col in df_convert_full.columns if '_DUPLICATED' in col or 'key' in col], inplace=True)
df_convert_full.drop_duplicates(inplace=True)

# %%
df_convert_full[df_convert_full['newWardCode']==3257]
# Out:
#        districtCode  provinceCode districtType        district  \
# 10197           925            92        Huyện     Huyện Cờ Đỏ
# 10374           947            94        Huyện  Huyện Mỹ Xuyên
#
#                 province  wardCode wardType          ward  newProvinceCode  \
# 10197  Thành phố Cần Thơ   31249.0       Xã  Xã Thạnh Phú               33
# 10374     Tỉnh Sóc Trăng   31708.0       Xã  Xã Thạnh Phú               33
#
#              newProvince  ...        wardUd     wardLower  isMergedWard  \
# 10197  Thành phố Cần Thơ  ...  xa thanh phu  xã thạnh phú         False
# 10374  Thành phố Cần Thơ  ...  xa thanh phu  xã thạnh phú         False
#
#          newWard newWardCode newWardType newWardLon newWardLat newWardAreaKm2  \
# 10197  Thạnh Phú      3257.0          xã    105.405    10.1295          99.07
# 10374  Thạnh Phú      3257.0          xã    105.405    10.1295          99.07
#
#          truocsapnhap
# 10197  Không sáp nhập
# 10374  Không sáp nhập
#
# [2 rows x 25 columns]

# %%
print('df_convert_full.shape:', df_convert_full.shape)
# Out:
# df_convert_full.shape: (10610, 25)

# %%
df_convert_full[df_convert_full['newWard'].isna()]
# Out:
#       districtCode  provinceCode districtType         district  \
# 959             34             2        Huyện  Huyện Bắc Quang
# 1358            75             8        Huyện    Huyện Yên Sơn
#
#               province  wardCode wardType            ward  newProvinceCode  \
# 959      Tỉnh Hà Giang    1174.0       Xã  Xã Thượng Bình                8
# 1358  Tỉnh Tuyên Quang    2488.0       Xã    Xã Trung Môn                8
#
#            newProvince  ...          wardUd       wardLower  isMergedWard  \
# 959   Tỉnh Tuyên Quang  ...  xa thuong binh  xã thượng bình           NaN
# 1358  Tỉnh Tuyên Quang  ...    xa trung mon    xã trung môn           NaN
#
#      newWard newWardCode newWardType newWardLon newWardLat newWardAreaKm2  \
# 959      NaN         NaN         NaN        NaN        NaN            NaN
# 1358     NaN         NaN         NaN        NaN        NaN            NaN
#
#       truocsapnhap
# 959            NaN
# 1358           NaN
#
# [2 rows x 25 columns]

# %%
new_province = 'Thành phố Cần Thơ'
ward_ud = 'thanh phu'
df_sapnhap_ward[(df_sapnhap_ward['newProvince'] == new_province) & (df_sapnhap_ward['wardUd'].fillna('').str.contains(ward_ud))]
# Out:
#       province district          ward  isMergedWard    newWard  \
# 10236      NaN      NaN  Xã Thạnh Phú          True    Nhu Gia
# 10296      NaN      NaN  Xã Thạnh Phú         False  Thạnh Phú
#
#              newProvince  newWardCode newWardType  newWardLon  newWardLat  \
# 10236  Thành phố Cần Thơ         3234          xã     105.855     9.47039
# 10296  Thành phố Cần Thơ         3257          xã     105.405    10.12950
#
#        newWardAreaKm2    truocsapnhap districtUd districtLower        wardUd  \
# 10236           75.59    Xã Thạnh Phú        NaN           NaN  xa thanh phu
# 10296           99.07  Không sáp nhập        NaN           NaN  xa thanh phu
#
#           wardLower keyNewProvinceProvinceDistrictWard  \
# 10236  xã thạnh phú                                NaN
# 10296  xã thạnh phú                                NaN
#
#       keyNewProvinceDistrictWard keyNewProvinceDistrict  \
# 10236                        NaN                    NaN
# 10296                        NaN                    NaN
#
#                    keyNewProvinceWard
# 10236  Thành phố Cần Thơ_xã thạnh phú
# 10296  Thành phố Cần Thơ_xã thạnh phú

# %%
df_danhmuc[(df_danhmuc['newProvince'] == new_province) & (df_danhmuc['wardUd'].fillna('').str.contains(ward_ud))]
# Out:
#       districtCode  provinceCode districtType        district  \
# 9665           925            92        Huyện     Huyện Cờ Đỏ
# 9829           947            94        Huyện  Huyện Mỹ Xuyên
#
#                province  wardCode wardType          ward  newProvinceCode  \
# 9665  Thành phố Cần Thơ   31249.0       Xã  Xã Thạnh Phú               33
# 9829     Tỉnh Sóc Trăng   31708.0       Xã  Xã Thạnh Phú               33
#
#             newProvince  ...  newProvinceLon  isMergedProvince  \
# 9665  Thành phố Cần Thơ  ...         105.757              True
# 9829  Thành phố Cần Thơ  ...         105.757              True
#
#           districtUd   districtLower        wardUd     wardLower  \
# 9665     huyen co do     huyện cờ đỏ  xa thanh phu  xã thạnh phú
# 9829  huyen my xuyen  huyện mỹ xuyên  xa thanh phu  xã thạnh phú
#
#                      keyNewProvinceProvinceDistrictWard  \
# 9665  Thành phố Cần Thơ_Thành phố Cần Thơ_huyện cờ đ...
# 9829  Thành phố Cần Thơ_Tỉnh Sóc Trăng_huyện mỹ xuyê...
#
#                          keyNewProvinceDistrictWard  \
# 9665     Thành phố Cần Thơ_huyện cờ đỏ_xã thạnh phú
# 9829  Thành phố Cần Thơ_huyện mỹ xuyên_xã thạnh phú
#
#                 keyNewProvinceDistrict              keyNewProvinceWard
# 9665     Thành phố Cần Thơ_huyện cờ đỏ  Thành phố Cần Thơ_xã thạnh phú
# 9829  Thành phố Cần Thơ_huyện mỹ xuyên  Thành phố Cần Thơ_xã thạnh phú
#
# [2 rows x 21 columns]

# %%
df_convert_full[(df_convert_full['newProvince'] == new_province) & (df_convert_full['wardUd'].fillna('').str.contains(ward_ud))]
# Out:
#        districtCode  provinceCode districtType        district  \
# 10196           925            92        Huyện     Huyện Cờ Đỏ
# 10197           925            92        Huyện     Huyện Cờ Đỏ
# 10373           947            94        Huyện  Huyện Mỹ Xuyên
# 10374           947            94        Huyện  Huyện Mỹ Xuyên
#
#                 province  wardCode wardType          ward  newProvinceCode  \
# 10196  Thành phố Cần Thơ   31249.0       Xã  Xã Thạnh Phú               33
# 10197  Thành phố Cần Thơ   31249.0       Xã  Xã Thạnh Phú               33
# 10373     Tỉnh Sóc Trăng   31708.0       Xã  Xã Thạnh Phú               33
# 10374     Tỉnh Sóc Trăng   31708.0       Xã  Xã Thạnh Phú               33
#
#              newProvince  ...        wardUd     wardLower  isMergedWard  \
# 10196  Thành phố Cần Thơ  ...  xa thanh phu  xã thạnh phú          True
# 10197  Thành phố Cần Thơ  ...  xa thanh phu  xã thạnh phú         False
# 10373  Thành phố Cần Thơ  ...  xa thanh phu  xã thạnh phú          True
# 10374  Thành phố Cần Thơ  ...  xa thanh phu  xã thạnh phú         False
#
#          newWard newWardCode newWardType newWardLon newWardLat newWardAreaKm2  \
# 10196    Nhu Gia      3234.0          xã    105.855    9.47039          75.59
# 10197  Thạnh Phú      3257.0          xã    105.405   10.12950          99.07
# 10373    Nhu Gia      3234.0          xã    105.855    9.47039          75.59
# 10374  Thạnh Phú      3257.0          xã    105.405   10.12950          99.07
#
#          truocsapnhap
# 10196    Xã Thạnh Phú
# 10197  Không sáp nhập
# 10373    Xã Thạnh Phú
# 10374  Không sáp nhập
#
# [4 rows x 25 columns]

# %%
wrong_index_1 = df_convert_full[(df_convert_full['newProvince'] == 'Thành phố Cần Thơ') & (df_convert_full['wardUd'].fillna('').str.contains('thanh phu'))  & (df_convert_full['province']=='Tỉnh Sóc Trăng') & (df_convert_full['isMergedWard']==False)].index[0]

wrong_index_2 = df_convert_full.loc[(df_convert_full['newProvince'] == 'Thành phố Cần Thơ') & (df_convert_full['wardUd'].fillna('').str.contains('thanh phu'))  & (df_convert_full['province']=='Thành phố Cần Thơ') & (df_convert_full['isMergedWard']==True)].index[0]

# %%
df_convert_full  = df_convert_full[~df_convert_full.index.isin([wrong_index_1, wrong_index_2])]

# %%
# Cần xóa đi các ward đã là isMergedWard = True rồi mà vẫn có một dòng isMergedWard = False
# Vì những case mà cùng newProvince nhưng ward bị trùng tên với một ward ở district khác (Tỉnh Quảng Ngãi, Xã Đăk Long)
# isMergedWard là boolean. Chúng ta sẽ tính COUNT và SUM
# SUM = 0 hoặc 1 và COUNT = 1: Là đúng (False vẫn COUNT là 1, nhưng SUM là 0)
# SUM = 1 mà COUNT = 2: Sai -> Lọc lấy những ward này, xóa dòng mà nó có isMergedWard = False
agg_isMergedWard = df_convert_full[['province', 'district', 'ward', 'isMergedWard']].drop_duplicates()
agg_isMergedWard['isMergedWard'] = agg_isMergedWard['isMergedWard'].map({True: 1, False: 0})
agg_isMergedWard = agg_isMergedWard.groupby(['province', 'district', 'ward']).agg(sumIsMergedWard=('isMergedWard', 'sum'), countIsMergedWard=('isMergedWard', 'count')).reset_index()

wrong_ward = agg_isMergedWard[(agg_isMergedWard['sumIsMergedWard']==1) & (agg_isMergedWard['countIsMergedWard']==2)]
wrong_ward['isMergedWard'] = False
wrong_ward['wrongWard'] = True
wrong_ward.drop(columns=['sumIsMergedWard', 'countIsMergedWard'], inplace=True)

df_convert_full = pd.merge(df_convert_full, wrong_ward, on=['province', 'district', 'ward', 'isMergedWard'], how='left')
df_convert_full = df_convert_full[df_convert_full['wrongWard']!=True]

# %%
# Điền vào ở bước tiếp theo
not_exist_in_sapnhap = [
    'Xã Thượng Bình', # newProvince = "Tỉnh Tuyên Quang" -> newWard = "Xã Đồng Tâm" https://address-converter.io.vn/
    'Xã Trung Môn', # newProvince = "Tỉnh Tuyên Quang" -> newWard = "Phường Minh Xuân" https://address-converter.io.vn/
]

# Quay lại bước kiểm tra chính tả 2 bên để bổ sung. Xuân Hòa và Phú Bình trong Thành phố Long Khánh là Phường mới đúng, sửa df_sapnhap_ward
exist_in_sapnhap = [
    'Phường Xuân Hòa', # ward = 'Xã Xuân Hòa' newWard = 'Long Khánh', newProvince = 'Tỉnh Đồng Nai'
    'Phường Phú Bình', # ward = 'Xã Phú Bình' newWard = 'Long Khánh', newProvince = 'Tỉnh Đồng Nai'
]

# %%
fill_map = [
    {
        'province': 'Tỉnh Hà Giang',
        'district': 'Huyện Bắc Quang',
        'ward': 'Xã Thượng Bình',
        'newProvince': 'Tỉnh Tuyên Quang',
        'newWard': 'Đồng Tâm'
    },
    {
        'province': 'Tỉnh Tuyên Quang',
        'district': 'Huyện Yên Sơn',
        'ward': 'Xã Trung Môn',
        'newProvince': 'Tỉnh Tuyên Quang',
        'newWard': 'Minh Xuân'
    },
]
fill_cols = ['isMergedWard', 'newWard', 'newWardCode', 'newWardType', 'newWardLon', 'newWardLat', 'newWardAreaKm2']
for record in fill_map:
    miss_condition = (df_convert_full['province'] == record['province']) & (df_convert_full['district'] == record['district']) & (df_convert_full['ward'] == record['ward'])
    fill_condition = (df_convert_full['newProvince'] == record['newProvince']) & (df_convert_full['newWard'] == record['newWard'])

    fill_values = df_convert_full.loc[fill_condition, fill_cols].iloc[0]
    df_convert_full.loc[miss_condition, fill_cols] = fill_values.values

# %%
# df_convert_full.to_csv('data/danhmuc_and_sapnhap.csv', index=False)

# %%
# Tính isDividedWard
count_unit = df_convert_full.groupby(['province', 'district', 'ward']).size().reset_index(name='count_unit')
count_unit['isDividedWard'] = np.where(count_unit['count_unit'] > 1, True, False)
df_convert_full = pd.merge(df_convert_full, count_unit[['province', 'district', 'ward', 'isDividedWard']], on=['province', 'district', 'ward'], how='left')
df_convert_full['isDividedWard'].fillna(False, inplace=True)

# %%
df_convert_full
# Out:
#        districtCode  provinceCode districtType         district  \
# 0                 1             1         Quận     Quận Ba Đình
# 1                 1             1         Quận     Quận Ba Đình
# 2                 1             1         Quận     Quận Ba Đình
# 3                 1             1         Quận     Quận Ba Đình
# 4                 1             1         Quận     Quận Ba Đình
# ...             ...           ...          ...              ...
# 10597           973            96        Huyện  Huyện Ngọc Hiển
# 10598           973            96        Huyện  Huyện Ngọc Hiển
# 10599           973            96        Huyện  Huyện Ngọc Hiển
# 10600           973            96        Huyện  Huyện Ngọc Hiển
# 10601           973            96        Huyện  Huyện Ngọc Hiển
#
#                province  wardCode  wardType               ward  \
# 0      Thành phố Hà Nội       1.0    Phường     Phường Phúc Xá
# 1      Thành phố Hà Nội       4.0    Phường   Phường Trúc Bạch
# 2      Thành phố Hà Nội       6.0    Phường   Phường Vĩnh Phúc
# 3      Thành phố Hà Nội       7.0    Phường     Phường Cống Vị
# 4      Thành phố Hà Nội       7.0    Phường     Phường Cống Vị
# ...                 ...       ...       ...                ...
# 10597       Tỉnh Cà Mau   32242.0        Xã         Xã Viên An
# 10598       Tỉnh Cà Mau   32244.0  Thị trấn  Thị trấn Rạch Gốc
# 10599       Tỉnh Cà Mau   32245.0        Xã          Xã Tân Ân
# 10600       Tỉnh Cà Mau   32245.0        Xã          Xã Tân Ân
# 10601       Tỉnh Cà Mau   32248.0        Xã         Xã Đất Mũi
#
#        newProvinceCode    newProvince  ...  isMergedWard           newWard  \
# 0                    1  Thủ đô Hà Nội  ...          True           Hồng Hà
# 1                    1  Thủ đô Hà Nội  ...          True           Ba Đình
# 2                    1  Thủ đô Hà Nội  ...          True           Ngọc Hà
# 3                    1  Thủ đô Hà Nội  ...          True          Giảng Võ
# 4                    1  Thủ đô Hà Nội  ...          True           Ngọc Hà
# ...                ...            ...  ...           ...               ...
# 10597               34    Tỉnh Cà Mau  ...          True         Đất Mũi
# 10598               34    Tỉnh Cà Mau  ...          True  Phan Ngọc Hiển
# 10599               34    Tỉnh Cà Mau  ...          True         Đất Mũi
# 10600               34    Tỉnh Cà Mau  ...          True  Phan Ngọc Hiển
# 10601               34    Tỉnh Cà Mau  ...          True         Đất Mũi
#
#        newWardCode newWardType newWardLon newWardLat newWardAreaKm2  \
# 0             42.0      phường    105.845   21.05670          15.09
# 1              3.0      phường    105.838   21.03860           2.97
# 2             61.0      phường    105.816   21.03810           2.68
# 3             30.0      phường    105.814   21.02750           2.60
# 4             61.0      phường    105.816   21.03810           2.68
# ...            ...         ...        ...        ...            ...
# 10597       3302.0          xã    104.820    8.63765         271.20
# 10598       3327.0          xã    104.943    8.64616         237.70
# 10599       3302.0          xã    104.820    8.63765         271.20
# 10600       3327.0          xã    104.943    8.64616         237.70
# 10601       3302.0          xã    104.820    8.63765         271.20
#
#             truocsapnhap wrongWard  isDividedWard
# 0         Phường Phúc Xá       NaN          False
# 1       Phường Trúc Bạch       NaN          False
# 2       Phường Vĩnh Phúc       NaN          False
# 3        Phường Cống Vị        NaN           True
# 4         Phường Cống Vị       NaN           True
# ...                  ...       ...            ...
# 10597         Xã Viên An       NaN           True
# 10598  Thị trấn Rạch Gốc       NaN          False
# 10599          Xã Tân Ân       NaN           True
# 10600          Xã Tân Ân       NaN           True
# 10601         Xã Đất Mũi       NaN          False
#
# [10602 rows x 27 columns]

# %%
save_cols = [
    'provinceCode',
    'isMergedProvince',
    'districtCode',
    'districtType',
    'wardCode',
    'wardType',
    'isMergedWard',
    'isDividedWard',

    'province',
    'district',
    'ward',

    'newProvince',
    'newWard',

    'newProvinceCode',
    'newProvinceLat',
    'newProvinceLon',
    'newWardCode',
    'newWardType',
    'newWardLat',
    'newWardLon',
    'newWardAreaKm2',
]

# %%
df_convert_full = df_convert_full[save_cols].drop_duplicates()

# %%
df_convert_full
# Out:
#        provinceCode  isMergedProvince  districtCode districtType  wardCode  \
# 0                 1             False             1         Quận       1.0
# 1                 1             False             1         Quận       4.0
# 2                 1             False             1         Quận       6.0
# 3                 1             False             1         Quận       7.0
# 4                 1             False             1         Quận       7.0
# ...             ...               ...           ...          ...       ...
# 10597            96              True           973        Huyện   32242.0
# 10598            96              True           973        Huyện   32244.0
# 10599            96              True           973        Huyện   32245.0
# 10600            96              True           973        Huyện   32245.0
# 10601            96              True           973        Huyện   32248.0
#
#        wardType isMergedWard  isDividedWard          province  \
# 0        Phường         True          False  Thành phố Hà Nội
# 1        Phường         True          False  Thành phố Hà Nội
# 2        Phường         True          False  Thành phố Hà Nội
# 3        Phường         True           True  Thành phố Hà Nội
# 4        Phường         True           True  Thành phố Hà Nội
# ...         ...          ...            ...               ...
# 10597        Xã         True           True       Tỉnh Cà Mau
# 10598  Thị trấn         True          False       Tỉnh Cà Mau
# 10599        Xã         True           True       Tỉnh Cà Mau
# 10600        Xã         True           True       Tỉnh Cà Mau
# 10601        Xã         True          False       Tỉnh Cà Mau
#
#               district  ...    newProvince           newWard newProvinceCode  \
# 0         Quận Ba Đình  ...  Thủ đô Hà Nội           Hồng Hà               1
# 1         Quận Ba Đình  ...  Thủ đô Hà Nội           Ba Đình               1
# 2         Quận Ba Đình  ...  Thủ đô Hà Nội           Ngọc Hà               1
# 3         Quận Ba Đình  ...  Thủ đô Hà Nội          Giảng Võ               1
# 4         Quận Ba Đình  ...  Thủ đô Hà Nội           Ngọc Hà               1
# ...                ...  ...            ...               ...             ...
# 10597  Huyện Ngọc Hiển  ...    Tỉnh Cà Mau         Đất Mũi              34
# 10598  Huyện Ngọc Hiển  ...    Tỉnh Cà Mau  Phan Ngọc Hiển              34
# 10599  Huyện Ngọc Hiển  ...    Tỉnh Cà Mau         Đất Mũi              34
# 10600  Huyện Ngọc Hiển  ...    Tỉnh Cà Mau  Phan Ngọc Hiển              34
# 10601  Huyện Ngọc Hiển  ...    Tỉnh Cà Mau         Đất Mũi              34
#
#        newProvinceLat  newProvinceLon  newWardCode  newWardType newWardLat  \
# 0             21.0001         105.698         42.0       phường   21.05670
# 1             21.0001         105.698          3.0       phường   21.03860
# 2             21.0001         105.698         61.0       phường   21.03810
# 3             21.0001         105.698         30.0       phường   21.02750
# 4             21.0001         105.698         61.0       phường   21.03810
# ...               ...             ...          ...          ...        ...
# 10597          9.1362         105.182       3302.0           xã    8.63765
# 10598          9.1362         105.182       3327.0           xã    8.64616
# 10599          9.1362         105.182       3302.0           xã    8.63765
# 10600          9.1362         105.182       3327.0           xã    8.64616
# 10601          9.1362         105.182       3302.0           xã    8.63765
#
#        newWardLon  newWardAreaKm2
# 0         105.845           15.09
# 1         105.838            2.97
# 2         105.816            2.68
# 3         105.814            2.60
# 4         105.816            2.68
# ...           ...             ...
# 10597     104.820          271.20
# 10598     104.943          237.70
# 10599     104.820          271.20
# 10600     104.943          237.70
# 10601     104.820          271.20
#
# [10602 rows x 21 columns]

# %%
if df_convert_full['newWard'].isna().sum():
    raise Exception('Missing new wards')

# %%
if df_convert_full[['province', 'district', 'ward']].drop_duplicates().shape[0] != df_danhmuc.shape[0]:
    raise Exception('Convert missing ward in danhmuc')

# %%
if df_convert_full[['newProvince', 'newWard', 'newWardCode']].drop_duplicates().shape[0] != 3321:
    raise Exception('Convert missing ward in sapnhap')

# %%
df_convert_full.to_csv(BASE_DIR / 'data/interim/convert_legacy_2025_simple.csv', index=False)
