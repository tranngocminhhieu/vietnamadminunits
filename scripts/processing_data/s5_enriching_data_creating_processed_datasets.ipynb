# %%
import sqlite3
import pandas as pd
import numpy as np
import json
import re

from pathlib import Path

from pathlib import Path
import sys
BASE_DIR = Path().resolve().parent.parent
sys.path.append((BASE_DIR / 'vietnamadminunits/parser').as_posix())

from utils import check_point_in_polygon, find_nearest_point

BASE_DIR = Path().resolve().parent.parent

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Adding Google Location for 63 provinces

# %%
df_province = pd.read_csv(BASE_DIR / 'data/raw/63_provinces_location_province_2025-07-24.csv')
df_district = pd.read_csv(BASE_DIR / 'data/raw/63_provinces_location_district_2025-07-25.csv')
df_ward = pd.read_csv(BASE_DIR / 'data/raw/63_provinces_location_ward_2025-07-24.csv')

# %%
col_name = {
    'address': 'province',
    'latitude': 'provinceLat',
    'longitude': 'provinceLon',
    'bounds': 'provinceBounds',
    'geo_address': 'provinceGeoAddress',
}
df_province.rename(columns=col_name, inplace=True)

# %%
col_name = {
    'address': 'districtAddress',
    'latitude': 'districtLat',
    'longitude': 'districtLon',
    'bounds': 'districtBounds',
    'geo_address': 'districtGeoAddress',
}
df_district.rename(columns=col_name, inplace=True)

# %%
col_name = {
    'address': 'wardAddress',
    'latitude': 'wardLat',
    'longitude': 'wardLon',
    'bounds': 'wardBounds',
    'geo_address': 'wardGeoAddress',
}
df_ward.rename(columns=col_name, inplace=True)

# %%
df = pd.read_csv(BASE_DIR / 'data/interim/convert_legacy_2025_simple.csv')

# %%
df = pd.merge(df, df_province, on='province', how='left')

df['districtAddress'] = df['district'] + ', ' + df['province']
df = pd.merge(df, df_district, on='districtAddress', how='left')

df['wardAddress'] = df['ward'].fillna('') + ', ' + df['district'] + ', ' + df['province']
df = pd.merge(df, df_ward, on='wardAddress', how='left')

# %% [markdown]
# # Choosing default new ward for divided wards

# %%
# Assign default new ward for divided wards
df_divided = df[df['isDividedWard'] == True].copy()
df_divided.sort_values(by=['province', 'district', 'ward', 'newWardAreaKm2'], inplace=True)
df_divided_ward = df_divided[['province', 'district', 'ward', 'wardLat', 'wardLon']].drop_duplicates()


for index, row in df_divided_ward.iterrows():
    province = row['province']
    district = row['district']
    ward = row['ward']
    ward_point = (row['wardLat'], row['wardLon'])


    new_wards = df[(df['province'] == province) & (df['district'] == district) & (df['ward'] == ward)]

    containing_points = []
    new_ward_points = []
    for new_ward_index, new_ward_row in new_wards.iterrows():
        new_ward_point = (new_ward_row['newWardLat'], new_ward_row['newWardLon'])
        new_ward_area_km2 = new_ward_row['newWardAreaKm2']
        new_ward_points.append(new_ward_point)

        is_contain = check_point_in_polygon(point=ward_point, polygon_center=new_ward_point,
                                            polygon_area_km2=new_ward_area_km2)
        if is_contain:
            containing_points.append(new_ward_point)
        df.loc[new_ward_index, 'isNewWardPolygonContainsWard'] = is_contain

    nearest_point = find_nearest_point(a_point=ward_point, list_of_b_points=new_ward_points)

    if len(containing_points) == 1:
        default_ward_point = containing_points[0]
    else:
        default_ward_point = nearest_point

    df.loc[(df['province'] == province) & (df['district'] == district) & (df['ward'] == ward) & (
                df['newWardLat'] == nearest_point[0]) & (
                       df['newWardLon'] == nearest_point[1]), 'isNearestNewWard'] = True
    df.loc[(df['province'] == province) & (df['district'] == district) & (df['ward'] == ward) & (
                df['newWardLat'] == default_ward_point[0]) & (
                       df['newWardLon'] == default_ward_point[1]), 'isDefaultNewWard'] = True

df.loc[(df['isDividedWard'] == True) & (df['isNearestNewWard'].isna()), 'isNearestNewWard'] = False
df.loc[(df['isDividedWard'] == True) & (df['isDefaultNewWard'].isna()), 'isDefaultNewWard'] = False

# %% [markdown]
# # Enriching data
#
# - short name
# - ~~english name~~

# %%
# 3321
def create_sort_34(text, level=1):
    if isinstance(text, str):
        if level == 1:
            text = re.sub(r'^Tỉnh\s|Thành phố\s|Thủ đô\s', '', text, flags=re.IGNORECASE)
        else:
            text = re.sub(r'^Phường\s|Đặc khu\s|Xã\s', '', text, flags=re.IGNORECASE)

        return text.strip()
    return text


df['newWardType'] = df['newWardType'].str.capitalize()
df.rename(columns={'newWard': 'newWardShort'}, inplace=True)
df['newWard'] = df['newWardType'] + ' ' + df['newWardShort']
df['newProvinceShort'] = df['newProvince'].apply(create_sort_34)

# %%
# 63
def create_sort_63(text, level=1):
    if isinstance(text, str):
        if level == 1:
            text = re.sub(r'^Tỉnh\s|Thành phố\s', '', text, flags=re.IGNORECASE)
        elif level == 2:
            if re.search(r'^Quận\s\d{1,2}', text, flags=re.IGNORECASE):
                pass
            else:
                text = re.sub(r'^Quận\s|Huyện\s|Thị xã\s|Thành phố\s', '', text, flags=re.IGNORECASE)
        else:
            if re.search(r'^Phường\s\d{1,2}', text, flags=re.IGNORECASE):
                pass
            else:
                text = re.sub(r'^Phường\s|Thị trấn\s|Xã\s', '', text, flags=re.IGNORECASE)

        return text.strip()
    return text


unit_cols = ['province', 'district', 'ward']
level_map = {
    'province': 1,
    'district': 2,
    'ward': 3
}

for col in unit_cols:
    # Create short version
    level = level_map[col]
    df[f"{col}Short"] = df[col].apply(create_sort_63, args=(level,))

# %%
df
# Out:
#        provinceCode  isMergedProvince  districtCode districtType  wardCode  \
# 0                 1             False             1         Quận       1.0
# 1                 1             False             1         Quận       4.0
# 2                 1             False             1         Quận       6.0
# 3                 1             False             1         Quận       7.0
# 4                 1             False             1         Quận       7.0
# ...             ...               ...           ...          ...       ...
# 10597            96              True           973        Huyện   32242.0
# 10598            96              True           973        Huyện   32244.0
# 10599            96              True           973        Huyện   32245.0
# 10600            96              True           973        Huyện   32245.0
# 10601            96              True           973        Huyện   32248.0
#
#        wardType  isMergedWard  isDividedWard          province  \
# 0        Phường          True          False  Thành phố Hà Nội
# 1        Phường          True          False  Thành phố Hà Nội
# 2        Phường          True          False  Thành phố Hà Nội
# 3        Phường          True           True  Thành phố Hà Nội
# 4        Phường          True           True  Thành phố Hà Nội
# ...         ...           ...            ...               ...
# 10597        Xã          True           True       Tỉnh Cà Mau
# 10598  Thị trấn          True          False       Tỉnh Cà Mau
# 10599        Xã          True           True       Tỉnh Cà Mau
# 10600        Xã          True           True       Tỉnh Cà Mau
# 10601        Xã          True          False       Tỉnh Cà Mau
#
#               district  ...                                   wardBounds  \
# 0         Quận Ba Đình  ...  21.040199,105.842293 – 21.053464,105.855959
# 1         Quận Ba Đình  ...  21.039976,105.836277 – 21.050836,105.850246
# 2         Quận Ba Đình  ...  21.035736,105.805872 – 21.047587,105.815001
# 3         Quận Ba Đình  ...  21.031335,105.804777 – 21.037841,105.814554
# 4         Quận Ba Đình  ...  21.031335,105.804777 – 21.037841,105.814554
# ...                ...  ...                                          ...
# 10597  Huyện Ngọc Hiển  ...    8.567442,104.772921 – 8.737998,104.915485
# 10598  Huyện Ngọc Hiển  ...    8.596467,104.967112 – 8.679712,105.061312
# 10599  Huyện Ngọc Hiển  ...    8.598292,105.007668 – 8.701729,105.142808
# 10600  Huyện Ngọc Hiển  ...    8.598292,105.007668 – 8.701729,105.142808
# 10601  Huyện Ngọc Hiển  ...    8.559124,104.707432 – 8.655954,104.852142
#
#                                       wardGeoAddress  \
# 0                   Phuc Xa, Ba Đình, Hanoi, Vietnam
# 1                 Truc Bach, Ba Đình, Hanoi, Vietnam
# 2                Vĩnh Phúc, Ba Đình, Hà Nội, Vietnam
# 3                  Cống Vị, Ba Đình, Hà Nội, Vietnam
# 4                  Cống Vị, Ba Đình, Hà Nội, Vietnam
# ...                                              ...
# 10597   Viên An, Ngọc Hiển District, Ca Mau, Vietnam
# 10598  Rạch Gốc, Ngọc Hiển District, Ca Mau, Vietnam
# 10599             Tân Ân, Ngọc Hiển, Cà Mau, Vietnam
# 10600             Tân Ân, Ngọc Hiển, Cà Mau, Vietnam
# 10601   Đất Mũi, Ngọc Hiển District, Ca Mau, Vietnam
#
#       isNewWardPolygonContainsWard  isNearestNewWard  isDefaultNewWard  \
# 0                              NaN               NaN               NaN
# 1                              NaN               NaN               NaN
# 2                              NaN               NaN               NaN
# 3                            False             False             False
# 4                             True              True              True
# ...                            ...               ...               ...
# 10597                         True              True              True
# 10598                          NaN               NaN               NaN
# 10599                        False             False             False
# 10600                        False              True              True
# 10601                          NaN               NaN               NaN
#
#                    newWard  newProvinceShort provinceShort  districtShort  \
# 0           Phường Hồng Hà            Hà Nội        Hà Nội        Ba Đình
# 1           Phường Ba Đình            Hà Nội        Hà Nội        Ba Đình
# 2           Phường Ngọc Hà            Hà Nội        Hà Nội        Ba Đình
# 3          Phường Giảng Võ            Hà Nội        Hà Nội        Ba Đình
# 4           Phường Ngọc Hà            Hà Nội        Hà Nội        Ba Đình
# ...                    ...               ...           ...            ...
# 10597         Xã Đất Mũi            Cà Mau        Cà Mau      Ngọc Hiển
# 10598  Xã Phan Ngọc Hiển            Cà Mau        Cà Mau      Ngọc Hiển
# 10599         Xã Đất Mũi            Cà Mau        Cà Mau      Ngọc Hiển
# 10600  Xã Phan Ngọc Hiển            Cà Mau        Cà Mau      Ngọc Hiển
# 10601         Xã Đất Mũi            Cà Mau        Cà Mau      Ngọc Hiển
#
#        wardShort
# 0        Phúc Xá
# 1      Trúc Bạch
# 2      Vĩnh Phúc
# 3        Cống Vị
# 4        Cống Vị
# ...          ...
# 10597    Viên An
# 10598   Rạch Gốc
# 10599     Tân Ân
# 10600     Tân Ân
# 10601    Đất Mũi
#
# [10602 rows x 43 columns]

# %% [markdown]
# ## 63 provinces

# %%
col_63 = [
    'province',
    'district',
    'ward',

    'provinceShort',
    'districtShort',
    'wardShort',

    'districtType',
    'wardType',

    'provinceCode',
    'provinceLat',
    'provinceLon',
    'provinceBounds',
    'provinceGeoAddress',

    'districtCode',

    'districtLat',
    'districtLon',
    'districtBounds',
    'districtGeoAddress',

    'wardCode',

    'wardLat',
    'wardLon',
    'wardBounds',
    'wardGeoAddress',
]
df_63 = df[col_63].drop_duplicates().reset_index(drop=True)

# %%
# Add info to duplicated districtShort in a province
df_63_district_short = df_63[['province', 'district', 'districtShort']].drop_duplicates()
count_63_district_short = df_63_district_short.groupby(['province', 'districtShort']).size().reset_index(name='count').sort_values(by=['count'], ascending=False)
duplicated_63_district_short = count_63_district_short[count_63_district_short['count'] >= 2].copy()
duplicated_63_district_short['districtShortDuplicated'] = True
duplicated_63_district_short.drop(columns=['count'], inplace=True)

df_63 = pd.merge(df_63, duplicated_63_district_short, on=['province', 'districtShort'], how='left')
df_63['districtShortDuplicated'].fillna(False, inplace=True)
df_63['districtShort'] = np.where(df_63['districtShortDuplicated']==True, df_63['districtShort'] + ' (' + df_63['districtType'] + ')', df_63['districtShort'] )
df_63[df_63['districtShortDuplicated']==True]
# Out:
#             province        district               ward provinceShort  \
# 5499    Tỉnh Hà Tĩnh    Huyện Kỳ Anh         Xã Kỳ Xuân       Hà Tĩnh
# 5500    Tỉnh Hà Tĩnh    Huyện Kỳ Anh          Xã Kỳ Bắc       Hà Tĩnh
# 5501    Tỉnh Hà Tĩnh    Huyện Kỳ Anh          Xã Kỳ Phú       Hà Tĩnh
# 5502    Tỉnh Hà Tĩnh    Huyện Kỳ Anh        Xã Kỳ Phong       Hà Tĩnh
# 5503    Tỉnh Hà Tĩnh    Huyện Kỳ Anh         Xã Kỳ Tiến       Hà Tĩnh
# ...              ...             ...                ...           ...
# 9763  Tỉnh Hậu Giang  Thị xã Long Mỹ  Phường Vĩnh Tường     Hậu Giang
# 9764  Tỉnh Hậu Giang  Thị xã Long Mỹ        Xã Long Trị     Hậu Giang
# 9765  Tỉnh Hậu Giang  Thị xã Long Mỹ      Xã Long Trị A     Hậu Giang
# 9766  Tỉnh Hậu Giang  Thị xã Long Mỹ        Xã Long Phú     Hậu Giang
# 9767  Tỉnh Hậu Giang  Thị xã Long Mỹ         Xã Tân Phú     Hậu Giang
#
#          districtShort   wardShort districtType wardType  provinceCode  \
# 5499    Kỳ Anh (Huyện)     Kỳ Xuân        Huyện       Xã            42
# 5500    Kỳ Anh (Huyện)      Kỳ Bắc        Huyện       Xã            42
# 5501    Kỳ Anh (Huyện)      Kỳ Phú        Huyện       Xã            42
# 5502    Kỳ Anh (Huyện)    Kỳ Phong        Huyện       Xã            42
# 5503    Kỳ Anh (Huyện)     Kỳ Tiến        Huyện       Xã            42
# ...                ...         ...          ...      ...           ...
# 9763  Long Mỹ (Thị xã)  Vĩnh Tường       Thị xã   Phường            93
# 9764  Long Mỹ (Thị xã)    Long Trị       Thị xã       Xã            93
# 9765  Long Mỹ (Thị xã)  Long Trị A       Thị xã       Xã            93
# 9766  Long Mỹ (Thị xã)    Long Phú       Thị xã       Xã            93
# 9767  Long Mỹ (Thị xã)     Tân Phú       Thị xã       Xã            93
#
#       provinceLat  ...  districtLat districtLon  \
# 5499    18.245968  ...    18.064047  106.205148
# 5500    18.245968  ...    18.064047  106.205148
# 5501    18.245968  ...    18.064047  106.205148
# 5502    18.245968  ...    18.064047  106.205148
# 5503    18.245968  ...    18.064047  106.205148
# ...           ...  ...          ...         ...
# 9763     9.757898  ...     9.669597  105.565024
# 9764     9.757898  ...     9.669597  105.565024
# 9765     9.757898  ...     9.669597  105.565024
# 9766     9.757898  ...     9.669597  105.565024
# 9767     9.757898  ...     9.669597  105.565024
#
#                                   districtBounds  \
# 5499  17.90839,106.014361 – 18.311613,106.338718
# 5500  17.90839,106.014361 – 18.311613,106.338718
# 5501  17.90839,106.014361 – 18.311613,106.338718
# 5502  17.90839,106.014361 – 18.311613,106.338718
# 5503  17.90839,106.014361 – 18.311613,106.338718
# ...                                          ...
# 9763      9.6511,105.54677 – 9.695774,105.592861
# 9764      9.6511,105.54677 – 9.695774,105.592861
# 9765      9.6511,105.54677 – 9.695774,105.592861
# 9766      9.6511,105.54677 – 9.695774,105.592861
# 9767      9.6511,105.54677 – 9.695774,105.592861
#
#                                  districtGeoAddress  wardCode    wardLat  \
# 5499              Kỳ Anh District, Ha Tinh, Vietnam   18757.0  18.232379
# 5500              Kỳ Anh District, Ha Tinh, Vietnam   18760.0  18.223910
# 5501              Kỳ Anh District, Ha Tinh, Vietnam   18763.0  18.204285
# 5502              Kỳ Anh District, Ha Tinh, Vietnam   18766.0  18.177876
# 5503              Kỳ Anh District, Ha Tinh, Vietnam   18769.0  18.186350
# ...                                             ...       ...        ...
# 9763  Long Mỹ, Long Mỹ District, Hau Giang, Vietnam   31475.0   9.732223
# 9764  Long Mỹ, Long Mỹ District, Hau Giang, Vietnam   31477.0   9.669597
# 9765  Long Mỹ, Long Mỹ District, Hau Giang, Vietnam   31478.0   9.669597
# 9766  Long Mỹ, Long Mỹ District, Hau Giang, Vietnam   31480.0   9.669597
# 9767  Long Mỹ, Long Mỹ District, Hau Giang, Vietnam   31481.0   9.660131
#
#          wardLon                                   wardBounds  \
# 5499  106.187502  18.206315,106.151429 – 18.267693,106.226654
# 5500  106.152213  18.194714,106.124572 – 18.257564,106.184113
# 5501  106.246331  18.171752,106.220233 – 18.223286,106.280559
# 5502  106.152213  18.130806,106.127012 – 18.217581,106.182509
# 5503  106.187502   18.15116,106.169389 – 18.219765,106.213669
# ...          ...                                          ...
# 9763  105.573697    9.730874,105.572348 – 9.733572,105.575045
# 9764  105.565024       9.6511,105.54677 – 9.695774,105.592861
# 9765  105.565024       9.6511,105.54677 – 9.695774,105.592861
# 9766  105.565024       9.6511,105.54677 – 9.695774,105.592861
# 9767  105.652983     9.62684,105.629734 – 9.704536,105.686108
#
#                                       wardGeoAddress  districtShortDuplicated
# 5499      Kỳ Xuân, Kỳ Anh District, Ha Tinh, Vietnam                     True
# 5500       Kỳ Bắc, Kỳ Anh District, Ha Tinh, Vietnam                     True
# 5501       Kỳ Phú, Kỳ Anh District, Ha Tinh, Vietnam                     True
# 5502     Kỳ Phong, Kỳ Anh District, Ha Tinh, Vietnam                     True
# 5503      Kỳ Tiến, Kỳ Anh District, Ha Tinh, Vietnam                     True
# ...                                              ...                      ...
# 9763         Vĩnh Tường, Long Mỹ, Hậu Giang, Vietnam                     True
# 9764   Long Mỹ, Long Mỹ District, Hau Giang, Vietnam                     True
# 9765   Long Mỹ, Long Mỹ District, Hau Giang, Vietnam                     True
# 9766   Long Mỹ, Long Mỹ District, Hau Giang, Vietnam                     True
# 9767  Tân Phú, Long Phú, Long Mỹ, Hậu Giang, Vietnam                     True
#
# [142 rows x 24 columns]

# %%
count_63_ward_short = df_63.groupby(['province', 'district', 'wardShort']).size().reset_index(name='count').sort_values(by=['count'], ascending=False)
duplicated_63_ward_short = count_63_ward_short[count_63_ward_short['count'] >= 2].copy()
duplicated_63_ward_short['wardShortDuplicated'] = True
duplicated_63_ward_short.drop(columns=['count'], inplace=True)

df_63 = pd.merge(df_63, duplicated_63_ward_short, on=['province', 'district', 'wardShort'], how='left')
df_63['wardShortDuplicated'].fillna(False, inplace=True)
df_63['wardShort'] = np.where(df_63['wardShortDuplicated']==True, df_63['wardShort'] + ' (' + df_63['wardType'] + ')', df_63['wardShort'])
df_63[df_63['wardShortDuplicated']==True]
# Out:
#                province          district                      ward  \
# 165    Thành phố Hà Nội     Huyện Gia Lâm         Thị trấn Yên Viên
# 167    Thành phố Hà Nội     Huyện Gia Lâm               Xã Yên Viên
# 1425      Tỉnh Lai Châu    Huyện Mường Tè         Thị trấn Mường Tè
# 1430      Tỉnh Lai Châu    Huyện Mường Tè               Xã Mường Tè
# 1648        Tỉnh Sơn La     Huyện Mai Sơn          Thị trấn Hát Lót
# 1658        Tỉnh Sơn La     Huyện Mai Sơn                Xã Hát Lót
# 1820       Tỉnh Yên Bái    Huyện Trạm Tấu         Thị trấn Trạm Tấu
# 1825       Tỉnh Yên Bái    Huyện Trạm Tấu               Xã Trạm Tấu
# 2345      Tỉnh Lạng Sơn    Huyện Chi Lăng         Thị trấn Chi Lăng
# 2363      Tỉnh Lạng Sơn    Huyện Chi Lăng               Xã Chi Lăng
# 2384      Tỉnh Lạng Sơn    Huyện Đình Lập         Thị trấn Đình Lập
# 2389      Tỉnh Lạng Sơn    Huyện Đình Lập               Xã Đình Lập
# 2487    Tỉnh Quảng Ninh      Huyện Đầm Hà           Thị trấn Đầm Hà
# 7642  Thị trấn            68    11.575279  ...   107.645209
# 7646        Xã            68    11.575279  ...   107.645209
# 8556  Thị trấn            80    10.685145  ...   106.417031
# 8562        Xã            80    10.685145  ...   106.417031
# 9042  Thị trấn            84     9.762666  ...   106.275751
# 9054        Xã            84     9.762666  ...   106.275751
# 9234  Thị trấn            87    10.493799  ...   105.829030
# 9243        Xã            87    10.493799  ...   105.829030
# 9247  Thị trấn            87    10.493799  ...   105.711646
# 9255        Xã            87    10.493799  ...   105.711646
# 9581  Thị trấn            91     9.824959  ...   105.184380
# 9585        Xã            91     9.824959  ...   105.184380
# 9653  Thị trấn            92    10.045162  ...   105.336536
# 9657        Xã            92    10.045162  ...   105.336536
# 9815  Thị trấn            94     9.617375  ...   106.087533
# 9825        Xã            94     9.617375  ...   106.087533
# 9868        Xã            94     9.617375  ...   106.087533
# 9869  Thị trấn            94     9.617375  ...   106.087533
# 9895  Thị trấn            95     9.289943  ...   105.430238
# 9898        Xã            95     9.289943  ...   105.430238
# 9949    Phường            96     8.962410  ...   105.196080
# 9950        Xã            96     8.962410  ...   105.196080
# 9964  Thị trấn            96     8.962410  ...   105.172682
# 9970        Xã            96     8.962410  ...   105.172682
#
#                                    districtBounds  \
# 165   20.926328,105.880257 – 21.121305,106.020073
# 167   20.926328,105.880257 – 21.121305,106.020073
# 1425  22.166967,102.320669 – 22.780852,102.986228
# 1430  22.166967,102.320669 – 22.780852,102.986228
# 1648  20.958818,103.697428 – 21.378427,104.292848
# 1658  20.958818,103.697428 – 21.378427,104.292848
# 1820  21.351131,104.276719 – 21.669032,104.662393
# 1825  21.351131,104.276719 – 21.669032,104.662393
# 2345  21.535728,106.420023 – 21.797534,106.831907
# 2363  21.535728,106.420023 – 21.797534,106.831907
# 2384   21.32515,106.888411 – 21.742754,107.363976
# 2389   21.32515,106.888411 – 21.742754,107.363976
# 2487  21.223098,107.468289 – 21.498776,107.678518
# 2493  21.223098,107.468289 – 21.498776,107.678518
# 7642  11.322768,107.475178 – 11.580789,107.798841
# 7646  11.322768,107.475178 – 11.580789,107.798841
# 8556  10.740895,106.269961 – 11.026342,106.534745
# 8562  10.740895,106.269961 – 11.026342,106.534745
# 9042     9.60246,106.132926 – 9.798841,106.417516
# 9054     9.60246,106.132926 – 9.798841,106.417516
# 9234   10.365695,105.635789 – 10.75264,105.942089
# 9243   10.365695,105.635789 – 10.75264,105.942089
# 9247   10.294174,105.55368 – 10.672245,105.838362
# 9255   10.294174,105.55368 – 10.672245,105.838362
# 9581    9.445167,105.136928 – 9.536426,105.233917
# 9585    9.445167,105.136928 – 9.536426,105.233917
# 9653  10.100679,105.225754 – 10.312396,105.498741
# 9657  10.100679,105.225754 – 10.312396,105.498741
# 9815    9.542002,105.983058 – 9.784115,106.184871
# 9825    9.542002,105.983058 – 9.784115,106.184871
# 9868    9.401704,105.964369 – 9.587495,106.219862
# 9869    9.401704,105.964369 – 9.587495,106.219862
# 9895      9.279743,105.248315 – 9.4927,105.578294
# 1825               Trạm Tấu, Tram Tau, Yên Bái, Vietnam
# 2345     Chi Lăng, Chi Lăng District, Lạng Sơn, Vietnam
# 2363           x. Chi Lăng, Chi Lăng, Lạng Sơn, Vietnam
# 2384          tt. Đình Lập, Đình Lập, Lạng Sơn, Vietnam
# 2389  H3H9+PH3, QL4B, Đình lập, Đình Lập, Lạng Sơn, ...
# 2487            tt. Đầm Hà, Đầm Hà, Quảng Ninh, Vietnam
# 2493       Đầm Hà, Đầm Hà District, Quảng Ninh, Vietnam
# 7642   Ma Đa Guôi, Đạ Huoai District, Lam Dong, Vietnam
# 7646   Ma Đa Guôi, Đạ Huoai District, Lam Dong, Vietnam
# 8556            tt. Hiệp Hòa, Đức Hòa, Long An, Vietnam
# 8562                Hiệp Hòa, Đức Hòa, Long An, Vietnam
# 9042        Định An, Trà Cú District, Tra Vinh, Vietnam
# 9054        Định An, Trà Cú District, Tra Vinh, Vietnam
# 9234      Mỹ An, Tháp Mười District, Dong Thap, Vietnam
# 9243      Mỹ An, Tháp Mười District, Dong Thap, Vietnam
# 9247           Mỹ Thọ, Tp. Cao Lãnh, Đồng Tháp, Vietnam
# 9255               Mỹ Thọ, Cao Lanh, Dong Thap, Vietnam
# 9581  Vĩnh Thuận, Vĩnh Thuận District, Kien Giang, V...
# 9585                    Vĩnh Thuận, Kiên Giang, Vietnam
# 9653                       Vĩnh Thạnh, Cần Thơ, Vietnam
# 9657             Thạnh An, Vĩnh Thạnh, Cần Thơ, Vietnam
# 9815    Long Phú, Long Phú District, Soc Trang, Vietnam
# 9825                       Long Phú, Sóc Trăng, Vietnam
# 9868     Lịch Hội Thượng, Vĩnh Châu, Soc Trang, Vietnam
# 9869     Lịch Hội Thượng, Vĩnh Châu, Soc Trang, Vietnam
# 9895                      Phước Long, Bac Lieu, Vietnam
# 9898  Phước Long Village, Phước Long District, Bạc L...
# 9949                 Tân Thành, Cà Mau, Ca Mau, Vietnam
# 9950                 Tân Thành, Cà Mau, Ca Mau, Vietnam
# 9964          tt. Thới Bình, Thới Bình, Cà Mau, Vietnam
# 9970           x. Thới Bình, Thới Bình, Cà Mau, Vietnam
#
#       districtShortDuplicated  wardShortDuplicated
# 165                     False                 True
# 167                     False                 True
# 1425                    False                 True
# 1430                    False                 True
# 1648                    False                 True
# 1658                    False                 True
# 1820                    False                 True
# 1825                    False                 True
# 2345                    False                 True
# 2363                    False                 True
# 2384                    False                 True
# 2389                    False                 True
# 2487                    False                 True
# 2493                    False                 True
# 7642                    False                 True
# 7646                    False                 True
# 8556                    False                 True
# 8562                    False                 True
# 9042                    False                 True
# 9054                    False                 True
# 9234                    False                 True
# 9243                    False                 True
# 9247                     True                 True
# 9255                     True                 True
# 9581                    False                 True
# 9585                    False                 True
# 9653                    False                 True
# 9657                    False                 True
# 9815                    False                 True
# 9825                    False                 True
# 9868                    False                 True
# 9869                    False                 True
# 9895                    False                 True
# 9898                    False                 True
# 9949                    False                 True
# 9950                    False                 True
# 9964                    False                 True
# 9970                    False                 True
#
# [38 rows x 25 columns]

# %%
df_63
# Out:
#                province         district               ward provinceShort  \
# 0      Thành phố Hà Nội     Quận Ba Đình     Phường Phúc Xá        Hà Nội
# 1      Thành phố Hà Nội     Quận Ba Đình   Phường Trúc Bạch        Hà Nội
# 2      Thành phố Hà Nội     Quận Ba Đình   Phường Vĩnh Phúc        Hà Nội
# 3      Thành phố Hà Nội     Quận Ba Đình     Phường Cống Vị        Hà Nội
# 4      Thành phố Hà Nội     Quận Ba Đình   Phường Liễu Giai        Hà Nội
# ...                 ...              ...                ...           ...
# 10035       Tỉnh Cà Mau  Huyện Ngọc Hiển    Xã Viên An Đông        Cà Mau
# 10036       Tỉnh Cà Mau  Huyện Ngọc Hiển         Xã Viên An        Cà Mau
# 10037       Tỉnh Cà Mau  Huyện Ngọc Hiển  Thị trấn Rạch Gốc        Cà Mau
# 10038       Tỉnh Cà Mau  Huyện Ngọc Hiển          Xã Tân Ân        Cà Mau
# 10039       Tỉnh Cà Mau  Huyện Ngọc Hiển         Xã Đất Mũi        Cà Mau
#
#       districtShort     wardShort districtType  wardType  provinceCode  \
# 0           Ba Đình       Phúc Xá         Quận    Phường             1
# 1           Ba Đình     Trúc Bạch         Quận    Phường             1
# 2           Ba Đình     Vĩnh Phúc         Quận    Phường             1
# 3           Ba Đình       Cống Vị         Quận    Phường             1
# 4           Ba Đình     Liễu Giai         Quận    Phường             1
# ...             ...           ...          ...       ...           ...
# 10035     Ngọc Hiển  Viên An Đông        Huyện        Xã            96
# 10036     Ngọc Hiển       Viên An        Huyện        Xã            96
# 10037     Ngọc Hiển      Rạch Gốc        Huyện  Thị trấn            96
# 10038     Ngọc Hiển        Tân Ân        Huyện        Xã            96
# 10039     Ngọc Hiển       Đất Mũi        Huyện        Xã            96
#
#        provinceLat  ...  districtLon  \
# 0        21.027764  ...   105.826094
# 1        21.027764  ...   105.826094
# 2        21.027764  ...   105.826094
# 3        21.027764  ...   105.826094
# 4        21.027764  ...   105.826094
# ...            ...  ...          ...
# 10035     8.962410  ...   104.962250
# 10036     8.962410  ...   104.962250
# 10037     8.962410  ...   104.962250
# 10038     8.962410  ...   104.962250
# 10039     8.962410  ...   104.962250
#
#                                     districtBounds  \
# 0      21.016004,105.801279 – 21.053565,105.857015
# 1      21.016004,105.801279 – 21.053565,105.857015
# 2      21.016004,105.801279 – 21.053565,105.857015
# 3      21.016004,105.801279 – 21.053565,105.857015
# 4      21.016004,105.801279 – 21.053565,105.857015
# ...                                            ...
# 10035     8.408631,104.70541 – 8.796906,105.218539
# 10036     8.408631,104.70541 – 8.796906,105.218539
# 10037     8.408631,104.70541 – 8.796906,105.218539
# 10038     8.408631,104.70541 – 8.796906,105.218539
# 10039     8.408631,104.70541 – 8.796906,105.218539
#
#                         districtGeoAddress  wardCode    wardLat     wardLon  \
# 0                  Ba Đình, Hanoi, Vietnam       1.0  21.046798  105.848112
# 1                  Ba Đình, Hanoi, Vietnam       4.0  21.044395  105.843174
# 2                  Ba Đình, Hanoi, Vietnam       6.0  21.041731  105.809950
# 3                  Ba Đình, Hanoi, Vietnam       7.0  21.035280  105.809216
# 4                  Ba Đình, Hanoi, Vietnam       8.0  21.037997  105.818756
# ...                                    ...       ...        ...         ...
# 10035  Ngọc Hiển District, Ca Mau, Vietnam   32239.0   8.637734  104.950567
# 10036  Ngọc Hiển District, Ca Mau, Vietnam   32242.0   8.663728  104.833788
# 10037  Ngọc Hiển District, Ca Mau, Vietnam   32244.0   8.656311  105.020676
# 10038  Ngọc Hiển District, Ca Mau, Vietnam   32245.0   8.653504  105.090815
# 10039  Ngọc Hiển District, Ca Mau, Vietnam   32248.0   8.600635  104.755782
#
#                                         wardBounds  \
# 0      21.040199,105.842293 – 21.053464,105.855959
# 1      21.039976,105.836277 – 21.050836,105.850246
# 2      21.035736,105.805872 – 21.047587,105.815001
# 3      21.031335,105.804777 – 21.037841,105.814554
# 4      21.033027,105.812652 – 21.042991,105.821777
# ...                                            ...
# 10035    8.570243,104.878836 – 8.749535,104.996595
# 10036    8.567442,104.772921 – 8.737998,104.915485
# 10037    8.596467,104.967112 – 8.679712,105.061312
# 10038    8.598292,105.007668 – 8.701729,105.142808
# 10039    8.559124,104.707432 – 8.655954,104.852142
#
#                                       wardGeoAddress  districtShortDuplicated  \
# 0                   Phuc Xa, Ba Đình, Hanoi, Vietnam                    False
# 1                 Truc Bach, Ba Đình, Hanoi, Vietnam                    False
# 2                Vĩnh Phúc, Ba Đình, Hà Nội, Vietnam                    False
# 3                  Cống Vị, Ba Đình, Hà Nội, Vietnam                    False
# 4                Liễu Giai, Ba Đình, Hà Nội, Vietnam                    False
# ...                                              ...                      ...
# 10035   Viên An, Ngọc Hiển District, Ca Mau, Vietnam                    False
# 10036   Viên An, Ngọc Hiển District, Ca Mau, Vietnam                    False
# 10037  Rạch Gốc, Ngọc Hiển District, Ca Mau, Vietnam                    False
# 10038             Tân Ân, Ngọc Hiển, Cà Mau, Vietnam                    False
# 10039   Đất Mũi, Ngọc Hiển District, Ca Mau, Vietnam                    False
#
#        wardShortDuplicated
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 10035                False
# 10036                False
# 10037                False
# 10038                False
# 10039                False
#
# [10040 rows x 25 columns]

# %%
df_63.to_csv(BASE_DIR / 'data/processed/legacy_63-province-10040-ward_with_location.csv', index=False)

# %% [markdown]
# ## 34 provinces

# %%
col_34 = {
    'newProvince': 'province',
    'newWard': 'ward',
    'newProvinceShort': 'provinceShort',
    'newWardShort': 'wardShort',
    'newWardType': 'wardType',

    'newProvinceCode': 'provinceCode',
    'newProvinceLat': 'provinceLat',
    'newProvinceLon': 'provinceLon',
    'newWardCode': 'wardCode',
    'newWardLat': 'wardLat',
    'newWardLon': 'wardLon',
    'newWardAreaKm2': 'wardAreaKm2',
}
df_34 = df[col_34.keys()].drop_duplicates().reset_index(drop=True).rename(columns=col_34)

# %%
df_34.groupby(['province', 'wardShort']).size().reset_index(name='count').sort_values(by=['count'], ascending=False)
# No duplicated with accented name
# Out:
#                province   wardShort  count
# 0     Thành phố Cần Thơ     An Bình      1
# 2218    Tỉnh Quảng Ninh    Đông Ngũ      1
# 2208    Tỉnh Quảng Ninh    Tiên Yên      1
# 2209    Tỉnh Quảng Ninh   Tuần Châu      1
# 2210    Tỉnh Quảng Ninh     Uông Bí      1
# ...                 ...         ...    ...
# 1110       Tỉnh Hà Tĩnh    Gia Hanh      1
# 1111       Tỉnh Hà Tĩnh   Hoành Sơn      1
# 1112       Tỉnh Hà Tĩnh  Hà Huy Tập      1
# 1113       Tỉnh Hà Tĩnh     Hà Linh      1
# 3320     Tỉnh Đồng Tháp    Đồng Sơn      1
#
# [3321 rows x 3 columns]

# %%
df_34
# Out:
#            province                    ward provinceShort  \
# 0     Thủ đô Hà Nội          Phường Hồng Hà        Hà Nội
# 1     Thủ đô Hà Nội          Phường Ba Đình        Hà Nội
# 2     Thủ đô Hà Nội          Phường Ngọc Hà        Hà Nội
# 3     Thủ đô Hà Nội         Phường Giảng Võ        Hà Nội
# 4     Thủ đô Hà Nội        Phường Hoàn Kiếm        Hà Nội
# ...             ...                     ...           ...
# 3316    Tỉnh Cà Mau             Xã Phú Tân        Cà Mau
# 3317    Tỉnh Cà Mau  Xã Nguyễn Việt Khái        Cà Mau
# 3318    Tỉnh Cà Mau               Xã Tân Ân        Cà Mau
# 3319    Tỉnh Cà Mau     Xã Phan Ngọc Hiển        Cà Mau
# 3320    Tỉnh Cà Mau            Xã Đất Mũi        Cà Mau
#
#                 wardShort wardType  provinceCode  provinceLat  provinceLon  \
# 0                 Hồng Hà   Phường             1      21.0001      105.698
# 1                 Ba Đình   Phường             1      21.0001      105.698
# 2                 Ngọc Hà   Phường             1      21.0001      105.698
# 3                Giảng Võ   Phường             1      21.0001      105.698
# 4               Hoàn Kiếm   Phường             1      21.0001      105.698
# ...                   ...      ...           ...          ...          ...
# 3316             Phú Tân       Xã            34       9.1362      105.182
# 3317  Nguyễn Việt Khái       Xã            34       9.1362      105.182
# 3318               Tân Ân       Xã            34       9.1362      105.182
# 3319     Phan Ngọc Hiển       Xã            34       9.1362      105.182
# 3320            Đất Mũi       Xã            34       9.1362      105.182
#
#       wardCode   wardLat  wardLon  wardAreaKm2
# 0         42.0  21.05670  105.845        15.09
# 1          3.0  21.03860  105.838         2.97
# 2         61.0  21.03810  105.816         2.68
# 3         30.0  21.02750  105.814         2.60
# 4         39.0  21.03200  105.850         1.91
# ...        ...       ...      ...          ...
# 3316    3331.0   8.92852  104.846       101.70
# 3317    3324.0   8.86914  104.930       129.90
# 3318    3337.0   8.72769  105.078       218.30
# 3319    3327.0   8.64616  104.943       237.70
# 3320    3302.0   8.63765  104.820       271.20
#
# [3321 rows x 12 columns]

# %%
df_34.to_csv(BASE_DIR / 'data/processed/2025_34-province-3221-ward_with_location.csv', index=False)

# %% [markdown]
# ## Convert

# %%
df.drop(columns=['districtShort', 'wardShort'], inplace=True)

# %%
df = pd.merge(df, df_63[['province', 'district', 'ward', 'districtShort', 'wardShort', 'districtShortDuplicated', 'wardShortDuplicated']], on=['province', 'district', 'ward'], how='left')

# %%
df
# Out:
#        provinceCode  isMergedProvince  districtCode districtType  wardCode  \
# 0                 1             False             1         Quận       1.0
# 1                 1             False             1         Quận       4.0
# 2                 1             False             1         Quận       6.0
# 3                 1             False             1         Quận       7.0
# 4                 1             False             1         Quận       7.0
# ...             ...               ...           ...          ...       ...
# 10597            96              True           973        Huyện   32242.0
# 10598            96              True           973        Huyện   32244.0
# 10599            96              True           973        Huyện   32245.0
# 10600            96              True           973        Huyện   32245.0
# 10601            96              True           973        Huyện   32248.0
#
#        wardType  isMergedWard  isDividedWard          province  \
# 0        Phường          True          False  Thành phố Hà Nội
# 1        Phường          True          False  Thành phố Hà Nội
# 2        Phường          True          False  Thành phố Hà Nội
# 3        Phường          True           True  Thành phố Hà Nội
# 4        Phường          True           True  Thành phố Hà Nội
# ...         ...           ...            ...               ...
# 10597        Xã          True           True       Tỉnh Cà Mau
# 10598  Thị trấn          True          False       Tỉnh Cà Mau
# 10599        Xã          True           True       Tỉnh Cà Mau
# 10600        Xã          True           True       Tỉnh Cà Mau
# 10601        Xã          True          False       Tỉnh Cà Mau
#
#               district  ... isNewWardPolygonContainsWard isNearestNewWard  \
# 0         Quận Ba Đình  ...                          NaN              NaN
# 1         Quận Ba Đình  ...                          NaN              NaN
# 2         Quận Ba Đình  ...                          NaN              NaN
# 3         Quận Ba Đình  ...                        False            False
# 4         Quận Ba Đình  ...                         True             True
# ...                ...  ...                          ...              ...
# 10597  Huyện Ngọc Hiển  ...                         True             True
# 10598  Huyện Ngọc Hiển  ...                          NaN              NaN
# 10599  Huyện Ngọc Hiển  ...                        False            False
# 10600  Huyện Ngọc Hiển  ...                        False             True
# 10601  Huyện Ngọc Hiển  ...                          NaN              NaN
#
#       isDefaultNewWard              newWard  newProvinceShort  provinceShort  \
# 0                  NaN       Phường Hồng Hà            Hà Nội         Hà Nội
# 1                  NaN       Phường Ba Đình            Hà Nội         Hà Nội
# 2                  NaN       Phường Ngọc Hà            Hà Nội         Hà Nội
# 3                False      Phường Giảng Võ            Hà Nội         Hà Nội
# 4                 True       Phường Ngọc Hà            Hà Nội         Hà Nội
# ...                ...                  ...               ...            ...
# 10597             True         Xã Đất Mũi            Cà Mau         Cà Mau
# 10598              NaN  Xã Phan Ngọc Hiển            Cà Mau         Cà Mau
# 10599            False         Xã Đất Mũi            Cà Mau         Cà Mau
# 10600             True  Xã Phan Ngọc Hiển            Cà Mau         Cà Mau
# 10601              NaN         Xã Đất Mũi            Cà Mau         Cà Mau
#
#        districtShort  wardShort  districtShortDuplicated  wardShortDuplicated
# 0            Ba Đình    Phúc Xá                    False                False
# 1            Ba Đình  Trúc Bạch                    False                False
# 2            Ba Đình  Vĩnh Phúc                    False                False
# 3            Ba Đình    Cống Vị                    False                False
# 4            Ba Đình    Cống Vị                    False                False
# ...              ...        ...                      ...                  ...
# 10597      Ngọc Hiển    Viên An                    False                False
# 10598      Ngọc Hiển   Rạch Gốc                    False                False
# 10599      Ngọc Hiển     Tân Ân                    False                False
# 10600      Ngọc Hiển     Tân Ân                    False                False
# 10601      Ngọc Hiển    Đất Mũi                    False                False
#
# [10602 rows x 45 columns]

# %%
cols = [
    'provinceCode',
    'isMergedProvince',
    'districtCode',
    'districtType',
    'districtShortDuplicated',
    'wardCode',
    'wardType',
    'wardShortDuplicated',
    'isMergedWard',
    'isDividedWard',

    'province',
    'district',
    'ward',

    'provinceShort',
    'districtShort',
    'wardShort',

    'newProvince',
    'newWard',
    'newWardShort',
    'newWardType',
    'newProvinceCode',
    'newProvinceLat',
    'newProvinceLon',
    'newWardCode',
    'newWardLat',
    'newWardLon',
    'newWardAreaKm2',
    'provinceLat',
    'provinceLon',
    'provinceBounds',
    'provinceGeoAddress',
    'districtAddress',
    'districtLat',
    'districtLon',
    'districtBounds',
    'districtGeoAddress',
    'wardAddress',
    'wardLat',
    'wardLon',
    'wardBounds',
    'wardGeoAddress',
    'isNewWardPolygonContainsWard',
    'isNearestNewWard',
    'isDefaultNewWard',
    'newProvinceShort',

]
df = df[cols]

# %%
df
# Out:
#        provinceCode  isMergedProvince  districtCode districtType  \
# 0                 1             False             1         Quận
# 1                 1             False             1         Quận
# 2                 1             False             1         Quận
# 3                 1             False             1         Quận
# 4                 1             False             1         Quận
# ...             ...               ...           ...          ...
# 10597            96              True           973        Huyện
# 10598            96              True           973        Huyện
# 10599            96              True           973        Huyện
# 10600            96              True           973        Huyện
# 10601            96              True           973        Huyện
#
#        districtShortDuplicated  wardCode  wardType  wardShortDuplicated  \
# 0                        False       1.0    Phường                False
# 1                        False       4.0    Phường                False
# 2                        False       6.0    Phường                False
# 3                        False       7.0    Phường                False
# 4                        False       7.0    Phường                False
# ...                        ...       ...       ...                  ...
# 10597                    False   32242.0        Xã                False
# 10598                    False   32244.0  Thị trấn                False
# 10599                    False   32245.0        Xã                False
# 10600                    False   32245.0        Xã                False
# 10601                    False   32248.0        Xã                False
#
#        isMergedWard  isDividedWard  ...                   districtGeoAddress  \
# 0              True          False  ...              Ba Đình, Hanoi, Vietnam
# 1              True          False  ...              Ba Đình, Hanoi, Vietnam
# 2              True          False  ...              Ba Đình, Hanoi, Vietnam
# 3              True           True  ...              Ba Đình, Hanoi, Vietnam
# 4              True           True  ...              Ba Đình, Hanoi, Vietnam
# ...             ...            ...  ...                                  ...
# 10597          True           True  ...  Ngọc Hiển District, Ca Mau, Vietnam
# 10598          True          False  ...  Ngọc Hiển District, Ca Mau, Vietnam
# 10599          True           True  ...  Ngọc Hiển District, Ca Mau, Vietnam
# 10600          True           True  ...  Ngọc Hiển District, Ca Mau, Vietnam
# 10601          True          False  ...  Ngọc Hiển District, Ca Mau, Vietnam
#
#                                             wardAddress    wardLat  \
# 0        Phường Phúc Xá, Quận Ba Đình, Thành phố Hà Nội  21.046798
# 1      Phường Trúc Bạch, Quận Ba Đình, Thành phố Hà Nội  21.044395
# 2      Phường Vĩnh Phúc, Quận Ba Đình, Thành phố Hà Nội  21.041731
# 3        Phường Cống Vị, Quận Ba Đình, Thành phố Hà Nội  21.035280
# 4        Phường Cống Vị, Quận Ba Đình, Thành phố Hà Nội  21.035280
# ...                                                 ...        ...
# 10597          Xã Viên An, Huyện Ngọc Hiển, Tỉnh Cà Mau   8.663728
# 10598   Thị trấn Rạch Gốc, Huyện Ngọc Hiển, Tỉnh Cà Mau   8.656311
# 10599           Xã Tân Ân, Huyện Ngọc Hiển, Tỉnh Cà Mau   8.653504
# 10600           Xã Tân Ân, Huyện Ngọc Hiển, Tỉnh Cà Mau   8.653504
# 10601          Xã Đất Mũi, Huyện Ngọc Hiển, Tỉnh Cà Mau   8.600635
#
#           wardLon                                   wardBounds  \
# 0      105.848112  21.040199,105.842293 – 21.053464,105.855959
# 1      105.843174  21.039976,105.836277 – 21.050836,105.850246
# 2      105.809950  21.035736,105.805872 – 21.047587,105.815001
# 3      105.809216  21.031335,105.804777 – 21.037841,105.814554
# 4      105.809216  21.031335,105.804777 – 21.037841,105.814554
# ...           ...                                          ...
# 10597  104.833788    8.567442,104.772921 – 8.737998,104.915485
# 10598  105.020676    8.596467,104.967112 – 8.679712,105.061312
# 10599  105.090815    8.598292,105.007668 – 8.701729,105.142808
# 10600  105.090815    8.598292,105.007668 – 8.701729,105.142808
# 10601  104.755782    8.559124,104.707432 – 8.655954,104.852142
#
#                                       wardGeoAddress  \
# 0                   Phuc Xa, Ba Đình, Hanoi, Vietnam
# 1                 Truc Bach, Ba Đình, Hanoi, Vietnam
# 2                Vĩnh Phúc, Ba Đình, Hà Nội, Vietnam
# 3                  Cống Vị, Ba Đình, Hà Nội, Vietnam
# 4                  Cống Vị, Ba Đình, Hà Nội, Vietnam
# ...                                              ...
# 10597   Viên An, Ngọc Hiển District, Ca Mau, Vietnam
# 10598  Rạch Gốc, Ngọc Hiển District, Ca Mau, Vietnam
# 10599             Tân Ân, Ngọc Hiển, Cà Mau, Vietnam
# 10600             Tân Ân, Ngọc Hiển, Cà Mau, Vietnam
# 10601   Đất Mũi, Ngọc Hiển District, Ca Mau, Vietnam
#
#       isNewWardPolygonContainsWard isNearestNewWard isDefaultNewWard  \
# 0                              NaN              NaN              NaN
# 1                              NaN              NaN              NaN
# 2                              NaN              NaN              NaN
# 3                            False            False            False
# 4                             True             True             True
# ...                            ...              ...              ...
# 10597                         True             True             True
# 10598                          NaN              NaN              NaN
# 10599                        False            False            False
# 10600                        False             True             True
# 10601                          NaN              NaN              NaN
#
#       newProvinceShort
# 0               Hà Nội
# 1               Hà Nội
# 2               Hà Nội
# 3               Hà Nội
# 4               Hà Nội
# ...                ...
# 10597           Cà Mau
# 10598           Cà Mau
# 10599           Cà Mau
# 10600           Cà Mau
# 10601           Cà Mau
#
# [10602 rows x 45 columns]

# %%
df.to_csv(BASE_DIR / 'data/processed/convert_legacy_2025_with_location_and_default_ward.csv', index=False)
