# %%
import sqlite3
import pandas as pd
import json

from pathlib import Path

from vietnamadminunits.parser.utils import key_normalize

BASE_DIR = Path().resolve().parent.parent

# %%
df_province = pd.read_csv(BASE_DIR / 'data/raw/63_provinces_location_province_2025-07-24.csv')
df_ward = pd.read_csv(BASE_DIR / 'data/raw/63_provinces_location_ward_2025-07-24.csv')

# %%
df_province
# Out:
#             address   latitude   longitude  \
# 0      Tỉnh Bến Tre  10.108155  106.440587
# 1     Tỉnh An Giang  10.521584  105.125896
# 2    Tỉnh Hải Dương  20.908720  106.393478
# 3   Tỉnh Quảng Ninh  21.243250  107.195720
# 4   Tỉnh Bình Dương  11.142383  106.629130
# ..              ...        ...         ...
# 58    Tỉnh Nam Định  20.279180  106.205148
# 59    Tỉnh Bắc Ninh  21.121444  106.111050
# 60   Tỉnh Vĩnh Phúc  21.360881  105.547437
# 61     Tỉnh Phú Thọ  21.260668  105.125896
# 62   Tỉnh Thái Bình  20.538694  106.393478
#
#                                          bounds          geo_address
# 0    9.790439,106.028225 – 10.340423,106.791908     Ben Tre, Vietnam
# 1   10.183524,104.778069 – 10.962524,105.575616    An Giang, Vietnam
# 2   20.684379,106.124369 – 21.236993,106.611436   Hai Duong, Vietnam
# 3    20.687466,106.439154 – 21.663764,108.08694  Quảng Ninh, Vietnam
# 4   10.863808,106.326367 – 11.500854,106.966691  Binh Duong, Vietnam
# ..                                          ...                  ...
# 58    19.88846,105.92405 – 20.499194,106.591923    Nam Dinh, Vietnam
# 59    20.969118,105.90247 – 21.264298,106.31193    Bac Ninh, Vietnam
# 60  21.154104,105.322481 – 21.573842,105.792899   Vĩnh Phúc, Vietnam
# 61  20.917027,104.815401 – 21.719645,105.456822     Phú Thọ, Vietnam
# 62   20.244052,106.10967 – 20.728989,106.656427   Thai Binh, Vietnam
#
# [63 rows x 5 columns]
