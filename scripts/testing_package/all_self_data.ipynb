# %%
from vietnamadminunits.database import get_data
from vietnamadminunits.pandas import standardize_admin_unit_columns, convert_address_column
from vietnamadminunits import parse_address, ParseMode, convert_address, ConvertMode
import pandas as pd

# %% [markdown]
# ## Testing core functions

# %%
# Parse a new administrative unit address
address = '70 Nguyễn Sỹ Sách, Tan Son, tp.HCM'

admin_unit = parse_address(address)

print(admin_unit)
# Out:
# Admin Unit: 70 Nguyễn Sỹ Sách, Phường Tân Sơn, Thành phố Hồ Chí Minh
# Attribute       | Value
# ----------------------------------------
# province        | Thành phố Hồ Chí Minh
# ward            | Phường Tân Sơn
# street          | 70 Nguyễn Sỹ Sách
# short_province  | Hồ Chí Minh
# short_ward      | Tân Sơn
# ward_type       | Phường
# province_code   | 79
# ward_code       | 27007
# latitude        | 10.8224
# longitude       | 106.65

# %%
# Parse an old administrative unit address
address = '70 nguyễn sỹ sách, p.15, Tân Bình, Tp.HCM' # Old administrative unit address structure

admin_unit = parse_address(address, mode='LEGACY', level=3) # Use 'LEGACY' or ParseMode.LEGACY for mode

print(admin_unit)
# Out:
# Admin Unit: 70 Nguyễn Sỹ Sách, Phường 15, Quận Tân Bình, Thành phố Hồ Chí Minh
# Attribute       | Value
# ----------------------------------------
# province        | Thành phố Hồ Chí Minh
# district        | Quận Tân Bình
# ward            | Phường 15
# street          | 70 Nguyễn Sỹ Sách
# short_province  | Hồ Chí Minh
# short_district  | Tân Bình
# short_ward      | Phường 15
# district_type   | Quận
# ward_type       | Phường
# province_code   | 79
# district_code   | 766
# ward_code       | 27007
# latitude        | 10.823333
# longitude       | 106.63616

# %%
# Convert address
address = '70 nguyễn sỹ sách, p.15, Tân Bình, Tp.HCM' # Old administrative unit address structure

admin_unit = convert_address(address)

print(admin_unit)
# Out:
# Admin Unit: 70 Nguyễn Sỹ Sách, Phường Tân Sơn, Thành phố Hồ Chí Minh
# Attribute       | Value
# ----------------------------------------
# province        | Thành phố Hồ Chí Minh
# ward            | Phường Tân Sơn
# street          | 70 Nguyễn Sỹ Sách
# short_province  | Hồ Chí Minh
# short_ward      | Tân Sơn
# ward_type       | Phường
# province_code   | 79
# ward_code       | 27007
# latitude        | 10.8224
# longitude       | 106.65

# %%
# Get data
print(get_data(limit=2))
print('-'*50)
print(get_data(table='admin_units_legacy', limit=2))
# Out:
# [{'province': 'Thành phố Hà Nội', 'ward': 'Phường Hồng Hà', 'provinceShort': 'Hà Nội', 'wardShort': 'Hồng Hà', 'wardType': 'Phường', 'provinceCode': '01', 'provinceLat': 21.0001, 'provinceLon': 105.698, 'wardCode': '00097', 'wardLat': 21.0567, 'wardLon': 105.845, 'wardAreaKm2': 15.09, 'provinceKey': 'thanhphohanoi', 'provinceShortKey': 'hanoi', 'wardKey': 'phuonghongha', 'wardShortKey': 'hongha', 'provinceAlias': None, 'wardAlias': None, 'wardKeyDuplicated': 0, 'wardShortKeyDuplicated': 0, 'provinceKeywords': '["thanhphohanoi", "hanoi"]', 'wardKeywords': '["phuonghongha", "hongha"]', 'wardUnique': 1}, {'province': 'Thành phố Hà Nội', 'ward': 'Phường Ba Đình', 'provinceShort': 'Hà Nội', 'wardShort': 'Ba Đình', 'wardType': 'Phường', 'provinceCode': '01', 'provinceLat': 21.0001, 'provinceLon': 105.698, 'wardCode': '00004', 'wardLat': 21.0386, 'wardLon': 105.838, 'wardAreaKm2': 2.97, 'provinceKey': 'thanhphohanoi', 'provinceShortKey': 'hanoi', 'wardKey': 'phuongbadinh', 'wardShortKey': 'badinh', 'provinceAlias': None, 'wardAlias': None, 'wardKeyDuplicated': 0, 'wardShortKeyDuplicated': 0, 'provinceKeywords': '["thanhphohanoi", "hanoi"]', 'wardKeywords': '["phuongbadinh", "badinh"]', 'wardUnique': 0}]
# --------------------------------------------------
# [{'province': 'Thành phố Hà Nội', 'district': 'Quận Ba Đình', 'ward': 'Phường Phúc Xá', 'provinceShort': 'Hà Nội', 'districtShort': 'Ba Đình', 'wardShort': 'Phúc Xá', 'districtType': 'Quận', 'wardType': 'Phường', 'provinceCode': '01', 'provinceLat': 21.027764, 'provinceLon': 105.83416, 'provinceBounds': '20.995099,105.797482 – 21.05038,105.876446', 'provinceGeoAddress': 'Hanoi, Vietnam', 'districtCode': '001', 'districtLat': 21.035852, 'districtLon': 105.826094, 'districtBounds': '21.016004,105.801279 – 21.053565,105.857015', 'districtGeoAddress': 'Ba Đình, Hanoi, Vietnam', 'wardCode': '00001', 'wardLat': 21.046798, 'wardLon': 105.848112, 'wardBounds': '21.040199,105.842293 – 21.053464,105.855959', 'wardGeoAddress': 'Phuc Xa, Ba Đình, Hanoi, Vietnam', 'districtShortDuplicated': 0, 'wardShortDuplicated': 0, 'provinceKey': 'thanhphohanoi', 'provinceShortKey': 'hanoi', 'districtKey': 'quanbadinh', 'districtShortKey': 'badinh', 'wardKey': 'phuongphucxa', 'wardShortKey': 'phucxa', 'provinceAlias': '["hn"]', 'districtAlias': None, 'wardAlias': None, 'districtShortKeyDuplicated': 0, 'wardKeyDuplicated': 0, 'wardShortKeyDuplicated': 0, 'provinceKeywords': '["thanhphohanoi", "hanoi", "hn"]', 'districtKeywords': '["quanbadinh", "badinh"]', 'wardKeywords': '["phuongphucxa", "phuongphucsa", "phucxa", "phucsa"]'}, {'province': 'Thành phố Hà Nội', 'district': 'Quận Ba Đình', 'ward': 'Phường Trúc Bạch', 'provinceShort': 'Hà Nội', 'districtShort': 'Ba Đình', 'wardShort': 'Trúc Bạch', 'districtType': 'Quận', 'wardType': 'Phường', 'provinceCode': '01', 'provinceLat': 21.027764, 'provinceLon': 105.83416, 'provinceBounds': '20.995099,105.797482 – 21.05038,105.876446', 'provinceGeoAddress': 'Hanoi, Vietnam', 'districtCode': '001', 'districtLat': 21.035852, 'districtLon': 105.826094, 'districtBounds': '21.016004,105.801279 – 21.053565,105.857015', 'districtGeoAddress': 'Ba Đình, Hanoi, Vietnam', 'wardCode': '00004', 'wardLat': 21.044395, 'wardLon': 105.843174, 'wardBounds': '21.039976,105.836277 – 21.050836,105.850246', 'wardGeoAddress': 'Truc Bach, Ba Đình, Hanoi, Vietnam', 'districtShortDuplicated': 0, 'wardShortDuplicated': 0, 'provinceKey': 'thanhphohanoi', 'provinceShortKey': 'hanoi', 'districtKey': 'quanbadinh', 'districtShortKey': 'badinh', 'wardKey': 'phuongtrucbach', 'wardShortKey': 'trucbach', 'provinceAlias': '["hn"]', 'districtAlias': None, 'wardAlias': '["phuongnguyentrungtruc", "nguyentrungtruc"]', 'districtShortKeyDuplicated': 0, 'wardKeyDuplicated': 0, 'wardShortKeyDuplicated': 0, 'provinceKeywords': '["thanhphohanoi", "hanoi", "hn"]', 'districtKeywords': '["quanbadinh", "badinh"]', 'wardKeywords': '["phuongnguyentrungtruc", "nguyentrungtruc", "phuongtrucbach", "trucbach"]'}]

# %% [markdown]
# ## Testing multiple functions with DataFrame

# %%
# Standardize new administrative unit columns
df = pd.DataFrame(get_data(fields=['province', 'ward']))
df = standardize_admin_unit_columns(df, province='province', ward='ward', short_name=False)
df
# Out:
# Standardizing unique administrative units: 100%|██████████| 3321/3321 [00:00<00:00, 14389.65it/s]
#               province                 ward standardized_province  \
# 0     Thành phố Hà Nội       Phường Hồng Hà      Thành phố Hà Nội
# 1     Thành phố Hà Nội       Phường Ba Đình      Thành phố Hà Nội
# 2     Thành phố Hà Nội       Phường Ngọc Hà      Thành phố Hà Nội
# 3     Thành phố Hà Nội      Phường Giảng Võ      Thành phố Hà Nội
# 4     Thành phố Hà Nội     Phường Hoàn Kiếm      Thành phố Hà Nội
# ...                ...                  ...                   ...
# 3316       Tỉnh Cà Mau           Xã Phú Tân           Tỉnh Cà Mau
# 3317       Tỉnh Cà Mau  Xã Nguyễn Việt Khái           Tỉnh Cà Mau
# 3318       Tỉnh Cà Mau            Xã Tân Ân           Tỉnh Cà Mau
# 3319       Tỉnh Cà Mau    Xã Phan Ngọc Hiển           Tỉnh Cà Mau
# 3320       Tỉnh Cà Mau           Xã Đất Mũi           Tỉnh Cà Mau
#
#         standardized_ward
# 0          Phường Hồng Hà
# 1          Phường Ba Đình
# 2          Phường Ngọc Hà
# 3         Phường Giảng Võ
# 4        Phường Hoàn Kiếm
# ...                   ...
# 3316           Xã Phú Tân
# 3317  Xã Nguyễn Việt Khái
# 3318            Xã Tân Ân
# 3319    Xã Phan Ngọc Hiển
# 3320           Xã Đất Mũi
#
# [3321 rows x 4 columns]

# %%
df.describe()
# Out:
#                      province          ward  standardized_province  \
# count                    3321          3321                   3321
# unique                     34          2991                     34
# top     Thành phố Hồ Chí Minh  Xã Tân Thành  Thành phố Hồ Chí Minh
# freq                      168             7                    168
#
#        standardized_ward
# count               3321
# unique              2991
# top         Xã Tân Thành
# freq                   7

# %%
# Standardize new administrative unit columns
df = pd.DataFrame(get_data(fields=['provinceShort', 'wardShort']))
df = standardize_admin_unit_columns(df, province='provinceShort', ward='wardShort', short_name=True)
df
# Out:
# Standardizing unique administrative units: 100%|██████████| 3321/3321 [00:00<00:00, 20639.37it/s]
#      provinceShort         wardShort standardized_provinceShort  \
# 0           Hà Nội           Hồng Hà                     Hà Nội
# 1           Hà Nội           Ba Đình                     Hà Nội
# 2           Hà Nội           Ngọc Hà                     Hà Nội
# 3           Hà Nội          Giảng Võ                     Hà Nội
# 4           Hà Nội         Hoàn Kiếm                     Hà Nội
# ...            ...               ...                        ...
# 3316        Cà Mau           Phú Tân                     Cà Mau
# 3317        Cà Mau  Nguyễn Việt Khái                     Cà Mau
# 3318        Cà Mau            Tân Ân                     Cà Mau
# 3319        Cà Mau    Phan Ngọc Hiển                     Cà Mau
# 3320        Cà Mau           Đất Mũi                     Cà Mau
#
#      standardized_wardShort
# 0                   Hồng Hà
# 1                   Ba Đình
# 2                   Ngọc Hà
# 3                  Giảng Võ
# 4                 Hoàn Kiếm
# ...                     ...
# 3316                Phú Tân
# 3317       Nguyễn Việt Khái
# 3318                 Tân Ân
# 3319         Phan Ngọc Hiển
# 3320                Đất Mũi
#
# [3321 rows x 4 columns]

# %%
df.describe()
# Out:
#        provinceShort wardShort standardized_provinceShort  \
# count           3321      3321                       3321
# unique            34      2848                         34
# top      Hồ Chí Minh    Tân An                Hồ Chí Minh
# freq             168        10                        168
#
#        standardized_wardShort
# count                    3321
# unique                   2848
# top                    Tân An
# freq                       10

# %%
# Standardize old administrative unit columns
df = pd.DataFrame(get_data(fields=['province', 'district', 'ward'], table='admin_units_legacy'))
df = standardize_admin_unit_columns(df, province='province', district='district', ward='ward', parse_mode='LEGACY', short_name=False)
df
# Out:
# Standardizing unique administrative units: 100%|██████████| 10040/10040 [00:00<00:00, 14040.74it/s]
#                province         district               ward  \
# 0      Thành phố Hà Nội     Quận Ba Đình     Phường Phúc Xá
# 1      Thành phố Hà Nội     Quận Ba Đình   Phường Trúc Bạch
# 2      Thành phố Hà Nội     Quận Ba Đình   Phường Vĩnh Phúc
# 3      Thành phố Hà Nội     Quận Ba Đình     Phường Cống Vị
# 4      Thành phố Hà Nội     Quận Ba Đình   Phường Liễu Giai
# ...                 ...              ...                ...
# 10035       Tỉnh Cà Mau  Huyện Ngọc Hiển    Xã Viên An Đông
# 10036       Tỉnh Cà Mau  Huyện Ngọc Hiển         Xã Viên An
# 10037       Tỉnh Cà Mau  Huyện Ngọc Hiển  Thị trấn Rạch Gốc
# 10038       Tỉnh Cà Mau  Huyện Ngọc Hiển          Xã Tân Ân
# 10039       Tỉnh Cà Mau  Huyện Ngọc Hiển         Xã Đất Mũi
#
#       standardized_province standardized_district  standardized_ward
# 0          Thành phố Hà Nội          Quận Ba Đình     Phường Phúc Xá
# 1          Thành phố Hà Nội          Quận Ba Đình   Phường Trúc Bạch
# 2          Thành phố Hà Nội          Quận Ba Đình   Phường Vĩnh Phúc
# 3          Thành phố Hà Nội          Quận Ba Đình     Phường Cống Vị
# 4          Thành phố Hà Nội          Quận Ba Đình   Phường Liễu Giai
# ...                     ...                   ...                ...
# 10035           Tỉnh Cà Mau       Huyện Ngọc Hiển    Xã Viên An Đông
# 10036           Tỉnh Cà Mau       Huyện Ngọc Hiển         Xã Viên An
# 10037           Tỉnh Cà Mau       Huyện Ngọc Hiển  Thị trấn Rạch Gốc
# 10038           Tỉnh Cà Mau       Huyện Ngọc Hiển          Xã Tân Ân
# 10039           Tỉnh Cà Mau       Huyện Ngọc Hiển         Xã Đất Mũi
#
# [10040 rows x 6 columns]

# %%
df.describe()
# Out:
#               province          district      ward standardized_province  \
# count            10040             10040     10035                 10040
# unique              63               681      7572                    63
# top     Tỉnh Thanh Hóa  Huyện Châu Thành  Phường 1        Tỉnh Thanh Hóa
# freq               547               129        33                   547
#
#        standardized_district standardized_ward
# count                  10040             10035
# unique                   681              7572
# top         Huyện Châu Thành          Phường 1
# freq                     129                33

# %%
# Standardize old administrative unit columns
df = pd.DataFrame(get_data(fields=['provinceShort', 'districtShort', 'wardShort'], table='admin_units_legacy'))
df = standardize_admin_unit_columns(df, province='provinceShort', district='districtShort', ward='wardShort', parse_mode='LEGACY', short_name=True)
df
# Out:
# Standardizing unique administrative units: 100%|██████████| 10040/10040 [00:00<00:00, 16001.28it/s]
#       provinceShort districtShort     wardShort standardized_provinceShort  \
# 0            Hà Nội       Ba Đình       Phúc Xá                     Hà Nội
# 1            Hà Nội       Ba Đình     Trúc Bạch                     Hà Nội
# 2            Hà Nội       Ba Đình     Vĩnh Phúc                     Hà Nội
# 3            Hà Nội       Ba Đình       Cống Vị                     Hà Nội
# 4            Hà Nội       Ba Đình     Liễu Giai                     Hà Nội
# ...             ...           ...           ...                        ...
# 10035        Cà Mau     Ngọc Hiển  Viên An Đông                     Cà Mau
# 10036        Cà Mau     Ngọc Hiển       Viên An                     Cà Mau
# 10037        Cà Mau     Ngọc Hiển      Rạch Gốc                     Cà Mau
# 10038        Cà Mau     Ngọc Hiển        Tân Ân                     Cà Mau
# 10039        Cà Mau     Ngọc Hiển       Đất Mũi                     Cà Mau
#
#       standardized_districtShort standardized_wardShort
# 0                        Ba Đình                Phúc Xá
# 1                        Ba Đình              Trúc Bạch
# 2                        Ba Đình              Vĩnh Phúc
# 3                        Ba Đình                Cống Vị
# 4                        Ba Đình              Liễu Giai
# ...                          ...                    ...
# 10035                  Ngọc Hiển           Viên An Đông
# 10036                  Ngọc Hiển                Viên An
# 10037                  Ngọc Hiển               Rạch Gốc
# 10038                  Ngọc Hiển                 Tân Ân
# 10039                  Ngọc Hiển                Đất Mũi
#
# [10040 rows x 6 columns]

# %%
df.describe()
# Out:
#        provinceShort districtShort wardShort standardized_provinceShort  \
# count          10040         10040     10035                      10040
# unique            63           672      6972                         63
# top        Thanh Hóa    Châu Thành  Phường 1                  Thanh Hóa
# freq             547           129        33                        547
#
#        standardized_districtShort standardized_wardShort
# count                       10040                  10035
# unique                        672                   6972
# top                    Châu Thành               Phường 1
# freq                          129                     33

# %%
# Convert old administrative unit columns to new administrative unit columns
df = pd.DataFrame(get_data(fields=['province', 'district', 'ward'], table='admin_units_legacy'))
df = standardize_admin_unit_columns(df, province='province', district='district', ward='ward', convert_mode='CONVERT_2025', short_name=False)
df
# Out:
# Standardizing unique administrative units: 100%|██████████| 10040/10040 [00:01<00:00, 7471.31it/s]
#                province         district               ward  \
# 0      Thành phố Hà Nội     Quận Ba Đình     Phường Phúc Xá
# 1      Thành phố Hà Nội     Quận Ba Đình   Phường Trúc Bạch
# 2      Thành phố Hà Nội     Quận Ba Đình   Phường Vĩnh Phúc
# 3      Thành phố Hà Nội     Quận Ba Đình     Phường Cống Vị
# 4      Thành phố Hà Nội     Quận Ba Đình   Phường Liễu Giai
# ...                 ...              ...                ...
# 10035       Tỉnh Cà Mau  Huyện Ngọc Hiển    Xã Viên An Đông
# 10036       Tỉnh Cà Mau  Huyện Ngọc Hiển         Xã Viên An
# 10037       Tỉnh Cà Mau  Huyện Ngọc Hiển  Thị trấn Rạch Gốc
# 10038       Tỉnh Cà Mau  Huyện Ngọc Hiển          Xã Tân Ân
# 10039       Tỉnh Cà Mau  Huyện Ngọc Hiển         Xã Đất Mũi
#
#       standardized_province  standardized_ward
# 0          Thành phố Hà Nội     Phường Hồng Hà
# 1          Thành phố Hà Nội     Phường Ba Đình
# 2          Thành phố Hà Nội     Phường Ngọc Hà
# 3          Thành phố Hà Nội     Phường Ngọc Hà
# 4          Thành phố Hà Nội     Phường Ngọc Hà
# ...                     ...                ...
# 10035           Tỉnh Cà Mau  Xã Phan Ngọc Hiển
# 10036           Tỉnh Cà Mau         Xã Đất Mũi
# 10037           Tỉnh Cà Mau  Xã Phan Ngọc Hiển
# 10038           Tỉnh Cà Mau  Xã Phan Ngọc Hiển
# 10039           Tỉnh Cà Mau         Xã Đất Mũi
#
# [10040 rows x 5 columns]

# %%
df[df['standardized_ward'].isna()]
# Out:
# Empty DataFrame
# Columns: [province, district, ward, standardized_province, standardized_ward]
# Index: []

# %%
df.describe()
# Out:
#               province          district      ward standardized_province  \
# count            10040             10040     10035                 10040
# unique              63               681      7572                    34
# top     Tỉnh Thanh Hóa  Huyện Châu Thành  Phường 1        Tỉnh Thanh Hóa
# freq               547               129        33                   547
#
#        standardized_ward
# count              10040
# unique              2990
# top          Xã Tân Tiến
# freq                  20

# %%
data = {
    'address': [
        'Ngã 4 xóm ao dài, thôn Tự Khoát, Xã Ngũ Hiệp, Huyện Thanh Trì, Hà Nội',
        '50 ngõ 133 thái hà, hà nội, Phường Trung Liệt, Quận Đống Đa, Hà Nội',
        'P402 CT9A KĐT VIỆT HƯNG, Phường Đức Giang, Quận Long Biên, Hà Nội',
        '169/8A, Thoại Ngọc Hầu, Phường Phú Thạnh, Quận Tân Phú, TP. Hồ Chí Minh',
        '02 lê đại hành, phường 15, quận 11, tp.hcm, Phường 15, Quận 11, TP. Hồ Chí Minh'
    ]
}

df = pd.DataFrame(data)

converted_df = convert_address_column(df, address='address', short_name=False)
print(converted_df.to_markdown(index=False))
# Out:
# Converting unique addresses: 100%|██████████| 5/5 [00:00<00:00,  5.60it/s]
# | address                                                                         | converted_address                                           |
# |:--------------------------------------------------------------------------------|:------------------------------------------------------------|
# | Ngã 4 xóm ao dài, thôn Tự Khoát, Xã Ngũ Hiệp, Huyện Thanh Trì, Hà Nội           | Ngã 4 Xóm Ao Dài, Xã Thanh Trì, Thành phố Hà Nội            |
# | 50 ngõ 133 thái hà, hà nội, Phường Trung Liệt, Quận Đống Đa, Hà Nội             | 50 Ngõ 133 Thái Hà, Phường Đống Đa, Thành phố Hà Nội        |
# | P402 CT9A KĐT VIỆT HƯNG, Phường Đức Giang, Quận Long Biên, Hà Nội               | P402 Ct9A Kđt Việt Hưng, Phường Việt Hưng, Thành phố Hà Nội |
# | 169/8A, Thoại Ngọc Hầu, Phường Phú Thạnh, Quận Tân Phú, TP. Hồ Chí Minh         | 169/8A, Phường Phú Thạnh, Thành phố Hồ Chí Minh             |
# | 02 lê đại hành, phường 15, quận 11, tp.hcm, Phường 15, Quận 11, TP. Hồ Chí Minh | 02 Lê Đại Hành, Phường Phú Thọ, Thành phố Hồ Chí Minh       |

# %%
data = [
    {'province': 'Thành phố Hồ Chí Minh', 'district': 'Quận 1', 'ward': 'Phường Tân Định'},
    {'province': 'Thành phố Hồ Chí Minh', 'district': 'Quận 1', 'ward': 'Phường Đa Kao'},
    {'province': 'Thành phố Hồ Chí Minh', 'district': 'Quận 1', 'ward': 'Phường Bến Nghé'},
    {'province': 'Thành phố Hồ Chí Minh', 'district': 'Quận 1', 'ward': 'Phường Bến Thành'},
    {'province': 'Thành phố Hồ Chí Minh', 'district': 'Quận 1', 'ward': 'Phường Nguyễn Thái Bình'}
]

df = pd.DataFrame(data)

standardized_df = standardize_admin_unit_columns(df, province='province', district='district', ward='ward', convert_mode='CONVERT_2025')

print(standardized_df.to_markdown(index=False))
# Out:
# Standardizing unique administrative units: 100%|██████████| 5/5 [00:00<00:00, 3750.94it/s]
# | province              | district   | ward                    | standardized_province   | standardized_ward   |
# |:----------------------|:-----------|:------------------------|:------------------------|:--------------------|
# | Thành phố Hồ Chí Minh | Quận 1     | Phường Tân Định         | Hồ Chí Minh             | Tân Định            |
# | Thành phố Hồ Chí Minh | Quận 1     | Phường Đa Kao           | Hồ Chí Minh             | Sài Gòn             |
# | Thành phố Hồ Chí Minh | Quận 1     | Phường Bến Nghé         | Hồ Chí Minh             | Sài Gòn             |
# | Thành phố Hồ Chí Minh | Quận 1     | Phường Bến Thành        | Hồ Chí Minh             | Bến Thành           |
# | Thành phố Hồ Chí Minh | Quận 1     | Phường Nguyễn Thái Bình | Hồ Chí Minh             | Bến Thành           |
