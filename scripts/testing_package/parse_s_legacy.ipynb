# %%
from vietnamadminunits.pandas import standardize_admin_unit_columns
from vietnamadminunits.database import get_data
from vietnamadminunits import parse_address
import pandas as pd

# %%
df = pd.read_csv('data/input/s_legacy_2020-2025.csv')
sd_df = standardize_admin_unit_columns(df, province='province', district='district', ward='ward', parse_mode='LEGACY', short_name=False)
sd_df = sd_df[sd_df['standardized_ward'].isna()].sort_values(by=['province', 'district', 'ward'])
print(sd_df.shape)
if sd_df.shape[0]:
    sd_df.to_excel('data/output/s_legacy_2020-2025_missing.xlsx', index=False)

df = pd.DataFrame(get_data(table='admin_units_legacy'))
# Out:
# Standardizing unique administrative units: 100%|██████████| 10688/10688 [00:02<00:00, 4479.25it/s]
# (0, 7)

# %%
df[(df['provinceKey'].str.contains('yenbai')) & (df['districtKey'].str.contains('yenbai'))][['province', 'district', 'districtShort', 'provinceKey', 'districtKey', 'ward', 'wardKey', 'wardKeywords']].drop_duplicates()
# Out:
#           province           district districtShort provinceKey  \
# 1711  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1712  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1713  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1714  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1715  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1716  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1717  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1718  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1719  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1720  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1721  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1722  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1723  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
# 1724  Tỉnh Yên Bái  Thành phố Yên Bái       Yên Bái  tinhyenbai
#
#          districtKey                    ward              wardKey  \
# 1711  thanhphoyenbai        Phường Yên Thịnh       phuongyenthinh
# 1712  thanhphoyenbai         Phường Yên Ninh        phuongyenninh
# 1713  thanhphoyenbai         Phường Minh Tân        phuongminhtan
# 1714  thanhphoyenbai  Phường Nguyễn Thái Học  phuongnguyenthaihoc
# 1715  thanhphoyenbai         Phường Đồng Tâm        phuongdongtam
# 1716  thanhphoyenbai          Phường Hồng Hà         phuonghongha
# 1717  thanhphoyenbai             Xã Minh Bảo            xaminhbao
# 1718  thanhphoyenbai        Phường Nam Cường       phuongnamcuong
# 1719  thanhphoyenbai              Xã Tuy Lộc             xatuyloc
# 1720  thanhphoyenbai            Xã Tân Thịnh           xatanthinh
# 1721  thanhphoyenbai               Xã Âu Lâu              xaaulau
# 1722  thanhphoyenbai           Xã Giới Phiên          xagioiphien
# 1723  thanhphoyenbai         Phường Hợp Minh        phuonghopminh
# 1724  thanhphoyenbai              Xã Văn Phú             xavanphu
#
#                                            wardKeywords
# 1711                     ["phuongyenthinh", "yenthinh"]
# 1712                       ["phuongyenninh", "yenninh"]
# 1713                       ["phuongminhtan", "minhtan"]
# 1714           ["phuongnguyenthaihoc", "nguyenthaihoc"]
# 1715                       ["phuongdongtam", "dongtam"]
# 1716  ["phuongnguyenphuc", "phuonghongha", "nguyenph...
# 1717                           ["xaminhbao", "minhbao"]
# 1718                     ["phuongnamcuong", "namcuong"]
# 1719                             ["xatuyloc", "tuyloc"]
# 1720                         ["xatanthinh", "tanthinh"]
# 1721                               ["xaaulau", "aulau"]
# 1722                       ["xagioiphien", "gioiphien"]
# 1723                       ["phuonghopminh", "hopminh"]
# 1724                             ["xavanphu", "vanphu"]

# %%
df[(df['provinceKey'].str.contains('bacgiang')) & (df['wardKey'].str.contains('thanhhai'))][['province', 'district', 'districtShort', 'provinceKey', 'districtKey', 'ward', 'wardKey', 'wardKeywords']].drop_duplicates()
# Out:
#             province    district districtShort   provinceKey districtKey  \
# 2750  Tỉnh Bắc Giang  Thị xã Chũ           Chũ  tinhbacgiang    thixachu
#
#                   ward         wardKey  \
# 2750  Phường Thanh Hải  phuongthanhhai
#
#                                       wardKeywords
# 2750  ["phuongthanhhai", "xathanhhai", "thanhhai"]
